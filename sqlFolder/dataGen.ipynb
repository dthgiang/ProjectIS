# %%
import random as rd

insert = "insert into table "

# %%
Ho = [ 'Ho','Bui', 'Đoan', 'Le', 'Nguyen', 'Duong', 'Tran', 'Ly', 'Vu', 'Vo', 'Đang', 'Pham', 'Ung', 'An', 'Au','Truong', 'Lai', 'Gian' ]
tendem = ['Van','Thi','Chi','Gia','Hoang', 'Song', 'Tung' ]
ten = ['Ngoc Nhi','An','Anh','Bac','Bao','Cau','Cuc','Đan','Đang','Đuc','Thong','Tien','Tuan','Tin','Tiep','Viet','Vinh','Vu','Vy','Minh','Giang','khanh','Sang','Duy','Chi','Thuong','Chung','Phu','Quoc','Nam','Ngan','Nguyet','May' 
       ,'Tu','Thien','Tan','Han']

# %%
'''
NhanVien (
	MaNV 		varchar(10) primary key,
	TenNV 	varchar2(60) not null,
	Phai 		varchar2(4),
	NgaySinh 	date,
	DiaChi 	varchar2(100),
	SoDT 		varchar(10) not null unique,
	Luong 	number,
	PhuCap 	number,
	VaiTro 	varchar2(50),
	MaNQL 	varchar(10),
	PHG 		number
	
)
go
'''
'''
Nhân viên - 300
Quản lí - 20
Trưởng phòng - 8
Tài chính - 5
Nhân sự - 5
Trưởng đề án - 3
Ban giám đốc - 5
'''
sex = ['Nam', 'Nu']
import string

username = ''
MaNV = ''
TenNV = ''
Phai = ''
NgaySinh = ''
DiaChi 	= ''
SoDT 	= ''
Luong 	= 0
PhuCap 	= 0
VaiTro 	= ''
MaNQL 	= 'NULL'
PHG 	= 0
for i in range(1, 347):
    Luong = rd.randint(1000, 9999)
    PhuCap = rd.randint(1000, 2000)
    PHG = i % 8 + 1
    if i < 6:
        MaNV = '\'GD00'+ str(i) + '\''
        VaiTro 	= '\'Ban giam doc\''
        Luong = 55555
    elif i < 11:
        MaNV = '\'TC0'+ str(i) + '\''
        VaiTro 	= '\'Tai chinh\''
        Luong = 11000
    elif i < 16:
        MaNV = '\'NS0'+ str(i) + '\''
        VaiTro 	= '\'Nhan su\''
        Luong = 13000
    elif i < 36:
        MaNV = '\'QL0'+ str(i) + '\''
        VaiTro 	= '\'Quan li\''
        Luong = 25000
    elif i < 39:
        MaNV = '\'TDA0'+ str(i) + '\''
        VaiTro 	= '\'Truong de an\''
        Luong = 20000
    elif i < 47:
        MaNV = '\'TP0'+ str(i) + '\''
        VaiTro 	= '\'Truong phong\''
        Luong = 22000
        PHG = i - 38
    else:
        MaNV = '\'NV'+ str(i) + '\''
        VaiTro 	= '\'Nhan vien\''
        MaNQL = '\'QL0' + str((i - 47) % 20 + 16) + '\''
     
    
    account_suffix = MaNV.replace("'", "")
    username = f'\'123\''

    SoDT = '\'0945000' + str(i) + '\''
    TenNV = '\'' + rd.choice(Ho) + ' ' + rd.choice(tendem) + ' ' + rd.choice(ten) + '\''
    DiaChi = '\'227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh\'' 
    Phai = '\'' + rd.choice(sex) + '\''
    NgaySinh  = 'TO_DATE(' + '\'' + str(rd.randint(2000, 2022)) + '-' + str(rd.randint(1, 12)) + '-' + str(rd.randint(1, 28)) + '\',\'YYYY-MM-DD\')'
    
    final = MaNV + ', ' + TenNV + ', ' + Phai + ', ' + NgaySinh + ', ' + DiaChi +', ' + SoDT + ', ' + str(Luong) + ', ' + str(PhuCap) +', '+ VaiTro + ', ' + MaNQL + ', ' + str(PHG) + ', ' + username
    
    print (' into GOD.NHANVIEN values(' +  final + ')')
    
   # print('insert into TaiKhoan values(' + TenTaiKhoan + HoTen + str(Mk) + sdt + DiaChi + Email + LoaiTaiKhoan +')')
# Out:
#  into GOD.NHANVIEN values('GD001', 'Đang Gia Viet', 'Nam', TO_DATE('2009-8-6','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '09450001', 55555, 1191, 'Ban giam doc', NULL, 2, '123')
#  into GOD.NHANVIEN values('GD002', 'An Tung Bao', 'Nu', TO_DATE('2001-5-2','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '09450002', 55555, 1549, 'Ban giam doc', NULL, 3, '123')
#  into GOD.NHANVIEN values('GD003', 'Ly Van Chung', 'Nam', TO_DATE('2014-5-6','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '09450003', 55555, 1598, 'Ban giam doc', NULL, 4, '123')
#  into GOD.NHANVIEN values('GD004', 'Lai Van Vinh', 'Nu', TO_DATE('2003-4-12','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '09450004', 55555, 1899, 'Ban giam doc', NULL, 5, '123')
#  into GOD.NHANVIEN values('GD005', 'Vu Thi Viet', 'Nu', TO_DATE('2003-8-12','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '09450005', 55555, 1020, 'Ban giam doc', NULL, 6, '123')
#  into GOD.NHANVIEN values('TC06', 'Pham Gia Cau', 'Nu', TO_DATE('2001-1-3','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '09450006', 11000, 1973, 'Tai chinh', NULL, 7, '123')
#  into GOD.NHANVIEN values('TC07', 'Duong Van Duy', 'Nu', TO_DATE('2014-2-7','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '09450007', 11000, 1906, 'Tai chinh', NULL, 8, '123')
#  into GOD.NHANVIEN values('TC08', 'Pham Gia Thien', 'Nam', TO_DATE('2020-9-12','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '09450008', 11000, 1716, 'Tai chinh', NULL, 1, '123')
#  into GOD.NHANVIEN values('TC09', 'Đoan Thi Đang', 'Nu', TO_DATE('2011-6-11','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '09450009', 11000, 1779, 'Tai chinh', NULL, 2, '123')
#  into GOD.NHANVIEN values('TC010', 'Vo Tung Bac', 'Nam', TO_DATE('2012-5-17','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500010', 11000, 1476, 'Tai chinh', NULL, 3, '123')
#  into GOD.NHANVIEN values('NS011', 'Nguyen Gia Minh', 'Nam', TO_DATE('2018-9-6','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500011', 13000, 1310, 'Nhan su', NULL, 4, '123')
#  into GOD.NHANVIEN values('NS012', 'Ung Thi khanh', 'Nam', TO_DATE('2014-7-7','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500012', 13000, 1590, 'Nhan su', NULL, 5, '123')
#  into GOD.NHANVIEN values('NS013', 'Nguyen Tung Bao', 'Nu', TO_DATE('2021-5-6','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500013', 13000, 1767, 'Nhan su', NULL, 6, '123')
#  into GOD.NHANVIEN values('NS014', 'Truong Chi Quoc', 'Nu', TO_DATE('2013-2-1','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500014', 13000, 1883, 'Nhan su', NULL, 7, '123')
#  into GOD.NHANVIEN values('NS015', 'Đoan Thi Ngan', 'Nam', TO_DATE('2005-12-10','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500015', 13000, 1823, 'Nhan su', NULL, 8, '123')
#  into GOD.NHANVIEN values('QL016', 'Ho Tung May', 'Nu', TO_DATE('2010-12-12','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500016', 25000, 1441, 'Quan li', NULL, 1, '123')
#  into GOD.NHANVIEN values('QL017', 'An Chi Chi', 'Nu', TO_DATE('2014-1-21','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500017', 25000, 1176, 'Quan li', NULL, 2, '123')
#  into GOD.NHANVIEN values('QL018', 'Duong Gia Phu', 'Nu', TO_DATE('2017-8-23','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500018', 25000, 1349, 'Quan li', NULL, 3, '123')
#  into GOD.NHANVIEN values('QL019', 'Truong Chi Minh', 'Nu', TO_DATE('2017-11-24','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500019', 25000, 1294, 'Quan li', NULL, 4, '123')
#  into GOD.NHANVIEN values('QL020', 'Truong Van Tien', 'Nam', TO_DATE('2017-12-22','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500020', 25000, 1163, 'Quan li', NULL, 5, '123')
#  into GOD.NHANVIEN values('QL021', 'Lai Song Tuan', 'Nu', TO_DATE('2005-12-11','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500021', 25000, 1343, 'Quan li', NULL, 6, '123')
#  into GOD.NHANVIEN values('QL022', 'Tran Chi Giang', 'Nu', TO_DATE('2009-5-4','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500022', 25000, 1570, 'Quan li', NULL, 7, '123')
#  into GOD.NHANVIEN values('QL023', 'Ung Song Bao', 'Nam', TO_DATE('2012-4-1','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500023', 25000, 1633, 'Quan li', NULL, 8, '123')
#  into GOD.NHANVIEN values('QL024', 'Ung Tung Minh', 'Nam', TO_DATE('2015-7-28','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500024', 25000, 1624, 'Quan li', NULL, 1, '123')
#  into GOD.NHANVIEN values('QL025', 'Ly Chi Cuc', 'Nam', TO_DATE('2014-2-5','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500025', 25000, 1721, 'Quan li', NULL, 2, '123')
#  into GOD.NHANVIEN values('QL026', 'Bui Thi Đuc', 'Nu', TO_DATE('2020-5-17','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500026', 25000, 1458, 'Quan li', NULL, 3, '123')
#  into GOD.NHANVIEN values('QL027', 'Duong Tung Đan', 'Nu', TO_DATE('2004-8-26','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500027', 25000, 1673, 'Quan li', NULL, 4, '123')
#  into GOD.NHANVIEN values('QL028', 'Au Van Tuan', 'Nu', TO_DATE('2006-2-7','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500028', 25000, 1735, 'Quan li', NULL, 5, '123')
#  into GOD.NHANVIEN values('QL029', 'Ung Thi Vu', 'Nu', TO_DATE('2017-3-1','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500029', 25000, 1546, 'Quan li', NULL, 6, '123')
#  into GOD.NHANVIEN values('QL030', 'Au Chi Vinh', 'Nu', TO_DATE('2004-10-27','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500030', 25000, 1420, 'Quan li', NULL, 7, '123')
#  into GOD.NHANVIEN values('QL031', 'Ho Chi Cuc', 'Nu', TO_DATE('2021-5-20','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500031', 25000, 1780, 'Quan li', NULL, 8, '123')
#  into GOD.NHANVIEN values('QL032', 'An Chi Vu', 'Nam', TO_DATE('2018-7-12','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500032', 25000, 1997, 'Quan li', NULL, 1, '123')
#  into GOD.NHANVIEN values('QL033', 'Ung Tung Nam', 'Nam', TO_DATE('2001-6-4','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500033', 25000, 1322, 'Quan li', NULL, 2, '123')
#  into GOD.NHANVIEN values('QL034', 'Le Song Sang', 'Nam', TO_DATE('2019-6-12','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500034', 25000, 1496, 'Quan li', NULL, 3, '123')
#  into GOD.NHANVIEN values('QL035', 'Vu Gia Nguyet', 'Nam', TO_DATE('2012-5-2','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500035', 25000, 1901, 'Quan li', NULL, 4, '123')
#  into GOD.NHANVIEN values('TDA036', 'An Chi khanh', 'Nam', TO_DATE('2010-5-9','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500036', 20000, 1436, 'Truong de an', NULL, 5, '123')
#  into GOD.NHANVIEN values('TDA037', 'Au Thi Minh', 'Nu', TO_DATE('2001-7-2','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500037', 20000, 1050, 'Truong de an', NULL, 6, '123')
#  into GOD.NHANVIEN values('TDA038', 'Nguyen Van Anh', 'Nu', TO_DATE('2011-10-27','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500038', 20000, 1200, 'Truong de an', NULL, 7, '123')
#  into GOD.NHANVIEN values('TP039', 'Ly Hoang Tien', 'Nu', TO_DATE('2022-1-16','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500039', 22000, 1942, 'Truong phong', NULL, 1, '123')
#  into GOD.NHANVIEN values('TP040', 'Gian Chi Han', 'Nam', TO_DATE('2002-10-9','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500040', 22000, 1115, 'Truong phong', NULL, 2, '123')
#  into GOD.NHANVIEN values('TP041', 'Le Thi Tien', 'Nam', TO_DATE('2022-1-17','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500041', 22000, 1748, 'Truong phong', NULL, 3, '123')
#  into GOD.NHANVIEN values('TP042', 'Tran Hoang Đuc', 'Nam', TO_DATE('2006-7-27','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500042', 22000, 1043, 'Truong phong', NULL, 4, '123')
#  into GOD.NHANVIEN values('TP043', 'Ly Chi Vy', 'Nu', TO_DATE('2015-2-27','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500043', 22000, 1322, 'Truong phong', NULL, 5, '123')
#  into GOD.NHANVIEN values('TP044', 'Vu Gia Duy', 'Nam', TO_DATE('2008-1-4','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500044', 22000, 1257, 'Truong phong', NULL, 6, '123')
#  into GOD.NHANVIEN values('TP045', 'An Gia Bao', 'Nam', TO_DATE('2006-9-11','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500045', 22000, 1536, 'Truong phong', NULL, 7, '123')
#  into GOD.NHANVIEN values('TP046', 'Ho Tung Đuc', 'Nu', TO_DATE('2006-2-6','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500046', 22000, 1845, 'Truong phong', NULL, 8, '123')
#  into GOD.NHANVIEN values('NV47', 'Duong Thi Đan', 'Nu', TO_DATE('2020-3-3','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500047', 7883, 1495, 'Nhan vien', 'QL016', 8, '123')
#  into GOD.NHANVIEN values('NV48', 'Ho Thi Vu', 'Nam', TO_DATE('2011-1-20','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500048', 2521, 1783, 'Nhan vien', 'QL017', 1, '123')
#  into GOD.NHANVIEN values('NV49', 'Ung Song Ngan', 'Nam', TO_DATE('2004-5-26','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500049', 9659, 1018, 'Nhan vien', 'QL018', 2, '123')
#  into GOD.NHANVIEN values('NV50', 'Nguyen Tung Bac', 'Nam', TO_DATE('2014-8-4','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500050', 6574, 1494, 'Nhan vien', 'QL019', 3, '123')
#  into GOD.NHANVIEN values('NV51', 'Vo Tung May', 'Nam', TO_DATE('2019-8-21','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500051', 8234, 1528, 'Nhan vien', 'QL020', 4, '123')
#  into GOD.NHANVIEN values('NV52', 'Tran Chi Tin', 'Nu', TO_DATE('2013-2-4','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500052', 6917, 1994, 'Nhan vien', 'QL021', 5, '123')
#  into GOD.NHANVIEN values('NV53', 'Đang Chi Đang', 'Nu', TO_DATE('2014-9-27','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500053', 8062, 1389, 'Nhan vien', 'QL022', 6, '123')
#  into GOD.NHANVIEN values('NV54', 'Ho Chi Đuc', 'Nam', TO_DATE('2008-4-7','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500054', 4031, 1665, 'Nhan vien', 'QL023', 7, '123')
#  into GOD.NHANVIEN values('NV55', 'Le Hoang Chung', 'Nu', TO_DATE('2019-11-11','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500055', 4695, 1626, 'Nhan vien', 'QL024', 8, '123')
#  into GOD.NHANVIEN values('NV56', 'Pham Tung Ngoc Nhi', 'Nam', TO_DATE('2001-8-2','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500056', 6123, 1289, 'Nhan vien', 'QL025', 1, '123')
#  into GOD.NHANVIEN values('NV57', 'Ung Tung Minh', 'Nam', TO_DATE('2013-4-10','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500057', 6513, 1618, 'Nhan vien', 'QL026', 2, '123')
#  into GOD.NHANVIEN values('NV58', 'Nguyen Thi Viet', 'Nam', TO_DATE('2010-9-20','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500058', 4605, 1785, 'Nhan vien', 'QL027', 3, '123')
#  into GOD.NHANVIEN values('NV59', 'Duong Tung Tan', 'Nu', TO_DATE('2009-8-15','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500059', 3022, 1153, 'Nhan vien', 'QL028', 4, '123')
#  into GOD.NHANVIEN values('NV60', 'Au Gia Anh', 'Nu', TO_DATE('2014-9-13','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500060', 6542, 1330, 'Nhan vien', 'QL029', 5, '123')
#  into GOD.NHANVIEN values('NV61', 'Bui Thi Vy', 'Nu', TO_DATE('2001-1-19','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500061', 7857, 1575, 'Nhan vien', 'QL030', 6, '123')
#  into GOD.NHANVIEN values('NV62', 'Lai Gia Anh', 'Nu', TO_DATE('2017-4-27','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500062', 2546, 1929, 'Nhan vien', 'QL031', 7, '123')
#  into GOD.NHANVIEN values('NV63', 'Duong Thi Cuc', 'Nam', TO_DATE('2020-6-12','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500063', 3251, 1030, 'Nhan vien', 'QL032', 8, '123')
#  into GOD.NHANVIEN values('NV64', 'An Song khanh', 'Nam', TO_DATE('2007-9-4','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500064', 4535, 1528, 'Nhan vien', 'QL033', 1, '123')
#  into GOD.NHANVIEN values('NV65', 'Pham Tung Tan', 'Nu', TO_DATE('2016-2-12','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500065', 1889, 1727, 'Nhan vien', 'QL034', 2, '123')
#  into GOD.NHANVIEN values('NV66', 'Au Tung May', 'Nam', TO_DATE('2009-11-5','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500066', 6605, 1697, 'Nhan vien', 'QL035', 3, '123')
#  into GOD.NHANVIEN values('NV67', 'Bui Song Tien', 'Nu', TO_DATE('2003-5-8','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500067', 7974, 1237, 'Nhan vien', 'QL016', 4, '123')
#  into GOD.NHANVIEN values('NV68', 'Duong Thi Viet', 'Nu', TO_DATE('2008-7-19','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500068', 1066, 1305, 'Nhan vien', 'QL017', 5, '123')
#  into GOD.NHANVIEN values('NV69', 'Truong Tung Viet', 'Nam', TO_DATE('2001-6-22','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500069', 7790, 1873, 'Nhan vien', 'QL018', 6, '123')
#  into GOD.NHANVIEN values('NV70', 'Gian Chi Bao', 'Nu', TO_DATE('2019-7-10','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500070', 5576, 1586, 'Nhan vien', 'QL019', 7, '123')
#  into GOD.NHANVIEN values('NV71', 'Đang Chi Thien', 'Nu', TO_DATE('2011-6-3','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500071', 4970, 1756, 'Nhan vien', 'QL020', 8, '123')
#  into GOD.NHANVIEN values('NV72', 'Au Hoang khanh', 'Nam', TO_DATE('2005-8-9','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500072', 5105, 1101, 'Nhan vien', 'QL021', 1, '123')
#  into GOD.NHANVIEN values('NV73', 'Pham Song Viet', 'Nam', TO_DATE('2004-2-10','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500073', 6729, 1238, 'Nhan vien', 'QL022', 2, '123')
#  into GOD.NHANVIEN values('NV74', 'Ho Gia Tin', 'Nam', TO_DATE('2015-8-27','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500074', 3540, 1947, 'Nhan vien', 'QL023', 3, '123')
#  into GOD.NHANVIEN values('NV75', 'Đoan Thi Han', 'Nam', TO_DATE('2017-2-17','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500075', 1113, 1777, 'Nhan vien', 'QL024', 4, '123')
#  into GOD.NHANVIEN values('NV76', 'Vo Van Cau', 'Nam', TO_DATE('2002-3-21','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500076', 3027, 1632, 'Nhan vien', 'QL025', 5, '123')
#  into GOD.NHANVIEN values('NV77', 'Ly Van Bao', 'Nam', TO_DATE('2002-11-24','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500077', 7140, 1937, 'Nhan vien', 'QL026', 6, '123')
#  into GOD.NHANVIEN values('NV78', 'Đang Thi Chi', 'Nu', TO_DATE('2014-7-14','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500078', 6258, 1412, 'Nhan vien', 'QL027', 7, '123')
#  into GOD.NHANVIEN values('NV79', 'Au Song Tuan', 'Nu', TO_DATE('2004-12-24','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500079', 5350, 1927, 'Nhan vien', 'QL028', 8, '123')
#  into GOD.NHANVIEN values('NV80', 'Truong Van Thien', 'Nam', TO_DATE('2016-7-6','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500080', 9791, 1110, 'Nhan vien', 'QL029', 1, '123')
#  into GOD.NHANVIEN values('NV81', 'Ung Gia Chung', 'Nu', TO_DATE('2012-3-23','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500081', 2484, 1973, 'Nhan vien', 'QL030', 2, '123')
#  into GOD.NHANVIEN values('NV82', 'Ly Song Nam', 'Nu', TO_DATE('2003-11-12','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500082', 6099, 1781, 'Nhan vien', 'QL031', 3, '123')
#  into GOD.NHANVIEN values('NV83', 'Đang Thi May', 'Nam', TO_DATE('2000-6-16','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500083', 7711, 1649, 'Nhan vien', 'QL032', 4, '123')
#  into GOD.NHANVIEN values('NV84', 'Bui Van Tan', 'Nam', TO_DATE('2005-4-3','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500084', 6920, 1940, 'Nhan vien', 'QL033', 5, '123')
#  into GOD.NHANVIEN values('NV85', 'Pham Tung Tiep', 'Nu', TO_DATE('2020-10-26','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500085', 1571, 1863, 'Nhan vien', 'QL034', 6, '123')
#  into GOD.NHANVIEN values('NV86', 'Tran Hoang Vu', 'Nam', TO_DATE('2014-7-22','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500086', 2392, 1261, 'Nhan vien', 'QL035', 7, '123')
#  into GOD.NHANVIEN values('NV87', 'Duong Hoang Sang', 'Nam', TO_DATE('2009-4-20','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500087', 7036, 1501, 'Nhan vien', 'QL016', 8, '123')
#  into GOD.NHANVIEN values('NV88', 'Duong Hoang Vu', 'Nu', TO_DATE('2018-10-22','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500088', 1659, 1647, 'Nhan vien', 'QL017', 1, '123')
#  into GOD.NHANVIEN values('NV89', 'Gian Song Tiep', 'Nam', TO_DATE('2016-5-17','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500089', 2074, 1041, 'Nhan vien', 'QL018', 2, '123')
#  into GOD.NHANVIEN values('NV90', 'Ho Gia Tiep', 'Nu', TO_DATE('2000-2-15','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500090', 2705, 1418, 'Nhan vien', 'QL019', 3, '123')
#  into GOD.NHANVIEN values('NV91', 'Duong Song Tu', 'Nu', TO_DATE('2006-2-5','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500091', 5050, 1389, 'Nhan vien', 'QL020', 4, '123')
#  into GOD.NHANVIEN values('NV92', 'Vo Tung Vinh', 'Nam', TO_DATE('2014-2-12','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500092', 7874, 1024, 'Nhan vien', 'QL021', 5, '123')
#  into GOD.NHANVIEN values('NV93', 'Le Hoang Ngoc Nhi', 'Nu', TO_DATE('2010-1-24','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500093', 8717, 1503, 'Nhan vien', 'QL022', 6, '123')
#  into GOD.NHANVIEN values('NV94', 'An Hoang Ngoc Nhi', 'Nam', TO_DATE('2000-11-24','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500094', 5920, 1041, 'Nhan vien', 'QL023', 7, '123')
#  into GOD.NHANVIEN values('NV95', 'Pham Hoang Cuc', 'Nam', TO_DATE('2020-3-17','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500095', 8045, 1469, 'Nhan vien', 'QL024', 8, '123')
#  into GOD.NHANVIEN values('NV96', 'Tran Hoang Chi', 'Nu', TO_DATE('2016-11-23','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500096', 7424, 1364, 'Nhan vien', 'QL025', 1, '123')
#  into GOD.NHANVIEN values('NV97', 'Ho Gia Tiep', 'Nu', TO_DATE('2009-3-25','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500097', 2140, 1750, 'Nhan vien', 'QL026', 2, '123')
#  into GOD.NHANVIEN values('NV98', 'Truong Tung May', 'Nam', TO_DATE('2013-9-25','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500098', 3263, 1235, 'Nhan vien', 'QL027', 3, '123')
#  into GOD.NHANVIEN values('NV99', 'Truong Gia Tiep', 'Nu', TO_DATE('2000-1-2','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500099', 1715, 1583, 'Nhan vien', 'QL028', 4, '123')
#  into GOD.NHANVIEN values('NV100', 'Ung Chi Cau', 'Nu', TO_DATE('2019-11-8','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000100', 1572, 1551, 'Nhan vien', 'QL029', 5, '123')
#  into GOD.NHANVIEN values('NV101', 'Bui Chi Han', 'Nu', TO_DATE('2004-10-1','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000101', 2944, 1076, 'Nhan vien', 'QL030', 6, '123')
#  into GOD.NHANVIEN values('NV102', 'Vo Van Đuc', 'Nam', TO_DATE('2005-3-23','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000102', 1885, 1811, 'Nhan vien', 'QL031', 7, '123')
#  into GOD.NHANVIEN values('NV103', 'Vu Song Vy', 'Nu', TO_DATE('2018-7-23','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000103', 6718, 1789, 'Nhan vien', 'QL032', 8, '123')
#  into GOD.NHANVIEN values('NV104', 'Gian Chi Thien', 'Nam', TO_DATE('2013-6-12','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000104', 6530, 1380, 'Nhan vien', 'QL033', 1, '123')
#  into GOD.NHANVIEN values('NV105', 'Đoan Chi Phu', 'Nu', TO_DATE('2003-1-14','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000105', 2463, 1753, 'Nhan vien', 'QL034', 2, '123')
#  into GOD.NHANVIEN values('NV106', 'Ung Song Giang', 'Nam', TO_DATE('2006-8-25','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000106', 8597, 1382, 'Nhan vien', 'QL035', 3, '123')
#  into GOD.NHANVIEN values('NV107', 'Vu Van Minh', 'Nu', TO_DATE('2001-2-14','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000107', 1432, 1668, 'Nhan vien', 'QL016', 4, '123')
#  into GOD.NHANVIEN values('NV108', 'Le Chi Thien', 'Nam', TO_DATE('2000-2-26','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000108', 9435, 1306, 'Nhan vien', 'QL017', 5, '123')
#  into GOD.NHANVIEN values('NV109', 'Le Van Giang', 'Nu', TO_DATE('2017-12-18','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000109', 3976, 1638, 'Nhan vien', 'QL018', 6, '123')
#  into GOD.NHANVIEN values('NV110', 'Lai Song Duy', 'Nu', TO_DATE('2019-6-7','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000110', 5006, 1854, 'Nhan vien', 'QL019', 7, '123')
#  into GOD.NHANVIEN values('NV111', 'Gian Song May', 'Nam', TO_DATE('2016-1-21','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000111', 2425, 1306, 'Nhan vien', 'QL020', 8, '123')
#  into GOD.NHANVIEN values('NV112', 'Tran Song Tu', 'Nam', TO_DATE('2014-2-19','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000112', 6600, 1671, 'Nhan vien', 'QL021', 1, '123')
#  into GOD.NHANVIEN values('NV113', 'Duong Chi Duy', 'Nu', TO_DATE('2010-3-12','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000113', 4831, 1674, 'Nhan vien', 'QL022', 2, '123')
#  into GOD.NHANVIEN values('NV114', 'Nguyen Tung Tiep', 'Nu', TO_DATE('2020-10-16','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000114', 9968, 1838, 'Nhan vien', 'QL023', 3, '123')
#  into GOD.NHANVIEN values('NV115', 'Tran Van Chi', 'Nam', TO_DATE('2012-1-15','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000115', 8502, 1552, 'Nhan vien', 'QL024', 4, '123')
#  into GOD.NHANVIEN values('NV116', 'Duong Gia Vy', 'Nu', TO_DATE('2018-8-19','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000116', 8567, 1366, 'Nhan vien', 'QL025', 5, '123')
#  into GOD.NHANVIEN values('NV117', 'Ho Tung Vu', 'Nam', TO_DATE('2022-3-8','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000117', 6599, 1591, 'Nhan vien', 'QL026', 6, '123')
#  into GOD.NHANVIEN values('NV118', 'Lai Van khanh', 'Nu', TO_DATE('2022-5-5','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000118', 4719, 1366, 'Nhan vien', 'QL027', 7, '123')
#  into GOD.NHANVIEN values('NV119', 'Nguyen Van Chi', 'Nu', TO_DATE('2022-5-18','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000119', 4083, 1696, 'Nhan vien', 'QL028', 8, '123')
#  into GOD.NHANVIEN values('NV120', 'Ung Tung Tiep', 'Nam', TO_DATE('2018-10-21','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000120', 1391, 1654, 'Nhan vien', 'QL029', 1, '123')
#  into GOD.NHANVIEN values('NV121', 'Vu Chi Tuan', 'Nam', TO_DATE('2019-8-15','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000121', 9097, 1702, 'Nhan vien', 'QL030', 2, '123')
#  into GOD.NHANVIEN values('NV122', 'Ho Tung Chi', 'Nu', TO_DATE('2000-9-12','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000122', 3816, 1886, 'Nhan vien', 'QL031', 3, '123')
#  into GOD.NHANVIEN values('NV123', 'Truong Tung Viet', 'Nu', TO_DATE('2001-4-26','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000123', 4572, 1451, 'Nhan vien', 'QL032', 4, '123')
#  into GOD.NHANVIEN values('NV124', 'Gian Hoang Ngan', 'Nu', TO_DATE('2016-9-22','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000124', 1740, 1576, 'Nhan vien', 'QL033', 5, '123')
#  into GOD.NHANVIEN values('NV125', 'Vu Gia Anh', 'Nu', TO_DATE('2008-2-16','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000125', 5768, 1676, 'Nhan vien', 'QL034', 6, '123')
#  into GOD.NHANVIEN values('NV126', 'Bui Tung May', 'Nam', TO_DATE('2010-2-23','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000126', 4312, 1665, 'Nhan vien', 'QL035', 7, '123')
#  into GOD.NHANVIEN values('NV127', 'Le Song May', 'Nam', TO_DATE('2016-5-12','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000127', 8218, 1429, 'Nhan vien', 'QL016', 8, '123')
#  into GOD.NHANVIEN values('NV128', 'Ung Tung Đuc', 'Nu', TO_DATE('2022-4-9','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000128', 6499, 1849, 'Nhan vien', 'QL017', 1, '123')
#  into GOD.NHANVIEN values('NV129', 'Tran Tung Bao', 'Nu', TO_DATE('2007-9-3','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000129', 6628, 1952, 'Nhan vien', 'QL018', 2, '123')
#  into GOD.NHANVIEN values('NV130', 'Truong Gia Cuc', 'Nam', TO_DATE('2017-12-9','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000130', 4188, 1506, 'Nhan vien', 'QL019', 3, '123')
#  into GOD.NHANVIEN values('NV131', 'Duong Thi Quoc', 'Nam', TO_DATE('2016-2-27','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000131', 7647, 1211, 'Nhan vien', 'QL020', 4, '123')
#  into GOD.NHANVIEN values('NV132', 'Au Tung Tuan', 'Nu', TO_DATE('2009-1-1','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000132', 1566, 1558, 'Nhan vien', 'QL021', 5, '123')
#  into GOD.NHANVIEN values('NV133', 'Nguyen Gia May', 'Nu', TO_DATE('2015-12-26','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000133', 1781, 1766, 'Nhan vien', 'QL022', 6, '123')
#  into GOD.NHANVIEN values('NV134', 'Vo Van Tan', 'Nu', TO_DATE('2011-12-25','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000134', 9750, 1263, 'Nhan vien', 'QL023', 7, '123')
#  into GOD.NHANVIEN values('NV135', 'Tran Thi Cau', 'Nu', TO_DATE('2003-3-14','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000135', 6267, 1917, 'Nhan vien', 'QL024', 8, '123')
#  into GOD.NHANVIEN values('NV136', 'Ly Song Sang', 'Nu', TO_DATE('2013-8-10','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000136', 6983, 1056, 'Nhan vien', 'QL025', 1, '123')
#  into GOD.NHANVIEN values('NV137', 'Pham Song khanh', 'Nu', TO_DATE('2019-10-28','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000137', 5363, 1591, 'Nhan vien', 'QL026', 2, '123')
#  into GOD.NHANVIEN values('NV138', 'Ho Van Thien', 'Nu', TO_DATE('2014-6-23','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000138', 3618, 1279, 'Nhan vien', 'QL027', 3, '123')
#  into GOD.NHANVIEN values('NV139', 'Le Hoang Bac', 'Nu', TO_DATE('2008-9-21','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000139', 4547, 1755, 'Nhan vien', 'QL028', 4, '123')
#  into GOD.NHANVIEN values('NV140', 'An Chi Ngoc Nhi', 'Nu', TO_DATE('2021-1-11','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000140', 7334, 1096, 'Nhan vien', 'QL029', 5, '123')
#  into GOD.NHANVIEN values('NV141', 'Ly Tung Vy', 'Nu', TO_DATE('2002-12-27','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000141', 1169, 1383, 'Nhan vien', 'QL030', 6, '123')
#  into GOD.NHANVIEN values('NV142', 'Gian Van Tu', 'Nam', TO_DATE('2002-12-15','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000142', 7503, 1584, 'Nhan vien', 'QL031', 7, '123')
#  into GOD.NHANVIEN values('NV143', 'Vo Gia Tuan', 'Nam', TO_DATE('2011-9-4','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000143', 3396, 1876, 'Nhan vien', 'QL032', 8, '123')
#  into GOD.NHANVIEN values('NV144', 'Nguyen Hoang Bao', 'Nu', TO_DATE('2018-1-17','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000144', 8305, 1996, 'Nhan vien', 'QL033', 1, '123')
#  into GOD.NHANVIEN values('NV145', 'Lai Gia Viet', 'Nam', TO_DATE('2015-2-15','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000145', 6952, 1495, 'Nhan vien', 'QL034', 2, '123')
#  into GOD.NHANVIEN values('NV146', 'Tran Tung Ngan', 'Nu', TO_DATE('2000-3-16','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000146', 2026, 1874, 'Nhan vien', 'QL035', 3, '123')
#  into GOD.NHANVIEN values('NV147', 'Bui Song Thong', 'Nam', TO_DATE('2010-7-13','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000147', 1100, 1581, 'Nhan vien', 'QL016', 4, '123')
#  into GOD.NHANVIEN values('NV148', 'Pham Thi Phu', 'Nu', TO_DATE('2018-10-12','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000148', 7286, 1579, 'Nhan vien', 'QL017', 5, '123')
#  into GOD.NHANVIEN values('NV149', 'Tran Thi Anh', 'Nu', TO_DATE('2008-11-10','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000149', 1145, 1182, 'Nhan vien', 'QL018', 6, '123')
#  into GOD.NHANVIEN values('NV150', 'Lai Van May', 'Nu', TO_DATE('2005-5-9','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000150', 4625, 1893, 'Nhan vien', 'QL019', 7, '123')
#  into GOD.NHANVIEN values('NV151', 'Lai Hoang Viet', 'Nam', TO_DATE('2001-2-20','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000151', 3420, 1576, 'Nhan vien', 'QL020', 8, '123')
#  into GOD.NHANVIEN values('NV152', 'Duong Tung Phu', 'Nam', TO_DATE('2022-4-14','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000152', 7885, 1392, 'Nhan vien', 'QL021', 1, '123')
#  into GOD.NHANVIEN values('NV153', 'Le Song Duy', 'Nam', TO_DATE('2014-10-11','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000153', 7157, 1518, 'Nhan vien', 'QL022', 2, '123')
#  into GOD.NHANVIEN values('NV154', 'Nguyen Gia Chung', 'Nu', TO_DATE('2010-6-8','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000154', 4574, 1892, 'Nhan vien', 'QL023', 3, '123')
#  into GOD.NHANVIEN values('NV155', 'Au Van Tuan', 'Nu', TO_DATE('2016-10-13','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000155', 1874, 1719, 'Nhan vien', 'QL024', 4, '123')
#  into GOD.NHANVIEN values('NV156', 'Ho Song Cuc', 'Nu', TO_DATE('2017-4-27','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000156', 8511, 1354, 'Nhan vien', 'QL025', 5, '123')
#  into GOD.NHANVIEN values('NV157', 'Bui Song Thuong', 'Nu', TO_DATE('2013-3-9','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000157', 7081, 1037, 'Nhan vien', 'QL026', 6, '123')
#  into GOD.NHANVIEN values('NV158', 'Vo Tung May', 'Nu', TO_DATE('2001-6-28','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000158', 5940, 1992, 'Nhan vien', 'QL027', 7, '123')
#  into GOD.NHANVIEN values('NV159', 'Nguyen Hoang Thien', 'Nu', TO_DATE('2022-6-5','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000159', 6005, 1370, 'Nhan vien', 'QL028', 8, '123')
#  into GOD.NHANVIEN values('NV160', 'Vo Thi Vu', 'Nam', TO_DATE('2020-6-13','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000160', 2279, 1860, 'Nhan vien', 'QL029', 1, '123')
#  into GOD.NHANVIEN values('NV161', 'Ung Van Chi', 'Nu', TO_DATE('2020-4-14','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000161', 7677, 1584, 'Nhan vien', 'QL030', 2, '123')
#  into GOD.NHANVIEN values('NV162', 'Ho Thi Chi', 'Nam', TO_DATE('2013-3-12','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000162', 6877, 1614, 'Nhan vien', 'QL031', 3, '123')
#  into GOD.NHANVIEN values('NV163', 'Đoan Song Nguyet', 'Nu', TO_DATE('2022-4-20','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000163', 1705, 1608, 'Nhan vien', 'QL032', 4, '123')
#  into GOD.NHANVIEN values('NV164', 'Gian Gia Tiep', 'Nu', TO_DATE('2005-10-13','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000164', 5965, 1960, 'Nhan vien', 'QL033', 5, '123')
#  into GOD.NHANVIEN values('NV165', 'Vo Tung Bao', 'Nu', TO_DATE('2015-3-25','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000165', 5037, 1142, 'Nhan vien', 'QL034', 6, '123')
#  into GOD.NHANVIEN values('NV166', 'Lai Tung Minh', 'Nam', TO_DATE('2018-2-27','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000166', 7576, 1421, 'Nhan vien', 'QL035', 7, '123')
#  into GOD.NHANVIEN values('NV167', 'Pham Van Sang', 'Nu', TO_DATE('2013-8-21','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000167', 3955, 1291, 'Nhan vien', 'QL016', 8, '123')
#  into GOD.NHANVIEN values('NV168', 'Pham Tung Ngan', 'Nam', TO_DATE('2000-2-13','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000168', 5571, 1297, 'Nhan vien', 'QL017', 1, '123')
#  into GOD.NHANVIEN values('NV169', 'Au Tung Đan', 'Nam', TO_DATE('2001-6-3','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000169', 9707, 1326, 'Nhan vien', 'QL018', 2, '123')
#  into GOD.NHANVIEN values('NV170', 'Nguyen Van Viet', 'Nam', TO_DATE('2018-4-12','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000170', 7400, 1761, 'Nhan vien', 'QL019', 3, '123')
#  into GOD.NHANVIEN values('NV171', 'Bui Hoang Vy', 'Nam', TO_DATE('2017-4-25','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000171', 9140, 1049, 'Nhan vien', 'QL020', 4, '123')
#  into GOD.NHANVIEN values('NV172', 'Gian Hoang Nguyet', 'Nam', TO_DATE('2022-7-25','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000172', 5147, 1779, 'Nhan vien', 'QL021', 5, '123')
#  into GOD.NHANVIEN values('NV173', 'Au Gia Chung', 'Nu', TO_DATE('2000-9-6','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000173', 1920, 1714, 'Nhan vien', 'QL022', 6, '123')
#  into GOD.NHANVIEN values('NV174', 'Duong Hoang Sang', 'Nu', TO_DATE('2008-2-17','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000174', 5868, 1563, 'Nhan vien', 'QL023', 7, '123')
#  into GOD.NHANVIEN values('NV175', 'Ho Tung Tin', 'Nu', TO_DATE('2007-11-11','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000175', 7855, 1532, 'Nhan vien', 'QL024', 8, '123')
#  into GOD.NHANVIEN values('NV176', 'Pham Tung Cau', 'Nu', TO_DATE('2002-2-23','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000176', 5875, 1066, 'Nhan vien', 'QL025', 1, '123')
#  into GOD.NHANVIEN values('NV177', 'Ho Hoang Đan', 'Nu', TO_DATE('2012-3-26','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000177', 9056, 1807, 'Nhan vien', 'QL026', 2, '123')
#  into GOD.NHANVIEN values('NV178', 'Vo Gia Chung', 'Nam', TO_DATE('2011-11-22','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000178', 4808, 1957, 'Nhan vien', 'QL027', 3, '123')
#  into GOD.NHANVIEN values('NV179', 'Ly Gia Vu', 'Nam', TO_DATE('2018-11-28','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000179', 9266, 1655, 'Nhan vien', 'QL028', 4, '123')
#  into GOD.NHANVIEN values('NV180', 'An Tung Bac', 'Nu', TO_DATE('2002-10-3','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000180', 7356, 1588, 'Nhan vien', 'QL029', 5, '123')
#  into GOD.NHANVIEN values('NV181', 'Gian Tung Ngan', 'Nam', TO_DATE('2006-5-16','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000181', 7696, 1517, 'Nhan vien', 'QL030', 6, '123')
#  into GOD.NHANVIEN values('NV182', 'Vo Thi Giang', 'Nu', TO_DATE('2002-5-23','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000182', 3792, 1469, 'Nhan vien', 'QL031', 7, '123')
#  into GOD.NHANVIEN values('NV183', 'Đoan Song Thuong', 'Nam', TO_DATE('2006-10-23','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000183', 8923, 1434, 'Nhan vien', 'QL032', 8, '123')
#  into GOD.NHANVIEN values('NV184', 'Vo Gia Vy', 'Nam', TO_DATE('2012-4-13','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000184', 1169, 1700, 'Nhan vien', 'QL033', 1, '123')
#  into GOD.NHANVIEN values('NV185', 'Ly Thi May', 'Nam', TO_DATE('2015-3-14','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000185', 8991, 1720, 'Nhan vien', 'QL034', 2, '123')
#  into GOD.NHANVIEN values('NV186', 'Ho Chi Ngoc Nhi', 'Nam', TO_DATE('2021-6-4','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000186', 9015, 1174, 'Nhan vien', 'QL035', 3, '123')
#  into GOD.NHANVIEN values('NV187', 'Gian Hoang Duy', 'Nu', TO_DATE('2022-6-19','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000187', 5036, 1441, 'Nhan vien', 'QL016', 4, '123')
#  into GOD.NHANVIEN values('NV188', 'Au Hoang Nam', 'Nam', TO_DATE('2007-11-19','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000188', 1146, 1059, 'Nhan vien', 'QL017', 5, '123')
#  into GOD.NHANVIEN values('NV189', 'Đoan Chi Vinh', 'Nam', TO_DATE('2019-1-12','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000189', 2470, 1593, 'Nhan vien', 'QL018', 6, '123')
#  into GOD.NHANVIEN values('NV190', 'An Van Chung', 'Nu', TO_DATE('2001-1-3','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000190', 1534, 1882, 'Nhan vien', 'QL019', 7, '123')
#  into GOD.NHANVIEN values('NV191', 'Gian Van Tien', 'Nam', TO_DATE('2010-11-22','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000191', 3431, 1079, 'Nhan vien', 'QL020', 8, '123')
#  into GOD.NHANVIEN values('NV192', 'Ung Gia Thong', 'Nu', TO_DATE('2012-11-13','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000192', 1849, 1964, 'Nhan vien', 'QL021', 1, '123')
#  into GOD.NHANVIEN values('NV193', 'Le Van Viet', 'Nam', TO_DATE('2001-3-19','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000193', 2778, 1659, 'Nhan vien', 'QL022', 2, '123')
#  into GOD.NHANVIEN values('NV194', 'Đang Van Vu', 'Nu', TO_DATE('2004-12-3','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000194', 3731, 1585, 'Nhan vien', 'QL023', 3, '123')
#  into GOD.NHANVIEN values('NV195', 'An Song Tu', 'Nam', TO_DATE('2005-5-23','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000195', 6336, 1614, 'Nhan vien', 'QL024', 4, '123')
#  into GOD.NHANVIEN values('NV196', 'Duong Song Đang', 'Nu', TO_DATE('2022-4-15','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000196', 7159, 1495, 'Nhan vien', 'QL025', 5, '123')
#  into GOD.NHANVIEN values('NV197', 'Truong Chi Tan', 'Nam', TO_DATE('2004-11-5','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000197', 6111, 1217, 'Nhan vien', 'QL026', 6, '123')
#  into GOD.NHANVIEN values('NV198', 'An Thi Tiep', 'Nu', TO_DATE('2022-3-28','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000198', 5332, 1561, 'Nhan vien', 'QL027', 7, '123')
#  into GOD.NHANVIEN values('NV199', 'Truong Hoang Tan', 'Nam', TO_DATE('2003-12-25','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000199', 4789, 1672, 'Nhan vien', 'QL028', 8, '123')
#  into GOD.NHANVIEN values('NV200', 'Ly Song Duy', 'Nu', TO_DATE('2018-5-23','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000200', 4445, 1824, 'Nhan vien', 'QL029', 1, '123')
#  into GOD.NHANVIEN values('NV201', 'Ung Chi Đan', 'Nam', TO_DATE('2006-7-18','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000201', 6812, 1740, 'Nhan vien', 'QL030', 2, '123')
#  into GOD.NHANVIEN values('NV202', 'Ly Van Đang', 'Nu', TO_DATE('2019-11-27','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000202', 5684, 1838, 'Nhan vien', 'QL031', 3, '123')
#  into GOD.NHANVIEN values('NV203', 'Vu Hoang May', 'Nu', TO_DATE('2019-3-11','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000203', 3139, 1940, 'Nhan vien', 'QL032', 4, '123')
#  into GOD.NHANVIEN values('NV204', 'Gian Chi Cuc', 'Nu', TO_DATE('2006-1-20','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000204', 2264, 1736, 'Nhan vien', 'QL033', 5, '123')
#  into GOD.NHANVIEN values('NV205', 'An Song khanh', 'Nam', TO_DATE('2018-7-24','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000205', 6865, 1864, 'Nhan vien', 'QL034', 6, '123')
#  into GOD.NHANVIEN values('NV206', 'Ly Chi Tin', 'Nam', TO_DATE('2013-2-4','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000206', 6870, 1718, 'Nhan vien', 'QL035', 7, '123')
#  into GOD.NHANVIEN values('NV207', 'Au Chi Tuan', 'Nam', TO_DATE('2020-4-17','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000207', 9880, 1278, 'Nhan vien', 'QL016', 8, '123')
#  into GOD.NHANVIEN values('NV208', 'Le Tung Tiep', 'Nam', TO_DATE('2016-4-13','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000208', 2932, 1927, 'Nhan vien', 'QL017', 1, '123')
#  into GOD.NHANVIEN values('NV209', 'Au Van Sang', 'Nam', TO_DATE('2010-11-13','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000209', 5425, 1743, 'Nhan vien', 'QL018', 2, '123')
#  into GOD.NHANVIEN values('NV210', 'Vu Chi Cau', 'Nam', TO_DATE('2005-1-18','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000210', 9757, 1187, 'Nhan vien', 'QL019', 3, '123')
#  into GOD.NHANVIEN values('NV211', 'Le Chi Phu', 'Nu', TO_DATE('2001-9-8','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000211', 1027, 1294, 'Nhan vien', 'QL020', 4, '123')
#  into GOD.NHANVIEN values('NV212', 'Ly Hoang Duy', 'Nu', TO_DATE('2000-8-7','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000212', 4810, 1333, 'Nhan vien', 'QL021', 5, '123')
#  into GOD.NHANVIEN values('NV213', 'Au Hoang Sang', 'Nam', TO_DATE('2001-11-12','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000213', 1117, 1796, 'Nhan vien', 'QL022', 6, '123')
#  into GOD.NHANVIEN values('NV214', 'Ho Gia Đuc', 'Nu', TO_DATE('2000-12-1','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000214', 9667, 1815, 'Nhan vien', 'QL023', 7, '123')
#  into GOD.NHANVIEN values('NV215', 'Le Song Han', 'Nam', TO_DATE('2006-11-22','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000215', 5794, 1179, 'Nhan vien', 'QL024', 8, '123')
#  into GOD.NHANVIEN values('NV216', 'Gian Chi Đan', 'Nam', TO_DATE('2011-5-11','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000216', 4224, 1310, 'Nhan vien', 'QL025', 1, '123')
#  into GOD.NHANVIEN values('NV217', 'Nguyen Gia Đang', 'Nu', TO_DATE('2016-5-21','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000217', 7525, 1858, 'Nhan vien', 'QL026', 2, '123')
#  into GOD.NHANVIEN values('NV218', 'Duong Thi khanh', 'Nu', TO_DATE('2009-12-10','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000218', 1641, 1440, 'Nhan vien', 'QL027', 3, '123')
#  into GOD.NHANVIEN values('NV219', 'Lai Song Han', 'Nam', TO_DATE('2018-10-12','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000219', 4462, 1329, 'Nhan vien', 'QL028', 4, '123')
#  into GOD.NHANVIEN values('NV220', 'Le Song Vy', 'Nam', TO_DATE('2002-8-20','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000220', 9071, 1146, 'Nhan vien', 'QL029', 5, '123')
#  into GOD.NHANVIEN values('NV221', 'Vu Chi Thuong', 'Nam', TO_DATE('2010-2-12','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000221', 1961, 1810, 'Nhan vien', 'QL030', 6, '123')
#  into GOD.NHANVIEN values('NV222', 'Tran Chi Tien', 'Nam', TO_DATE('2014-9-18','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000222', 8891, 1236, 'Nhan vien', 'QL031', 7, '123')
#  into GOD.NHANVIEN values('NV223', 'Ho Gia Chi', 'Nu', TO_DATE('2011-11-9','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000223', 9959, 1655, 'Nhan vien', 'QL032', 8, '123')
#  into GOD.NHANVIEN values('NV224', 'Đang Van Vy', 'Nu', TO_DATE('2010-7-2','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000224', 8812, 1499, 'Nhan vien', 'QL033', 1, '123')
#  into GOD.NHANVIEN values('NV225', 'Pham Hoang Vu', 'Nam', TO_DATE('2005-1-14','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000225', 1907, 1655, 'Nhan vien', 'QL034', 2, '123')
#  into GOD.NHANVIEN values('NV226', 'Nguyen Hoang Ngan', 'Nu', TO_DATE('2006-10-24','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000226', 7644, 1880, 'Nhan vien', 'QL035', 3, '123')
#  into GOD.NHANVIEN values('NV227', 'Duong Hoang Thien', 'Nam', TO_DATE('2016-1-1','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000227', 1251, 1208, 'Nhan vien', 'QL016', 4, '123')
#  into GOD.NHANVIEN values('NV228', 'Gian Hoang Đang', 'Nam', TO_DATE('2016-9-25','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000228', 1036, 1923, 'Nhan vien', 'QL017', 5, '123')
#  into GOD.NHANVIEN values('NV229', 'Đang Van Ngoc Nhi', 'Nam', TO_DATE('2014-2-24','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000229', 3079, 1371, 'Nhan vien', 'QL018', 6, '123')
#  into GOD.NHANVIEN values('NV230', 'Gian Tung Anh', 'Nam', TO_DATE('2003-10-8','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000230', 4229, 1824, 'Nhan vien', 'QL019', 7, '123')
#  into GOD.NHANVIEN values('NV231', 'Bui Gia Đuc', 'Nu', TO_DATE('2013-2-1','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000231', 7174, 1256, 'Nhan vien', 'QL020', 8, '123')
#  into GOD.NHANVIEN values('NV232', 'Vu Thi Quoc', 'Nam', TO_DATE('2017-10-1','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000232', 7535, 1767, 'Nhan vien', 'QL021', 1, '123')
#  into GOD.NHANVIEN values('NV233', 'Ly Hoang Ngoc Nhi', 'Nu', TO_DATE('2001-8-4','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000233', 8266, 1165, 'Nhan vien', 'QL022', 2, '123')
# ...
#  into GOD.NHANVIEN values('NV270', 'An Song Bac', 'Nu', TO_DATE('2020-2-3','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000270', 4341, 1460, 'Nhan vien', 'QL019', 7, '123')
#  into GOD.NHANVIEN values('NV271', 'Le Gia Tiep', 'Nu', TO_DATE('2017-8-8','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000271', 9479, 1801, 'Nhan vien', 'QL020', 8, '123')
#  into GOD.NHANVIEN values('NV272', 'Vo Hoang Cuc', 'Nam', TO_DATE('2002-4-28','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000272', 3462, 1156, 'Nhan vien', 'QL021', 1, '123')
#  into GOD.NHANVIEN values('NV273', 'Đoan Thi Chi', 'Nam', TO_DATE('2021-11-24','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000273', 5372, 1479, 'Nhan vien', 'QL022', 2, '123')
#  into GOD.NHANVIEN values('NV274', 'Truong Song Duy', 'Nu', TO_DATE('2020-5-14','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000274', 1413, 1290, 'Nhan vien', 'QL023', 3, '123')
#  into GOD.NHANVIEN values('NV275', 'Duong Gia Duy', 'Nam', TO_DATE('2022-4-2','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000275', 3990, 1985, 'Nhan vien', 'QL024', 4, '123')
#  into GOD.NHANVIEN values('NV276', 'Au Gia Phu', 'Nu', TO_DATE('2005-3-10','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000276', 2456, 1692, 'Nhan vien', 'QL025', 5, '123')
#  into GOD.NHANVIEN values('NV277', 'Duong Song Nguyet', 'Nu', TO_DATE('2012-6-11','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000277', 7359, 1639, 'Nhan vien', 'QL026', 6, '123')
#  into GOD.NHANVIEN values('NV278', 'Ung Gia May', 'Nu', TO_DATE('2009-10-15','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000278', 6913, 1053, 'Nhan vien', 'QL027', 7, '123')
#  into GOD.NHANVIEN values('NV279', 'Đang Van Sang', 'Nam', TO_DATE('2011-10-12','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000279', 6552, 1442, 'Nhan vien', 'QL028', 8, '123')
#  into GOD.NHANVIEN values('NV280', 'Vu Van Tin', 'Nu', TO_DATE('2012-8-4','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000280', 6391, 1075, 'Nhan vien', 'QL029', 1, '123')
#  into GOD.NHANVIEN values('NV281', 'Lai Song Tu', 'Nu', TO_DATE('2022-6-21','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000281', 2784, 1600, 'Nhan vien', 'QL030', 2, '123')
#  into GOD.NHANVIEN values('NV282', 'Pham Chi Bac', 'Nam', TO_DATE('2000-2-16','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000282', 9757, 1988, 'Nhan vien', 'QL031', 3, '123')
#  into GOD.NHANVIEN values('NV283', 'Bui Thi Vinh', 'Nam', TO_DATE('2009-10-10','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000283', 3599, 1719, 'Nhan vien', 'QL032', 4, '123')
#  into GOD.NHANVIEN values('NV284', 'Lai Van Sang', 'Nu', TO_DATE('2020-11-25','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000284', 8231, 1989, 'Nhan vien', 'QL033', 5, '123')
#  into GOD.NHANVIEN values('NV285', 'Ly Van Vinh', 'Nu', TO_DATE('2021-3-12','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000285', 2014, 1285, 'Nhan vien', 'QL034', 6, '123')
#  into GOD.NHANVIEN values('NV286', 'Ho Van Bao', 'Nam', TO_DATE('2005-3-15','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000286', 1961, 1502, 'Nhan vien', 'QL035', 7, '123')
#  into GOD.NHANVIEN values('NV287', 'Nguyen Gia Duy', 'Nu', TO_DATE('2007-8-1','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000287', 7788, 1524, 'Nhan vien', 'QL016', 8, '123')
#  into GOD.NHANVIEN values('NV288', 'Ho Song Minh', 'Nam', TO_DATE('2007-6-10','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000288', 2729, 1680, 'Nhan vien', 'QL017', 1, '123')
#  into GOD.NHANVIEN values('NV289', 'Lai Song Thong', 'Nu', TO_DATE('2007-1-16','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000289', 4399, 1184, 'Nhan vien', 'QL018', 2, '123')
#  into GOD.NHANVIEN values('NV290', 'Pham Tung Tan', 'Nu', TO_DATE('2015-11-19','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000290', 1079, 1681, 'Nhan vien', 'QL019', 3, '123')
#  into GOD.NHANVIEN values('NV291', 'Duong Hoang Han', 'Nu', TO_DATE('2022-11-4','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000291', 5306, 1630, 'Nhan vien', 'QL020', 4, '123')
#  into GOD.NHANVIEN values('NV292', 'Tran Van Cau', 'Nu', TO_DATE('2014-2-20','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000292', 5286, 1316, 'Nhan vien', 'QL021', 5, '123')
#  into GOD.NHANVIEN values('NV293', 'Ho Thi Han', 'Nu', TO_DATE('2000-12-16','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000293', 1763, 1046, 'Nhan vien', 'QL022', 6, '123')
#  into GOD.NHANVIEN values('NV294', 'Vu Chi Đan', 'Nam', TO_DATE('2019-6-16','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000294', 4230, 1972, 'Nhan vien', 'QL023', 7, '123')
#  into GOD.NHANVIEN values('NV295', 'Vo Thi Ngoc Nhi', 'Nu', TO_DATE('2002-9-1','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000295', 7647, 1162, 'Nhan vien', 'QL024', 8, '123')
#  into GOD.NHANVIEN values('NV296', 'Nguyen Van Ngan', 'Nam', TO_DATE('2015-4-7','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000296', 3504, 1590, 'Nhan vien', 'QL025', 1, '123')
#  into GOD.NHANVIEN values('NV297', 'Đoan Gia Anh', 'Nu', TO_DATE('2022-6-13','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000297', 3881, 1608, 'Nhan vien', 'QL026', 2, '123')
#  into GOD.NHANVIEN values('NV298', 'Vu Gia Tin', 'Nu', TO_DATE('2004-12-18','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000298', 1950, 1485, 'Nhan vien', 'QL027', 3, '123')
#  into GOD.NHANVIEN values('NV299', 'Đang Van Phu', 'Nu', TO_DATE('2015-6-23','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000299', 3452, 1438, 'Nhan vien', 'QL028', 4, '123')
#  into GOD.NHANVIEN values('NV300', 'Đoan Van Tuan', 'Nu', TO_DATE('2012-2-13','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000300', 3800, 1262, 'Nhan vien', 'QL029', 5, '123')
#  into GOD.NHANVIEN values('NV301', 'Ung Gia Viet', 'Nu', TO_DATE('2007-3-8','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000301', 3746, 1459, 'Nhan vien', 'QL030', 6, '123')
#  into GOD.NHANVIEN values('NV302', 'Ung Chi Chi', 'Nam', TO_DATE('2002-12-10','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000302', 4487, 1703, 'Nhan vien', 'QL031', 7, '123')
#  into GOD.NHANVIEN values('NV303', 'Au Gia Sang', 'Nu', TO_DATE('2006-5-22','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000303', 4035, 1004, 'Nhan vien', 'QL032', 8, '123')
#  into GOD.NHANVIEN values('NV304', 'Nguyen Thi Thong', 'Nam', TO_DATE('2021-10-7','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000304', 2296, 1515, 'Nhan vien', 'QL033', 1, '123')
#  into GOD.NHANVIEN values('NV305', 'Pham Tung Thien', 'Nam', TO_DATE('2021-12-3','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000305', 8220, 1762, 'Nhan vien', 'QL034', 2, '123')
#  into GOD.NHANVIEN values('NV306', 'Duong Hoang An', 'Nam', TO_DATE('2001-3-27','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000306', 5235, 1916, 'Nhan vien', 'QL035', 3, '123')
#  into GOD.NHANVIEN values('NV307', 'Tran Song khanh', 'Nam', TO_DATE('2015-6-23','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000307', 4451, 1664, 'Nhan vien', 'QL016', 4, '123')
#  into GOD.NHANVIEN values('NV308', 'Ho Tung May', 'Nam', TO_DATE('2007-7-15','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000308', 2416, 1513, 'Nhan vien', 'QL017', 5, '123')
#  into GOD.NHANVIEN values('NV309', 'Pham Thi Chi', 'Nu', TO_DATE('2004-6-20','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000309', 6005, 1998, 'Nhan vien', 'QL018', 6, '123')
#  into GOD.NHANVIEN values('NV310', 'Đang Hoang Phu', 'Nam', TO_DATE('2008-5-21','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000310', 9628, 1458, 'Nhan vien', 'QL019', 7, '123')
#  into GOD.NHANVIEN values('NV311', 'Ung Hoang Ngoc Nhi', 'Nu', TO_DATE('2010-5-18','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000311', 8580, 1758, 'Nhan vien', 'QL020', 8, '123')
#  into GOD.NHANVIEN values('NV312', 'Đoan Thi Vu', 'Nu', TO_DATE('2016-1-1','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000312', 3556, 1976, 'Nhan vien', 'QL021', 1, '123')
#  into GOD.NHANVIEN values('NV313', 'Vo Hoang Duy', 'Nam', TO_DATE('2012-5-9','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000313', 3431, 1632, 'Nhan vien', 'QL022', 2, '123')
#  into GOD.NHANVIEN values('NV314', 'Le Chi Nguyet', 'Nu', TO_DATE('2004-5-6','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000314', 9587, 1627, 'Nhan vien', 'QL023', 3, '123')
#  into GOD.NHANVIEN values('NV315', 'Le Van Đan', 'Nu', TO_DATE('2014-3-2','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000315', 5624, 1111, 'Nhan vien', 'QL024', 4, '123')
#  into GOD.NHANVIEN values('NV316', 'Tran Thi Thien', 'Nu', TO_DATE('2014-4-15','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000316', 9753, 1694, 'Nhan vien', 'QL025', 5, '123')
#  into GOD.NHANVIEN values('NV317', 'An Chi Quoc', 'Nam', TO_DATE('2016-3-27','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000317', 3398, 1687, 'Nhan vien', 'QL026', 6, '123')
#  into GOD.NHANVIEN values('NV318', 'An Van Vu', 'Nam', TO_DATE('2012-7-8','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000318', 6780, 1545, 'Nhan vien', 'QL027', 7, '123')
#  into GOD.NHANVIEN values('NV319', 'Tran Hoang Phu', 'Nam', TO_DATE('2006-4-21','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000319', 7115, 1346, 'Nhan vien', 'QL028', 8, '123')
#  into GOD.NHANVIEN values('NV320', 'Le Hoang khanh', 'Nu', TO_DATE('2020-8-21','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000320', 3314, 1045, 'Nhan vien', 'QL029', 1, '123')
#  into GOD.NHANVIEN values('NV321', 'Ly Gia Duy', 'Nam', TO_DATE('2017-6-17','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000321', 2247, 1592, 'Nhan vien', 'QL030', 2, '123')
#  into GOD.NHANVIEN values('NV322', 'Ung Chi May', 'Nu', TO_DATE('2009-11-10','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000322', 7023, 1221, 'Nhan vien', 'QL031', 3, '123')
#  into GOD.NHANVIEN values('NV323', 'Vu Van Thong', 'Nam', TO_DATE('2003-5-14','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000323', 3799, 1957, 'Nhan vien', 'QL032', 4, '123')
#  into GOD.NHANVIEN values('NV324', 'Vo Gia Giang', 'Nam', TO_DATE('2021-4-28','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000324', 1687, 1044, 'Nhan vien', 'QL033', 5, '123')
#  into GOD.NHANVIEN values('NV325', 'Duong Chi Thien', 'Nu', TO_DATE('2013-3-26','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000325', 6473, 1086, 'Nhan vien', 'QL034', 6, '123')
#  into GOD.NHANVIEN values('NV326', 'An Gia Tu', 'Nam', TO_DATE('2006-11-23','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000326', 5369, 1456, 'Nhan vien', 'QL035', 7, '123')
#  into GOD.NHANVIEN values('NV327', 'Đang Gia Tiep', 'Nu', TO_DATE('2010-2-9','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000327', 2516, 1188, 'Nhan vien', 'QL016', 8, '123')
#  into GOD.NHANVIEN values('NV328', 'Duong Song Ngan', 'Nu', TO_DATE('2013-9-7','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000328', 7973, 1328, 'Nhan vien', 'QL017', 1, '123')
#  into GOD.NHANVIEN values('NV329', 'Ho Van Tuan', 'Nam', TO_DATE('2017-7-15','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000329', 8487, 1125, 'Nhan vien', 'QL018', 2, '123')
#  into GOD.NHANVIEN values('NV330', 'Ung Gia Viet', 'Nam', TO_DATE('2021-6-26','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000330', 6004, 1302, 'Nhan vien', 'QL019', 3, '123')
#  into GOD.NHANVIEN values('NV331', 'Lai Chi Chung', 'Nu', TO_DATE('2015-11-7','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000331', 6559, 1220, 'Nhan vien', 'QL020', 4, '123')
#  into GOD.NHANVIEN values('NV332', 'Vu Thi Tien', 'Nam', TO_DATE('2002-9-11','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000332', 3360, 1503, 'Nhan vien', 'QL021', 5, '123')
#  into GOD.NHANVIEN values('NV333', 'Lai Van Đan', 'Nu', TO_DATE('2021-6-12','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000333', 8820, 1788, 'Nhan vien', 'QL022', 6, '123')
#  into GOD.NHANVIEN values('NV334', 'Đang Tung Đan', 'Nam', TO_DATE('2013-1-10','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000334', 7337, 1272, 'Nhan vien', 'QL023', 7, '123')
#  into GOD.NHANVIEN values('NV335', 'An Chi Đang', 'Nam', TO_DATE('2001-5-25','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000335', 1261, 1361, 'Nhan vien', 'QL024', 8, '123')
#  into GOD.NHANVIEN values('NV336', 'Vo Gia Duy', 'Nu', TO_DATE('2012-12-27','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000336', 9021, 1698, 'Nhan vien', 'QL025', 1, '123')
#  into GOD.NHANVIEN values('NV337', 'Tran Tung Cuc', 'Nam', TO_DATE('2020-10-16','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000337', 5700, 1706, 'Nhan vien', 'QL026', 2, '123')
#  into GOD.NHANVIEN values('NV338', 'Le Hoang Chung', 'Nu', TO_DATE('2021-7-3','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000338', 5174, 1909, 'Nhan vien', 'QL027', 3, '123')
#  into GOD.NHANVIEN values('NV339', 'Gian Hoang Ngan', 'Nu', TO_DATE('2005-5-9','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000339', 7206, 1425, 'Nhan vien', 'QL028', 4, '123')
#  into GOD.NHANVIEN values('NV340', 'Đoan Van Tu', 'Nu', TO_DATE('2018-8-22','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000340', 8198, 1177, 'Nhan vien', 'QL029', 5, '123')
#  into GOD.NHANVIEN values('NV341', 'Vu Gia Thuong', 'Nam', TO_DATE('2000-5-5','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000341', 3675, 1728, 'Nhan vien', 'QL030', 6, '123')
#  into GOD.NHANVIEN values('NV342', 'Đang Thi Chi', 'Nu', TO_DATE('2001-11-26','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000342', 2029, 1217, 'Nhan vien', 'QL031', 7, '123')
#  into GOD.NHANVIEN values('NV343', 'Vu Hoang Vy', 'Nam', TO_DATE('2018-7-16','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000343', 9383, 1015, 'Nhan vien', 'QL032', 8, '123')
#  into GOD.NHANVIEN values('NV344', 'Duong Gia Đan', 'Nu', TO_DATE('2005-8-3','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000344', 3994, 1709, 'Nhan vien', 'QL033', 1, '123')
#  into GOD.NHANVIEN values('NV345', 'Ho Tung Tu', 'Nam', TO_DATE('2011-4-14','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000345', 3088, 1776, 'Nhan vien', 'QL034', 2, '123')
#  into GOD.NHANVIEN values('NV346', 'Ho Van An', 'Nam', TO_DATE('2004-2-18','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000346', 3660, 1103, 'Nhan vien', 'QL035', 3, '123')

# %%
KV = ['Quan 1', 'Quan 2', 'Quan 3','Quan 4','Quan 5','Quan 6','Quan 7','Quan 8','Quan 9','Quan 10','Quan 11','Quan 12','Quan 13', 'Quan Bình Thạnh', 'Quan Tân Bình', 'Hóoc Môn']

# %% [markdown]
# ## Phong Ban

# %%
'''
PhongBan (
	MaPB 	number primary key,
	TenPB 	varchar2(60) not null,
	TrPHG 	varchar(10)
	
)	
'''


for i in range(1, 9):
    final = str(i) + ', ' + '\'Phong ' + str(i) + '\', NULL' 
    print('into GOD.PHONGBAN values(' +  final + ')')
# Out:
# into GOD.PHONGBAN values(1, 'Phong 1', NULL)
# into GOD.PHONGBAN values(2, 'Phong 2', NULL)
# into GOD.PHONGBAN values(3, 'Phong 3', NULL)
# into GOD.PHONGBAN values(4, 'Phong 4', NULL)
# into GOD.PHONGBAN values(5, 'Phong 5', NULL)
# into GOD.PHONGBAN values(6, 'Phong 6', NULL)
# into GOD.PHONGBAN values(7, 'Phong 7', NULL)
# into GOD.PHONGBAN values(8, 'Phong 8', NULL)

# %%
for i in range(1, 9):
    print( ' UPDATE GOD.PHONGBAN set TrPHG = ' + '\'TP0'+ str(i+ 38) + '\'' + ' WHERE ' +  'MaPB = ' + str(i)+ ';')
# Out:
#  UPDATE GOD.PHONGBAN set TrPHG = 'TP039' WHERE MaPB = 1;
#  UPDATE GOD.PHONGBAN set TrPHG = 'TP040' WHERE MaPB = 2;
#  UPDATE GOD.PHONGBAN set TrPHG = 'TP041' WHERE MaPB = 3;
#  UPDATE GOD.PHONGBAN set TrPHG = 'TP042' WHERE MaPB = 4;
#  UPDATE GOD.PHONGBAN set TrPHG = 'TP043' WHERE MaPB = 5;
#  UPDATE GOD.PHONGBAN set TrPHG = 'TP044' WHERE MaPB = 6;
#  UPDATE GOD.PHONGBAN set TrPHG = 'TP045' WHERE MaPB = 7;
#  UPDATE GOD.PHONGBAN set TrPHG = 'TP046' WHERE MaPB = 8;

# %% [markdown]
# # DE AN

# %%
'''
DeAn (
	MaDA 		varchar(10) primary key,
	TenDA 	varchar2(60) not null,
	NgayBD 	date,
	Phong 	number,
    TruongDeAn varchar(10)
	
)
'''
l = []
for i in range(1, 9):
    for j in range(1, rd.randint(3, 5)):
        MaDA = '\'DA' + str(i) + '0' + str(j) + '\'';
        l.append(MaDA);

        TenDA = '\'De An so ' + str(j) + ' Phong ' + str(i) + '\'';
        NgayBD  = 'TO_DATE(' + '\'' + str(rd.randint(2020, 2022)) + '-' + str(rd.randint(1, 12)) + '-' + str(rd.randint(1, 28)) + '\',\'YYYY-MM-DD\')'
        Phong = str(i)
        TruongDA = 'TDA0' + str(rd.randint(36, 38))
        final = MaDA + ', ' + TenDA + ', ' + NgayBD + ', ' + Phong + ', ' + '\'' +  TruongDA + '\''
        print('into GOD.DEAN values(' +  final + ')')
# Out:
# into GOD.DEAN values('DA101', 'De An so 1 Phong 1', TO_DATE('2020-12-24','YYYY-MM-DD'), 1, 'TDA038')
# into GOD.DEAN values('DA102', 'De An so 2 Phong 1', TO_DATE('2022-11-25','YYYY-MM-DD'), 1, 'TDA038')
# into GOD.DEAN values('DA103', 'De An so 3 Phong 1', TO_DATE('2020-6-14','YYYY-MM-DD'), 1, 'TDA036')
# into GOD.DEAN values('DA104', 'De An so 4 Phong 1', TO_DATE('2022-5-24','YYYY-MM-DD'), 1, 'TDA038')
# into GOD.DEAN values('DA201', 'De An so 1 Phong 2', TO_DATE('2022-2-15','YYYY-MM-DD'), 2, 'TDA037')
# into GOD.DEAN values('DA202', 'De An so 2 Phong 2', TO_DATE('2020-7-12','YYYY-MM-DD'), 2, 'TDA036')
# into GOD.DEAN values('DA301', 'De An so 1 Phong 3', TO_DATE('2021-12-16','YYYY-MM-DD'), 3, 'TDA038')
# into GOD.DEAN values('DA302', 'De An so 2 Phong 3', TO_DATE('2022-4-27','YYYY-MM-DD'), 3, 'TDA036')
# into GOD.DEAN values('DA401', 'De An so 1 Phong 4', TO_DATE('2022-5-28','YYYY-MM-DD'), 4, 'TDA037')
# into GOD.DEAN values('DA402', 'De An so 2 Phong 4', TO_DATE('2020-2-15','YYYY-MM-DD'), 4, 'TDA038')
# into GOD.DEAN values('DA403', 'De An so 3 Phong 4', TO_DATE('2020-10-26','YYYY-MM-DD'), 4, 'TDA038')
# into GOD.DEAN values('DA404', 'De An so 4 Phong 4', TO_DATE('2020-9-23','YYYY-MM-DD'), 4, 'TDA038')
# into GOD.DEAN values('DA501', 'De An so 1 Phong 5', TO_DATE('2022-12-14','YYYY-MM-DD'), 5, 'TDA037')
# into GOD.DEAN values('DA502', 'De An so 2 Phong 5', TO_DATE('2021-7-11','YYYY-MM-DD'), 5, 'TDA037')
# into GOD.DEAN values('DA601', 'De An so 1 Phong 6', TO_DATE('2021-6-23','YYYY-MM-DD'), 6, 'TDA037')
# into GOD.DEAN values('DA602', 'De An so 2 Phong 6', TO_DATE('2021-12-7','YYYY-MM-DD'), 6, 'TDA038')
# into GOD.DEAN values('DA603', 'De An so 3 Phong 6', TO_DATE('2021-3-10','YYYY-MM-DD'), 6, 'TDA037')
# into GOD.DEAN values('DA604', 'De An so 4 Phong 6', TO_DATE('2022-6-22','YYYY-MM-DD'), 6, 'TDA036')
# into GOD.DEAN values('DA701', 'De An so 1 Phong 7', TO_DATE('2022-5-22','YYYY-MM-DD'), 7, 'TDA038')
# into GOD.DEAN values('DA702', 'De An so 2 Phong 7', TO_DATE('2022-3-12','YYYY-MM-DD'), 7, 'TDA036')
# into GOD.DEAN values('DA801', 'De An so 1 Phong 8', TO_DATE('2020-4-25','YYYY-MM-DD'), 8, 'TDA038')
# into GOD.DEAN values('DA802', 'De An so 2 Phong 8', TO_DATE('2020-8-23','YYYY-MM-DD'), 8, 'TDA036')
# into GOD.DEAN values('DA803', 'De An so 3 Phong 8', TO_DATE('2021-10-17','YYYY-MM-DD'), 8, 'TDA038')

# %% [markdown]
# ## Phan Cong

# %%
'''
	PhanCong (
	MaNV 		varchar(10) primary key,
	MaDA 		varchar(10) primary key,
	ThoiGian 	date
	
)

'''
import numpy as np
for i in range(47, 347, 3):
    MaNV = '\'NV'+ str(i) + '\''
    for j in range(1, rd.randint(2, 3)):
        MaDA = '\'DA' + str(i%8 + 1) + '0' + str(j) + '\'';
        TG  = 'TO_DATE(' + '\'' + str(rd.randint(2020, 2022)) + '-' + str(rd.randint(1, 12)) + '-' + str(rd.randint(1, 28)) + '\',\'YYYY-MM-DD\')'
        final = MaNV + ', ' + MaDA + ', ' + TG  
        print('into PHANCONG values(' +  final + ')')
# Out:
# into PHANCONG values('NV47', 'DA801', TO_DATE('2022-12-6','YYYY-MM-DD'))
# into PHANCONG values('NV50', 'DA301', TO_DATE('2020-7-8','YYYY-MM-DD'))
# into PHANCONG values('NV50', 'DA302', TO_DATE('2021-5-10','YYYY-MM-DD'))
# into PHANCONG values('NV53', 'DA601', TO_DATE('2022-7-2','YYYY-MM-DD'))
# into PHANCONG values('NV56', 'DA101', TO_DATE('2021-1-23','YYYY-MM-DD'))
# into PHANCONG values('NV59', 'DA401', TO_DATE('2022-9-8','YYYY-MM-DD'))
# into PHANCONG values('NV59', 'DA402', TO_DATE('2020-8-4','YYYY-MM-DD'))
# into PHANCONG values('NV62', 'DA701', TO_DATE('2020-2-21','YYYY-MM-DD'))
# into PHANCONG values('NV62', 'DA702', TO_DATE('2021-4-26','YYYY-MM-DD'))
# into PHANCONG values('NV65', 'DA201', TO_DATE('2021-4-5','YYYY-MM-DD'))
# into PHANCONG values('NV65', 'DA202', TO_DATE('2021-6-3','YYYY-MM-DD'))
# into PHANCONG values('NV68', 'DA501', TO_DATE('2021-12-22','YYYY-MM-DD'))
# into PHANCONG values('NV68', 'DA502', TO_DATE('2022-12-26','YYYY-MM-DD'))
# into PHANCONG values('NV71', 'DA801', TO_DATE('2022-2-14','YYYY-MM-DD'))
# into PHANCONG values('NV74', 'DA301', TO_DATE('2021-6-21','YYYY-MM-DD'))
# into PHANCONG values('NV74', 'DA302', TO_DATE('2021-3-6','YYYY-MM-DD'))
# into PHANCONG values('NV77', 'DA601', TO_DATE('2020-6-25','YYYY-MM-DD'))
# into PHANCONG values('NV77', 'DA602', TO_DATE('2021-12-19','YYYY-MM-DD'))
# into PHANCONG values('NV80', 'DA101', TO_DATE('2021-8-9','YYYY-MM-DD'))
# into PHANCONG values('NV83', 'DA401', TO_DATE('2021-9-22','YYYY-MM-DD'))
# into PHANCONG values('NV83', 'DA402', TO_DATE('2022-9-22','YYYY-MM-DD'))
# into PHANCONG values('NV86', 'DA701', TO_DATE('2022-10-16','YYYY-MM-DD'))
# into PHANCONG values('NV86', 'DA702', TO_DATE('2020-11-17','YYYY-MM-DD'))
# into PHANCONG values('NV89', 'DA201', TO_DATE('2022-7-9','YYYY-MM-DD'))
# into PHANCONG values('NV92', 'DA501', TO_DATE('2021-9-11','YYYY-MM-DD'))
# into PHANCONG values('NV95', 'DA801', TO_DATE('2020-3-16','YYYY-MM-DD'))
# into PHANCONG values('NV95', 'DA802', TO_DATE('2021-7-12','YYYY-MM-DD'))
# into PHANCONG values('NV98', 'DA301', TO_DATE('2022-3-7','YYYY-MM-DD'))
# into PHANCONG values('NV98', 'DA302', TO_DATE('2021-7-8','YYYY-MM-DD'))
# into PHANCONG values('NV101', 'DA601', TO_DATE('2021-9-1','YYYY-MM-DD'))
# into PHANCONG values('NV101', 'DA602', TO_DATE('2020-10-10','YYYY-MM-DD'))
# into PHANCONG values('NV104', 'DA101', TO_DATE('2020-1-26','YYYY-MM-DD'))
# into PHANCONG values('NV104', 'DA102', TO_DATE('2020-6-13','YYYY-MM-DD'))
# into PHANCONG values('NV107', 'DA401', TO_DATE('2020-2-14','YYYY-MM-DD'))
# into PHANCONG values('NV107', 'DA402', TO_DATE('2020-7-8','YYYY-MM-DD'))
# into PHANCONG values('NV110', 'DA701', TO_DATE('2022-10-17','YYYY-MM-DD'))
# into PHANCONG values('NV113', 'DA201', TO_DATE('2022-3-9','YYYY-MM-DD'))
# into PHANCONG values('NV113', 'DA202', TO_DATE('2022-1-20','YYYY-MM-DD'))
# into PHANCONG values('NV116', 'DA501', TO_DATE('2022-2-17','YYYY-MM-DD'))
# into PHANCONG values('NV119', 'DA801', TO_DATE('2022-4-14','YYYY-MM-DD'))
# into PHANCONG values('NV122', 'DA301', TO_DATE('2020-12-20','YYYY-MM-DD'))
# into PHANCONG values('NV125', 'DA601', TO_DATE('2020-4-3','YYYY-MM-DD'))
# into PHANCONG values('NV128', 'DA101', TO_DATE('2021-3-27','YYYY-MM-DD'))
# into PHANCONG values('NV128', 'DA102', TO_DATE('2022-2-14','YYYY-MM-DD'))
# into PHANCONG values('NV131', 'DA401', TO_DATE('2021-5-11','YYYY-MM-DD'))
# into PHANCONG values('NV131', 'DA402', TO_DATE('2020-6-18','YYYY-MM-DD'))
# into PHANCONG values('NV134', 'DA701', TO_DATE('2021-8-27','YYYY-MM-DD'))
# into PHANCONG values('NV134', 'DA702', TO_DATE('2022-11-26','YYYY-MM-DD'))
# into PHANCONG values('NV137', 'DA201', TO_DATE('2020-2-14','YYYY-MM-DD'))
# into PHANCONG values('NV137', 'DA202', TO_DATE('2021-12-1','YYYY-MM-DD'))
# into PHANCONG values('NV140', 'DA501', TO_DATE('2021-5-15','YYYY-MM-DD'))
# into PHANCONG values('NV143', 'DA801', TO_DATE('2021-8-28','YYYY-MM-DD'))
# into PHANCONG values('NV143', 'DA802', TO_DATE('2020-11-6','YYYY-MM-DD'))
# into PHANCONG values('NV146', 'DA301', TO_DATE('2020-7-26','YYYY-MM-DD'))
# into PHANCONG values('NV149', 'DA601', TO_DATE('2021-9-2','YYYY-MM-DD'))
# into PHANCONG values('NV152', 'DA101', TO_DATE('2022-1-15','YYYY-MM-DD'))
# into PHANCONG values('NV152', 'DA102', TO_DATE('2020-11-18','YYYY-MM-DD'))
# into PHANCONG values('NV155', 'DA401', TO_DATE('2021-6-3','YYYY-MM-DD'))
# into PHANCONG values('NV158', 'DA701', TO_DATE('2020-1-4','YYYY-MM-DD'))
# into PHANCONG values('NV158', 'DA702', TO_DATE('2021-3-21','YYYY-MM-DD'))
# into PHANCONG values('NV161', 'DA201', TO_DATE('2020-2-24','YYYY-MM-DD'))
# into PHANCONG values('NV161', 'DA202', TO_DATE('2020-5-9','YYYY-MM-DD'))
# into PHANCONG values('NV164', 'DA501', TO_DATE('2021-1-12','YYYY-MM-DD'))
# into PHANCONG values('NV167', 'DA801', TO_DATE('2022-1-10','YYYY-MM-DD'))
# into PHANCONG values('NV170', 'DA301', TO_DATE('2020-2-27','YYYY-MM-DD'))
# into PHANCONG values('NV173', 'DA601', TO_DATE('2020-6-14','YYYY-MM-DD'))
# into PHANCONG values('NV173', 'DA602', TO_DATE('2020-5-2','YYYY-MM-DD'))
# into PHANCONG values('NV176', 'DA101', TO_DATE('2022-6-10','YYYY-MM-DD'))
# into PHANCONG values('NV179', 'DA401', TO_DATE('2021-11-25','YYYY-MM-DD'))
# into PHANCONG values('NV179', 'DA402', TO_DATE('2022-2-22','YYYY-MM-DD'))
# into PHANCONG values('NV182', 'DA701', TO_DATE('2020-6-24','YYYY-MM-DD'))
# into PHANCONG values('NV182', 'DA702', TO_DATE('2021-11-25','YYYY-MM-DD'))
# into PHANCONG values('NV185', 'DA201', TO_DATE('2022-11-3','YYYY-MM-DD'))
# into PHANCONG values('NV188', 'DA501', TO_DATE('2020-5-18','YYYY-MM-DD'))
# into PHANCONG values('NV188', 'DA502', TO_DATE('2022-10-4','YYYY-MM-DD'))
# into PHANCONG values('NV191', 'DA801', TO_DATE('2020-11-9','YYYY-MM-DD'))
# into PHANCONG values('NV194', 'DA301', TO_DATE('2022-6-25','YYYY-MM-DD'))
# into PHANCONG values('NV194', 'DA302', TO_DATE('2020-5-5','YYYY-MM-DD'))
# into PHANCONG values('NV197', 'DA601', TO_DATE('2021-2-2','YYYY-MM-DD'))
# into PHANCONG values('NV200', 'DA101', TO_DATE('2021-4-24','YYYY-MM-DD'))
# into PHANCONG values('NV203', 'DA401', TO_DATE('2021-6-20','YYYY-MM-DD'))
# into PHANCONG values('NV206', 'DA701', TO_DATE('2022-6-2','YYYY-MM-DD'))
# into PHANCONG values('NV209', 'DA201', TO_DATE('2020-6-18','YYYY-MM-DD'))
# into PHANCONG values('NV212', 'DA501', TO_DATE('2022-1-12','YYYY-MM-DD'))
# into PHANCONG values('NV212', 'DA502', TO_DATE('2021-2-4','YYYY-MM-DD'))
# into PHANCONG values('NV215', 'DA801', TO_DATE('2021-6-15','YYYY-MM-DD'))
# into PHANCONG values('NV218', 'DA301', TO_DATE('2020-10-11','YYYY-MM-DD'))
# into PHANCONG values('NV221', 'DA601', TO_DATE('2020-11-14','YYYY-MM-DD'))
# into PHANCONG values('NV221', 'DA602', TO_DATE('2020-1-4','YYYY-MM-DD'))
# into PHANCONG values('NV224', 'DA101', TO_DATE('2020-2-6','YYYY-MM-DD'))
# into PHANCONG values('NV224', 'DA102', TO_DATE('2022-6-26','YYYY-MM-DD'))
# into PHANCONG values('NV227', 'DA401', TO_DATE('2021-12-7','YYYY-MM-DD'))
# into PHANCONG values('NV230', 'DA701', TO_DATE('2020-8-27','YYYY-MM-DD'))
# into PHANCONG values('NV230', 'DA702', TO_DATE('2022-11-4','YYYY-MM-DD'))
# into PHANCONG values('NV233', 'DA201', TO_DATE('2022-5-13','YYYY-MM-DD'))
# into PHANCONG values('NV236', 'DA501', TO_DATE('2022-11-25','YYYY-MM-DD'))
# into PHANCONG values('NV239', 'DA801', TO_DATE('2020-2-5','YYYY-MM-DD'))
# into PHANCONG values('NV239', 'DA802', TO_DATE('2021-1-13','YYYY-MM-DD'))
# into PHANCONG values('NV242', 'DA301', TO_DATE('2020-9-7','YYYY-MM-DD'))
# into PHANCONG values('NV242', 'DA302', TO_DATE('2020-1-19','YYYY-MM-DD'))
# into PHANCONG values('NV245', 'DA601', TO_DATE('2022-4-8','YYYY-MM-DD'))
# into PHANCONG values('NV245', 'DA602', TO_DATE('2022-10-9','YYYY-MM-DD'))
# into PHANCONG values('NV248', 'DA101', TO_DATE('2020-3-9','YYYY-MM-DD'))
# into PHANCONG values('NV251', 'DA401', TO_DATE('2021-5-1','YYYY-MM-DD'))
# into PHANCONG values('NV251', 'DA402', TO_DATE('2021-6-27','YYYY-MM-DD'))
# into PHANCONG values('NV254', 'DA701', TO_DATE('2022-7-12','YYYY-MM-DD'))
# into PHANCONG values('NV254', 'DA702', TO_DATE('2022-7-7','YYYY-MM-DD'))
# into PHANCONG values('NV257', 'DA201', TO_DATE('2022-4-18','YYYY-MM-DD'))
# into PHANCONG values('NV260', 'DA501', TO_DATE('2021-5-13','YYYY-MM-DD'))
# into PHANCONG values('NV260', 'DA502', TO_DATE('2022-9-14','YYYY-MM-DD'))
# into PHANCONG values('NV263', 'DA801', TO_DATE('2020-4-17','YYYY-MM-DD'))
# into PHANCONG values('NV266', 'DA301', TO_DATE('2022-5-22','YYYY-MM-DD'))
# into PHANCONG values('NV269', 'DA601', TO_DATE('2020-1-17','YYYY-MM-DD'))
# into PHANCONG values('NV272', 'DA101', TO_DATE('2020-5-3','YYYY-MM-DD'))
# into PHANCONG values('NV272', 'DA102', TO_DATE('2021-5-12','YYYY-MM-DD'))
# into PHANCONG values('NV275', 'DA401', TO_DATE('2021-1-21','YYYY-MM-DD'))
# into PHANCONG values('NV278', 'DA701', TO_DATE('2020-1-16','YYYY-MM-DD'))
# into PHANCONG values('NV281', 'DA201', TO_DATE('2020-4-24','YYYY-MM-DD'))
# into PHANCONG values('NV284', 'DA501', TO_DATE('2021-4-15','YYYY-MM-DD'))
# into PHANCONG values('NV284', 'DA502', TO_DATE('2021-3-14','YYYY-MM-DD'))
# into PHANCONG values('NV287', 'DA801', TO_DATE('2020-7-2','YYYY-MM-DD'))
# into PHANCONG values('NV287', 'DA802', TO_DATE('2021-8-21','YYYY-MM-DD'))
# into PHANCONG values('NV290', 'DA301', TO_DATE('2021-8-15','YYYY-MM-DD'))
# into PHANCONG values('NV293', 'DA601', TO_DATE('2022-8-19','YYYY-MM-DD'))
# into PHANCONG values('NV293', 'DA602', TO_DATE('2022-4-11','YYYY-MM-DD'))
# into PHANCONG values('NV296', 'DA101', TO_DATE('2020-12-25','YYYY-MM-DD'))
# into PHANCONG values('NV299', 'DA401', TO_DATE('2020-6-24','YYYY-MM-DD'))
# into PHANCONG values('NV299', 'DA402', TO_DATE('2020-10-4','YYYY-MM-DD'))
# into PHANCONG values('NV302', 'DA701', TO_DATE('2020-2-16','YYYY-MM-DD'))
# into PHANCONG values('NV305', 'DA201', TO_DATE('2021-4-6','YYYY-MM-DD'))
# into PHANCONG values('NV308', 'DA501', TO_DATE('2022-4-23','YYYY-MM-DD'))
# into PHANCONG values('NV308', 'DA502', TO_DATE('2021-3-27','YYYY-MM-DD'))
# into PHANCONG values('NV311', 'DA801', TO_DATE('2020-2-5','YYYY-MM-DD'))
# into PHANCONG values('NV314', 'DA301', TO_DATE('2020-8-13','YYYY-MM-DD'))
# into PHANCONG values('NV317', 'DA601', TO_DATE('2022-9-28','YYYY-MM-DD'))
# into PHANCONG values('NV320', 'DA101', TO_DATE('2022-6-11','YYYY-MM-DD'))
# into PHANCONG values('NV320', 'DA102', TO_DATE('2021-9-20','YYYY-MM-DD'))
# into PHANCONG values('NV323', 'DA401', TO_DATE('2022-10-3','YYYY-MM-DD'))
# into PHANCONG values('NV326', 'DA701', TO_DATE('2022-6-25','YYYY-MM-DD'))
# into PHANCONG values('NV329', 'DA201', TO_DATE('2020-8-26','YYYY-MM-DD'))
# into PHANCONG values('NV332', 'DA501', TO_DATE('2021-7-13','YYYY-MM-DD'))
# into PHANCONG values('NV332', 'DA502', TO_DATE('2022-10-15','YYYY-MM-DD'))
# into PHANCONG values('NV335', 'DA801', TO_DATE('2021-8-28','YYYY-MM-DD'))
# into PHANCONG values('NV335', 'DA802', TO_DATE('2021-11-8','YYYY-MM-DD'))
# into PHANCONG values('NV338', 'DA301', TO_DATE('2022-3-10','YYYY-MM-DD'))
# into PHANCONG values('NV341', 'DA601', TO_DATE('2021-10-2','YYYY-MM-DD'))
# into PHANCONG values('NV341', 'DA602', TO_DATE('2020-12-13','YYYY-MM-DD'))
# into PHANCONG values('NV344', 'DA101', TO_DATE('2021-3-25','YYYY-MM-DD'))

# %% [markdown]
# # Tai khoan

# %%
'''
tai khoan:
    username varchar(50),
    password varchar(150)
'''
import random
import string

username = ''
password = ''
for i in range(1, 347):
    if i < 6:
        username = '\'UserGD00'+ str(i) + '\''

    elif i < 11:
        username = '\'UserTC0'+ str(i) + '\''

    elif i < 16:
        username = '\'UserNS0'+ str(i) + '\''

    elif i < 36:
        username = '\'UserQL0'+ str(i) + '\''

    elif i < 39:
        username = '\'UserTDA0'+ str(i) + '\''
    elif i < 47:
        username = '\'UserTP0'+ str(i) + '\''

    else:
        username = '\'UserNV'+ str(i) + '\''
        
    
    # pass random mac dinh 10 char
    password = '123'
    print (f'INTO GOD.TAIKHOAN VALUES({username}, \'{password}\')')
# Out:
# INTO GOD.TAIKHOAN VALUES('UserGD001', '123')
# INTO GOD.TAIKHOAN VALUES('UserGD002', '123')
# INTO GOD.TAIKHOAN VALUES('UserGD003', '123')
# INTO GOD.TAIKHOAN VALUES('UserGD004', '123')
# INTO GOD.TAIKHOAN VALUES('UserGD005', '123')
# INTO GOD.TAIKHOAN VALUES('UserTC06', '123')
# INTO GOD.TAIKHOAN VALUES('UserTC07', '123')
# INTO GOD.TAIKHOAN VALUES('UserTC08', '123')
# INTO GOD.TAIKHOAN VALUES('UserTC09', '123')
# INTO GOD.TAIKHOAN VALUES('UserTC010', '123')
# INTO GOD.TAIKHOAN VALUES('UserNS011', '123')
# INTO GOD.TAIKHOAN VALUES('UserNS012', '123')
# INTO GOD.TAIKHOAN VALUES('UserNS013', '123')
# INTO GOD.TAIKHOAN VALUES('UserNS014', '123')
# INTO GOD.TAIKHOAN VALUES('UserNS015', '123')
# INTO GOD.TAIKHOAN VALUES('UserQL016', '123')
# INTO GOD.TAIKHOAN VALUES('UserQL017', '123')
# INTO GOD.TAIKHOAN VALUES('UserQL018', '123')
# INTO GOD.TAIKHOAN VALUES('UserQL019', '123')
# INTO GOD.TAIKHOAN VALUES('UserQL020', '123')
# INTO GOD.TAIKHOAN VALUES('UserQL021', '123')
# INTO GOD.TAIKHOAN VALUES('UserQL022', '123')
# INTO GOD.TAIKHOAN VALUES('UserQL023', '123')
# INTO GOD.TAIKHOAN VALUES('UserQL024', '123')
# INTO GOD.TAIKHOAN VALUES('UserQL025', '123')
# INTO GOD.TAIKHOAN VALUES('UserQL026', '123')
# INTO GOD.TAIKHOAN VALUES('UserQL027', '123')
# INTO GOD.TAIKHOAN VALUES('UserQL028', '123')
# INTO GOD.TAIKHOAN VALUES('UserQL029', '123')
# INTO GOD.TAIKHOAN VALUES('UserQL030', '123')
# INTO GOD.TAIKHOAN VALUES('UserQL031', '123')
# INTO GOD.TAIKHOAN VALUES('UserQL032', '123')
# INTO GOD.TAIKHOAN VALUES('UserQL033', '123')
# INTO GOD.TAIKHOAN VALUES('UserQL034', '123')
# INTO GOD.TAIKHOAN VALUES('UserQL035', '123')
# INTO GOD.TAIKHOAN VALUES('UserTDA036', '123')
# INTO GOD.TAIKHOAN VALUES('UserTDA037', '123')
# INTO GOD.TAIKHOAN VALUES('UserTDA038', '123')
# INTO GOD.TAIKHOAN VALUES('UserTP039', '123')
# INTO GOD.TAIKHOAN VALUES('UserTP040', '123')
# INTO GOD.TAIKHOAN VALUES('UserTP041', '123')
# INTO GOD.TAIKHOAN VALUES('UserTP042', '123')
# INTO GOD.TAIKHOAN VALUES('UserTP043', '123')
# INTO GOD.TAIKHOAN VALUES('UserTP044', '123')
# INTO GOD.TAIKHOAN VALUES('UserTP045', '123')
# INTO GOD.TAIKHOAN VALUES('UserTP046', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV47', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV48', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV49', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV50', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV51', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV52', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV53', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV54', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV55', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV56', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV57', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV58', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV59', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV60', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV61', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV62', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV63', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV64', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV65', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV66', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV67', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV68', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV69', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV70', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV71', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV72', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV73', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV74', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV75', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV76', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV77', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV78', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV79', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV80', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV81', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV82', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV83', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV84', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV85', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV86', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV87', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV88', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV89', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV90', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV91', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV92', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV93', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV94', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV95', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV96', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV97', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV98', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV99', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV100', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV101', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV102', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV103', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV104', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV105', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV106', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV107', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV108', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV109', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV110', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV111', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV112', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV113', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV114', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV115', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV116', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV117', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV118', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV119', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV120', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV121', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV122', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV123', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV124', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV125', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV126', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV127', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV128', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV129', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV130', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV131', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV132', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV133', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV134', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV135', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV136', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV137', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV138', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV139', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV140', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV141', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV142', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV143', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV144', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV145', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV146', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV147', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV148', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV149', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV150', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV151', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV152', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV153', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV154', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV155', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV156', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV157', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV158', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV159', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV160', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV161', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV162', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV163', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV164', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV165', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV166', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV167', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV168', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV169', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV170', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV171', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV172', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV173', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV174', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV175', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV176', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV177', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV178', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV179', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV180', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV181', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV182', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV183', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV184', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV185', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV186', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV187', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV188', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV189', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV190', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV191', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV192', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV193', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV194', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV195', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV196', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV197', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV198', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV199', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV200', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV201', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV202', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV203', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV204', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV205', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV206', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV207', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV208', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV209', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV210', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV211', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV212', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV213', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV214', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV215', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV216', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV217', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV218', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV219', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV220', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV221', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV222', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV223', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV224', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV225', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV226', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV227', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV228', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV229', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV230', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV231', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV232', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV233', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV234', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV235', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV236', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV237', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV238', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV239', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV240', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV241', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV242', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV243', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV244', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV245', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV246', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV247', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV248', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV249', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV250', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV251', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV252', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV253', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV254', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV255', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV256', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV257', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV258', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV259', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV260', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV261', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV262', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV263', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV264', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV265', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV266', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV267', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV268', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV269', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV270', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV271', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV272', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV273', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV274', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV275', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV276', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV277', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV278', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV279', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV280', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV281', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV282', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV283', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV284', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV285', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV286', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV287', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV288', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV289', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV290', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV291', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV292', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV293', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV294', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV295', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV296', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV297', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV298', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV299', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV300', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV301', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV302', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV303', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV304', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV305', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV306', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV307', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV308', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV309', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV310', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV311', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV312', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV313', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV314', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV315', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV316', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV317', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV318', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV319', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV320', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV321', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV322', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV323', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV324', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV325', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV326', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV327', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV328', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV329', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV330', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV331', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV332', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV333', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV334', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV335', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV336', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV337', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV338', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV339', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV340', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV341', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV342', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV343', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV344', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV345', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV346', '123')
