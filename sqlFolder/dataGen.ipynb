# %%
import random as rd

insert = "insert into table "

# %%
Ho = [ 'Ho','Bui', 'Đoan', 'Le', 'Nguyen', 'Duong', 'Tran', 'Ly', 'Vu', 'Vo', 'Đang', 'Pham', 'Ung', 'An', 'Au','Truong', 'Lai', 'Gian' ]
tendem = ['Van','Thi','Chi','Gia','Hoang', 'Song', 'Tung' ]
ten = ['Ngoc Nhi','An','Anh','Bac','Bao','Cau','Cuc','Đan','Đang','Đuc','Thong','Tien','Tuan','Tin','Tiep','Viet','Vinh','Vu','Vy','Minh','Giang','khanh','Sang','Duy','Chi','Thuong','Chung','Phu','Quoc','Nam','Ngan','Nguyet','May' 
       ,'Tu','Thien','Tan','Han']

# %%
'''
NhanVien (
	MaNV 		varchar(10) primary key,
	TenNV 	varchar2(60) not null,
	Phai 		varchar2(4),
	NgaySinh 	date,
	DiaChi 	varchar2(100),
	SoDT 		varchar(10) not null unique,
	Luong 	number,
	PhuCap 	number,
	VaiTro 	varchar2(50),
	MaNQL 	varchar(10),
	PHG 		number
	
)
go
'''
'''
Nhân viên - 300
Quản lí - 20
Trưởng phòng - 8
Tài chính - 5
Nhân sự - 5
Trưởng đề án - 3
Ban giám đốc - 5
'''
sex = ['Nam', 'Nu']
import string

username = ''
MaNV = ''
TenNV = ''
Phai = ''
NgaySinh = ''
DiaChi 	= ''
SoDT 	= ''
Luong 	= 0
PhuCap 	= 0
VaiTro 	= ''
MaNQL 	= 'NULL'
PHG 	= 0
for i in range(1, 347):
    Luong = rd.randint(1000, 9999)
    PhuCap = rd.randint(1000, 2000)
    PHG = i % 8 + 1
    if i < 6:
        MaNV = '\'GD00'+ str(i) + '\''
        VaiTro 	= '\'Ban giam doc\''
        Luong = 55555
    elif i < 11:
        MaNV = '\'TC0'+ str(i) + '\''
        VaiTro 	= '\'Tai chinh\''
        Luong = 11000
    elif i < 16:
        MaNV = '\'NS0'+ str(i) + '\''
        VaiTro 	= '\'Nhan su\''
        Luong = 13000
    elif i < 36:
        MaNV = '\'QL0'+ str(i) + '\''
        VaiTro 	= '\'Quan li\''
        Luong = 25000
    elif i < 39:
        MaNV = '\'TDA0'+ str(i) + '\''
        VaiTro 	= '\'Truong de an\''
        Luong = 20000
    elif i < 47:
        MaNV = '\'TP0'+ str(i) + '\''
        VaiTro 	= '\'Truong phong\''
        Luong = 22000
        PHG = i - 38
    else:
        MaNV = '\'NV'+ str(i) + '\''
        VaiTro 	= '\'Nhan vien\''
        MaNQL = '\'QL0'+ str((i-47)% 20 + 16) + '\'' #16-35
    
    account_suffix = MaNV.replace("'", "")
    username = f'\'User{account_suffix}\''
    

    SoDT = '\'0945000' + str(i) + '\''
    tenD = rd.choice(tendem);
    TenNV = '\'' + rd.choice(Ho) + ' ' + tenD + ' ' + rd.choice(ten) + '\''
    DiaChi = '\'227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh\'' 
    Phai = '\'Nam\''
    if (tenD == 'Thi' or tenD == 'Song'):
        Phai = '\'Nu\''
    NgaySinh  = 'TO_DATE(' + '\'' + str(rd.randint(2000, 2022)) + '-' + str(rd.randint(1, 12)) + '-' + str(rd.randint(1, 28)) + '\',\'YYYY-MM-DD\')'
    
    final = MaNV + ', ' + TenNV + ', ' + Phai + ', ' + NgaySinh + ', ' + DiaChi +', ' + SoDT + ', ' + str(Luong) + ', ' + str(PhuCap) +', '+ VaiTro + ', ' + MaNQL + ', ' + str(PHG) + ', ' + username
    
    print (' into NHANVIEN values(' +  final + ')')
    
   # print('insert into TaiKhoan values(' + TenTaiKhoan + HoTen + str(Mk) + sdt + DiaChi + Email + LoaiTaiKhoan +')')
# Out:
#  into NHANVIEN values('GD001', 'Vu Van Chung', 'Nam', TO_DATE('2016-8-4','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '09450001', 55555, 1569, 'Ban giam doc', NULL, 2, 'UserGD001')
#  into NHANVIEN values('GD002', 'Au Van Thien', 'Nam', TO_DATE('2015-12-8','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '09450002', 55555, 1216, 'Ban giam doc', NULL, 3, 'UserGD002')
#  into NHANVIEN values('GD003', 'Vu Hoang Cuc', 'Nam', TO_DATE('2017-6-9','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '09450003', 55555, 1438, 'Ban giam doc', NULL, 4, 'UserGD003')
#  into NHANVIEN values('GD004', 'Duong Song Cuc', 'Nu', TO_DATE('2002-8-9','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '09450004', 55555, 1532, 'Ban giam doc', NULL, 5, 'UserGD004')
#  into NHANVIEN values('GD005', 'Gian Chi Thong', 'Nam', TO_DATE('2010-10-3','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '09450005', 55555, 1360, 'Ban giam doc', NULL, 6, 'UserGD005')
#  into NHANVIEN values('TC06', 'Ung Tung Quoc', 'Nam', TO_DATE('2018-1-16','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '09450006', 11000, 1828, 'Tai chinh', NULL, 7, 'UserTC06')
#  into NHANVIEN values('TC07', 'An Song May', 'Nu', TO_DATE('2019-12-16','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '09450007', 11000, 1788, 'Tai chinh', NULL, 8, 'UserTC07')
#  into NHANVIEN values('TC08', 'Ho Chi Tin', 'Nam', TO_DATE('2004-7-18','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '09450008', 11000, 1056, 'Tai chinh', NULL, 1, 'UserTC08')
#  into NHANVIEN values('TC09', 'Lai Gia Tuan', 'Nam', TO_DATE('2011-3-17','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '09450009', 11000, 1039, 'Tai chinh', NULL, 2, 'UserTC09')
#  into NHANVIEN values('TC010', 'Tran Gia Minh', 'Nam', TO_DATE('2009-6-6','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500010', 11000, 1699, 'Tai chinh', NULL, 3, 'UserTC010')
#  into NHANVIEN values('NS011', 'Ly Chi Ngan', 'Nam', TO_DATE('2003-11-13','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500011', 13000, 1513, 'Nhan su', NULL, 4, 'UserNS011')
#  into NHANVIEN values('NS012', 'Vu Song Minh', 'Nu', TO_DATE('2014-6-8','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500012', 13000, 1318, 'Nhan su', NULL, 5, 'UserNS012')
#  into NHANVIEN values('NS013', 'Au Chi Tien', 'Nam', TO_DATE('2015-4-7','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500013', 13000, 1763, 'Nhan su', NULL, 6, 'UserNS013')
#  into NHANVIEN values('NS014', 'Duong Chi Phu', 'Nam', TO_DATE('2002-9-20','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500014', 13000, 1921, 'Nhan su', NULL, 7, 'UserNS014')
#  into NHANVIEN values('NS015', 'Bui Van Đang', 'Nam', TO_DATE('2007-3-26','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500015', 13000, 1368, 'Nhan su', NULL, 8, 'UserNS015')
#  into NHANVIEN values('QL016', 'Đang Thi Anh', 'Nu', TO_DATE('2002-7-22','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500016', 25000, 1760, 'Quan li', NULL, 1, 'UserQL016')
#  into NHANVIEN values('QL017', 'Duong Gia Chung', 'Nam', TO_DATE('2002-5-28','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500017', 25000, 1000, 'Quan li', NULL, 2, 'UserQL017')
#  into NHANVIEN values('QL018', 'Truong Gia Nguyet', 'Nam', TO_DATE('2008-2-7','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500018', 25000, 1476, 'Quan li', NULL, 3, 'UserQL018')
#  into NHANVIEN values('QL019', 'Duong Hoang khanh', 'Nam', TO_DATE('2015-3-14','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500019', 25000, 1709, 'Quan li', NULL, 4, 'UserQL019')
#  into NHANVIEN values('QL020', 'Duong Song Tu', 'Nu', TO_DATE('2019-12-17','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500020', 25000, 1053, 'Quan li', NULL, 5, 'UserQL020')
#  into NHANVIEN values('QL021', 'Nguyen Song Viet', 'Nu', TO_DATE('2010-5-1','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500021', 25000, 1322, 'Quan li', NULL, 6, 'UserQL021')
#  into NHANVIEN values('QL022', 'Ung Chi Tuan', 'Nam', TO_DATE('2017-9-5','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500022', 25000, 1877, 'Quan li', NULL, 7, 'UserQL022')
#  into NHANVIEN values('QL023', 'An Van Cuc', 'Nam', TO_DATE('2003-11-24','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500023', 25000, 1608, 'Quan li', NULL, 8, 'UserQL023')
#  into NHANVIEN values('QL024', 'Lai Chi Tien', 'Nam', TO_DATE('2020-5-17','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500024', 25000, 1568, 'Quan li', NULL, 1, 'UserQL024')
#  into NHANVIEN values('QL025', 'Nguyen Tung khanh', 'Nam', TO_DATE('2000-4-24','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500025', 25000, 1475, 'Quan li', NULL, 2, 'UserQL025')
#  into NHANVIEN values('QL026', 'Đoan Song Bao', 'Nu', TO_DATE('2006-3-5','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500026', 25000, 1170, 'Quan li', NULL, 3, 'UserQL026')
#  into NHANVIEN values('QL027', 'Vo Gia Anh', 'Nam', TO_DATE('2012-10-10','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500027', 25000, 1794, 'Quan li', NULL, 4, 'UserQL027')
#  into NHANVIEN values('QL028', 'Duong Chi Chung', 'Nam', TO_DATE('2002-10-28','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500028', 25000, 1490, 'Quan li', NULL, 5, 'UserQL028')
#  into NHANVIEN values('QL029', 'Vo Chi Duy', 'Nam', TO_DATE('2013-11-27','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500029', 25000, 1227, 'Quan li', NULL, 6, 'UserQL029')
#  into NHANVIEN values('QL030', 'Gian Hoang Tien', 'Nam', TO_DATE('2001-6-8','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500030', 25000, 1189, 'Quan li', NULL, 7, 'UserQL030')
#  into NHANVIEN values('QL031', 'Ly Van Vinh', 'Nam', TO_DATE('2001-3-4','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500031', 25000, 1042, 'Quan li', NULL, 8, 'UserQL031')
#  into NHANVIEN values('QL032', 'Ho Hoang Chung', 'Nam', TO_DATE('2022-11-10','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500032', 25000, 1623, 'Quan li', NULL, 1, 'UserQL032')
#  into NHANVIEN values('QL033', 'Bui Song May', 'Nu', TO_DATE('2022-4-26','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500033', 25000, 1892, 'Quan li', NULL, 2, 'UserQL033')
#  into NHANVIEN values('QL034', 'Pham Van Phu', 'Nam', TO_DATE('2014-9-27','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500034', 25000, 1922, 'Quan li', NULL, 3, 'UserQL034')
#  into NHANVIEN values('QL035', 'Đoan Tung Thien', 'Nam', TO_DATE('2003-10-9','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500035', 25000, 1757, 'Quan li', NULL, 4, 'UserQL035')
#  into NHANVIEN values('TDA036', 'Pham Song Phu', 'Nu', TO_DATE('2006-10-23','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500036', 20000, 1072, 'Truong de an', NULL, 5, 'UserTDA036')
#  into NHANVIEN values('TDA037', 'Duong Song Bac', 'Nu', TO_DATE('2018-7-14','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500037', 20000, 1633, 'Truong de an', NULL, 6, 'UserTDA037')
#  into NHANVIEN values('TDA038', 'Le Hoang Viet', 'Nam', TO_DATE('2013-8-2','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500038', 20000, 1343, 'Truong de an', NULL, 7, 'UserTDA038')
#  into NHANVIEN values('TP039', 'Ly Hoang Thien', 'Nam', TO_DATE('2015-2-3','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500039', 22000, 1000, 'Truong phong', NULL, 1, 'UserTP039')
#  into NHANVIEN values('TP040', 'Truong Van Nguyet', 'Nam', TO_DATE('2019-1-27','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500040', 22000, 1537, 'Truong phong', NULL, 2, 'UserTP040')
#  into NHANVIEN values('TP041', 'Đang Gia An', 'Nam', TO_DATE('2005-6-8','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500041', 22000, 1688, 'Truong phong', NULL, 3, 'UserTP041')
#  into NHANVIEN values('TP042', 'Bui Hoang Anh', 'Nam', TO_DATE('2005-12-5','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500042', 22000, 1545, 'Truong phong', NULL, 4, 'UserTP042')
#  into NHANVIEN values('TP043', 'Le Chi Chung', 'Nam', TO_DATE('2017-1-20','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500043', 22000, 1862, 'Truong phong', NULL, 5, 'UserTP043')
#  into NHANVIEN values('TP044', 'Le Thi Duy', 'Nu', TO_DATE('2003-12-25','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500044', 22000, 1281, 'Truong phong', NULL, 6, 'UserTP044')
#  into NHANVIEN values('TP045', 'Gian Thi Tuan', 'Nu', TO_DATE('2004-12-28','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500045', 22000, 1022, 'Truong phong', NULL, 7, 'UserTP045')
#  into NHANVIEN values('TP046', 'Lai Song Tiep', 'Nu', TO_DATE('2016-11-12','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500046', 22000, 1918, 'Truong phong', NULL, 8, 'UserTP046')
#  into NHANVIEN values('NV47', 'Vu Chi Vinh', 'Nam', TO_DATE('2010-10-2','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500047', 3380, 1168, 'Nhan vien', 'QL016', 8, 'UserNV47')
#  into NHANVIEN values('NV48', 'Nguyen Hoang Quoc', 'Nam', TO_DATE('2011-1-2','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500048', 5929, 1930, 'Nhan vien', 'QL017', 1, 'UserNV48')
#  into NHANVIEN values('NV49', 'Truong Van Bao', 'Nam', TO_DATE('2017-9-26','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500049', 6696, 1140, 'Nhan vien', 'QL018', 2, 'UserNV49')
#  into NHANVIEN values('NV50', 'Truong Tung Sang', 'Nam', TO_DATE('2001-10-28','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500050', 9394, 1545, 'Nhan vien', 'QL019', 3, 'UserNV50')
#  into NHANVIEN values('NV51', 'Tran Song Tuan', 'Nu', TO_DATE('2022-12-7','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500051', 8062, 1892, 'Nhan vien', 'QL020', 4, 'UserNV51')
#  into NHANVIEN values('NV52', 'Pham Tung Thong', 'Nam', TO_DATE('2014-6-2','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500052', 2440, 1189, 'Nhan vien', 'QL021', 5, 'UserNV52')
#  into NHANVIEN values('NV53', 'Ung Hoang Phu', 'Nam', TO_DATE('2010-11-27','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500053', 1797, 1303, 'Nhan vien', 'QL022', 6, 'UserNV53')
#  into NHANVIEN values('NV54', 'Ung Gia Đang', 'Nam', TO_DATE('2012-11-25','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500054', 2287, 1106, 'Nhan vien', 'QL023', 7, 'UserNV54')
#  into NHANVIEN values('NV55', 'Ly Hoang Cuc', 'Nam', TO_DATE('2004-2-12','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500055', 7807, 1332, 'Nhan vien', 'QL024', 8, 'UserNV55')
#  into NHANVIEN values('NV56', 'Duong Thi Thuong', 'Nu', TO_DATE('2002-2-10','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500056', 1947, 1119, 'Nhan vien', 'QL025', 1, 'UserNV56')
#  into NHANVIEN values('NV57', 'Đang Hoang Tien', 'Nam', TO_DATE('2014-12-5','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500057', 3175, 1969, 'Nhan vien', 'QL026', 2, 'UserNV57')
#  into NHANVIEN values('NV58', 'Vo Van Vy', 'Nam', TO_DATE('2001-12-11','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500058', 1731, 1801, 'Nhan vien', 'QL027', 3, 'UserNV58')
#  into NHANVIEN values('NV59', 'Vo Hoang Bao', 'Nam', TO_DATE('2020-5-25','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500059', 8898, 1606, 'Nhan vien', 'QL028', 4, 'UserNV59')
#  into NHANVIEN values('NV60', 'Đang Van Ngoc Nhi', 'Nam', TO_DATE('2019-9-21','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500060', 2927, 1861, 'Nhan vien', 'QL029', 5, 'UserNV60')
#  into NHANVIEN values('NV61', 'Tran Tung Sang', 'Nam', TO_DATE('2003-3-18','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500061', 6074, 1444, 'Nhan vien', 'QL030', 6, 'UserNV61')
#  into NHANVIEN values('NV62', 'Ung Tung Quoc', 'Nam', TO_DATE('2010-7-7','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500062', 2001, 1523, 'Nhan vien', 'QL031', 7, 'UserNV62')
#  into NHANVIEN values('NV63', 'Pham Thi Sang', 'Nu', TO_DATE('2003-3-1','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500063', 4323, 1915, 'Nhan vien', 'QL032', 8, 'UserNV63')
#  into NHANVIEN values('NV64', 'Nguyen Song Chung', 'Nu', TO_DATE('2019-7-24','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500064', 5748, 1033, 'Nhan vien', 'QL033', 1, 'UserNV64')
#  into NHANVIEN values('NV65', 'Duong Chi Nam', 'Nam', TO_DATE('2004-11-16','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500065', 4598, 1683, 'Nhan vien', 'QL034', 2, 'UserNV65')
#  into NHANVIEN values('NV66', 'Ung Song Ngoc Nhi', 'Nu', TO_DATE('2003-9-3','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500066', 4714, 1981, 'Nhan vien', 'QL035', 3, 'UserNV66')
#  into NHANVIEN values('NV67', 'Truong Chi Ngoc Nhi', 'Nam', TO_DATE('2003-1-7','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500067', 3428, 1592, 'Nhan vien', 'QL016', 4, 'UserNV67')
#  into NHANVIEN values('NV68', 'Đang Van Chung', 'Nam', TO_DATE('2020-5-6','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500068', 6822, 1436, 'Nhan vien', 'QL017', 5, 'UserNV68')
#  into NHANVIEN values('NV69', 'Vu Gia Nguyet', 'Nam', TO_DATE('2008-7-8','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500069', 8724, 1411, 'Nhan vien', 'QL018', 6, 'UserNV69')
#  into NHANVIEN values('NV70', 'Vo Chi Giang', 'Nam', TO_DATE('2003-12-18','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500070', 2567, 1449, 'Nhan vien', 'QL019', 7, 'UserNV70')
#  into NHANVIEN values('NV71', 'Vu Van Nguyet', 'Nam', TO_DATE('2010-7-5','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500071', 1699, 1878, 'Nhan vien', 'QL020', 8, 'UserNV71')
#  into NHANVIEN values('NV72', 'Gian Tung Ngoc Nhi', 'Nam', TO_DATE('2000-5-7','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500072', 3226, 1297, 'Nhan vien', 'QL021', 1, 'UserNV72')
#  into NHANVIEN values('NV73', 'Truong Song Vy', 'Nu', TO_DATE('2015-7-4','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500073', 6566, 1561, 'Nhan vien', 'QL022', 2, 'UserNV73')
#  into NHANVIEN values('NV74', 'Ung Song Chi', 'Nu', TO_DATE('2003-3-1','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500074', 7832, 1874, 'Nhan vien', 'QL023', 3, 'UserNV74')
#  into NHANVIEN values('NV75', 'Ho Van Vinh', 'Nam', TO_DATE('2015-8-19','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500075', 4615, 1673, 'Nhan vien', 'QL024', 4, 'UserNV75')
#  into NHANVIEN values('NV76', 'Nguyen Hoang Tin', 'Nam', TO_DATE('2018-8-4','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500076', 5410, 1614, 'Nhan vien', 'QL025', 5, 'UserNV76')
#  into NHANVIEN values('NV77', 'Lai Hoang Ngoc Nhi', 'Nam', TO_DATE('2013-7-7','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500077', 4223, 1591, 'Nhan vien', 'QL026', 6, 'UserNV77')
#  into NHANVIEN values('NV78', 'Ung Van Nguyet', 'Nam', TO_DATE('2001-9-23','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500078', 9897, 1390, 'Nhan vien', 'QL027', 7, 'UserNV78')
#  into NHANVIEN values('NV79', 'Tran Tung Tu', 'Nam', TO_DATE('2003-1-24','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500079', 4827, 1930, 'Nhan vien', 'QL028', 8, 'UserNV79')
#  into NHANVIEN values('NV80', 'Ung Hoang Vinh', 'Nam', TO_DATE('2009-12-7','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500080', 2459, 1400, 'Nhan vien', 'QL029', 1, 'UserNV80')
#  into NHANVIEN values('NV81', 'Lai Song Vinh', 'Nu', TO_DATE('2022-2-16','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500081', 6957, 1680, 'Nhan vien', 'QL030', 2, 'UserNV81')
#  into NHANVIEN values('NV82', 'Le Song Ngoc Nhi', 'Nu', TO_DATE('2022-6-16','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500082', 8755, 1188, 'Nhan vien', 'QL031', 3, 'UserNV82')
#  into NHANVIEN values('NV83', 'Ly Chi Tin', 'Nam', TO_DATE('2001-8-15','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500083', 6005, 1944, 'Nhan vien', 'QL032', 4, 'UserNV83')
#  into NHANVIEN values('NV84', 'Nguyen Thi Phu', 'Nu', TO_DATE('2022-5-22','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500084', 1107, 1758, 'Nhan vien', 'QL033', 5, 'UserNV84')
#  into NHANVIEN values('NV85', 'Au Thi Chi', 'Nu', TO_DATE('2021-7-7','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500085', 8755, 1180, 'Nhan vien', 'QL034', 6, 'UserNV85')
#  into NHANVIEN values('NV86', 'Đang Van Tuan', 'Nam', TO_DATE('2001-2-7','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500086', 5605, 1043, 'Nhan vien', 'QL035', 7, 'UserNV86')
#  into NHANVIEN values('NV87', 'Duong Chi Han', 'Nam', TO_DATE('2007-3-17','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500087', 5681, 1203, 'Nhan vien', 'QL016', 8, 'UserNV87')
#  into NHANVIEN values('NV88', 'Lai Hoang Viet', 'Nam', TO_DATE('2018-5-21','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500088', 4884, 1731, 'Nhan vien', 'QL017', 1, 'UserNV88')
#  into NHANVIEN values('NV89', 'Tran Song Duy', 'Nu', TO_DATE('2012-10-24','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500089', 5727, 1511, 'Nhan vien', 'QL018', 2, 'UserNV89')
#  into NHANVIEN values('NV90', 'Le Hoang Chi', 'Nam', TO_DATE('2013-10-22','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500090', 8762, 1934, 'Nhan vien', 'QL019', 3, 'UserNV90')
#  into NHANVIEN values('NV91', 'Vo Van Nguyet', 'Nam', TO_DATE('2017-7-26','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500091', 8470, 1965, 'Nhan vien', 'QL020', 4, 'UserNV91')
#  into NHANVIEN values('NV92', 'Lai Thi Anh', 'Nu', TO_DATE('2003-9-8','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500092', 1050, 1070, 'Nhan vien', 'QL021', 5, 'UserNV92')
#  into NHANVIEN values('NV93', 'Au Tung Tan', 'Nam', TO_DATE('2004-2-23','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500093', 7843, 1764, 'Nhan vien', 'QL022', 6, 'UserNV93')
#  into NHANVIEN values('NV94', 'Ly Hoang Nam', 'Nam', TO_DATE('2010-2-2','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500094', 1729, 1240, 'Nhan vien', 'QL023', 7, 'UserNV94')
#  into NHANVIEN values('NV95', 'Duong Hoang Viet', 'Nam', TO_DATE('2001-3-26','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500095', 1516, 1896, 'Nhan vien', 'QL024', 8, 'UserNV95')
#  into NHANVIEN values('NV96', 'Vo Song Ngoc Nhi', 'Nu', TO_DATE('2008-1-8','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500096', 7708, 1902, 'Nhan vien', 'QL025', 1, 'UserNV96')
#  into NHANVIEN values('NV97', 'Tran Tung Minh', 'Nam', TO_DATE('2019-3-19','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500097', 7356, 1690, 'Nhan vien', 'QL026', 2, 'UserNV97')
#  into NHANVIEN values('NV98', 'Lai Song Anh', 'Nu', TO_DATE('2014-7-15','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500098', 9821, 2000, 'Nhan vien', 'QL027', 3, 'UserNV98')
#  into NHANVIEN values('NV99', 'An Van Thong', 'Nam', TO_DATE('2020-12-9','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500099', 2497, 1430, 'Nhan vien', 'QL028', 4, 'UserNV99')
#  into NHANVIEN values('NV100', 'Ho Thi Chung', 'Nu', TO_DATE('2015-2-18','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000100', 6714, 1258, 'Nhan vien', 'QL029', 5, 'UserNV100')
#  into NHANVIEN values('NV101', 'Đang Hoang Thien', 'Nam', TO_DATE('2007-11-20','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000101', 1043, 1417, 'Nhan vien', 'QL030', 6, 'UserNV101')
#  into NHANVIEN values('NV102', 'Đang Chi Đan', 'Nam', TO_DATE('2021-11-7','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000102', 5833, 1978, 'Nhan vien', 'QL031', 7, 'UserNV102')
#  into NHANVIEN values('NV103', 'Đoan Tung Ngoc Nhi', 'Nam', TO_DATE('2014-2-9','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000103', 2742, 1256, 'Nhan vien', 'QL032', 8, 'UserNV103')
#  into NHANVIEN values('NV104', 'Vo Hoang Ngan', 'Nam', TO_DATE('2021-9-26','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000104', 5860, 1873, 'Nhan vien', 'QL033', 1, 'UserNV104')
#  into NHANVIEN values('NV105', 'Ho Chi Tien', 'Nam', TO_DATE('2006-7-19','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000105', 2623, 1825, 'Nhan vien', 'QL034', 2, 'UserNV105')
#  into NHANVIEN values('NV106', 'Ly Song Ngoc Nhi', 'Nu', TO_DATE('2012-5-13','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000106', 5585, 1095, 'Nhan vien', 'QL035', 3, 'UserNV106')
#  into NHANVIEN values('NV107', 'Tran Song Cau', 'Nu', TO_DATE('2006-2-15','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000107', 6309, 1890, 'Nhan vien', 'QL016', 4, 'UserNV107')
#  into NHANVIEN values('NV108', 'Tran Song Chung', 'Nu', TO_DATE('2017-1-8','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000108', 8035, 1198, 'Nhan vien', 'QL017', 5, 'UserNV108')
#  into NHANVIEN values('NV109', 'Vo Thi Anh', 'Nu', TO_DATE('2021-6-26','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000109', 5828, 1934, 'Nhan vien', 'QL018', 6, 'UserNV109')
#  into NHANVIEN values('NV110', 'Vo Van Nguyet', 'Nam', TO_DATE('2014-1-28','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000110', 8751, 1073, 'Nhan vien', 'QL019', 7, 'UserNV110')
#  into NHANVIEN values('NV111', 'Au Van Cau', 'Nam', TO_DATE('2015-11-3','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000111', 3687, 1903, 'Nhan vien', 'QL020', 8, 'UserNV111')
#  into NHANVIEN values('NV112', 'Đoan Song Tuan', 'Nu', TO_DATE('2010-10-14','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000112', 4300, 1081, 'Nhan vien', 'QL021', 1, 'UserNV112')
#  into NHANVIEN values('NV113', 'Đang Song Ngan', 'Nu', TO_DATE('2009-10-10','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000113', 3120, 1072, 'Nhan vien', 'QL022', 2, 'UserNV113')
#  into NHANVIEN values('NV114', 'Lai Gia Giang', 'Nam', TO_DATE('2010-2-15','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000114', 9849, 1511, 'Nhan vien', 'QL023', 3, 'UserNV114')
#  into NHANVIEN values('NV115', 'Bui Van Thuong', 'Nam', TO_DATE('2002-7-26','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000115', 6025, 1762, 'Nhan vien', 'QL024', 4, 'UserNV115')
#  into NHANVIEN values('NV116', 'Gian Chi Vy', 'Nam', TO_DATE('2012-9-9','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000116', 9866, 1596, 'Nhan vien', 'QL025', 5, 'UserNV116')
#  into NHANVIEN values('NV117', 'Truong Gia An', 'Nam', TO_DATE('2015-10-22','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000117', 4802, 1126, 'Nhan vien', 'QL026', 6, 'UserNV117')
#  into NHANVIEN values('NV118', 'Nguyen Chi Tin', 'Nam', TO_DATE('2013-9-12','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000118', 3728, 1613, 'Nhan vien', 'QL027', 7, 'UserNV118')
#  into NHANVIEN values('NV119', 'Gian Van Đang', 'Nam', TO_DATE('2022-11-3','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000119', 8429, 1289, 'Nhan vien', 'QL028', 8, 'UserNV119')
#  into NHANVIEN values('NV120', 'Nguyen Song An', 'Nu', TO_DATE('2006-3-25','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000120', 8093, 1971, 'Nhan vien', 'QL029', 1, 'UserNV120')
#  into NHANVIEN values('NV121', 'Le Hoang Vu', 'Nam', TO_DATE('2019-12-17','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000121', 2075, 1332, 'Nhan vien', 'QL030', 2, 'UserNV121')
#  into NHANVIEN values('NV122', 'Duong Gia khanh', 'Nam', TO_DATE('2020-7-19','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000122', 3555, 1611, 'Nhan vien', 'QL031', 3, 'UserNV122')
#  into NHANVIEN values('NV123', 'Ung Van Viet', 'Nam', TO_DATE('2016-5-4','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000123', 2374, 1984, 'Nhan vien', 'QL032', 4, 'UserNV123')
#  into NHANVIEN values('NV124', 'Truong Thi Bao', 'Nu', TO_DATE('2004-8-28','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000124', 7985, 1948, 'Nhan vien', 'QL033', 5, 'UserNV124')
#  into NHANVIEN values('NV125', 'Vo Song Tuan', 'Nu', TO_DATE('2011-2-12','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000125', 3183, 1938, 'Nhan vien', 'QL034', 6, 'UserNV125')
#  into NHANVIEN values('NV126', 'An Song Tan', 'Nu', TO_DATE('2011-10-20','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000126', 2469, 1086, 'Nhan vien', 'QL035', 7, 'UserNV126')
#  into NHANVIEN values('NV127', 'Pham Thi Cau', 'Nu', TO_DATE('2018-12-24','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000127', 1988, 1036, 'Nhan vien', 'QL016', 8, 'UserNV127')
#  into NHANVIEN values('NV128', 'Nguyen Hoang Vu', 'Nam', TO_DATE('2016-1-13','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000128', 1405, 1159, 'Nhan vien', 'QL017', 1, 'UserNV128')
#  into NHANVIEN values('NV129', 'Ho Hoang Cau', 'Nam', TO_DATE('2006-2-21','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000129', 1653, 1183, 'Nhan vien', 'QL018', 2, 'UserNV129')
#  into NHANVIEN values('NV130', 'Nguyen Thi Phu', 'Nu', TO_DATE('2020-6-14','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000130', 9155, 1398, 'Nhan vien', 'QL019', 3, 'UserNV130')
#  into NHANVIEN values('NV131', 'Duong Song Bac', 'Nu', TO_DATE('2006-8-3','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000131', 2382, 1764, 'Nhan vien', 'QL020', 4, 'UserNV131')
#  into NHANVIEN values('NV132', 'Ly Tung Vy', 'Nam', TO_DATE('2014-2-19','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000132', 1765, 1690, 'Nhan vien', 'QL021', 5, 'UserNV132')
#  into NHANVIEN values('NV133', 'Pham Gia Ngoc Nhi', 'Nam', TO_DATE('2002-10-18','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000133', 8702, 1741, 'Nhan vien', 'QL022', 6, 'UserNV133')
#  into NHANVIEN values('NV134', 'Truong Gia Tiep', 'Nam', TO_DATE('2008-5-22','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000134', 1145, 1603, 'Nhan vien', 'QL023', 7, 'UserNV134')
#  into NHANVIEN values('NV135', 'Ung Van Tuan', 'Nam', TO_DATE('2002-10-9','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000135', 4422, 1356, 'Nhan vien', 'QL024', 8, 'UserNV135')
#  into NHANVIEN values('NV136', 'Duong Tung Giang', 'Nam', TO_DATE('2019-4-28','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000136', 5802, 1886, 'Nhan vien', 'QL025', 1, 'UserNV136')
#  into NHANVIEN values('NV137', 'Vu Song Tu', 'Nu', TO_DATE('2018-6-11','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000137', 1219, 1419, 'Nhan vien', 'QL026', 2, 'UserNV137')
#  into NHANVIEN values('NV138', 'Le Chi khanh', 'Nam', TO_DATE('2006-11-3','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000138', 3996, 1451, 'Nhan vien', 'QL027', 3, 'UserNV138')
#  into NHANVIEN values('NV139', 'Tran Chi Tien', 'Nam', TO_DATE('2009-11-10','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000139', 6992, 1555, 'Nhan vien', 'QL028', 4, 'UserNV139')
#  into NHANVIEN values('NV140', 'Ung Chi Ngoc Nhi', 'Nam', TO_DATE('2021-2-5','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000140', 5590, 1589, 'Nhan vien', 'QL029', 5, 'UserNV140')
#  into NHANVIEN values('NV141', 'Le Song Ngan', 'Nu', TO_DATE('2003-6-10','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000141', 4184, 1847, 'Nhan vien', 'QL030', 6, 'UserNV141')
#  into NHANVIEN values('NV142', 'Le Tung Tien', 'Nam', TO_DATE('2015-3-9','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000142', 2911, 1340, 'Nhan vien', 'QL031', 7, 'UserNV142')
#  into NHANVIEN values('NV143', 'An Hoang Thien', 'Nam', TO_DATE('2015-2-1','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000143', 5034, 1716, 'Nhan vien', 'QL032', 8, 'UserNV143')
#  into NHANVIEN values('NV144', 'Au Thi Nam', 'Nu', TO_DATE('2019-10-27','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000144', 3796, 1013, 'Nhan vien', 'QL033', 1, 'UserNV144')
#  into NHANVIEN values('NV145', 'Tran Thi Giang', 'Nu', TO_DATE('2001-10-15','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000145', 2849, 1141, 'Nhan vien', 'QL034', 2, 'UserNV145')
#  into NHANVIEN values('NV146', 'Au Hoang Đan', 'Nam', TO_DATE('2008-11-17','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000146', 1274, 1130, 'Nhan vien', 'QL035', 3, 'UserNV146')
#  into NHANVIEN values('NV147', 'Đang Hoang Tin', 'Nam', TO_DATE('2014-9-9','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000147', 8453, 1010, 'Nhan vien', 'QL016', 4, 'UserNV147')
#  into NHANVIEN values('NV148', 'Gian Song Thong', 'Nu', TO_DATE('2019-1-18','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000148', 3612, 1562, 'Nhan vien', 'QL017', 5, 'UserNV148')
#  into NHANVIEN values('NV149', 'An Tung Tiep', 'Nam', TO_DATE('2001-8-20','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000149', 9606, 1290, 'Nhan vien', 'QL018', 6, 'UserNV149')
#  into NHANVIEN values('NV150', 'Đang Tung Tu', 'Nam', TO_DATE('2000-8-4','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000150', 4042, 1053, 'Nhan vien', 'QL019', 7, 'UserNV150')
#  into NHANVIEN values('NV151', 'Nguyen Chi Thien', 'Nam', TO_DATE('2005-1-25','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000151', 3954, 1159, 'Nhan vien', 'QL020', 8, 'UserNV151')
#  into NHANVIEN values('NV152', 'Ly Tung Vinh', 'Nam', TO_DATE('2003-2-5','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000152', 8210, 1805, 'Nhan vien', 'QL021', 1, 'UserNV152')
#  into NHANVIEN values('NV153', 'Gian Hoang An', 'Nam', TO_DATE('2010-6-25','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000153', 6235, 1771, 'Nhan vien', 'QL022', 2, 'UserNV153')
#  into NHANVIEN values('NV154', 'Ung Thi Tan', 'Nu', TO_DATE('2021-12-16','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000154', 5678, 1967, 'Nhan vien', 'QL023', 3, 'UserNV154')
#  into NHANVIEN values('NV155', 'Tran Thi An', 'Nu', TO_DATE('2010-11-16','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000155', 9165, 1157, 'Nhan vien', 'QL024', 4, 'UserNV155')
#  into NHANVIEN values('NV156', 'Tran Van Tin', 'Nam', TO_DATE('2001-9-18','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000156', 9284, 1738, 'Nhan vien', 'QL025', 5, 'UserNV156')
#  into NHANVIEN values('NV157', 'Lai Tung Vu', 'Nam', TO_DATE('2003-8-19','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000157', 8704, 1867, 'Nhan vien', 'QL026', 6, 'UserNV157')
#  into NHANVIEN values('NV158', 'Đang Song Tin', 'Nu', TO_DATE('2000-7-12','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000158', 8014, 1132, 'Nhan vien', 'QL027', 7, 'UserNV158')
#  into NHANVIEN values('NV159', 'Gian Song Giang', 'Nu', TO_DATE('2014-7-7','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000159', 2527, 1233, 'Nhan vien', 'QL028', 8, 'UserNV159')
#  into NHANVIEN values('NV160', 'Au Song Thien', 'Nu', TO_DATE('2014-8-13','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000160', 1804, 1201, 'Nhan vien', 'QL029', 1, 'UserNV160')
#  into NHANVIEN values('NV161', 'Đoan Van Tan', 'Nam', TO_DATE('2000-9-10','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000161', 2862, 1291, 'Nhan vien', 'QL030', 2, 'UserNV161')
#  into NHANVIEN values('NV162', 'Ung Gia khanh', 'Nam', TO_DATE('2019-9-15','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000162', 2817, 1623, 'Nhan vien', 'QL031', 3, 'UserNV162')
#  into NHANVIEN values('NV163', 'Tran Van Đang', 'Nam', TO_DATE('2000-7-19','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000163', 1232, 1853, 'Nhan vien', 'QL032', 4, 'UserNV163')
#  into NHANVIEN values('NV164', 'Đoan Hoang Phu', 'Nam', TO_DATE('2016-1-22','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000164', 1313, 1035, 'Nhan vien', 'QL033', 5, 'UserNV164')
#  into NHANVIEN values('NV165', 'Duong Song Ngoc Nhi', 'Nu', TO_DATE('2003-8-21','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000165', 2701, 1720, 'Nhan vien', 'QL034', 6, 'UserNV165')
#  into NHANVIEN values('NV166', 'Bui Thi Han', 'Nu', TO_DATE('2015-6-22','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000166', 5099, 1354, 'Nhan vien', 'QL035', 7, 'UserNV166')
#  into NHANVIEN values('NV167', 'Au Van Bao', 'Nam', TO_DATE('2012-5-22','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000167', 4719, 1337, 'Nhan vien', 'QL016', 8, 'UserNV167')
#  into NHANVIEN values('NV168', 'Đang Song Nguyet', 'Nu', TO_DATE('2011-8-2','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000168', 9841, 1929, 'Nhan vien', 'QL017', 1, 'UserNV168')
#  into NHANVIEN values('NV169', 'Truong Tung Bac', 'Nam', TO_DATE('2019-2-13','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000169', 3918, 1767, 'Nhan vien', 'QL018', 2, 'UserNV169')
#  into NHANVIEN values('NV170', 'Pham Tung Tuan', 'Nam', TO_DATE('2004-2-6','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000170', 6502, 1021, 'Nhan vien', 'QL019', 3, 'UserNV170')
#  into NHANVIEN values('NV171', 'Ung Hoang Tan', 'Nam', TO_DATE('2022-10-6','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000171', 4496, 1986, 'Nhan vien', 'QL020', 4, 'UserNV171')
#  into NHANVIEN values('NV172', 'An Thi Vu', 'Nu', TO_DATE('2001-8-27','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000172', 7105, 1875, 'Nhan vien', 'QL021', 5, 'UserNV172')
#  into NHANVIEN values('NV173', 'Ung Van khanh', 'Nam', TO_DATE('2014-1-9','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000173', 4387, 1682, 'Nhan vien', 'QL022', 6, 'UserNV173')
#  into NHANVIEN values('NV174', 'Au Hoang khanh', 'Nam', TO_DATE('2015-8-27','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000174', 9965, 1002, 'Nhan vien', 'QL023', 7, 'UserNV174')
#  into NHANVIEN values('NV175', 'Ly Song Ngoc Nhi', 'Nu', TO_DATE('2014-2-16','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000175', 8305, 1398, 'Nhan vien', 'QL024', 8, 'UserNV175')
#  into NHANVIEN values('NV176', 'Pham Van Vinh', 'Nam', TO_DATE('2013-10-16','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000176', 1682, 1472, 'Nhan vien', 'QL025', 1, 'UserNV176')
#  into NHANVIEN values('NV177', 'Lai Gia Duy', 'Nam', TO_DATE('2014-5-9','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000177', 3231, 1747, 'Nhan vien', 'QL026', 2, 'UserNV177')
#  into NHANVIEN values('NV178', 'Ly Thi Thong', 'Nu', TO_DATE('2007-8-7','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000178', 4748, 1817, 'Nhan vien', 'QL027', 3, 'UserNV178')
#  into NHANVIEN values('NV179', 'Tran Gia Nguyet', 'Nam', TO_DATE('2010-2-21','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000179', 3375, 1415, 'Nhan vien', 'QL028', 4, 'UserNV179')
#  into NHANVIEN values('NV180', 'Duong Hoang An', 'Nam', TO_DATE('2007-6-27','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000180', 8785, 1252, 'Nhan vien', 'QL029', 5, 'UserNV180')
#  into NHANVIEN values('NV181', 'Ung Song Ngan', 'Nu', TO_DATE('2009-9-9','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000181', 9834, 1873, 'Nhan vien', 'QL030', 6, 'UserNV181')
#  into NHANVIEN values('NV182', 'Ung Van Đuc', 'Nam', TO_DATE('2016-8-20','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000182', 5997, 1253, 'Nhan vien', 'QL031', 7, 'UserNV182')
#  into NHANVIEN values('NV183', 'Đoan Hoang Sang', 'Nam', TO_DATE('2020-10-26','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000183', 2876, 1322, 'Nhan vien', 'QL032', 8, 'UserNV183')
#  into NHANVIEN values('NV184', 'Pham Van Vinh', 'Nam', TO_DATE('2009-4-9','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000184', 3949, 1760, 'Nhan vien', 'QL033', 1, 'UserNV184')
#  into NHANVIEN values('NV185', 'Au Hoang Tiep', 'Nam', TO_DATE('2018-4-13','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000185', 8288, 1519, 'Nhan vien', 'QL034', 2, 'UserNV185')
#  into NHANVIEN values('NV186', 'Ho Gia Quoc', 'Nam', TO_DATE('2008-7-5','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000186', 5844, 1826, 'Nhan vien', 'QL035', 3, 'UserNV186')
#  into NHANVIEN values('NV187', 'Au Hoang An', 'Nam', TO_DATE('2014-7-4','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000187', 4572, 1702, 'Nhan vien', 'QL016', 4, 'UserNV187')
#  into NHANVIEN values('NV188', 'Ung Thi Anh', 'Nu', TO_DATE('2003-4-8','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000188', 9189, 1113, 'Nhan vien', 'QL017', 5, 'UserNV188')
#  into NHANVIEN values('NV189', 'Tran Hoang Đang', 'Nam', TO_DATE('2001-2-19','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000189', 1335, 1939, 'Nhan vien', 'QL018', 6, 'UserNV189')
#  into NHANVIEN values('NV190', 'Pham Gia Nguyet', 'Nam', TO_DATE('2003-8-5','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000190', 7738, 2000, 'Nhan vien', 'QL019', 7, 'UserNV190')
#  into NHANVIEN values('NV191', 'Vo Chi Nam', 'Nam', TO_DATE('2019-4-18','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000191', 2177, 1834, 'Nhan vien', 'QL020', 8, 'UserNV191')
#  into NHANVIEN values('NV192', 'Duong Hoang Minh', 'Nam', TO_DATE('2015-2-16','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000192', 8155, 1591, 'Nhan vien', 'QL021', 1, 'UserNV192')
#  into NHANVIEN values('NV193', 'Đoan Chi Nam', 'Nam', TO_DATE('2003-12-21','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000193', 4981, 1009, 'Nhan vien', 'QL022', 2, 'UserNV193')
#  into NHANVIEN values('NV194', 'Ung Gia Viet', 'Nam', TO_DATE('2010-3-21','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000194', 7886, 1973, 'Nhan vien', 'QL023', 3, 'UserNV194')
#  into NHANVIEN values('NV195', 'Đoan Song Tu', 'Nu', TO_DATE('2014-8-24','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000195', 5259, 1920, 'Nhan vien', 'QL024', 4, 'UserNV195')
#  into NHANVIEN values('NV196', 'Bui Song May', 'Nu', TO_DATE('2008-12-23','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000196', 2371, 1955, 'Nhan vien', 'QL025', 5, 'UserNV196')
#  into NHANVIEN values('NV197', 'Vu Song Chung', 'Nu', TO_DATE('2014-5-3','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000197', 9079, 1804, 'Nhan vien', 'QL026', 6, 'UserNV197')
#  into NHANVIEN values('NV198', 'Nguyen Chi Vinh', 'Nam', TO_DATE('2018-3-24','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000198', 8587, 1372, 'Nhan vien', 'QL027', 7, 'UserNV198')
#  into NHANVIEN values('NV199', 'Au Hoang Sang', 'Nam', TO_DATE('2017-11-16','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000199', 2950, 1779, 'Nhan vien', 'QL028', 8, 'UserNV199')
#  into NHANVIEN values('NV200', 'Duong Song Đuc', 'Nu', TO_DATE('2015-10-22','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000200', 9668, 1322, 'Nhan vien', 'QL029', 1, 'UserNV200')
#  into NHANVIEN values('NV201', 'An Song Ngoc Nhi', 'Nu', TO_DATE('2014-4-23','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000201', 7541, 1116, 'Nhan vien', 'QL030', 2, 'UserNV201')
#  into NHANVIEN values('NV202', 'Bui Thi Minh', 'Nu', TO_DATE('2003-6-9','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000202', 5531, 1314, 'Nhan vien', 'QL031', 3, 'UserNV202')
#  into NHANVIEN values('NV203', 'Au Tung Duy', 'Nam', TO_DATE('2007-7-18','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000203', 5589, 1292, 'Nhan vien', 'QL032', 4, 'UserNV203')
#  into NHANVIEN values('NV204', 'Gian Thi Đuc', 'Nu', TO_DATE('2003-11-24','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000204', 8850, 1969, 'Nhan vien', 'QL033', 5, 'UserNV204')
#  into NHANVIEN values('NV205', 'Ly Chi Cuc', 'Nam', TO_DATE('2020-11-20','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000205', 7936, 1474, 'Nhan vien', 'QL034', 6, 'UserNV205')
#  into NHANVIEN values('NV206', 'Vu Hoang Duy', 'Nam', TO_DATE('2003-4-24','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000206', 4543, 1252, 'Nhan vien', 'QL035', 7, 'UserNV206')
#  into NHANVIEN values('NV207', 'Au Thi Tu', 'Nu', TO_DATE('2009-6-9','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000207', 6278, 1253, 'Nhan vien', 'QL016', 8, 'UserNV207')
#  into NHANVIEN values('NV208', 'Duong Song Thien', 'Nu', TO_DATE('2020-3-6','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000208', 5799, 1510, 'Nhan vien', 'QL017', 1, 'UserNV208')
#  into NHANVIEN values('NV209', 'Lai Song Tan', 'Nu', TO_DATE('2016-11-13','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000209', 8593, 1266, 'Nhan vien', 'QL018', 2, 'UserNV209')
#  into NHANVIEN values('NV210', 'An Gia Thuong', 'Nam', TO_DATE('2001-9-8','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000210', 8162, 1595, 'Nhan vien', 'QL019', 3, 'UserNV210')
#  into NHANVIEN values('NV211', 'Truong Chi Thong', 'Nam', TO_DATE('2003-12-23','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000211', 8536, 1843, 'Nhan vien', 'QL020', 4, 'UserNV211')
#  into NHANVIEN values('NV212', 'Au Chi May', 'Nam', TO_DATE('2003-2-4','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000212', 6348, 1922, 'Nhan vien', 'QL021', 5, 'UserNV212')
#  into NHANVIEN values('NV213', 'Tran Gia Cuc', 'Nam', TO_DATE('2012-12-23','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000213', 1394, 1742, 'Nhan vien', 'QL022', 6, 'UserNV213')
#  into NHANVIEN values('NV214', 'Đang Thi Thien', 'Nu', TO_DATE('2002-8-3','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000214', 2882, 1110, 'Nhan vien', 'QL023', 7, 'UserNV214')
#  into NHANVIEN values('NV215', 'Lai Van Thien', 'Nam', TO_DATE('2018-3-28','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000215', 5263, 1143, 'Nhan vien', 'QL024', 8, 'UserNV215')
#  into NHANVIEN values('NV216', 'Ho Tung Anh', 'Nam', TO_DATE('2006-4-2','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000216', 5427, 1645, 'Nhan vien', 'QL025', 1, 'UserNV216')
#  into NHANVIEN values('NV217', 'Bui Chi Han', 'Nam', TO_DATE('2015-8-7','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000217', 8314, 1783, 'Nhan vien', 'QL026', 2, 'UserNV217')
#  into NHANVIEN values('NV218', 'Ly Tung Tin', 'Nam', TO_DATE('2014-5-16','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000218', 2386, 1379, 'Nhan vien', 'QL027', 3, 'UserNV218')
#  into NHANVIEN values('NV219', 'Nguyen Van Cuc', 'Nam', TO_DATE('2011-12-7','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000219', 3662, 1409, 'Nhan vien', 'QL028', 4, 'UserNV219')
#  into NHANVIEN values('NV220', 'Nguyen Van Tuan', 'Nam', TO_DATE('2017-5-13','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000220', 2527, 1400, 'Nhan vien', 'QL029', 5, 'UserNV220')
#  into NHANVIEN values('NV221', 'Truong Chi Han', 'Nam', TO_DATE('2019-9-20','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000221', 2127, 1441, 'Nhan vien', 'QL030', 6, 'UserNV221')
#  into NHANVIEN values('NV222', 'Pham Chi Ngan', 'Nam', TO_DATE('2008-8-25','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000222', 1276, 1917, 'Nhan vien', 'QL031', 7, 'UserNV222')
#  into NHANVIEN values('NV223', 'Đoan Tung Cuc', 'Nam', TO_DATE('2006-12-11','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000223', 9344, 1186, 'Nhan vien', 'QL032', 8, 'UserNV223')
#  into NHANVIEN values('NV224', 'Pham Song Tan', 'Nu', TO_DATE('2017-12-18','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000224', 8205, 1858, 'Nhan vien', 'QL033', 1, 'UserNV224')
#  into NHANVIEN values('NV225', 'An Gia Đan', 'Nam', TO_DATE('2004-8-27','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000225', 2669, 1831, 'Nhan vien', 'QL034', 2, 'UserNV225')
#  into NHANVIEN values('NV226', 'Ly Song Tan', 'Nu', TO_DATE('2017-5-1','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000226', 7990, 1852, 'Nhan vien', 'QL035', 3, 'UserNV226')
#  into NHANVIEN values('NV227', 'Bui Thi Đan', 'Nu', TO_DATE('2001-11-20','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000227', 4684, 1660, 'Nhan vien', 'QL016', 4, 'UserNV227')
#  into NHANVIEN values('NV228', 'An Hoang Tan', 'Nam', TO_DATE('2011-12-5','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000228', 4199, 1347, 'Nhan vien', 'QL017', 5, 'UserNV228')
#  into NHANVIEN values('NV229', 'Ung Chi Chi', 'Nam', TO_DATE('2009-4-12','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000229', 9703, 1073, 'Nhan vien', 'QL018', 6, 'UserNV229')
#  into NHANVIEN values('NV230', 'Đoan Hoang Thuong', 'Nam', TO_DATE('2021-11-18','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000230', 3550, 1388, 'Nhan vien', 'QL019', 7, 'UserNV230')
# ...
#  into NHANVIEN values('NV271', 'Lai Chi Cau', 'Nam', TO_DATE('2005-7-18','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000271', 2008, 1404, 'Nhan vien', 'QL020', 8, 'UserNV271')
#  into NHANVIEN values('NV272', 'An Tung Phu', 'Nam', TO_DATE('2006-10-22','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000272', 5050, 1773, 'Nhan vien', 'QL021', 1, 'UserNV272')
#  into NHANVIEN values('NV273', 'Tran Gia Giang', 'Nam', TO_DATE('2007-11-4','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000273', 6794, 1433, 'Nhan vien', 'QL022', 2, 'UserNV273')
#  into NHANVIEN values('NV274', 'Truong Thi Vu', 'Nu', TO_DATE('2003-12-24','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000274', 9074, 1759, 'Nhan vien', 'QL023', 3, 'UserNV274')
#  into NHANVIEN values('NV275', 'Ho Hoang Cuc', 'Nam', TO_DATE('2000-2-24','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000275', 5437, 1252, 'Nhan vien', 'QL024', 4, 'UserNV275')
#  into NHANVIEN values('NV276', 'Truong Thi Tin', 'Nu', TO_DATE('2004-1-23','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000276', 5132, 1342, 'Nhan vien', 'QL025', 5, 'UserNV276')
#  into NHANVIEN values('NV277', 'Bui Van Tan', 'Nam', TO_DATE('2005-7-4','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000277', 4569, 1315, 'Nhan vien', 'QL026', 6, 'UserNV277')
#  into NHANVIEN values('NV278', 'Ho Gia Chung', 'Nam', TO_DATE('2013-10-23','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000278', 2751, 1814, 'Nhan vien', 'QL027', 7, 'UserNV278')
#  into NHANVIEN values('NV279', 'Pham Chi Han', 'Nam', TO_DATE('2006-3-28','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000279', 8231, 1131, 'Nhan vien', 'QL028', 8, 'UserNV279')
#  into NHANVIEN values('NV280', 'Nguyen Hoang Giang', 'Nam', TO_DATE('2012-11-27','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000280', 3229, 1356, 'Nhan vien', 'QL029', 1, 'UserNV280')
#  into NHANVIEN values('NV281', 'An Van Tuan', 'Nam', TO_DATE('2016-6-1','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000281', 1927, 1641, 'Nhan vien', 'QL030', 2, 'UserNV281')
#  into NHANVIEN values('NV282', 'Pham Chi Chung', 'Nam', TO_DATE('2002-11-20','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000282', 5399, 1166, 'Nhan vien', 'QL031', 3, 'UserNV282')
#  into NHANVIEN values('NV283', 'Lai Hoang Quoc', 'Nam', TO_DATE('2001-1-26','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000283', 6508, 1729, 'Nhan vien', 'QL032', 4, 'UserNV283')
#  into NHANVIEN values('NV284', 'Đang Hoang Sang', 'Nam', TO_DATE('2007-11-26','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000284', 3961, 1150, 'Nhan vien', 'QL033', 5, 'UserNV284')
#  into NHANVIEN values('NV285', 'Duong Van khanh', 'Nam', TO_DATE('2022-2-21','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000285', 6741, 1869, 'Nhan vien', 'QL034', 6, 'UserNV285')
#  into NHANVIEN values('NV286', 'Vo Gia Sang', 'Nam', TO_DATE('2007-5-25','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000286', 8285, 1103, 'Nhan vien', 'QL035', 7, 'UserNV286')
#  into NHANVIEN values('NV287', 'Gian Thi An', 'Nu', TO_DATE('2004-7-19','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000287', 1467, 1112, 'Nhan vien', 'QL016', 8, 'UserNV287')
#  into NHANVIEN values('NV288', 'Au Chi Anh', 'Nam', TO_DATE('2021-12-5','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000288', 6317, 1801, 'Nhan vien', 'QL017', 1, 'UserNV288')
#  into NHANVIEN values('NV289', 'Le Hoang khanh', 'Nam', TO_DATE('2018-9-4','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000289', 6312, 1714, 'Nhan vien', 'QL018', 2, 'UserNV289')
#  into NHANVIEN values('NV290', 'Au Hoang Vinh', 'Nam', TO_DATE('2005-8-14','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000290', 3838, 1920, 'Nhan vien', 'QL019', 3, 'UserNV290')
#  into NHANVIEN values('NV291', 'Bui Hoang Thien', 'Nam', TO_DATE('2010-8-4','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000291', 2080, 1628, 'Nhan vien', 'QL020', 4, 'UserNV291')
#  into NHANVIEN values('NV292', 'Lai Thi Han', 'Nu', TO_DATE('2020-1-3','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000292', 5384, 1533, 'Nhan vien', 'QL021', 5, 'UserNV292')
#  into NHANVIEN values('NV293', 'Đang Hoang Quoc', 'Nam', TO_DATE('2019-6-14','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000293', 1816, 1271, 'Nhan vien', 'QL022', 6, 'UserNV293')
#  into NHANVIEN values('NV294', 'Lai Van Chung', 'Nam', TO_DATE('2022-12-5','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000294', 2377, 1322, 'Nhan vien', 'QL023', 7, 'UserNV294')
#  into NHANVIEN values('NV295', 'Đang Song Vinh', 'Nu', TO_DATE('2010-2-13','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000295', 2370, 1710, 'Nhan vien', 'QL024', 8, 'UserNV295')
#  into NHANVIEN values('NV296', 'Au Chi Anh', 'Nam', TO_DATE('2021-9-17','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000296', 4350, 1432, 'Nhan vien', 'QL025', 1, 'UserNV296')
#  into NHANVIEN values('NV297', 'Duong Hoang Đang', 'Nam', TO_DATE('2012-2-21','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000297', 9899, 1185, 'Nhan vien', 'QL026', 2, 'UserNV297')
#  into NHANVIEN values('NV298', 'Pham Gia Minh', 'Nam', TO_DATE('2002-7-19','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000298', 1595, 1427, 'Nhan vien', 'QL027', 3, 'UserNV298')
#  into NHANVIEN values('NV299', 'Vu Hoang May', 'Nam', TO_DATE('2006-5-18','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000299', 2974, 1100, 'Nhan vien', 'QL028', 4, 'UserNV299')
#  into NHANVIEN values('NV300', 'Pham Gia Tien', 'Nam', TO_DATE('2011-9-24','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000300', 1509, 1615, 'Nhan vien', 'QL029', 5, 'UserNV300')
#  into NHANVIEN values('NV301', 'Vo Gia Giang', 'Nam', TO_DATE('2013-8-14','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000301', 1753, 1045, 'Nhan vien', 'QL030', 6, 'UserNV301')
#  into NHANVIEN values('NV302', 'Pham Chi Anh', 'Nam', TO_DATE('2008-5-20','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000302', 1693, 1113, 'Nhan vien', 'QL031', 7, 'UserNV302')
#  into NHANVIEN values('NV303', 'Đoan Van Đang', 'Nam', TO_DATE('2018-5-4','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000303', 8816, 1835, 'Nhan vien', 'QL032', 8, 'UserNV303')
#  into NHANVIEN values('NV304', 'Le Chi Duy', 'Nam', TO_DATE('2003-4-1','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000304', 9163, 1313, 'Nhan vien', 'QL033', 1, 'UserNV304')
#  into NHANVIEN values('NV305', 'Lai Chi Thong', 'Nam', TO_DATE('2013-9-20','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000305', 9152, 1691, 'Nhan vien', 'QL034', 2, 'UserNV305')
#  into NHANVIEN values('NV306', 'Ly Chi Sang', 'Nam', TO_DATE('2008-11-22','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000306', 1499, 1002, 'Nhan vien', 'QL035', 3, 'UserNV306')
#  into NHANVIEN values('NV307', 'Truong Tung Vu', 'Nam', TO_DATE('2000-10-21','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000307', 5989, 1885, 'Nhan vien', 'QL016', 4, 'UserNV307')
#  into NHANVIEN values('NV308', 'Đang Song Anh', 'Nu', TO_DATE('2011-1-20','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000308', 9000, 1813, 'Nhan vien', 'QL017', 5, 'UserNV308')
#  into NHANVIEN values('NV309', 'Ly Song Chi', 'Nu', TO_DATE('2020-11-20','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000309', 7670, 1577, 'Nhan vien', 'QL018', 6, 'UserNV309')
#  into NHANVIEN values('NV310', 'Đoan Chi Nguyet', 'Nam', TO_DATE('2018-8-14','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000310', 6032, 1236, 'Nhan vien', 'QL019', 7, 'UserNV310')
#  into NHANVIEN values('NV311', 'Nguyen Tung Đan', 'Nam', TO_DATE('2005-9-6','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000311', 4870, 1109, 'Nhan vien', 'QL020', 8, 'UserNV311')
#  into NHANVIEN values('NV312', 'An Song Nam', 'Nu', TO_DATE('2020-1-23','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000312', 8991, 1398, 'Nhan vien', 'QL021', 1, 'UserNV312')
#  into NHANVIEN values('NV313', 'Vu Song Han', 'Nu', TO_DATE('2021-4-18','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000313', 6672, 1968, 'Nhan vien', 'QL022', 2, 'UserNV313')
#  into NHANVIEN values('NV314', 'Vo Thi Nam', 'Nu', TO_DATE('2019-12-5','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000314', 8626, 1870, 'Nhan vien', 'QL023', 3, 'UserNV314')
#  into NHANVIEN values('NV315', 'Le Tung Thuong', 'Nam', TO_DATE('2001-12-19','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000315', 8588, 1718, 'Nhan vien', 'QL024', 4, 'UserNV315')
#  into NHANVIEN values('NV316', 'Gian Chi May', 'Nam', TO_DATE('2017-1-13','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000316', 2233, 1349, 'Nhan vien', 'QL025', 5, 'UserNV316')
#  into NHANVIEN values('NV317', 'Le Thi Đuc', 'Nu', TO_DATE('2004-10-27','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000317', 8592, 1984, 'Nhan vien', 'QL026', 6, 'UserNV317')
#  into NHANVIEN values('NV318', 'Lai Song Chung', 'Nu', TO_DATE('2007-4-11','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000318', 6976, 1071, 'Nhan vien', 'QL027', 7, 'UserNV318')
#  into NHANVIEN values('NV319', 'Vu Tung Tuan', 'Nam', TO_DATE('2017-3-6','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000319', 6313, 1312, 'Nhan vien', 'QL028', 8, 'UserNV319')
#  into NHANVIEN values('NV320', 'Pham Chi Cau', 'Nam', TO_DATE('2022-7-28','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000320', 5945, 1814, 'Nhan vien', 'QL029', 1, 'UserNV320')
#  into NHANVIEN values('NV321', 'Đang Tung khanh', 'Nam', TO_DATE('2020-2-28','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000321', 4183, 1025, 'Nhan vien', 'QL030', 2, 'UserNV321')
#  into NHANVIEN values('NV322', 'Ho Song Han', 'Nu', TO_DATE('2002-3-11','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000322', 8019, 1038, 'Nhan vien', 'QL031', 3, 'UserNV322')
#  into NHANVIEN values('NV323', 'Lai Hoang Vu', 'Nam', TO_DATE('2011-11-14','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000323', 2423, 1230, 'Nhan vien', 'QL032', 4, 'UserNV323')
#  into NHANVIEN values('NV324', 'Ung Hoang Bao', 'Nam', TO_DATE('2016-7-26','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000324', 1726, 1413, 'Nhan vien', 'QL033', 5, 'UserNV324')
#  into NHANVIEN values('NV325', 'Ly Chi Vu', 'Nam', TO_DATE('2004-7-17','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000325', 1056, 1596, 'Nhan vien', 'QL034', 6, 'UserNV325')
#  into NHANVIEN values('NV326', 'An Tung Chung', 'Nam', TO_DATE('2007-3-4','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000326', 1669, 1343, 'Nhan vien', 'QL035', 7, 'UserNV326')
#  into NHANVIEN values('NV327', 'Duong Hoang Tin', 'Nam', TO_DATE('2003-5-7','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000327', 3194, 1718, 'Nhan vien', 'QL016', 8, 'UserNV327')
#  into NHANVIEN values('NV328', 'Vo Thi An', 'Nu', TO_DATE('2015-11-23','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000328', 3965, 1887, 'Nhan vien', 'QL017', 1, 'UserNV328')
#  into NHANVIEN values('NV329', 'Duong Chi Tuan', 'Nam', TO_DATE('2018-9-14','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000329', 1681, 1870, 'Nhan vien', 'QL018', 2, 'UserNV329')
#  into NHANVIEN values('NV330', 'Pham Song Cuc', 'Nu', TO_DATE('2020-4-17','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000330', 9066, 1130, 'Nhan vien', 'QL019', 3, 'UserNV330')
#  into NHANVIEN values('NV331', 'Vu Thi Bac', 'Nu', TO_DATE('2022-4-27','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000331', 1839, 1681, 'Nhan vien', 'QL020', 4, 'UserNV331')
#  into NHANVIEN values('NV332', 'Đoan Hoang Thien', 'Nam', TO_DATE('2020-2-13','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000332', 8812, 1898, 'Nhan vien', 'QL021', 5, 'UserNV332')
#  into NHANVIEN values('NV333', 'Vo Gia Nguyet', 'Nam', TO_DATE('2014-2-5','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000333', 8393, 1624, 'Nhan vien', 'QL022', 6, 'UserNV333')
#  into NHANVIEN values('NV334', 'Duong Song Tan', 'Nu', TO_DATE('2006-6-20','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000334', 3514, 1760, 'Nhan vien', 'QL023', 7, 'UserNV334')
#  into NHANVIEN values('NV335', 'Nguyen Hoang Đang', 'Nam', TO_DATE('2011-9-7','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000335', 7537, 1521, 'Nhan vien', 'QL024', 8, 'UserNV335')
#  into NHANVIEN values('NV336', 'Ho Song Quoc', 'Nu', TO_DATE('2013-3-1','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000336', 6161, 1169, 'Nhan vien', 'QL025', 1, 'UserNV336')
#  into NHANVIEN values('NV337', 'Nguyen Hoang Nguyet', 'Nam', TO_DATE('2005-1-28','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000337', 6348, 1169, 'Nhan vien', 'QL026', 2, 'UserNV337')
#  into NHANVIEN values('NV338', 'Ly Hoang Duy', 'Nam', TO_DATE('2008-1-24','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000338', 7609, 1771, 'Nhan vien', 'QL027', 3, 'UserNV338')
#  into NHANVIEN values('NV339', 'Le Tung Vy', 'Nam', TO_DATE('2007-5-23','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000339', 6859, 1135, 'Nhan vien', 'QL028', 4, 'UserNV339')
#  into NHANVIEN values('NV340', 'Tran Song Tuan', 'Nu', TO_DATE('2009-9-18','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000340', 2456, 1628, 'Nhan vien', 'QL029', 5, 'UserNV340')
#  into NHANVIEN values('NV341', 'Truong Song Đuc', 'Nu', TO_DATE('2006-3-16','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000341', 5562, 1073, 'Nhan vien', 'QL030', 6, 'UserNV341')
#  into NHANVIEN values('NV342', 'Le Chi Đuc', 'Nam', TO_DATE('2016-1-28','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000342', 5215, 1384, 'Nhan vien', 'QL031', 7, 'UserNV342')
#  into NHANVIEN values('NV343', 'Đang Tung Anh', 'Nam', TO_DATE('2020-5-20','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000343', 4150, 1583, 'Nhan vien', 'QL032', 8, 'UserNV343')
#  into NHANVIEN values('NV344', 'Tran Van Bao', 'Nam', TO_DATE('2019-9-20','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000344', 4839, 1859, 'Nhan vien', 'QL033', 1, 'UserNV344')
#  into NHANVIEN values('NV345', 'Đoan Tung Vinh', 'Nam', TO_DATE('2013-2-17','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000345', 8133, 1938, 'Nhan vien', 'QL034', 2, 'UserNV345')
#  into NHANVIEN values('NV346', 'Au Hoang Cuc', 'Nam', TO_DATE('2015-11-21','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000346', 1742, 1981, 'Nhan vien', 'QL035', 3, 'UserNV346')

# %%
KV = ['Quan 1', 'Quan 2', 'Quan 3','Quan 4','Quan 5','Quan 6','Quan 7','Quan 8','Quan 9','Quan 10','Quan 11','Quan 12','Quan 13', 'Quan Bình Thạnh', 'Quan Tân Bình', 'Hóoc Môn']

# %% [markdown]
# ## Phong Ban

# %%
'''
PhongBan (
	MaPB 	number primary key,
	TenPB 	varchar2(60) not null,
	TrPHG 	varchar(10)
	
)	
'''


for i in range(1, 9):
    final = str(i) + ', ' + '\'Phong ' + str(i) + '\', NULL' 
    print('insert into PHONGBAN values(' +  final + ');')
# Out:
# insert into PHONGBAN values(1, 'Phong 1', NULL);
# insert into PHONGBAN values(2, 'Phong 2', NULL);
# insert into PHONGBAN values(3, 'Phong 3', NULL);
# insert into PHONGBAN values(4, 'Phong 4', NULL);
# insert into PHONGBAN values(5, 'Phong 5', NULL);
# insert into PHONGBAN values(6, 'Phong 6', NULL);
# insert into PHONGBAN values(7, 'Phong 7', NULL);
# insert into PHONGBAN values(8, 'Phong 8', NULL);

# %%
for i in range(1, 9):
    print( ' UPDATE PHONGBAN set TrPHG = ' + '\'TP0'+ str(i+ 38) + '\'' + ' WHERE ' +  'MaPB = ' + str(i)+ ';')
# Out:
#  UPDATE PHONGBAN set TrPHG = 'TP039' WHERE MaPB = 1;
#  UPDATE PHONGBAN set TrPHG = 'TP040' WHERE MaPB = 2;
#  UPDATE PHONGBAN set TrPHG = 'TP041' WHERE MaPB = 3;
#  UPDATE PHONGBAN set TrPHG = 'TP042' WHERE MaPB = 4;
#  UPDATE PHONGBAN set TrPHG = 'TP043' WHERE MaPB = 5;
#  UPDATE PHONGBAN set TrPHG = 'TP044' WHERE MaPB = 6;
#  UPDATE PHONGBAN set TrPHG = 'TP045' WHERE MaPB = 7;
#  UPDATE PHONGBAN set TrPHG = 'TP046' WHERE MaPB = 8;

# %% [markdown]
# # DE AN

# %%
'''
DeAn (
	MaDA 		varchar(10) primary key,
	TenDA 	varchar2(60) not null,
	NgayBD 	date,
	Phong 	number,
    TruongDeAn varchar(10)
	
)
'''
l = []
for i in range(1, 9):
    for j in range(1, rd.randint(3, 5)):
        MaDA = '\'DA' + str(i) + '0' + str(j) + '\'';
        l.append(MaDA);

        TenDA = '\'De An so ' + str(j) + ' Phong ' + str(i) + '\'';
        NgayBD  = 'TO_DATE(' + '\'' + str(rd.randint(2020, 2022)) + '-' + str(rd.randint(1, 12)) + '-' + str(rd.randint(1, 28)) + '\',\'YYYY-MM-DD\')'
        Phong = str(i)
        final = MaDA + ', ' + TenDA + ', ' + NgayBD + ', ' + Phong 
        print('into DEAN values(' +  final + ')')
# Out:
# into DEAN values('DA101', 'De An so 1 Phong 1', TO_DATE('2021-7-2','YYYY-MM-DD'), 1)
# into DEAN values('DA102', 'De An so 2 Phong 1', TO_DATE('2022-6-3','YYYY-MM-DD'), 1)
# into DEAN values('DA201', 'De An so 1 Phong 2', TO_DATE('2021-6-3','YYYY-MM-DD'), 2)
# into DEAN values('DA202', 'De An so 2 Phong 2', TO_DATE('2022-12-25','YYYY-MM-DD'), 2)
# into DEAN values('DA301', 'De An so 1 Phong 3', TO_DATE('2022-11-15','YYYY-MM-DD'), 3)
# into DEAN values('DA302', 'De An so 2 Phong 3', TO_DATE('2022-7-4','YYYY-MM-DD'), 3)
# into DEAN values('DA303', 'De An so 3 Phong 3', TO_DATE('2022-2-9','YYYY-MM-DD'), 3)
# into DEAN values('DA401', 'De An so 1 Phong 4', TO_DATE('2021-9-22','YYYY-MM-DD'), 4)
# into DEAN values('DA402', 'De An so 2 Phong 4', TO_DATE('2022-6-25','YYYY-MM-DD'), 4)
# into DEAN values('DA403', 'De An so 3 Phong 4', TO_DATE('2022-2-20','YYYY-MM-DD'), 4)
# into DEAN values('DA501', 'De An so 1 Phong 5', TO_DATE('2020-7-10','YYYY-MM-DD'), 5)
# into DEAN values('DA502', 'De An so 2 Phong 5', TO_DATE('2021-7-11','YYYY-MM-DD'), 5)
# into DEAN values('DA503', 'De An so 3 Phong 5', TO_DATE('2022-6-3','YYYY-MM-DD'), 5)
# into DEAN values('DA504', 'De An so 4 Phong 5', TO_DATE('2022-9-12','YYYY-MM-DD'), 5)
# into DEAN values('DA601', 'De An so 1 Phong 6', TO_DATE('2022-6-8','YYYY-MM-DD'), 6)
# into DEAN values('DA602', 'De An so 2 Phong 6', TO_DATE('2020-5-9','YYYY-MM-DD'), 6)
# into DEAN values('DA603', 'De An so 3 Phong 6', TO_DATE('2022-7-22','YYYY-MM-DD'), 6)
# into DEAN values('DA604', 'De An so 4 Phong 6', TO_DATE('2022-11-8','YYYY-MM-DD'), 6)
# into DEAN values('DA701', 'De An so 1 Phong 7', TO_DATE('2021-3-20','YYYY-MM-DD'), 7)
# into DEAN values('DA702', 'De An so 2 Phong 7', TO_DATE('2022-8-14','YYYY-MM-DD'), 7)
# into DEAN values('DA703', 'De An so 3 Phong 7', TO_DATE('2022-1-7','YYYY-MM-DD'), 7)
# into DEAN values('DA704', 'De An so 4 Phong 7', TO_DATE('2022-7-23','YYYY-MM-DD'), 7)
# into DEAN values('DA801', 'De An so 1 Phong 8', TO_DATE('2022-7-11','YYYY-MM-DD'), 8)
# into DEAN values('DA802', 'De An so 2 Phong 8', TO_DATE('2021-7-8','YYYY-MM-DD'), 8)
# into DEAN values('DA803', 'De An so 3 Phong 8', TO_DATE('2022-10-7','YYYY-MM-DD'), 8)

# %% [markdown]
# ## Phan Cong

# %%
'''
	PhanCong (
	MaNV 		varchar(10) primary key,
	MaDA 		varchar(10) primary key,
	ThoiGian 	date
	
)

'''
import numpy as np
for i in range(47, 347, 3):
    MaNV = '\'NV'+ str(i) + '\''
    for j in range(1, rd.randint(2, 3)):
        MaDA = '\'DA' + str(i%8 + 1) + '0' + str(j) + '\'';
        TG  = 'TO_DATE(' + '\'' + str(rd.randint(2020, 2022)) + '-' + str(rd.randint(1, 12)) + '-' + str(rd.randint(1, 28)) + '\',\'YYYY-MM-DD\')'
        final = MaNV + ', ' + MaDA + ', ' + TG  
        print('into PHANCONG values(' +  final + ')')
# Out:
# into PHANCONG values('NV47', 'DA801', TO_DATE('2021-5-12','YYYY-MM-DD'))
# into PHANCONG values('NV50', 'DA301', TO_DATE('2020-4-5','YYYY-MM-DD'))
# into PHANCONG values('NV50', 'DA302', TO_DATE('2022-12-13','YYYY-MM-DD'))
# into PHANCONG values('NV53', 'DA601', TO_DATE('2022-9-7','YYYY-MM-DD'))
# into PHANCONG values('NV56', 'DA101', TO_DATE('2022-8-28','YYYY-MM-DD'))
# into PHANCONG values('NV59', 'DA401', TO_DATE('2022-9-13','YYYY-MM-DD'))
# into PHANCONG values('NV62', 'DA701', TO_DATE('2020-11-27','YYYY-MM-DD'))
# into PHANCONG values('NV65', 'DA201', TO_DATE('2021-6-8','YYYY-MM-DD'))
# into PHANCONG values('NV65', 'DA202', TO_DATE('2021-11-11','YYYY-MM-DD'))
# into PHANCONG values('NV68', 'DA501', TO_DATE('2021-7-27','YYYY-MM-DD'))
# into PHANCONG values('NV68', 'DA502', TO_DATE('2022-6-8','YYYY-MM-DD'))
# into PHANCONG values('NV71', 'DA801', TO_DATE('2020-5-19','YYYY-MM-DD'))
# into PHANCONG values('NV71', 'DA802', TO_DATE('2020-1-12','YYYY-MM-DD'))
# into PHANCONG values('NV74', 'DA301', TO_DATE('2022-6-2','YYYY-MM-DD'))
# into PHANCONG values('NV74', 'DA302', TO_DATE('2022-3-21','YYYY-MM-DD'))
# into PHANCONG values('NV77', 'DA601', TO_DATE('2020-1-8','YYYY-MM-DD'))
# into PHANCONG values('NV77', 'DA602', TO_DATE('2022-9-5','YYYY-MM-DD'))
# into PHANCONG values('NV80', 'DA101', TO_DATE('2021-5-18','YYYY-MM-DD'))
# into PHANCONG values('NV83', 'DA401', TO_DATE('2021-1-22','YYYY-MM-DD'))
# into PHANCONG values('NV86', 'DA701', TO_DATE('2020-11-5','YYYY-MM-DD'))
# into PHANCONG values('NV89', 'DA201', TO_DATE('2021-1-23','YYYY-MM-DD'))
# into PHANCONG values('NV92', 'DA501', TO_DATE('2020-8-8','YYYY-MM-DD'))
# into PHANCONG values('NV92', 'DA502', TO_DATE('2020-4-20','YYYY-MM-DD'))
# into PHANCONG values('NV95', 'DA801', TO_DATE('2022-2-8','YYYY-MM-DD'))
# into PHANCONG values('NV95', 'DA802', TO_DATE('2020-10-26','YYYY-MM-DD'))
# into PHANCONG values('NV98', 'DA301', TO_DATE('2020-8-10','YYYY-MM-DD'))
# into PHANCONG values('NV101', 'DA601', TO_DATE('2022-5-22','YYYY-MM-DD'))
# into PHANCONG values('NV104', 'DA101', TO_DATE('2021-12-5','YYYY-MM-DD'))
# into PHANCONG values('NV104', 'DA102', TO_DATE('2020-2-20','YYYY-MM-DD'))
# into PHANCONG values('NV107', 'DA401', TO_DATE('2021-11-24','YYYY-MM-DD'))
# into PHANCONG values('NV110', 'DA701', TO_DATE('2021-10-22','YYYY-MM-DD'))
# into PHANCONG values('NV110', 'DA702', TO_DATE('2020-1-14','YYYY-MM-DD'))
# into PHANCONG values('NV113', 'DA201', TO_DATE('2020-8-14','YYYY-MM-DD'))
# into PHANCONG values('NV116', 'DA501', TO_DATE('2022-9-20','YYYY-MM-DD'))
# into PHANCONG values('NV119', 'DA801', TO_DATE('2021-1-26','YYYY-MM-DD'))
# into PHANCONG values('NV119', 'DA802', TO_DATE('2021-7-15','YYYY-MM-DD'))
# into PHANCONG values('NV122', 'DA301', TO_DATE('2021-3-2','YYYY-MM-DD'))
# into PHANCONG values('NV122', 'DA302', TO_DATE('2021-2-16','YYYY-MM-DD'))
# into PHANCONG values('NV125', 'DA601', TO_DATE('2021-7-19','YYYY-MM-DD'))
# into PHANCONG values('NV128', 'DA101', TO_DATE('2021-10-9','YYYY-MM-DD'))
# into PHANCONG values('NV128', 'DA102', TO_DATE('2020-9-24','YYYY-MM-DD'))
# into PHANCONG values('NV131', 'DA401', TO_DATE('2022-12-3','YYYY-MM-DD'))
# into PHANCONG values('NV134', 'DA701', TO_DATE('2020-5-15','YYYY-MM-DD'))
# into PHANCONG values('NV137', 'DA201', TO_DATE('2020-11-3','YYYY-MM-DD'))
# into PHANCONG values('NV137', 'DA202', TO_DATE('2022-8-7','YYYY-MM-DD'))
# into PHANCONG values('NV140', 'DA501', TO_DATE('2020-9-18','YYYY-MM-DD'))
# into PHANCONG values('NV140', 'DA502', TO_DATE('2021-8-3','YYYY-MM-DD'))
# into PHANCONG values('NV143', 'DA801', TO_DATE('2020-5-21','YYYY-MM-DD'))
# into PHANCONG values('NV143', 'DA802', TO_DATE('2021-10-12','YYYY-MM-DD'))
# into PHANCONG values('NV146', 'DA301', TO_DATE('2022-11-21','YYYY-MM-DD'))
# into PHANCONG values('NV149', 'DA601', TO_DATE('2020-2-8','YYYY-MM-DD'))
# into PHANCONG values('NV149', 'DA602', TO_DATE('2022-5-22','YYYY-MM-DD'))
# into PHANCONG values('NV152', 'DA101', TO_DATE('2022-6-20','YYYY-MM-DD'))
# into PHANCONG values('NV155', 'DA401', TO_DATE('2020-9-23','YYYY-MM-DD'))
# into PHANCONG values('NV155', 'DA402', TO_DATE('2022-4-13','YYYY-MM-DD'))
# into PHANCONG values('NV158', 'DA701', TO_DATE('2020-4-16','YYYY-MM-DD'))
# into PHANCONG values('NV158', 'DA702', TO_DATE('2021-11-8','YYYY-MM-DD'))
# into PHANCONG values('NV161', 'DA201', TO_DATE('2020-4-6','YYYY-MM-DD'))
# into PHANCONG values('NV161', 'DA202', TO_DATE('2021-2-16','YYYY-MM-DD'))
# into PHANCONG values('NV164', 'DA501', TO_DATE('2022-1-9','YYYY-MM-DD'))
# into PHANCONG values('NV167', 'DA801', TO_DATE('2021-2-20','YYYY-MM-DD'))
# into PHANCONG values('NV167', 'DA802', TO_DATE('2022-12-16','YYYY-MM-DD'))
# into PHANCONG values('NV170', 'DA301', TO_DATE('2021-1-22','YYYY-MM-DD'))
# into PHANCONG values('NV170', 'DA302', TO_DATE('2022-4-27','YYYY-MM-DD'))
# into PHANCONG values('NV173', 'DA601', TO_DATE('2020-8-27','YYYY-MM-DD'))
# into PHANCONG values('NV176', 'DA101', TO_DATE('2020-2-12','YYYY-MM-DD'))
# into PHANCONG values('NV176', 'DA102', TO_DATE('2022-7-12','YYYY-MM-DD'))
# into PHANCONG values('NV179', 'DA401', TO_DATE('2020-3-11','YYYY-MM-DD'))
# into PHANCONG values('NV182', 'DA701', TO_DATE('2022-4-21','YYYY-MM-DD'))
# into PHANCONG values('NV185', 'DA201', TO_DATE('2021-10-25','YYYY-MM-DD'))
# into PHANCONG values('NV185', 'DA202', TO_DATE('2022-5-12','YYYY-MM-DD'))
# into PHANCONG values('NV188', 'DA501', TO_DATE('2022-6-22','YYYY-MM-DD'))
# into PHANCONG values('NV188', 'DA502', TO_DATE('2020-1-21','YYYY-MM-DD'))
# into PHANCONG values('NV191', 'DA801', TO_DATE('2020-1-6','YYYY-MM-DD'))
# into PHANCONG values('NV191', 'DA802', TO_DATE('2022-7-24','YYYY-MM-DD'))
# into PHANCONG values('NV194', 'DA301', TO_DATE('2020-3-23','YYYY-MM-DD'))
# into PHANCONG values('NV197', 'DA601', TO_DATE('2020-9-5','YYYY-MM-DD'))
# into PHANCONG values('NV197', 'DA602', TO_DATE('2020-12-6','YYYY-MM-DD'))
# into PHANCONG values('NV200', 'DA101', TO_DATE('2022-9-21','YYYY-MM-DD'))
# into PHANCONG values('NV200', 'DA102', TO_DATE('2020-9-17','YYYY-MM-DD'))
# into PHANCONG values('NV203', 'DA401', TO_DATE('2022-8-26','YYYY-MM-DD'))
# into PHANCONG values('NV203', 'DA402', TO_DATE('2020-3-5','YYYY-MM-DD'))
# into PHANCONG values('NV206', 'DA701', TO_DATE('2020-12-26','YYYY-MM-DD'))
# into PHANCONG values('NV209', 'DA201', TO_DATE('2020-9-10','YYYY-MM-DD'))
# into PHANCONG values('NV212', 'DA501', TO_DATE('2022-1-1','YYYY-MM-DD'))
# into PHANCONG values('NV215', 'DA801', TO_DATE('2020-7-9','YYYY-MM-DD'))
# into PHANCONG values('NV215', 'DA802', TO_DATE('2022-8-13','YYYY-MM-DD'))
# into PHANCONG values('NV218', 'DA301', TO_DATE('2020-12-4','YYYY-MM-DD'))
# into PHANCONG values('NV218', 'DA302', TO_DATE('2022-5-27','YYYY-MM-DD'))
# into PHANCONG values('NV221', 'DA601', TO_DATE('2021-7-13','YYYY-MM-DD'))
# into PHANCONG values('NV224', 'DA101', TO_DATE('2022-2-17','YYYY-MM-DD'))
# into PHANCONG values('NV224', 'DA102', TO_DATE('2020-3-5','YYYY-MM-DD'))
# into PHANCONG values('NV227', 'DA401', TO_DATE('2021-1-10','YYYY-MM-DD'))
# into PHANCONG values('NV230', 'DA701', TO_DATE('2021-10-10','YYYY-MM-DD'))
# into PHANCONG values('NV233', 'DA201', TO_DATE('2020-2-28','YYYY-MM-DD'))
# into PHANCONG values('NV233', 'DA202', TO_DATE('2021-11-11','YYYY-MM-DD'))
# into PHANCONG values('NV236', 'DA501', TO_DATE('2021-9-10','YYYY-MM-DD'))
# into PHANCONG values('NV239', 'DA801', TO_DATE('2021-12-26','YYYY-MM-DD'))
# into PHANCONG values('NV239', 'DA802', TO_DATE('2021-8-18','YYYY-MM-DD'))
# into PHANCONG values('NV242', 'DA301', TO_DATE('2020-2-18','YYYY-MM-DD'))
# into PHANCONG values('NV242', 'DA302', TO_DATE('2020-5-8','YYYY-MM-DD'))
# into PHANCONG values('NV245', 'DA601', TO_DATE('2022-6-10','YYYY-MM-DD'))
# into PHANCONG values('NV248', 'DA101', TO_DATE('2021-4-24','YYYY-MM-DD'))
# into PHANCONG values('NV248', 'DA102', TO_DATE('2021-12-8','YYYY-MM-DD'))
# into PHANCONG values('NV251', 'DA401', TO_DATE('2022-6-28','YYYY-MM-DD'))
# into PHANCONG values('NV254', 'DA701', TO_DATE('2021-6-26','YYYY-MM-DD'))
# into PHANCONG values('NV254', 'DA702', TO_DATE('2020-1-22','YYYY-MM-DD'))
# into PHANCONG values('NV257', 'DA201', TO_DATE('2020-6-15','YYYY-MM-DD'))
# into PHANCONG values('NV257', 'DA202', TO_DATE('2020-5-26','YYYY-MM-DD'))
# into PHANCONG values('NV260', 'DA501', TO_DATE('2020-7-19','YYYY-MM-DD'))
# into PHANCONG values('NV263', 'DA801', TO_DATE('2022-5-13','YYYY-MM-DD'))
# into PHANCONG values('NV266', 'DA301', TO_DATE('2021-1-15','YYYY-MM-DD'))
# into PHANCONG values('NV266', 'DA302', TO_DATE('2022-10-19','YYYY-MM-DD'))
# into PHANCONG values('NV269', 'DA601', TO_DATE('2021-6-2','YYYY-MM-DD'))
# into PHANCONG values('NV269', 'DA602', TO_DATE('2021-2-28','YYYY-MM-DD'))
# into PHANCONG values('NV272', 'DA101', TO_DATE('2021-12-10','YYYY-MM-DD'))
# into PHANCONG values('NV275', 'DA401', TO_DATE('2020-10-19','YYYY-MM-DD'))
# into PHANCONG values('NV275', 'DA402', TO_DATE('2021-2-4','YYYY-MM-DD'))
# into PHANCONG values('NV278', 'DA701', TO_DATE('2022-12-3','YYYY-MM-DD'))
# into PHANCONG values('NV281', 'DA201', TO_DATE('2022-7-11','YYYY-MM-DD'))
# into PHANCONG values('NV284', 'DA501', TO_DATE('2022-6-25','YYYY-MM-DD'))
# into PHANCONG values('NV287', 'DA801', TO_DATE('2021-11-25','YYYY-MM-DD'))
# into PHANCONG values('NV287', 'DA802', TO_DATE('2022-11-28','YYYY-MM-DD'))
# into PHANCONG values('NV290', 'DA301', TO_DATE('2022-11-14','YYYY-MM-DD'))
# into PHANCONG values('NV290', 'DA302', TO_DATE('2020-11-17','YYYY-MM-DD'))
# into PHANCONG values('NV293', 'DA601', TO_DATE('2022-8-26','YYYY-MM-DD'))
# into PHANCONG values('NV296', 'DA101', TO_DATE('2020-2-3','YYYY-MM-DD'))
# into PHANCONG values('NV299', 'DA401', TO_DATE('2022-3-28','YYYY-MM-DD'))
# into PHANCONG values('NV302', 'DA701', TO_DATE('2021-7-1','YYYY-MM-DD'))
# into PHANCONG values('NV302', 'DA702', TO_DATE('2022-6-23','YYYY-MM-DD'))
# into PHANCONG values('NV305', 'DA201', TO_DATE('2020-4-26','YYYY-MM-DD'))
# into PHANCONG values('NV308', 'DA501', TO_DATE('2022-12-25','YYYY-MM-DD'))
# into PHANCONG values('NV311', 'DA801', TO_DATE('2020-4-26','YYYY-MM-DD'))
# into PHANCONG values('NV314', 'DA301', TO_DATE('2022-12-13','YYYY-MM-DD'))
# into PHANCONG values('NV317', 'DA601', TO_DATE('2020-2-8','YYYY-MM-DD'))
# into PHANCONG values('NV320', 'DA101', TO_DATE('2021-4-14','YYYY-MM-DD'))
# into PHANCONG values('NV320', 'DA102', TO_DATE('2021-3-25','YYYY-MM-DD'))
# into PHANCONG values('NV323', 'DA401', TO_DATE('2020-5-11','YYYY-MM-DD'))
# into PHANCONG values('NV326', 'DA701', TO_DATE('2020-6-9','YYYY-MM-DD'))
# into PHANCONG values('NV329', 'DA201', TO_DATE('2021-9-20','YYYY-MM-DD'))
# into PHANCONG values('NV332', 'DA501', TO_DATE('2021-12-20','YYYY-MM-DD'))
# into PHANCONG values('NV332', 'DA502', TO_DATE('2022-8-20','YYYY-MM-DD'))
# into PHANCONG values('NV335', 'DA801', TO_DATE('2022-7-4','YYYY-MM-DD'))
# into PHANCONG values('NV338', 'DA301', TO_DATE('2020-4-15','YYYY-MM-DD'))
# into PHANCONG values('NV341', 'DA601', TO_DATE('2022-10-26','YYYY-MM-DD'))
# into PHANCONG values('NV341', 'DA602', TO_DATE('2020-9-12','YYYY-MM-DD'))
# into PHANCONG values('NV344', 'DA101', TO_DATE('2022-10-27','YYYY-MM-DD'))
# into PHANCONG values('NV344', 'DA102', TO_DATE('2022-9-24','YYYY-MM-DD'))

# %% [markdown]
# # Tai khoan

# %%
'''
tai khoan:
    username varchar(50),
    password varchar(150),
    MaNV varchar(10)
'''
