# %%
import random as rd

insert = "insert into table "

# %%
Ho = [ 'Ho','Bui', 'Đoan', 'Le', 'Nguyen', 'Duong', 'Tran', 'Ly', 'Vu', 'Vo', 'Đang', 'Pham', 'Ung', 'An', 'Au','Truong', 'Lai', 'Gian' ]
tendem = ['Van','Thi','Chi','Gia','Hoang', 'Song', 'Tung' ]
ten = ['Ngoc Nhi','An','Anh','Bac','Bao','Cau','Cuc','Đan','Đang','Đuc','Thong','Tien','Tuan','Tin','Tiep','Viet','Vinh','Vu','Vy','Minh','Giang','khanh','Sang','Duy','Chi','Thuong','Chung','Phu','Quoc','Nam','Ngan','Nguyet','May' 
       ,'Tu','Thien','Tan','Han']

# %%
'''
NhanVien (
	MaNV 		varchar(10) primary key,
	TenNV 	varchar2(60) not null,
	Phai 		varchar2(4),
	NgaySinh 	date,
	DiaChi 	varchar2(100),
	SoDT 		varchar(10) not null unique,
	Luong 	number,
	PhuCap 	number,
	VaiTro 	varchar2(50),
	MaNQL 	varchar(10),
	PHG 		number
	
)
go
'''
'''
Nhân viên - 300
Quản lí - 20
Trưởng phòng - 8
Tài chính - 5
Nhân sự - 5
Trưởng đề án - 3
Ban giám đốc - 5
'''
sex = ['Nam', 'Nu']
import string

username = ''
MaNV = ''
TenNV = ''
Phai = ''
NgaySinh = ''
DiaChi 	= ''
SoDT 	= ''
Luong 	= 0
PhuCap 	= 0
VaiTro 	= ''
MaNQL 	= 'NULL'
PHG 	= 0
for i in range(1, 347):
    Luong = rd.randint(1000, 9999)
    PhuCap = rd.randint(1000, 2000)
    PHG = i % 8 + 1
    if i < 6:
        MaNV = '\'GD00'+ str(i) + '\''
        VaiTro 	= '\'Ban giam doc\''
        Luong = 55555
    elif i < 11:
        MaNV = '\'TC0'+ str(i) + '\''
        VaiTro 	= '\'Tai chinh\''
        Luong = 11000
    elif i < 16:
        MaNV = '\'NS0'+ str(i) + '\''
        VaiTro 	= '\'Nhan su\''
        Luong = 13000
    elif i < 36:
        MaNV = '\'QL0'+ str(i) + '\''
        VaiTro 	= '\'Quan li\''
        Luong = 25000
    elif i < 39:
        MaNV = '\'TDA0'+ str(i) + '\''
        VaiTro 	= '\'Truong de an\''
        Luong = 20000
    elif i < 47:
        MaNV = '\'TP0'+ str(i) + '\''
        VaiTro 	= '\'Truong phong\''
        Luong = 22000
        PHG = i - 38
    else:
        MaNV = '\'NV'+ str(i) + '\''
        VaiTro 	= '\'Nhan vien\''
     
    
    account_suffix = MaNV.replace("'", "")
    username = f'\'User{account_suffix}\''

    SoDT = '\'0945000' + str(i) + '\''
    TenNV = '\'' + rd.choice(Ho) + ' ' + rd.choice(tendem) + ' ' + rd.choice(ten) + '\''
    DiaChi = '\'227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh\'' 
    Phai = '\'' + rd.choice(sex) + '\''
    NgaySinh  = 'TO_DATE(' + '\'' + str(rd.randint(2000, 2022)) + '-' + str(rd.randint(1, 12)) + '-' + str(rd.randint(1, 28)) + '\',\'YYYY-MM-DD\')'
    
    final = MaNV + ', ' + TenNV + ', ' + Phai + ', ' + NgaySinh + ', ' + DiaChi +', ' + SoDT + ', ' + str(Luong) + ', ' + str(PhuCap) +', '+ VaiTro + ', ' + MaNQL + ', ' + str(PHG) + ', ' + username
    
    print (' into NHANVIEN values(' +  final + ')')
    
   # print('insert into TaiKhoan values(' + TenTaiKhoan + HoTen + str(Mk) + sdt + DiaChi + Email + LoaiTaiKhoan +')')
# Out:
#  into NHANVIEN values('GD001', 'Gian Hoang Vinh', 'Nu', TO_DATE('2001-11-12','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '09450001', 55555, 1148, 'Ban giam doc', NULL, 2, 'UserGD001')
#  into NHANVIEN values('GD002', 'Au Van Vinh', 'Nam', TO_DATE('2005-6-3','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '09450002', 55555, 1652, 'Ban giam doc', NULL, 3, 'UserGD002')
#  into NHANVIEN values('GD003', 'Đang Chi Giang', 'Nam', TO_DATE('2005-9-10','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '09450003', 55555, 1295, 'Ban giam doc', NULL, 4, 'UserGD003')
#  into NHANVIEN values('GD004', 'Ly Van Thuong', 'Nam', TO_DATE('2004-6-17','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '09450004', 55555, 1674, 'Ban giam doc', NULL, 5, 'UserGD004')
#  into NHANVIEN values('GD005', 'Vu Gia Thuong', 'Nam', TO_DATE('2015-11-15','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '09450005', 55555, 1865, 'Ban giam doc', NULL, 6, 'UserGD005')
#  into NHANVIEN values('TC06', 'Lai Hoang Bac', 'Nam', TO_DATE('2021-3-13','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '09450006', 11000, 1454, 'Tai chinh', NULL, 7, 'UserTC06')
#  into NHANVIEN values('TC07', 'Ly Thi khanh', 'Nu', TO_DATE('2007-10-10','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '09450007', 11000, 1093, 'Tai chinh', NULL, 8, 'UserTC07')
#  into NHANVIEN values('TC08', 'Duong Song Nguyet', 'Nam', TO_DATE('2001-5-15','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '09450008', 11000, 1855, 'Tai chinh', NULL, 1, 'UserTC08')
#  into NHANVIEN values('TC09', 'Ho Chi Nguyet', 'Nam', TO_DATE('2003-3-11','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '09450009', 11000, 1347, 'Tai chinh', NULL, 2, 'UserTC09')
#  into NHANVIEN values('TC010', 'Lai Chi Tu', 'Nam', TO_DATE('2006-8-1','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500010', 11000, 1798, 'Tai chinh', NULL, 3, 'UserTC010')
#  into NHANVIEN values('NS011', 'An Van khanh', 'Nam', TO_DATE('2003-12-1','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500011', 13000, 1061, 'Nhan su', NULL, 4, 'UserNS011')
#  into NHANVIEN values('NS012', 'Ung Song Tiep', 'Nu', TO_DATE('2018-4-6','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500012', 13000, 1220, 'Nhan su', NULL, 5, 'UserNS012')
#  into NHANVIEN values('NS013', 'Duong Van Bao', 'Nam', TO_DATE('2009-5-14','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500013', 13000, 1283, 'Nhan su', NULL, 6, 'UserNS013')
#  into NHANVIEN values('NS014', 'Duong Van Phu', 'Nam', TO_DATE('2017-1-25','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500014', 13000, 1558, 'Nhan su', NULL, 7, 'UserNS014')
#  into NHANVIEN values('NS015', 'Đoan Tung Đang', 'Nam', TO_DATE('2009-6-7','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500015', 13000, 1439, 'Nhan su', NULL, 8, 'UserNS015')
#  into NHANVIEN values('QL016', 'Đoan Chi Chi', 'Nu', TO_DATE('2020-4-1','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500016', 25000, 1061, 'Quan li', NULL, 1, 'UserQL016')
#  into NHANVIEN values('QL017', 'Truong Van Duy', 'Nam', TO_DATE('2002-3-10','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500017', 25000, 1659, 'Quan li', NULL, 2, 'UserQL017')
#  into NHANVIEN values('QL018', 'Le Song Nguyet', 'Nu', TO_DATE('2000-12-1','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500018', 25000, 1443, 'Quan li', NULL, 3, 'UserQL018')
#  into NHANVIEN values('QL019', 'Tran Hoang Quoc', 'Nu', TO_DATE('2003-10-2','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500019', 25000, 1413, 'Quan li', NULL, 4, 'UserQL019')
#  into NHANVIEN values('QL020', 'Duong Hoang Cuc', 'Nu', TO_DATE('2018-7-13','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500020', 25000, 1866, 'Quan li', NULL, 5, 'UserQL020')
#  into NHANVIEN values('QL021', 'Le Thi Chung', 'Nam', TO_DATE('2015-3-17','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500021', 25000, 1662, 'Quan li', NULL, 6, 'UserQL021')
#  into NHANVIEN values('QL022', 'Ho Song Tuan', 'Nu', TO_DATE('2004-4-2','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500022', 25000, 1534, 'Quan li', NULL, 7, 'UserQL022')
#  into NHANVIEN values('QL023', 'Tran Thi Tiep', 'Nam', TO_DATE('2019-6-12','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500023', 25000, 1715, 'Quan li', NULL, 8, 'UserQL023')
#  into NHANVIEN values('QL024', 'Đoan Hoang Giang', 'Nam', TO_DATE('2000-11-11','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500024', 25000, 1095, 'Quan li', NULL, 1, 'UserQL024')
#  into NHANVIEN values('QL025', 'Ho Chi Vinh', 'Nam', TO_DATE('2009-9-11','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500025', 25000, 1119, 'Quan li', NULL, 2, 'UserQL025')
#  into NHANVIEN values('QL026', 'Bui Van Vy', 'Nam', TO_DATE('2014-11-9','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500026', 25000, 1970, 'Quan li', NULL, 3, 'UserQL026')
#  into NHANVIEN values('QL027', 'Ho Gia Han', 'Nu', TO_DATE('2010-7-7','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500027', 25000, 1074, 'Quan li', NULL, 4, 'UserQL027')
#  into NHANVIEN values('QL028', 'Au Thi Tuan', 'Nu', TO_DATE('2004-2-17','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500028', 25000, 1242, 'Quan li', NULL, 5, 'UserQL028')
#  into NHANVIEN values('QL029', 'Duong Gia Bac', 'Nu', TO_DATE('2010-10-1','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500029', 25000, 1442, 'Quan li', NULL, 6, 'UserQL029')
#  into NHANVIEN values('QL030', 'Tran Song Đan', 'Nu', TO_DATE('2000-10-6','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500030', 25000, 1600, 'Quan li', NULL, 7, 'UserQL030')
#  into NHANVIEN values('QL031', 'Đoan Van Phu', 'Nu', TO_DATE('2021-10-17','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500031', 25000, 1454, 'Quan li', NULL, 8, 'UserQL031')
#  into NHANVIEN values('QL032', 'Ung Hoang Tin', 'Nam', TO_DATE('2022-2-18','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500032', 25000, 1055, 'Quan li', NULL, 1, 'UserQL032')
#  into NHANVIEN values('QL033', 'Đang Gia Duy', 'Nu', TO_DATE('2020-1-5','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500033', 25000, 1037, 'Quan li', NULL, 2, 'UserQL033')
#  into NHANVIEN values('QL034', 'Đang Gia khanh', 'Nam', TO_DATE('2000-4-26','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500034', 25000, 1182, 'Quan li', NULL, 3, 'UserQL034')
#  into NHANVIEN values('QL035', 'Truong Tung Vinh', 'Nu', TO_DATE('2007-5-8','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500035', 25000, 1307, 'Quan li', NULL, 4, 'UserQL035')
#  into NHANVIEN values('TDA036', 'An Van Đan', 'Nam', TO_DATE('2021-5-17','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500036', 20000, 1593, 'Truong de an', NULL, 5, 'UserTDA036')
#  into NHANVIEN values('TDA037', 'Ho Thi Nguyet', 'Nam', TO_DATE('2015-11-8','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500037', 20000, 1861, 'Truong de an', NULL, 6, 'UserTDA037')
#  into NHANVIEN values('TDA038', 'Ly Tung Quoc', 'Nu', TO_DATE('2003-5-18','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500038', 20000, 1787, 'Truong de an', NULL, 7, 'UserTDA038')
#  into NHANVIEN values('TP039', 'Nguyen Gia Tiep', 'Nu', TO_DATE('2004-3-6','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500039', 22000, 1071, 'Truong phong', NULL, 1, 'UserTP039')
#  into NHANVIEN values('TP040', 'Truong Hoang Vinh', 'Nam', TO_DATE('2015-6-3','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500040', 22000, 1263, 'Truong phong', NULL, 2, 'UserTP040')
#  into NHANVIEN values('TP041', 'Nguyen Van Anh', 'Nam', TO_DATE('2013-8-13','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500041', 22000, 1716, 'Truong phong', NULL, 3, 'UserTP041')
#  into NHANVIEN values('TP042', 'Pham Hoang Tiep', 'Nam', TO_DATE('2002-7-10','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500042', 22000, 1234, 'Truong phong', NULL, 4, 'UserTP042')
#  into NHANVIEN values('TP043', 'Vo Tung Tan', 'Nam', TO_DATE('2013-4-28','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500043', 22000, 1565, 'Truong phong', NULL, 5, 'UserTP043')
#  into NHANVIEN values('TP044', 'Pham Van Cuc', 'Nu', TO_DATE('2014-4-4','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500044', 22000, 1654, 'Truong phong', NULL, 6, 'UserTP044')
#  into NHANVIEN values('TP045', 'Đang Thi Tien', 'Nu', TO_DATE('2000-7-6','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500045', 22000, 1842, 'Truong phong', NULL, 7, 'UserTP045')
#  into NHANVIEN values('TP046', 'Nguyen Tung Tin', 'Nam', TO_DATE('2018-8-18','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500046', 22000, 1146, 'Truong phong', NULL, 8, 'UserTP046')
#  into NHANVIEN values('NV47', 'An Gia Minh', 'Nu', TO_DATE('2006-3-10','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500047', 5750, 1077, 'Nhan vien', NULL, 8, 'UserNV47')
#  into NHANVIEN values('NV48', 'Lai Gia Bac', 'Nam', TO_DATE('2022-7-19','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500048', 9340, 1951, 'Nhan vien', NULL, 1, 'UserNV48')
#  into NHANVIEN values('NV49', 'Gian Gia Chung', 'Nam', TO_DATE('2015-7-13','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500049', 1359, 1665, 'Nhan vien', NULL, 2, 'UserNV49')
#  into NHANVIEN values('NV50', 'Vo Hoang Bac', 'Nu', TO_DATE('2021-6-5','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500050', 9472, 1961, 'Nhan vien', NULL, 3, 'UserNV50')
#  into NHANVIEN values('NV51', 'Đang Tung Thuong', 'Nam', TO_DATE('2020-6-22','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500051', 7388, 1024, 'Nhan vien', NULL, 4, 'UserNV51')
#  into NHANVIEN values('NV52', 'Đang Gia Thien', 'Nu', TO_DATE('2003-7-2','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500052', 8876, 1653, 'Nhan vien', NULL, 5, 'UserNV52')
#  into NHANVIEN values('NV53', 'Truong Gia Nguyet', 'Nam', TO_DATE('2000-7-16','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500053', 7527, 1717, 'Nhan vien', NULL, 6, 'UserNV53')
#  into NHANVIEN values('NV54', 'Vo Thi khanh', 'Nam', TO_DATE('2002-10-15','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500054', 7365, 1465, 'Nhan vien', NULL, 7, 'UserNV54')
#  into NHANVIEN values('NV55', 'Bui Song Chi', 'Nu', TO_DATE('2008-10-6','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500055', 9383, 1642, 'Nhan vien', NULL, 8, 'UserNV55')
#  into NHANVIEN values('NV56', 'Le Thi Thien', 'Nu', TO_DATE('2016-1-15','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500056', 6315, 1719, 'Nhan vien', NULL, 1, 'UserNV56')
#  into NHANVIEN values('NV57', 'Lai Thi Tien', 'Nam', TO_DATE('2000-2-17','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500057', 7047, 1790, 'Nhan vien', NULL, 2, 'UserNV57')
#  into NHANVIEN values('NV58', 'Lai Thi Ngan', 'Nu', TO_DATE('2016-9-26','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500058', 2305, 1461, 'Nhan vien', NULL, 3, 'UserNV58')
#  into NHANVIEN values('NV59', 'Đang Chi Duy', 'Nam', TO_DATE('2009-9-9','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500059', 2636, 1030, 'Nhan vien', NULL, 4, 'UserNV59')
#  into NHANVIEN values('NV60', 'Ho Van Tan', 'Nu', TO_DATE('2013-11-12','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500060', 3984, 1114, 'Nhan vien', NULL, 5, 'UserNV60')
#  into NHANVIEN values('NV61', 'Lai Chi Vy', 'Nam', TO_DATE('2009-11-23','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500061', 5106, 1229, 'Nhan vien', NULL, 6, 'UserNV61')
#  into NHANVIEN values('NV62', 'Duong Hoang Bac', 'Nam', TO_DATE('2010-7-13','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500062', 3542, 1483, 'Nhan vien', NULL, 7, 'UserNV62')
#  into NHANVIEN values('NV63', 'Đang Van Tien', 'Nam', TO_DATE('2016-1-11','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500063', 4424, 1601, 'Nhan vien', NULL, 8, 'UserNV63')
#  into NHANVIEN values('NV64', 'Au Hoang Viet', 'Nu', TO_DATE('2007-7-10','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500064', 1556, 1032, 'Nhan vien', NULL, 1, 'UserNV64')
#  into NHANVIEN values('NV65', 'Tran Song Ngoc Nhi', 'Nu', TO_DATE('2010-8-20','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500065', 1115, 1205, 'Nhan vien', NULL, 2, 'UserNV65')
#  into NHANVIEN values('NV66', 'Au Van Sang', 'Nu', TO_DATE('2007-7-27','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500066', 8130, 1261, 'Nhan vien', NULL, 3, 'UserNV66')
#  into NHANVIEN values('NV67', 'Đoan Chi Tuan', 'Nu', TO_DATE('2009-10-6','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500067', 2290, 1316, 'Nhan vien', NULL, 4, 'UserNV67')
#  into NHANVIEN values('NV68', 'Gian Van Quoc', 'Nu', TO_DATE('2018-8-26','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500068', 2694, 1211, 'Nhan vien', NULL, 5, 'UserNV68')
#  into NHANVIEN values('NV69', 'Pham Chi Han', 'Nu', TO_DATE('2008-11-22','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500069', 4850, 1181, 'Nhan vien', NULL, 6, 'UserNV69')
#  into NHANVIEN values('NV70', 'Duong Gia Sang', 'Nam', TO_DATE('2015-9-23','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500070', 5297, 1301, 'Nhan vien', NULL, 7, 'UserNV70')
#  into NHANVIEN values('NV71', 'Tran Hoang Thien', 'Nam', TO_DATE('2001-4-5','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500071', 5763, 1282, 'Nhan vien', NULL, 8, 'UserNV71')
#  into NHANVIEN values('NV72', 'Pham Song Tiep', 'Nu', TO_DATE('2016-11-14','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500072', 5603, 1438, 'Nhan vien', NULL, 1, 'UserNV72')
#  into NHANVIEN values('NV73', 'Nguyen Hoang Thuong', 'Nu', TO_DATE('2012-12-9','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500073', 4488, 1521, 'Nhan vien', NULL, 2, 'UserNV73')
#  into NHANVIEN values('NV74', 'Ung Tung Thien', 'Nu', TO_DATE('2020-10-8','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500074', 6189, 1036, 'Nhan vien', NULL, 3, 'UserNV74')
#  into NHANVIEN values('NV75', 'An Song Minh', 'Nu', TO_DATE('2000-2-4','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500075', 3476, 1167, 'Nhan vien', NULL, 4, 'UserNV75')
#  into NHANVIEN values('NV76', 'Truong Thi Ngoc Nhi', 'Nu', TO_DATE('2018-2-22','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500076', 8568, 1825, 'Nhan vien', NULL, 5, 'UserNV76')
#  into NHANVIEN values('NV77', 'Vu Chi Giang', 'Nu', TO_DATE('2011-10-8','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500077', 7805, 1308, 'Nhan vien', NULL, 6, 'UserNV77')
#  into NHANVIEN values('NV78', 'An Song Minh', 'Nu', TO_DATE('2014-2-9','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500078', 4334, 1441, 'Nhan vien', NULL, 7, 'UserNV78')
#  into NHANVIEN values('NV79', 'Au Chi Viet', 'Nam', TO_DATE('2013-4-12','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500079', 1427, 1787, 'Nhan vien', NULL, 8, 'UserNV79')
#  into NHANVIEN values('NV80', 'Ho Hoang Đuc', 'Nam', TO_DATE('2000-3-17','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500080', 5669, 1582, 'Nhan vien', NULL, 1, 'UserNV80')
#  into NHANVIEN values('NV81', 'An Chi Viet', 'Nam', TO_DATE('2005-4-8','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500081', 4927, 1444, 'Nhan vien', NULL, 2, 'UserNV81')
#  into NHANVIEN values('NV82', 'Ly Van Ngan', 'Nu', TO_DATE('2005-1-2','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500082', 2073, 1578, 'Nhan vien', NULL, 3, 'UserNV82')
#  into NHANVIEN values('NV83', 'Ung Thi Sang', 'Nam', TO_DATE('2019-10-28','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500083', 4234, 1881, 'Nhan vien', NULL, 4, 'UserNV83')
#  into NHANVIEN values('NV84', 'Đoan Gia Đang', 'Nu', TO_DATE('2006-12-18','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500084', 9461, 1571, 'Nhan vien', NULL, 5, 'UserNV84')
#  into NHANVIEN values('NV85', 'An Van Tu', 'Nu', TO_DATE('2020-8-10','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500085', 5961, 1358, 'Nhan vien', NULL, 6, 'UserNV85')
#  into NHANVIEN values('NV86', 'Le Hoang Thuong', 'Nu', TO_DATE('2004-7-1','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500086', 6292, 1916, 'Nhan vien', NULL, 7, 'UserNV86')
#  into NHANVIEN values('NV87', 'Bui Song May', 'Nam', TO_DATE('2015-10-18','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500087', 3881, 1644, 'Nhan vien', NULL, 8, 'UserNV87')
#  into NHANVIEN values('NV88', 'Đang Thi Bao', 'Nam', TO_DATE('2007-11-23','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500088', 5754, 1731, 'Nhan vien', NULL, 1, 'UserNV88')
#  into NHANVIEN values('NV89', 'Tran Song Nguyet', 'Nam', TO_DATE('2016-8-13','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500089', 1994, 1097, 'Nhan vien', NULL, 2, 'UserNV89')
#  into NHANVIEN values('NV90', 'Nguyen Van Ngoc Nhi', 'Nam', TO_DATE('2018-8-10','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500090', 3428, 1661, 'Nhan vien', NULL, 3, 'UserNV90')
#  into NHANVIEN values('NV91', 'An Thi Tan', 'Nam', TO_DATE('2003-5-9','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500091', 7567, 1542, 'Nhan vien', NULL, 4, 'UserNV91')
#  into NHANVIEN values('NV92', 'Bui Gia Quoc', 'Nam', TO_DATE('2011-3-12','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500092', 2925, 1683, 'Nhan vien', NULL, 5, 'UserNV92')
#  into NHANVIEN values('NV93', 'Đoan Hoang Tiep', 'Nu', TO_DATE('2019-4-10','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500093', 9253, 1246, 'Nhan vien', NULL, 6, 'UserNV93')
#  into NHANVIEN values('NV94', 'Pham Hoang Tiep', 'Nam', TO_DATE('2004-11-10','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500094', 1167, 1544, 'Nhan vien', NULL, 7, 'UserNV94')
#  into NHANVIEN values('NV95', 'Đang Hoang Tuan', 'Nam', TO_DATE('2015-10-13','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500095', 9638, 1209, 'Nhan vien', NULL, 8, 'UserNV95')
#  into NHANVIEN values('NV96', 'Vu Song Đang', 'Nam', TO_DATE('2020-7-10','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500096', 4902, 1849, 'Nhan vien', NULL, 1, 'UserNV96')
#  into NHANVIEN values('NV97', 'Nguyen Tung Duy', 'Nam', TO_DATE('2016-7-6','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500097', 3270, 1721, 'Nhan vien', NULL, 2, 'UserNV97')
#  into NHANVIEN values('NV98', 'Duong Thi An', 'Nu', TO_DATE('2019-6-1','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500098', 9405, 1086, 'Nhan vien', NULL, 3, 'UserNV98')
#  into NHANVIEN values('NV99', 'Ung Gia Vu', 'Nu', TO_DATE('2017-5-9','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500099', 3253, 1771, 'Nhan vien', NULL, 4, 'UserNV99')
#  into NHANVIEN values('NV100', 'Vu Tung Quoc', 'Nu', TO_DATE('2008-4-18','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000100', 6347, 1771, 'Nhan vien', NULL, 5, 'UserNV100')
#  into NHANVIEN values('NV101', 'Au Chi Cau', 'Nu', TO_DATE('2018-9-22','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000101', 9384, 1945, 'Nhan vien', NULL, 6, 'UserNV101')
#  into NHANVIEN values('NV102', 'Truong Tung Vy', 'Nam', TO_DATE('2000-11-14','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000102', 2929, 1774, 'Nhan vien', NULL, 7, 'UserNV102')
#  into NHANVIEN values('NV103', 'Pham Hoang Phu', 'Nu', TO_DATE('2001-9-24','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000103', 5756, 1429, 'Nhan vien', NULL, 8, 'UserNV103')
#  into NHANVIEN values('NV104', 'Tran Thi Minh', 'Nam', TO_DATE('2006-6-23','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000104', 5372, 1972, 'Nhan vien', NULL, 1, 'UserNV104')
#  into NHANVIEN values('NV105', 'Truong Gia Chi', 'Nu', TO_DATE('2021-4-13','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000105', 1867, 1377, 'Nhan vien', NULL, 2, 'UserNV105')
#  into NHANVIEN values('NV106', 'Lai Thi Tan', 'Nu', TO_DATE('2011-12-25','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000106', 8153, 1035, 'Nhan vien', NULL, 3, 'UserNV106')
#  into NHANVIEN values('NV107', 'Le Tung Anh', 'Nam', TO_DATE('2012-9-18','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000107', 1201, 1721, 'Nhan vien', NULL, 4, 'UserNV107')
#  into NHANVIEN values('NV108', 'Le Hoang Sang', 'Nu', TO_DATE('2020-12-10','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000108', 6326, 1244, 'Nhan vien', NULL, 5, 'UserNV108')
#  into NHANVIEN values('NV109', 'Đoan Thi Tien', 'Nu', TO_DATE('2019-3-7','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000109', 8406, 1877, 'Nhan vien', NULL, 6, 'UserNV109')
#  into NHANVIEN values('NV110', 'Ung Chi Tuan', 'Nu', TO_DATE('2022-10-7','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000110', 4631, 1310, 'Nhan vien', NULL, 7, 'UserNV110')
#  into NHANVIEN values('NV111', 'Truong Chi khanh', 'Nu', TO_DATE('2020-12-5','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000111', 3179, 1219, 'Nhan vien', NULL, 8, 'UserNV111')
#  into NHANVIEN values('NV112', 'Bui Chi khanh', 'Nam', TO_DATE('2019-1-2','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000112', 8174, 1162, 'Nhan vien', NULL, 1, 'UserNV112')
#  into NHANVIEN values('NV113', 'Duong Hoang Đang', 'Nam', TO_DATE('2011-1-1','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000113', 7652, 1648, 'Nhan vien', NULL, 2, 'UserNV113')
#  into NHANVIEN values('NV114', 'Ho Chi Tin', 'Nam', TO_DATE('2001-12-5','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000114', 7685, 1707, 'Nhan vien', NULL, 3, 'UserNV114')
#  into NHANVIEN values('NV115', 'Ung Chi Bac', 'Nam', TO_DATE('2011-9-10','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000115', 8084, 1583, 'Nhan vien', NULL, 4, 'UserNV115')
#  into NHANVIEN values('NV116', 'Le Tung Vinh', 'Nam', TO_DATE('2005-10-27','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000116', 6721, 1952, 'Nhan vien', NULL, 5, 'UserNV116')
#  into NHANVIEN values('NV117', 'Le Chi Anh', 'Nam', TO_DATE('2009-9-2','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000117', 7442, 1655, 'Nhan vien', NULL, 6, 'UserNV117')
#  into NHANVIEN values('NV118', 'Vu Hoang Cau', 'Nu', TO_DATE('2022-12-27','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000118', 6616, 1978, 'Nhan vien', NULL, 7, 'UserNV118')
#  into NHANVIEN values('NV119', 'Ung Hoang Viet', 'Nu', TO_DATE('2014-5-25','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000119', 1724, 1161, 'Nhan vien', NULL, 8, 'UserNV119')
#  into NHANVIEN values('NV120', 'Pham Hoang Giang', 'Nam', TO_DATE('2009-6-13','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000120', 2783, 1437, 'Nhan vien', NULL, 1, 'UserNV120')
#  into NHANVIEN values('NV121', 'Truong Song Tien', 'Nu', TO_DATE('2005-9-19','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000121', 6449, 1860, 'Nhan vien', NULL, 2, 'UserNV121')
#  into NHANVIEN values('NV122', 'Đoan Tung Tien', 'Nam', TO_DATE('2015-7-17','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000122', 1120, 1925, 'Nhan vien', NULL, 3, 'UserNV122')
#  into NHANVIEN values('NV123', 'An Gia Cau', 'Nam', TO_DATE('2008-4-4','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000123', 9511, 1933, 'Nhan vien', NULL, 4, 'UserNV123')
#  into NHANVIEN values('NV124', 'Tran Tung Thien', 'Nu', TO_DATE('2007-3-3','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000124', 6527, 1348, 'Nhan vien', NULL, 5, 'UserNV124')
#  into NHANVIEN values('NV125', 'Bui Chi Minh', 'Nu', TO_DATE('2019-7-4','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000125', 6413, 1403, 'Nhan vien', NULL, 6, 'UserNV125')
#  into NHANVIEN values('NV126', 'Vo Hoang Tiep', 'Nu', TO_DATE('2006-6-21','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000126', 7039, 1664, 'Nhan vien', NULL, 7, 'UserNV126')
#  into NHANVIEN values('NV127', 'Tran Song Tuan', 'Nu', TO_DATE('2021-4-8','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000127', 7862, 1937, 'Nhan vien', NULL, 8, 'UserNV127')
#  into NHANVIEN values('NV128', 'Ung Hoang Vy', 'Nam', TO_DATE('2010-4-1','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000128', 5155, 1056, 'Nhan vien', NULL, 1, 'UserNV128')
#  into NHANVIEN values('NV129', 'An Van Viet', 'Nam', TO_DATE('2020-11-5','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000129', 6790, 1368, 'Nhan vien', NULL, 2, 'UserNV129')
#  into NHANVIEN values('NV130', 'An Hoang Bao', 'Nu', TO_DATE('2014-1-20','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000130', 8322, 1036, 'Nhan vien', NULL, 3, 'UserNV130')
#  into NHANVIEN values('NV131', 'Truong Gia Thien', 'Nam', TO_DATE('2004-1-3','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000131', 2603, 1946, 'Nhan vien', NULL, 4, 'UserNV131')
#  into NHANVIEN values('NV132', 'Truong Thi Minh', 'Nam', TO_DATE('2003-7-24','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000132', 9188, 1708, 'Nhan vien', NULL, 5, 'UserNV132')
#  into NHANVIEN values('NV133', 'Au Hoang Nam', 'Nu', TO_DATE('2004-7-15','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000133', 2169, 1457, 'Nhan vien', NULL, 6, 'UserNV133')
#  into NHANVIEN values('NV134', 'Pham Hoang Tu', 'Nu', TO_DATE('2007-2-13','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000134', 4792, 1953, 'Nhan vien', NULL, 7, 'UserNV134')
#  into NHANVIEN values('NV135', 'Lai Chi Thien', 'Nam', TO_DATE('2003-4-4','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000135', 5169, 1074, 'Nhan vien', NULL, 8, 'UserNV135')
#  into NHANVIEN values('NV136', 'Đang Thi Bao', 'Nu', TO_DATE('2019-8-12','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000136', 4557, 1763, 'Nhan vien', NULL, 1, 'UserNV136')
#  into NHANVIEN values('NV137', 'Đoan Van Cuc', 'Nu', TO_DATE('2005-5-7','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000137', 6892, 1280, 'Nhan vien', NULL, 2, 'UserNV137')
#  into NHANVIEN values('NV138', 'Truong Chi Thien', 'Nam', TO_DATE('2008-5-19','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000138', 1385, 1297, 'Nhan vien', NULL, 3, 'UserNV138')
#  into NHANVIEN values('NV139', 'Lai Van Thuong', 'Nam', TO_DATE('2001-2-1','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000139', 1783, 1854, 'Nhan vien', NULL, 4, 'UserNV139')
#  into NHANVIEN values('NV140', 'Bui Thi Thong', 'Nu', TO_DATE('2013-10-13','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000140', 1890, 1862, 'Nhan vien', NULL, 5, 'UserNV140')
#  into NHANVIEN values('NV141', 'Ung Thi Đuc', 'Nu', TO_DATE('2005-10-16','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000141', 5858, 1811, 'Nhan vien', NULL, 6, 'UserNV141')
#  into NHANVIEN values('NV142', 'Duong Hoang Thuong', 'Nam', TO_DATE('2022-5-14','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000142', 8583, 1794, 'Nhan vien', NULL, 7, 'UserNV142')
#  into NHANVIEN values('NV143', 'Pham Hoang Nam', 'Nam', TO_DATE('2012-3-27','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000143', 7730, 1881, 'Nhan vien', NULL, 8, 'UserNV143')
#  into NHANVIEN values('NV144', 'Vu Chi Thong', 'Nu', TO_DATE('2008-7-26','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000144', 7616, 1007, 'Nhan vien', NULL, 1, 'UserNV144')
#  into NHANVIEN values('NV145', 'Lai Gia Bao', 'Nu', TO_DATE('2022-5-12','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000145', 3227, 1223, 'Nhan vien', NULL, 2, 'UserNV145')
#  into NHANVIEN values('NV146', 'Le Hoang Thong', 'Nam', TO_DATE('2021-8-2','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000146', 4741, 1282, 'Nhan vien', NULL, 3, 'UserNV146')
#  into NHANVIEN values('NV147', 'Gian Hoang Đan', 'Nam', TO_DATE('2004-12-20','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000147', 1483, 1071, 'Nhan vien', NULL, 4, 'UserNV147')
#  into NHANVIEN values('NV148', 'An Hoang Nguyet', 'Nu', TO_DATE('2020-6-6','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000148', 6161, 1729, 'Nhan vien', NULL, 5, 'UserNV148')
#  into NHANVIEN values('NV149', 'Đang Hoang Bao', 'Nu', TO_DATE('2022-9-28','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000149', 2630, 1174, 'Nhan vien', NULL, 6, 'UserNV149')
#  into NHANVIEN values('NV150', 'Gian Thi Ngan', 'Nu', TO_DATE('2008-10-22','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000150', 8093, 1188, 'Nhan vien', NULL, 7, 'UserNV150')
#  into NHANVIEN values('NV151', 'Đang Gia Viet', 'Nu', TO_DATE('2007-10-11','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000151', 5396, 1751, 'Nhan vien', NULL, 8, 'UserNV151')
#  into NHANVIEN values('NV152', 'Đoan Hoang Ngan', 'Nu', TO_DATE('2017-11-22','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000152', 4498, 1366, 'Nhan vien', NULL, 1, 'UserNV152')
#  into NHANVIEN values('NV153', 'Au Thi Nam', 'Nu', TO_DATE('2001-11-3','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000153', 8518, 1775, 'Nhan vien', NULL, 2, 'UserNV153')
#  into NHANVIEN values('NV154', 'Ung Van Tu', 'Nu', TO_DATE('2012-7-9','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000154', 6510, 1363, 'Nhan vien', NULL, 3, 'UserNV154')
#  into NHANVIEN values('NV155', 'Đoan Van Vu', 'Nam', TO_DATE('2003-9-2','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000155', 3769, 1002, 'Nhan vien', NULL, 4, 'UserNV155')
#  into NHANVIEN values('NV156', 'Au Tung Han', 'Nu', TO_DATE('2000-12-23','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000156', 1624, 1849, 'Nhan vien', NULL, 5, 'UserNV156')
#  into NHANVIEN values('NV157', 'Pham Chi Đan', 'Nam', TO_DATE('2005-2-22','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000157', 3182, 1990, 'Nhan vien', NULL, 6, 'UserNV157')
#  into NHANVIEN values('NV158', 'Bui Thi Tu', 'Nam', TO_DATE('2009-5-11','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000158', 6074, 1361, 'Nhan vien', NULL, 7, 'UserNV158')
#  into NHANVIEN values('NV159', 'Gian Van Vu', 'Nam', TO_DATE('2010-10-25','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000159', 4276, 1716, 'Nhan vien', NULL, 8, 'UserNV159')
#  into NHANVIEN values('NV160', 'Tran Song Tien', 'Nu', TO_DATE('2009-11-13','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000160', 5992, 1216, 'Nhan vien', NULL, 1, 'UserNV160')
#  into NHANVIEN values('NV161', 'An Chi May', 'Nam', TO_DATE('2021-2-10','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000161', 6276, 1878, 'Nhan vien', NULL, 2, 'UserNV161')
#  into NHANVIEN values('NV162', 'Đang Thi Tu', 'Nu', TO_DATE('2008-11-1','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000162', 6800, 1832, 'Nhan vien', NULL, 3, 'UserNV162')
#  into NHANVIEN values('NV163', 'Bui Chi Chung', 'Nu', TO_DATE('2010-8-9','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000163', 7323, 1110, 'Nhan vien', NULL, 4, 'UserNV163')
#  into NHANVIEN values('NV164', 'Duong Song Thien', 'Nam', TO_DATE('2015-3-15','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000164', 8341, 1704, 'Nhan vien', NULL, 5, 'UserNV164')
#  into NHANVIEN values('NV165', 'Ly Thi Vu', 'Nu', TO_DATE('2000-9-12','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000165', 5724, 1002, 'Nhan vien', NULL, 6, 'UserNV165')
#  into NHANVIEN values('NV166', 'Vu Chi Tu', 'Nu', TO_DATE('2017-2-22','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000166', 8045, 1768, 'Nhan vien', NULL, 7, 'UserNV166')
#  into NHANVIEN values('NV167', 'Au Thi Minh', 'Nam', TO_DATE('2011-10-26','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000167', 7541, 1167, 'Nhan vien', NULL, 8, 'UserNV167')
#  into NHANVIEN values('NV168', 'Au Song Tien', 'Nam', TO_DATE('2022-8-18','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000168', 4754, 1912, 'Nhan vien', NULL, 1, 'UserNV168')
#  into NHANVIEN values('NV169', 'Duong Hoang Nam', 'Nam', TO_DATE('2022-11-11','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000169', 8749, 1784, 'Nhan vien', NULL, 2, 'UserNV169')
#  into NHANVIEN values('NV170', 'Lai Tung Phu', 'Nam', TO_DATE('2003-12-26','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000170', 8824, 1671, 'Nhan vien', NULL, 3, 'UserNV170')
#  into NHANVIEN values('NV171', 'Đoan Song Vu', 'Nu', TO_DATE('2021-1-11','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000171', 5131, 1553, 'Nhan vien', NULL, 4, 'UserNV171')
#  into NHANVIEN values('NV172', 'Ly Tung Bac', 'Nu', TO_DATE('2016-6-25','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000172', 8056, 1716, 'Nhan vien', NULL, 5, 'UserNV172')
#  into NHANVIEN values('NV173', 'Vo Song Viet', 'Nu', TO_DATE('2014-10-19','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000173', 4148, 1615, 'Nhan vien', NULL, 6, 'UserNV173')
#  into NHANVIEN values('NV174', 'Đoan Chi Vu', 'Nam', TO_DATE('2002-8-20','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000174', 9240, 1181, 'Nhan vien', NULL, 7, 'UserNV174')
#  into NHANVIEN values('NV175', 'Ho Tung Tan', 'Nam', TO_DATE('2013-9-27','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000175', 9724, 1146, 'Nhan vien', NULL, 8, 'UserNV175')
#  into NHANVIEN values('NV176', 'Tran Thi Minh', 'Nu', TO_DATE('2002-10-21','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000176', 6745, 1643, 'Nhan vien', NULL, 1, 'UserNV176')
#  into NHANVIEN values('NV177', 'Truong Chi Thuong', 'Nu', TO_DATE('2005-10-5','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000177', 5149, 1561, 'Nhan vien', NULL, 2, 'UserNV177')
#  into NHANVIEN values('NV178', 'Ung Gia Bac', 'Nam', TO_DATE('2003-8-18','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000178', 4940, 1841, 'Nhan vien', NULL, 3, 'UserNV178')
#  into NHANVIEN values('NV179', 'An Thi Thien', 'Nu', TO_DATE('2013-7-20','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000179', 9308, 1274, 'Nhan vien', NULL, 4, 'UserNV179')
#  into NHANVIEN values('NV180', 'Duong Gia Đuc', 'Nam', TO_DATE('2021-7-17','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000180', 1171, 1569, 'Nhan vien', NULL, 5, 'UserNV180')
#  into NHANVIEN values('NV181', 'Au Tung khanh', 'Nu', TO_DATE('2012-3-18','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000181', 1686, 1078, 'Nhan vien', NULL, 6, 'UserNV181')
#  into NHANVIEN values('NV182', 'Ly Song Thuong', 'Nam', TO_DATE('2015-2-22','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000182', 8320, 1048, 'Nhan vien', NULL, 7, 'UserNV182')
#  into NHANVIEN values('NV183', 'Đang Van Vinh', 'Nam', TO_DATE('2020-9-21','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000183', 9033, 1730, 'Nhan vien', NULL, 8, 'UserNV183')
#  into NHANVIEN values('NV184', 'Le Tung Đang', 'Nu', TO_DATE('2003-4-5','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000184', 2903, 1978, 'Nhan vien', NULL, 1, 'UserNV184')
#  into NHANVIEN values('NV185', 'Lai Tung Tuan', 'Nam', TO_DATE('2004-4-21','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000185', 3341, 1898, 'Nhan vien', NULL, 2, 'UserNV185')
#  into NHANVIEN values('NV186', 'Ly Tung Đuc', 'Nu', TO_DATE('2010-12-25','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000186', 7915, 1664, 'Nhan vien', NULL, 3, 'UserNV186')
#  into NHANVIEN values('NV187', 'Ly Song An', 'Nu', TO_DATE('2001-8-11','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000187', 6364, 1905, 'Nhan vien', NULL, 4, 'UserNV187')
#  into NHANVIEN values('NV188', 'Vu Chi May', 'Nam', TO_DATE('2010-9-13','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000188', 1431, 1717, 'Nhan vien', NULL, 5, 'UserNV188')
#  into NHANVIEN values('NV189', 'Duong Chi khanh', 'Nu', TO_DATE('2006-11-18','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000189', 3806, 1604, 'Nhan vien', NULL, 6, 'UserNV189')
#  into NHANVIEN values('NV190', 'Gian Gia Chi', 'Nam', TO_DATE('2001-12-14','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000190', 1396, 1209, 'Nhan vien', NULL, 7, 'UserNV190')
#  into NHANVIEN values('NV191', 'Vo Hoang Đuc', 'Nam', TO_DATE('2009-6-19','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000191', 5061, 1764, 'Nhan vien', NULL, 8, 'UserNV191')
#  into NHANVIEN values('NV192', 'Pham Hoang Vinh', 'Nu', TO_DATE('2000-1-21','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000192', 3643, 1982, 'Nhan vien', NULL, 1, 'UserNV192')
#  into NHANVIEN values('NV193', 'Đang Van Ngoc Nhi', 'Nam', TO_DATE('2019-4-2','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000193', 6339, 1786, 'Nhan vien', NULL, 2, 'UserNV193')
#  into NHANVIEN values('NV194', 'Au Van Tiep', 'Nu', TO_DATE('2009-3-8','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000194', 4336, 1057, 'Nhan vien', NULL, 3, 'UserNV194')
#  into NHANVIEN values('NV195', 'Ung Thi Anh', 'Nu', TO_DATE('2016-6-7','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000195', 2765, 1659, 'Nhan vien', NULL, 4, 'UserNV195')
#  into NHANVIEN values('NV196', 'Đang Gia Thuong', 'Nam', TO_DATE('2003-2-15','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000196', 7377, 1852, 'Nhan vien', NULL, 5, 'UserNV196')
#  into NHANVIEN values('NV197', 'An Tung Giang', 'Nam', TO_DATE('2019-11-2','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000197', 6489, 1249, 'Nhan vien', NULL, 6, 'UserNV197')
#  into NHANVIEN values('NV198', 'Đang Gia Đan', 'Nu', TO_DATE('2011-12-2','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000198', 3664, 1046, 'Nhan vien', NULL, 7, 'UserNV198')
#  into NHANVIEN values('NV199', 'Đoan Tung Tuan', 'Nam', TO_DATE('2007-11-6','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000199', 6919, 1339, 'Nhan vien', NULL, 8, 'UserNV199')
#  into NHANVIEN values('NV200', 'Đoan Hoang Duy', 'Nam', TO_DATE('2002-10-21','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000200', 3993, 1961, 'Nhan vien', NULL, 1, 'UserNV200')
#  into NHANVIEN values('NV201', 'Pham Tung Tiep', 'Nam', TO_DATE('2005-12-12','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000201', 2715, 1675, 'Nhan vien', NULL, 2, 'UserNV201')
#  into NHANVIEN values('NV202', 'Lai Gia Tu', 'Nu', TO_DATE('2016-12-17','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000202', 6522, 1102, 'Nhan vien', NULL, 3, 'UserNV202')
#  into NHANVIEN values('NV203', 'Truong Tung Tien', 'Nam', TO_DATE('2001-9-6','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000203', 8439, 1250, 'Nhan vien', NULL, 4, 'UserNV203')
#  into NHANVIEN values('NV204', 'Nguyen Song Vinh', 'Nu', TO_DATE('2006-10-18','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000204', 9994, 1536, 'Nhan vien', NULL, 5, 'UserNV204')
#  into NHANVIEN values('NV205', 'Vu Van Vy', 'Nam', TO_DATE('2005-3-26','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000205', 8658, 1764, 'Nhan vien', NULL, 6, 'UserNV205')
#  into NHANVIEN values('NV206', 'Ho Song Tiep', 'Nam', TO_DATE('2005-4-22','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000206', 1537, 1479, 'Nhan vien', NULL, 7, 'UserNV206')
#  into NHANVIEN values('NV207', 'Lai Van Đuc', 'Nam', TO_DATE('2015-3-27','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000207', 5616, 1572, 'Nhan vien', NULL, 8, 'UserNV207')
#  into NHANVIEN values('NV208', 'An Thi Ngan', 'Nu', TO_DATE('2007-5-14','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000208', 9251, 1305, 'Nhan vien', NULL, 1, 'UserNV208')
#  into NHANVIEN values('NV209', 'Ly Thi Tin', 'Nam', TO_DATE('2015-11-15','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000209', 9496, 1084, 'Nhan vien', NULL, 2, 'UserNV209')
#  into NHANVIEN values('NV210', 'Au Chi Ngan', 'Nu', TO_DATE('2002-3-10','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000210', 9673, 1649, 'Nhan vien', NULL, 3, 'UserNV210')
#  into NHANVIEN values('NV211', 'Gian Gia Nguyet', 'Nu', TO_DATE('2001-4-23','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000211', 4246, 1954, 'Nhan vien', NULL, 4, 'UserNV211')
#  into NHANVIEN values('NV212', 'Nguyen Hoang Nam', 'Nu', TO_DATE('2012-4-15','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000212', 1034, 1612, 'Nhan vien', NULL, 5, 'UserNV212')
#  into NHANVIEN values('NV213', 'Vo Hoang Chi', 'Nu', TO_DATE('2017-7-2','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000213', 2261, 1529, 'Nhan vien', NULL, 6, 'UserNV213')
#  into NHANVIEN values('NV214', 'Ly Gia Đuc', 'Nu', TO_DATE('2017-1-4','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000214', 3635, 1782, 'Nhan vien', NULL, 7, 'UserNV214')
#  into NHANVIEN values('NV215', 'Gian Chi Tiep', 'Nu', TO_DATE('2006-1-23','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000215', 6787, 1958, 'Nhan vien', NULL, 8, 'UserNV215')
#  into NHANVIEN values('NV216', 'Gian Van Han', 'Nam', TO_DATE('2018-10-15','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000216', 2299, 1249, 'Nhan vien', NULL, 1, 'UserNV216')
#  into NHANVIEN values('NV217', 'Au Chi Đuc', 'Nam', TO_DATE('2003-2-24','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000217', 9121, 1147, 'Nhan vien', NULL, 2, 'UserNV217')
#  into NHANVIEN values('NV218', 'An Thi Vu', 'Nu', TO_DATE('2010-4-7','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000218', 3089, 1175, 'Nhan vien', NULL, 3, 'UserNV218')
#  into NHANVIEN values('NV219', 'Truong Tung Đuc', 'Nam', TO_DATE('2004-6-1','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000219', 2028, 1682, 'Nhan vien', NULL, 4, 'UserNV219')
#  into NHANVIEN values('NV220', 'An Van Ngan', 'Nu', TO_DATE('2017-4-4','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000220', 9878, 1980, 'Nhan vien', NULL, 5, 'UserNV220')
#  into NHANVIEN values('NV221', 'Ho Song Chung', 'Nam', TO_DATE('2009-12-28','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000221', 7526, 1531, 'Nhan vien', NULL, 6, 'UserNV221')
#  into NHANVIEN values('NV222', 'Gian Tung Nguyet', 'Nu', TO_DATE('2005-8-27','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000222', 8501, 1048, 'Nhan vien', NULL, 7, 'UserNV222')
#  into NHANVIEN values('NV223', 'Ho Gia Thuong', 'Nam', TO_DATE('2019-8-8','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000223', 7925, 1929, 'Nhan vien', NULL, 8, 'UserNV223')
#  into NHANVIEN values('NV224', 'Bui Chi May', 'Nu', TO_DATE('2013-2-16','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000224', 4835, 1087, 'Nhan vien', NULL, 1, 'UserNV224')
#  into NHANVIEN values('NV225', 'Vo Chi Vy', 'Nu', TO_DATE('2008-9-15','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000225', 6851, 1389, 'Nhan vien', NULL, 2, 'UserNV225')
#  into NHANVIEN values('NV226', 'Tran Gia Thien', 'Nu', TO_DATE('2004-8-10','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000226', 6968, 1901, 'Nhan vien', NULL, 3, 'UserNV226')
#  into NHANVIEN values('NV227', 'Truong Tung Phu', 'Nam', TO_DATE('2010-4-15','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000227', 1422, 1551, 'Nhan vien', NULL, 4, 'UserNV227')
#  into NHANVIEN values('NV228', 'Lai Hoang khanh', 'Nam', TO_DATE('2021-4-3','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000228', 9339, 1630, 'Nhan vien', NULL, 5, 'UserNV228')
#  into NHANVIEN values('NV229', 'Nguyen Chi Quoc', 'Nu', TO_DATE('2003-10-13','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000229', 9645, 1390, 'Nhan vien', NULL, 6, 'UserNV229')
#  into NHANVIEN values('NV230', 'Ly Tung Cau', 'Nam', TO_DATE('2005-7-24','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000230', 2385, 1330, 'Nhan vien', NULL, 7, 'UserNV230')
#  into NHANVIEN values('NV231', 'Lai Thi Đan', 'Nu', TO_DATE('2009-1-16','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000231', 8759, 1385, 'Nhan vien', NULL, 8, 'UserNV231')
#  into NHANVIEN values('NV232', 'Ung Tung Bao', 'Nam', TO_DATE('2020-10-27','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000232', 1148, 1243, 'Nhan vien', NULL, 1, 'UserNV232')
#  into NHANVIEN values('NV233', 'Duong Tung Cuc', 'Nam', TO_DATE('2004-3-9','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000233', 3761, 1092, 'Nhan vien', NULL, 2, 'UserNV233')
# ...
#  into NHANVIEN values('NV270', 'Le Tung Ngoc Nhi', 'Nam', TO_DATE('2007-8-4','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000270', 1891, 1175, 'Nhan vien', NULL, 7, 'UserNV270')
#  into NHANVIEN values('NV271', 'Bui Thi Đuc', 'Nam', TO_DATE('2016-3-1','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000271', 4295, 1243, 'Nhan vien', NULL, 8, 'UserNV271')
#  into NHANVIEN values('NV272', 'Tran Song Han', 'Nu', TO_DATE('2013-12-1','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000272', 5099, 1346, 'Nhan vien', NULL, 1, 'UserNV272')
#  into NHANVIEN values('NV273', 'An Hoang Thong', 'Nam', TO_DATE('2011-7-17','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000273', 8266, 1846, 'Nhan vien', NULL, 2, 'UserNV273')
#  into NHANVIEN values('NV274', 'An Thi Ngan', 'Nu', TO_DATE('2013-5-2','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000274', 4802, 1048, 'Nhan vien', NULL, 3, 'UserNV274')
#  into NHANVIEN values('NV275', 'Vo Van Tan', 'Nu', TO_DATE('2009-1-13','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000275', 5586, 1949, 'Nhan vien', NULL, 4, 'UserNV275')
#  into NHANVIEN values('NV276', 'Ung Chi Vinh', 'Nu', TO_DATE('2001-7-20','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000276', 5974, 1671, 'Nhan vien', NULL, 5, 'UserNV276')
#  into NHANVIEN values('NV277', 'Ung Van Viet', 'Nam', TO_DATE('2001-11-5','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000277', 6282, 1482, 'Nhan vien', NULL, 6, 'UserNV277')
#  into NHANVIEN values('NV278', 'Nguyen Van Chung', 'Nam', TO_DATE('2005-12-23','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000278', 1729, 1473, 'Nhan vien', NULL, 7, 'UserNV278')
#  into NHANVIEN values('NV279', 'Au Van Tien', 'Nu', TO_DATE('2011-11-18','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000279', 8667, 1626, 'Nhan vien', NULL, 8, 'UserNV279')
#  into NHANVIEN values('NV280', 'Le Van Nguyet', 'Nu', TO_DATE('2015-1-1','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000280', 8816, 1316, 'Nhan vien', NULL, 1, 'UserNV280')
#  into NHANVIEN values('NV281', 'Nguyen Tung Anh', 'Nu', TO_DATE('2019-2-14','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000281', 2953, 1569, 'Nhan vien', NULL, 2, 'UserNV281')
#  into NHANVIEN values('NV282', 'Nguyen Tung Quoc', 'Nam', TO_DATE('2021-2-6','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000282', 3146, 1883, 'Nhan vien', NULL, 3, 'UserNV282')
#  into NHANVIEN values('NV283', 'Ung Hoang khanh', 'Nam', TO_DATE('2012-12-21','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000283', 9035, 1568, 'Nhan vien', NULL, 4, 'UserNV283')
#  into NHANVIEN values('NV284', 'Gian Chi Chi', 'Nam', TO_DATE('2005-10-22','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000284', 7007, 1265, 'Nhan vien', NULL, 5, 'UserNV284')
#  into NHANVIEN values('NV285', 'Nguyen Hoang Cuc', 'Nu', TO_DATE('2007-7-8','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000285', 1139, 1079, 'Nhan vien', NULL, 6, 'UserNV285')
#  into NHANVIEN values('NV286', 'Duong Tung Quoc', 'Nu', TO_DATE('2004-5-9','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000286', 9218, 1798, 'Nhan vien', NULL, 7, 'UserNV286')
#  into NHANVIEN values('NV287', 'Au Hoang May', 'Nam', TO_DATE('2018-5-18','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000287', 6833, 1109, 'Nhan vien', NULL, 8, 'UserNV287')
#  into NHANVIEN values('NV288', 'Duong Song khanh', 'Nam', TO_DATE('2004-12-27','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000288', 8214, 1636, 'Nhan vien', NULL, 1, 'UserNV288')
#  into NHANVIEN values('NV289', 'Pham Hoang Duy', 'Nam', TO_DATE('2007-7-17','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000289', 4766, 1856, 'Nhan vien', NULL, 2, 'UserNV289')
#  into NHANVIEN values('NV290', 'Bui Song Chung', 'Nu', TO_DATE('2010-2-28','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000290', 5434, 1745, 'Nhan vien', NULL, 3, 'UserNV290')
#  into NHANVIEN values('NV291', 'Đoan Thi Thien', 'Nam', TO_DATE('2021-6-8','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000291', 4823, 1392, 'Nhan vien', NULL, 4, 'UserNV291')
#  into NHANVIEN values('NV292', 'Đoan Gia Tan', 'Nu', TO_DATE('2016-3-17','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000292', 6204, 1228, 'Nhan vien', NULL, 5, 'UserNV292')
#  into NHANVIEN values('NV293', 'Bui Hoang Giang', 'Nu', TO_DATE('2006-5-15','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000293', 6476, 1548, 'Nhan vien', NULL, 6, 'UserNV293')
#  into NHANVIEN values('NV294', 'Tran Hoang Bao', 'Nu', TO_DATE('2010-1-23','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000294', 5189, 1673, 'Nhan vien', NULL, 7, 'UserNV294')
#  into NHANVIEN values('NV295', 'Pham Hoang Han', 'Nu', TO_DATE('2012-7-21','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000295', 4495, 1608, 'Nhan vien', NULL, 8, 'UserNV295')
#  into NHANVIEN values('NV296', 'Ly Thi Tu', 'Nu', TO_DATE('2000-11-5','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000296', 3215, 1812, 'Nhan vien', NULL, 1, 'UserNV296')
#  into NHANVIEN values('NV297', 'Đang Song Bac', 'Nu', TO_DATE('2002-3-23','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000297', 1150, 1590, 'Nhan vien', NULL, 2, 'UserNV297')
#  into NHANVIEN values('NV298', 'Bui Gia Thien', 'Nam', TO_DATE('2005-3-13','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000298', 1917, 1780, 'Nhan vien', NULL, 3, 'UserNV298')
#  into NHANVIEN values('NV299', 'Nguyen Gia Đang', 'Nu', TO_DATE('2015-10-3','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000299', 6453, 1000, 'Nhan vien', NULL, 4, 'UserNV299')
#  into NHANVIEN values('NV300', 'An Tung Thuong', 'Nam', TO_DATE('2002-1-17','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000300', 6754, 1277, 'Nhan vien', NULL, 5, 'UserNV300')
#  into NHANVIEN values('NV301', 'Lai Thi Thuong', 'Nam', TO_DATE('2011-4-4','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000301', 7365, 1430, 'Nhan vien', NULL, 6, 'UserNV301')
#  into NHANVIEN values('NV302', 'Tran Gia Viet', 'Nam', TO_DATE('2016-12-20','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000302', 1619, 1276, 'Nhan vien', NULL, 7, 'UserNV302')
#  into NHANVIEN values('NV303', 'Tran Chi Anh', 'Nam', TO_DATE('2000-3-25','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000303', 6639, 1592, 'Nhan vien', NULL, 8, 'UserNV303')
#  into NHANVIEN values('NV304', 'Ly Tung Tu', 'Nu', TO_DATE('2011-4-14','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000304', 5115, 1108, 'Nhan vien', NULL, 1, 'UserNV304')
#  into NHANVIEN values('NV305', 'Vu Van Phu', 'Nu', TO_DATE('2001-2-28','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000305', 4719, 1663, 'Nhan vien', NULL, 2, 'UserNV305')
#  into NHANVIEN values('NV306', 'Vu Chi Vu', 'Nam', TO_DATE('2001-4-16','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000306', 4284, 1898, 'Nhan vien', NULL, 3, 'UserNV306')
#  into NHANVIEN values('NV307', 'Le Van Vu', 'Nu', TO_DATE('2021-9-12','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000307', 1586, 1016, 'Nhan vien', NULL, 4, 'UserNV307')
#  into NHANVIEN values('NV308', 'Bui Song Han', 'Nu', TO_DATE('2006-1-12','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000308', 8412, 1368, 'Nhan vien', NULL, 5, 'UserNV308')
#  into NHANVIEN values('NV309', 'Le Thi Sang', 'Nam', TO_DATE('2009-5-5','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000309', 9387, 1933, 'Nhan vien', NULL, 6, 'UserNV309')
#  into NHANVIEN values('NV310', 'Truong Chi Phu', 'Nu', TO_DATE('2010-11-23','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000310', 1085, 1194, 'Nhan vien', NULL, 7, 'UserNV310')
#  into NHANVIEN values('NV311', 'An Chi Cuc', 'Nu', TO_DATE('2018-1-19','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000311', 4924, 1988, 'Nhan vien', NULL, 8, 'UserNV311')
#  into NHANVIEN values('NV312', 'Le Chi Đan', 'Nu', TO_DATE('2002-12-3','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000312', 3781, 1180, 'Nhan vien', NULL, 1, 'UserNV312')
#  into NHANVIEN values('NV313', 'Pham Van Vy', 'Nu', TO_DATE('2014-1-24','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000313', 5316, 1514, 'Nhan vien', NULL, 2, 'UserNV313')
#  into NHANVIEN values('NV314', 'Đang Gia Bao', 'Nu', TO_DATE('2018-10-13','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000314', 8159, 1182, 'Nhan vien', NULL, 3, 'UserNV314')
#  into NHANVIEN values('NV315', 'Ung Thi Tuan', 'Nam', TO_DATE('2017-1-24','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000315', 9021, 1616, 'Nhan vien', NULL, 4, 'UserNV315')
#  into NHANVIEN values('NV316', 'Ung Chi Cuc', 'Nam', TO_DATE('2008-7-1','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000316', 3710, 1654, 'Nhan vien', NULL, 5, 'UserNV316')
#  into NHANVIEN values('NV317', 'Đoan Song Giang', 'Nu', TO_DATE('2002-5-9','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000317', 6501, 1835, 'Nhan vien', NULL, 6, 'UserNV317')
#  into NHANVIEN values('NV318', 'Vo Gia Tiep', 'Nam', TO_DATE('2011-4-2','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000318', 2105, 1904, 'Nhan vien', NULL, 7, 'UserNV318')
#  into NHANVIEN values('NV319', 'Gian Van Nguyet', 'Nam', TO_DATE('2019-7-25','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000319', 5619, 1547, 'Nhan vien', NULL, 8, 'UserNV319')
#  into NHANVIEN values('NV320', 'Le Van Tiep', 'Nam', TO_DATE('2002-11-11','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000320', 6607, 1013, 'Nhan vien', NULL, 1, 'UserNV320')
#  into NHANVIEN values('NV321', 'Au Chi Ngan', 'Nu', TO_DATE('2014-3-23','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000321', 3196, 1107, 'Nhan vien', NULL, 2, 'UserNV321')
#  into NHANVIEN values('NV322', 'Nguyen Gia Giang', 'Nu', TO_DATE('2000-10-18','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000322', 4837, 1102, 'Nhan vien', NULL, 3, 'UserNV322')
#  into NHANVIEN values('NV323', 'Đang Song Viet', 'Nam', TO_DATE('2006-10-24','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000323', 8914, 1509, 'Nhan vien', NULL, 4, 'UserNV323')
#  into NHANVIEN values('NV324', 'Ly Thi Han', 'Nu', TO_DATE('2021-3-23','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000324', 3901, 1004, 'Nhan vien', NULL, 5, 'UserNV324')
#  into NHANVIEN values('NV325', 'Truong Van Bac', 'Nu', TO_DATE('2016-12-19','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000325', 2211, 1662, 'Nhan vien', NULL, 6, 'UserNV325')
#  into NHANVIEN values('NV326', 'Ly Tung Đuc', 'Nu', TO_DATE('2021-7-2','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000326', 7043, 1341, 'Nhan vien', NULL, 7, 'UserNV326')
#  into NHANVIEN values('NV327', 'Vo Chi Sang', 'Nam', TO_DATE('2012-2-23','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000327', 6751, 1940, 'Nhan vien', NULL, 8, 'UserNV327')
#  into NHANVIEN values('NV328', 'Ho Song Minh', 'Nam', TO_DATE('2021-3-7','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000328', 4775, 1199, 'Nhan vien', NULL, 1, 'UserNV328')
#  into NHANVIEN values('NV329', 'Pham Gia Tan', 'Nu', TO_DATE('2021-4-1','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000329', 9942, 1441, 'Nhan vien', NULL, 2, 'UserNV329')
#  into NHANVIEN values('NV330', 'Tran Gia Bao', 'Nu', TO_DATE('2000-10-23','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000330', 3457, 1501, 'Nhan vien', NULL, 3, 'UserNV330')
#  into NHANVIEN values('NV331', 'Ly Tung Tan', 'Nam', TO_DATE('2020-4-5','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000331', 7921, 1201, 'Nhan vien', NULL, 4, 'UserNV331')
#  into NHANVIEN values('NV332', 'Nguyen Song Sang', 'Nu', TO_DATE('2021-11-2','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000332', 9512, 1266, 'Nhan vien', NULL, 5, 'UserNV332')
#  into NHANVIEN values('NV333', 'Bui Tung Tien', 'Nu', TO_DATE('2014-7-5','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000333', 2342, 1202, 'Nhan vien', NULL, 6, 'UserNV333')
#  into NHANVIEN values('NV334', 'An Song Duy', 'Nu', TO_DATE('2009-3-7','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000334', 5529, 1985, 'Nhan vien', NULL, 7, 'UserNV334')
#  into NHANVIEN values('NV335', 'Bui Tung Ngan', 'Nam', TO_DATE('2010-2-17','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000335', 2823, 1690, 'Nhan vien', NULL, 8, 'UserNV335')
#  into NHANVIEN values('NV336', 'Ly Van Giang', 'Nam', TO_DATE('2008-11-8','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000336', 6107, 1513, 'Nhan vien', NULL, 1, 'UserNV336')
#  into NHANVIEN values('NV337', 'Đang Hoang Bac', 'Nu', TO_DATE('2000-10-18','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000337', 3814, 1499, 'Nhan vien', NULL, 2, 'UserNV337')
#  into NHANVIEN values('NV338', 'Au Tung Thuong', 'Nam', TO_DATE('2008-3-17','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000338', 3343, 1766, 'Nhan vien', NULL, 3, 'UserNV338')
#  into NHANVIEN values('NV339', 'Nguyen Song Minh', 'Nam', TO_DATE('2013-1-1','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000339', 7036, 1969, 'Nhan vien', NULL, 4, 'UserNV339')
#  into NHANVIEN values('NV340', 'Tran Tung Duy', 'Nu', TO_DATE('2009-7-18','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000340', 4921, 1004, 'Nhan vien', NULL, 5, 'UserNV340')
#  into NHANVIEN values('NV341', 'Vo Gia Tuan', 'Nam', TO_DATE('2019-1-2','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000341', 9146, 1072, 'Nhan vien', NULL, 6, 'UserNV341')
#  into NHANVIEN values('NV342', 'Ung Gia khanh', 'Nam', TO_DATE('2005-7-20','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000342', 3937, 1020, 'Nhan vien', NULL, 7, 'UserNV342')
#  into NHANVIEN values('NV343', 'Vu Thi Cuc', 'Nu', TO_DATE('2018-8-5','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000343', 6636, 1812, 'Nhan vien', NULL, 8, 'UserNV343')
#  into NHANVIEN values('NV344', 'Pham Chi Phu', 'Nu', TO_DATE('2014-8-24','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000344', 1676, 1034, 'Nhan vien', NULL, 1, 'UserNV344')
#  into NHANVIEN values('NV345', 'Ly Hoang Duy', 'Nu', TO_DATE('2019-6-2','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000345', 3183, 1784, 'Nhan vien', NULL, 2, 'UserNV345')
#  into NHANVIEN values('NV346', 'Ly Song Vu', 'Nam', TO_DATE('2003-7-14','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000346', 7174, 1892, 'Nhan vien', NULL, 3, 'UserNV346')

# %%
KV = ['Quan 1', 'Quan 2', 'Quan 3','Quan 4','Quan 5','Quan 6','Quan 7','Quan 8','Quan 9','Quan 10','Quan 11','Quan 12','Quan 13', 'Quan Bình Thạnh', 'Quan Tân Bình', 'Hóoc Môn']

# %% [markdown]
# ## Phong Ban

# %%
'''
PhongBan (
	MaPB 	number primary key,
	TenPB 	varchar2(60) not null,
	TrPHG 	varchar(10)
	
)	
'''


for i in range(1, 9):
    final = str(i) + ', ' + '\'Phong ' + str(i) + '\', NULL' 
    print('insert into PHONGBAN values(' +  final + ');')
# Out:
# insert into PHONGBAN values(1, 'Phong 1', NULL);
# insert into PHONGBAN values(2, 'Phong 2', NULL);
# insert into PHONGBAN values(3, 'Phong 3', NULL);
# insert into PHONGBAN values(4, 'Phong 4', NULL);
# insert into PHONGBAN values(5, 'Phong 5', NULL);
# insert into PHONGBAN values(6, 'Phong 6', NULL);
# insert into PHONGBAN values(7, 'Phong 7', NULL);
# insert into PHONGBAN values(8, 'Phong 8', NULL);

# %%
for i in range(1, 9):
    print( ' UPDATE PHONGBAN set TrPHG = ' + '\'TP0'+ str(i+ 38) + '\'' + ' WHERE ' +  'MaPB = ' + str(i)+ ';')
# Out:
#  UPDATE PHONGBAN set TrPHG = 'TP039' WHERE MaPB = 1;
#  UPDATE PHONGBAN set TrPHG = 'TP040' WHERE MaPB = 2;
#  UPDATE PHONGBAN set TrPHG = 'TP041' WHERE MaPB = 3;
#  UPDATE PHONGBAN set TrPHG = 'TP042' WHERE MaPB = 4;
#  UPDATE PHONGBAN set TrPHG = 'TP043' WHERE MaPB = 5;
#  UPDATE PHONGBAN set TrPHG = 'TP044' WHERE MaPB = 6;
#  UPDATE PHONGBAN set TrPHG = 'TP045' WHERE MaPB = 7;
#  UPDATE PHONGBAN set TrPHG = 'TP046' WHERE MaPB = 8;

# %% [markdown]
# # DE AN

# %%
'''
DeAn (
	MaDA 		varchar(10) primary key,
	TenDA 	varchar2(60) not null,
	NgayBD 	date,
	Phong 	number,
    TruongDeAn varchar(10)
	
)
'''
l = []
for i in range(1, 9):
    for j in range(1, rd.randint(3, 5)):
        MaDA = '\'DA' + str(i) + '0' + str(j) + '\'';
        l.append(MaDA);

        TenDA = '\'De An so ' + str(j) + ' Phong ' + str(i) + '\'';
        NgayBD  = 'TO_DATE(' + '\'' + str(rd.randint(2020, 2022)) + '-' + str(rd.randint(1, 12)) + '-' + str(rd.randint(1, 28)) + '\',\'YYYY-MM-DD\')'
        Phong = str(i)
        TruongDA = 'TDA0' + str(rd.randint(36, 38))
        final = MaDA + ', ' + TenDA + ', ' + NgayBD + ', ' + Phong + ', ' + TruongDA
        print('into DEAN values(' +  final + ')')
# Out:
# into DEAN values('DA101', 'De An so 1 Phong 1', TO_DATE('2021-7-10','YYYY-MM-DD'), 1, TDA036)
# into DEAN values('DA102', 'De An so 2 Phong 1', TO_DATE('2021-3-28','YYYY-MM-DD'), 1, TDA037)
# into DEAN values('DA201', 'De An so 1 Phong 2', TO_DATE('2021-10-13','YYYY-MM-DD'), 2, TDA037)
# into DEAN values('DA202', 'De An so 2 Phong 2', TO_DATE('2020-8-2','YYYY-MM-DD'), 2, TDA038)
# into DEAN values('DA203', 'De An so 3 Phong 2', TO_DATE('2021-3-24','YYYY-MM-DD'), 2, TDA037)
# into DEAN values('DA301', 'De An so 1 Phong 3', TO_DATE('2020-4-11','YYYY-MM-DD'), 3, TDA037)
# into DEAN values('DA302', 'De An so 2 Phong 3', TO_DATE('2022-12-11','YYYY-MM-DD'), 3, TDA036)
# into DEAN values('DA401', 'De An so 1 Phong 4', TO_DATE('2020-9-3','YYYY-MM-DD'), 4, TDA036)
# into DEAN values('DA402', 'De An so 2 Phong 4', TO_DATE('2020-12-15','YYYY-MM-DD'), 4, TDA037)
# into DEAN values('DA403', 'De An so 3 Phong 4', TO_DATE('2021-9-2','YYYY-MM-DD'), 4, TDA036)
# into DEAN values('DA501', 'De An so 1 Phong 5', TO_DATE('2021-7-25','YYYY-MM-DD'), 5, TDA036)
# into DEAN values('DA502', 'De An so 2 Phong 5', TO_DATE('2020-2-25','YYYY-MM-DD'), 5, TDA038)
# into DEAN values('DA601', 'De An so 1 Phong 6', TO_DATE('2022-4-26','YYYY-MM-DD'), 6, TDA038)
# into DEAN values('DA602', 'De An so 2 Phong 6', TO_DATE('2021-1-17','YYYY-MM-DD'), 6, TDA037)
# into DEAN values('DA603', 'De An so 3 Phong 6', TO_DATE('2020-11-26','YYYY-MM-DD'), 6, TDA038)
# into DEAN values('DA604', 'De An so 4 Phong 6', TO_DATE('2021-6-5','YYYY-MM-DD'), 6, TDA037)
# into DEAN values('DA701', 'De An so 1 Phong 7', TO_DATE('2021-4-11','YYYY-MM-DD'), 7, TDA038)
# into DEAN values('DA702', 'De An so 2 Phong 7', TO_DATE('2020-8-24','YYYY-MM-DD'), 7, TDA037)
# into DEAN values('DA703', 'De An so 3 Phong 7', TO_DATE('2020-4-22','YYYY-MM-DD'), 7, TDA037)
# into DEAN values('DA704', 'De An so 4 Phong 7', TO_DATE('2022-12-2','YYYY-MM-DD'), 7, TDA037)
# into DEAN values('DA801', 'De An so 1 Phong 8', TO_DATE('2022-11-7','YYYY-MM-DD'), 8, TDA037)
# into DEAN values('DA802', 'De An so 2 Phong 8', TO_DATE('2021-9-21','YYYY-MM-DD'), 8, TDA038)
# into DEAN values('DA803', 'De An so 3 Phong 8', TO_DATE('2020-8-17','YYYY-MM-DD'), 8, TDA037)
# into DEAN values('DA804', 'De An so 4 Phong 8', TO_DATE('2021-9-23','YYYY-MM-DD'), 8, TDA037)

# %% [markdown]
# ## Phan Cong

# %%
'''
	PhanCong (
	MaNV 		varchar(10) primary key,
	MaDA 		varchar(10) primary key,
	ThoiGian 	date
	
)

'''
import numpy as np
for i in range(47, 347, 3):
    MaNV = '\'NV'+ str(i) + '\''
    for j in range(1, rd.randint(2, 3)):
        MaDA = '\'DA' + str(i%8 + 1) + '0' + str(j) + '\'';
        TG  = 'TO_DATE(' + '\'' + str(rd.randint(2020, 2022)) + '-' + str(rd.randint(1, 12)) + '-' + str(rd.randint(1, 28)) + '\',\'YYYY-MM-DD\')'
        final = MaNV + ', ' + MaDA + ', ' + TG  
        print('into PHANCONG values(' +  final + ')')
# Out:
# into PHANCONG values('NV47', 'DA801', TO_DATE('2021-5-12','YYYY-MM-DD'))
# into PHANCONG values('NV50', 'DA301', TO_DATE('2020-4-5','YYYY-MM-DD'))
# into PHANCONG values('NV50', 'DA302', TO_DATE('2022-12-13','YYYY-MM-DD'))
# into PHANCONG values('NV53', 'DA601', TO_DATE('2022-9-7','YYYY-MM-DD'))
# into PHANCONG values('NV56', 'DA101', TO_DATE('2022-8-28','YYYY-MM-DD'))
# into PHANCONG values('NV59', 'DA401', TO_DATE('2022-9-13','YYYY-MM-DD'))
# into PHANCONG values('NV62', 'DA701', TO_DATE('2020-11-27','YYYY-MM-DD'))
# into PHANCONG values('NV65', 'DA201', TO_DATE('2021-6-8','YYYY-MM-DD'))
# into PHANCONG values('NV65', 'DA202', TO_DATE('2021-11-11','YYYY-MM-DD'))
# into PHANCONG values('NV68', 'DA501', TO_DATE('2021-7-27','YYYY-MM-DD'))
# into PHANCONG values('NV68', 'DA502', TO_DATE('2022-6-8','YYYY-MM-DD'))
# into PHANCONG values('NV71', 'DA801', TO_DATE('2020-5-19','YYYY-MM-DD'))
# into PHANCONG values('NV71', 'DA802', TO_DATE('2020-1-12','YYYY-MM-DD'))
# into PHANCONG values('NV74', 'DA301', TO_DATE('2022-6-2','YYYY-MM-DD'))
# into PHANCONG values('NV74', 'DA302', TO_DATE('2022-3-21','YYYY-MM-DD'))
# into PHANCONG values('NV77', 'DA601', TO_DATE('2020-1-8','YYYY-MM-DD'))
# into PHANCONG values('NV77', 'DA602', TO_DATE('2022-9-5','YYYY-MM-DD'))
# into PHANCONG values('NV80', 'DA101', TO_DATE('2021-5-18','YYYY-MM-DD'))
# into PHANCONG values('NV83', 'DA401', TO_DATE('2021-1-22','YYYY-MM-DD'))
# into PHANCONG values('NV86', 'DA701', TO_DATE('2020-11-5','YYYY-MM-DD'))
# into PHANCONG values('NV89', 'DA201', TO_DATE('2021-1-23','YYYY-MM-DD'))
# into PHANCONG values('NV92', 'DA501', TO_DATE('2020-8-8','YYYY-MM-DD'))
# into PHANCONG values('NV92', 'DA502', TO_DATE('2020-4-20','YYYY-MM-DD'))
# into PHANCONG values('NV95', 'DA801', TO_DATE('2022-2-8','YYYY-MM-DD'))
# into PHANCONG values('NV95', 'DA802', TO_DATE('2020-10-26','YYYY-MM-DD'))
# into PHANCONG values('NV98', 'DA301', TO_DATE('2020-8-10','YYYY-MM-DD'))
# into PHANCONG values('NV101', 'DA601', TO_DATE('2022-5-22','YYYY-MM-DD'))
# into PHANCONG values('NV104', 'DA101', TO_DATE('2021-12-5','YYYY-MM-DD'))
# into PHANCONG values('NV104', 'DA102', TO_DATE('2020-2-20','YYYY-MM-DD'))
# into PHANCONG values('NV107', 'DA401', TO_DATE('2021-11-24','YYYY-MM-DD'))
# into PHANCONG values('NV110', 'DA701', TO_DATE('2021-10-22','YYYY-MM-DD'))
# into PHANCONG values('NV110', 'DA702', TO_DATE('2020-1-14','YYYY-MM-DD'))
# into PHANCONG values('NV113', 'DA201', TO_DATE('2020-8-14','YYYY-MM-DD'))
# into PHANCONG values('NV116', 'DA501', TO_DATE('2022-9-20','YYYY-MM-DD'))
# into PHANCONG values('NV119', 'DA801', TO_DATE('2021-1-26','YYYY-MM-DD'))
# into PHANCONG values('NV119', 'DA802', TO_DATE('2021-7-15','YYYY-MM-DD'))
# into PHANCONG values('NV122', 'DA301', TO_DATE('2021-3-2','YYYY-MM-DD'))
# into PHANCONG values('NV122', 'DA302', TO_DATE('2021-2-16','YYYY-MM-DD'))
# into PHANCONG values('NV125', 'DA601', TO_DATE('2021-7-19','YYYY-MM-DD'))
# into PHANCONG values('NV128', 'DA101', TO_DATE('2021-10-9','YYYY-MM-DD'))
# into PHANCONG values('NV128', 'DA102', TO_DATE('2020-9-24','YYYY-MM-DD'))
# into PHANCONG values('NV131', 'DA401', TO_DATE('2022-12-3','YYYY-MM-DD'))
# into PHANCONG values('NV134', 'DA701', TO_DATE('2020-5-15','YYYY-MM-DD'))
# into PHANCONG values('NV137', 'DA201', TO_DATE('2020-11-3','YYYY-MM-DD'))
# into PHANCONG values('NV137', 'DA202', TO_DATE('2022-8-7','YYYY-MM-DD'))
# into PHANCONG values('NV140', 'DA501', TO_DATE('2020-9-18','YYYY-MM-DD'))
# into PHANCONG values('NV140', 'DA502', TO_DATE('2021-8-3','YYYY-MM-DD'))
# into PHANCONG values('NV143', 'DA801', TO_DATE('2020-5-21','YYYY-MM-DD'))
# into PHANCONG values('NV143', 'DA802', TO_DATE('2021-10-12','YYYY-MM-DD'))
# into PHANCONG values('NV146', 'DA301', TO_DATE('2022-11-21','YYYY-MM-DD'))
# into PHANCONG values('NV149', 'DA601', TO_DATE('2020-2-8','YYYY-MM-DD'))
# into PHANCONG values('NV149', 'DA602', TO_DATE('2022-5-22','YYYY-MM-DD'))
# into PHANCONG values('NV152', 'DA101', TO_DATE('2022-6-20','YYYY-MM-DD'))
# into PHANCONG values('NV155', 'DA401', TO_DATE('2020-9-23','YYYY-MM-DD'))
# into PHANCONG values('NV155', 'DA402', TO_DATE('2022-4-13','YYYY-MM-DD'))
# into PHANCONG values('NV158', 'DA701', TO_DATE('2020-4-16','YYYY-MM-DD'))
# into PHANCONG values('NV158', 'DA702', TO_DATE('2021-11-8','YYYY-MM-DD'))
# into PHANCONG values('NV161', 'DA201', TO_DATE('2020-4-6','YYYY-MM-DD'))
# into PHANCONG values('NV161', 'DA202', TO_DATE('2021-2-16','YYYY-MM-DD'))
# into PHANCONG values('NV164', 'DA501', TO_DATE('2022-1-9','YYYY-MM-DD'))
# into PHANCONG values('NV167', 'DA801', TO_DATE('2021-2-20','YYYY-MM-DD'))
# into PHANCONG values('NV167', 'DA802', TO_DATE('2022-12-16','YYYY-MM-DD'))
# into PHANCONG values('NV170', 'DA301', TO_DATE('2021-1-22','YYYY-MM-DD'))
# into PHANCONG values('NV170', 'DA302', TO_DATE('2022-4-27','YYYY-MM-DD'))
# into PHANCONG values('NV173', 'DA601', TO_DATE('2020-8-27','YYYY-MM-DD'))
# into PHANCONG values('NV176', 'DA101', TO_DATE('2020-2-12','YYYY-MM-DD'))
# into PHANCONG values('NV176', 'DA102', TO_DATE('2022-7-12','YYYY-MM-DD'))
# into PHANCONG values('NV179', 'DA401', TO_DATE('2020-3-11','YYYY-MM-DD'))
# into PHANCONG values('NV182', 'DA701', TO_DATE('2022-4-21','YYYY-MM-DD'))
# into PHANCONG values('NV185', 'DA201', TO_DATE('2021-10-25','YYYY-MM-DD'))
# into PHANCONG values('NV185', 'DA202', TO_DATE('2022-5-12','YYYY-MM-DD'))
# into PHANCONG values('NV188', 'DA501', TO_DATE('2022-6-22','YYYY-MM-DD'))
# into PHANCONG values('NV188', 'DA502', TO_DATE('2020-1-21','YYYY-MM-DD'))
# into PHANCONG values('NV191', 'DA801', TO_DATE('2020-1-6','YYYY-MM-DD'))
# into PHANCONG values('NV191', 'DA802', TO_DATE('2022-7-24','YYYY-MM-DD'))
# into PHANCONG values('NV194', 'DA301', TO_DATE('2020-3-23','YYYY-MM-DD'))
# into PHANCONG values('NV197', 'DA601', TO_DATE('2020-9-5','YYYY-MM-DD'))
# into PHANCONG values('NV197', 'DA602', TO_DATE('2020-12-6','YYYY-MM-DD'))
# into PHANCONG values('NV200', 'DA101', TO_DATE('2022-9-21','YYYY-MM-DD'))
# into PHANCONG values('NV200', 'DA102', TO_DATE('2020-9-17','YYYY-MM-DD'))
# into PHANCONG values('NV203', 'DA401', TO_DATE('2022-8-26','YYYY-MM-DD'))
# into PHANCONG values('NV203', 'DA402', TO_DATE('2020-3-5','YYYY-MM-DD'))
# into PHANCONG values('NV206', 'DA701', TO_DATE('2020-12-26','YYYY-MM-DD'))
# into PHANCONG values('NV209', 'DA201', TO_DATE('2020-9-10','YYYY-MM-DD'))
# into PHANCONG values('NV212', 'DA501', TO_DATE('2022-1-1','YYYY-MM-DD'))
# into PHANCONG values('NV215', 'DA801', TO_DATE('2020-7-9','YYYY-MM-DD'))
# into PHANCONG values('NV215', 'DA802', TO_DATE('2022-8-13','YYYY-MM-DD'))
# into PHANCONG values('NV218', 'DA301', TO_DATE('2020-12-4','YYYY-MM-DD'))
# into PHANCONG values('NV218', 'DA302', TO_DATE('2022-5-27','YYYY-MM-DD'))
# into PHANCONG values('NV221', 'DA601', TO_DATE('2021-7-13','YYYY-MM-DD'))
# into PHANCONG values('NV224', 'DA101', TO_DATE('2022-2-17','YYYY-MM-DD'))
# into PHANCONG values('NV224', 'DA102', TO_DATE('2020-3-5','YYYY-MM-DD'))
# into PHANCONG values('NV227', 'DA401', TO_DATE('2021-1-10','YYYY-MM-DD'))
# into PHANCONG values('NV230', 'DA701', TO_DATE('2021-10-10','YYYY-MM-DD'))
# into PHANCONG values('NV233', 'DA201', TO_DATE('2020-2-28','YYYY-MM-DD'))
# into PHANCONG values('NV233', 'DA202', TO_DATE('2021-11-11','YYYY-MM-DD'))
# into PHANCONG values('NV236', 'DA501', TO_DATE('2021-9-10','YYYY-MM-DD'))
# into PHANCONG values('NV239', 'DA801', TO_DATE('2021-12-26','YYYY-MM-DD'))
# into PHANCONG values('NV239', 'DA802', TO_DATE('2021-8-18','YYYY-MM-DD'))
# into PHANCONG values('NV242', 'DA301', TO_DATE('2020-2-18','YYYY-MM-DD'))
# into PHANCONG values('NV242', 'DA302', TO_DATE('2020-5-8','YYYY-MM-DD'))
# into PHANCONG values('NV245', 'DA601', TO_DATE('2022-6-10','YYYY-MM-DD'))
# into PHANCONG values('NV248', 'DA101', TO_DATE('2021-4-24','YYYY-MM-DD'))
# into PHANCONG values('NV248', 'DA102', TO_DATE('2021-12-8','YYYY-MM-DD'))
# into PHANCONG values('NV251', 'DA401', TO_DATE('2022-6-28','YYYY-MM-DD'))
# into PHANCONG values('NV254', 'DA701', TO_DATE('2021-6-26','YYYY-MM-DD'))
# into PHANCONG values('NV254', 'DA702', TO_DATE('2020-1-22','YYYY-MM-DD'))
# into PHANCONG values('NV257', 'DA201', TO_DATE('2020-6-15','YYYY-MM-DD'))
# into PHANCONG values('NV257', 'DA202', TO_DATE('2020-5-26','YYYY-MM-DD'))
# into PHANCONG values('NV260', 'DA501', TO_DATE('2020-7-19','YYYY-MM-DD'))
# into PHANCONG values('NV263', 'DA801', TO_DATE('2022-5-13','YYYY-MM-DD'))
# into PHANCONG values('NV266', 'DA301', TO_DATE('2021-1-15','YYYY-MM-DD'))
# into PHANCONG values('NV266', 'DA302', TO_DATE('2022-10-19','YYYY-MM-DD'))
# into PHANCONG values('NV269', 'DA601', TO_DATE('2021-6-2','YYYY-MM-DD'))
# into PHANCONG values('NV269', 'DA602', TO_DATE('2021-2-28','YYYY-MM-DD'))
# into PHANCONG values('NV272', 'DA101', TO_DATE('2021-12-10','YYYY-MM-DD'))
# into PHANCONG values('NV275', 'DA401', TO_DATE('2020-10-19','YYYY-MM-DD'))
# into PHANCONG values('NV275', 'DA402', TO_DATE('2021-2-4','YYYY-MM-DD'))
# into PHANCONG values('NV278', 'DA701', TO_DATE('2022-12-3','YYYY-MM-DD'))
# into PHANCONG values('NV281', 'DA201', TO_DATE('2022-7-11','YYYY-MM-DD'))
# into PHANCONG values('NV284', 'DA501', TO_DATE('2022-6-25','YYYY-MM-DD'))
# into PHANCONG values('NV287', 'DA801', TO_DATE('2021-11-25','YYYY-MM-DD'))
# into PHANCONG values('NV287', 'DA802', TO_DATE('2022-11-28','YYYY-MM-DD'))
# into PHANCONG values('NV290', 'DA301', TO_DATE('2022-11-14','YYYY-MM-DD'))
# into PHANCONG values('NV290', 'DA302', TO_DATE('2020-11-17','YYYY-MM-DD'))
# into PHANCONG values('NV293', 'DA601', TO_DATE('2022-8-26','YYYY-MM-DD'))
# into PHANCONG values('NV296', 'DA101', TO_DATE('2020-2-3','YYYY-MM-DD'))
# into PHANCONG values('NV299', 'DA401', TO_DATE('2022-3-28','YYYY-MM-DD'))
# into PHANCONG values('NV302', 'DA701', TO_DATE('2021-7-1','YYYY-MM-DD'))
# into PHANCONG values('NV302', 'DA702', TO_DATE('2022-6-23','YYYY-MM-DD'))
# into PHANCONG values('NV305', 'DA201', TO_DATE('2020-4-26','YYYY-MM-DD'))
# into PHANCONG values('NV308', 'DA501', TO_DATE('2022-12-25','YYYY-MM-DD'))
# into PHANCONG values('NV311', 'DA801', TO_DATE('2020-4-26','YYYY-MM-DD'))
# into PHANCONG values('NV314', 'DA301', TO_DATE('2022-12-13','YYYY-MM-DD'))
# into PHANCONG values('NV317', 'DA601', TO_DATE('2020-2-8','YYYY-MM-DD'))
# into PHANCONG values('NV320', 'DA101', TO_DATE('2021-4-14','YYYY-MM-DD'))
# into PHANCONG values('NV320', 'DA102', TO_DATE('2021-3-25','YYYY-MM-DD'))
# into PHANCONG values('NV323', 'DA401', TO_DATE('2020-5-11','YYYY-MM-DD'))
# into PHANCONG values('NV326', 'DA701', TO_DATE('2020-6-9','YYYY-MM-DD'))
# into PHANCONG values('NV329', 'DA201', TO_DATE('2021-9-20','YYYY-MM-DD'))
# into PHANCONG values('NV332', 'DA501', TO_DATE('2021-12-20','YYYY-MM-DD'))
# into PHANCONG values('NV332', 'DA502', TO_DATE('2022-8-20','YYYY-MM-DD'))
# into PHANCONG values('NV335', 'DA801', TO_DATE('2022-7-4','YYYY-MM-DD'))
# into PHANCONG values('NV338', 'DA301', TO_DATE('2020-4-15','YYYY-MM-DD'))
# into PHANCONG values('NV341', 'DA601', TO_DATE('2022-10-26','YYYY-MM-DD'))
# into PHANCONG values('NV341', 'DA602', TO_DATE('2020-9-12','YYYY-MM-DD'))
# into PHANCONG values('NV344', 'DA101', TO_DATE('2022-10-27','YYYY-MM-DD'))
# into PHANCONG values('NV344', 'DA102', TO_DATE('2022-9-24','YYYY-MM-DD'))

# %% [markdown]
# # Tai khoan

# %%
'''
tai khoan:
    username varchar(50),
    password varchar(150),
    MaNV varchar(10)
'''
import random
import string

username = ''
password = ''
MaNV = ''
for i in range(1, 347):
    if i < 6:
        MaNV = '\'GD00'+ str(i) + '\''
        username = f'UserGD00{i}'
    elif i < 11:
        MaNV = '\'TC0'+ str(i) + '\''
        username = f'UserTC0{i}'
    elif i < 16:
        MaNV = '\'NS0'+ str(i) + '\''
        username = f'UserNS0{i}'
    elif i < 36:
        MaNV = '\'QL0'+ str(i) + '\''
        username = f'UserQL0{i}'
    elif i < 39:
        MaNV = '\'TDA0'+ str(i) + '\''
        username = f'UserTDA0{i}'
    elif i < 47:
        MaNV = '\'TP0'+ str(i) + '\''
        username = f'UserTP0{i}'
    else:
        MaNV = '\'NV'+ str(i) + '\''
        username = f'UserNV{i}'
    
    # pass random mac dinh 10 char
    password = ''.join(random.choice(string.ascii_letters) for i in range(10))

    print (f'INSERT INTO TAIKHOAN VALUES(\'{username}\', \'{password}\'. \'{MaNV}\')')
# Out:
# INSERT INTO TAIKHOAN VALUES('UserGD001', 'tzEDjqNvYl'. ''GD001'')
# INSERT INTO TAIKHOAN VALUES('UserGD002', 'zpfhHsErnD'. ''GD002'')
# INSERT INTO TAIKHOAN VALUES('UserGD003', 'BVYjxEeRPi'. ''GD003'')
# INSERT INTO TAIKHOAN VALUES('UserGD004', 'kZCxsEFdrF'. ''GD004'')
# INSERT INTO TAIKHOAN VALUES('UserGD005', 'hbsgdRNOFr'. ''GD005'')
# INSERT INTO TAIKHOAN VALUES('UserTC06', 'WOtKCrdlMp'. ''TC06'')
# INSERT INTO TAIKHOAN VALUES('UserTC07', 'ELhiKNVBnd'. ''TC07'')
# INSERT INTO TAIKHOAN VALUES('UserTC08', 'KLQncBPxBT'. ''TC08'')
# INSERT INTO TAIKHOAN VALUES('UserTC09', 'RSLSeokbxK'. ''TC09'')
# INSERT INTO TAIKHOAN VALUES('UserTC010', 'NvuovJMbyR'. ''TC010'')
# INSERT INTO TAIKHOAN VALUES('UserNS011', 'gSOgrlfVaP'. ''NS011'')
# INSERT INTO TAIKHOAN VALUES('UserNS012', 'qjOIOJxlUh'. ''NS012'')
# INSERT INTO TAIKHOAN VALUES('UserNS013', 'gDaviFRMvW'. ''NS013'')
# INSERT INTO TAIKHOAN VALUES('UserNS014', 'yefmjsgwSX'. ''NS014'')
# INSERT INTO TAIKHOAN VALUES('UserNS015', 'bSEcIBBHll'. ''NS015'')
# INSERT INTO TAIKHOAN VALUES('UserQL016', 'AqNDnfjkoH'. ''QL016'')
# INSERT INTO TAIKHOAN VALUES('UserQL017', 'YHsppZvxJQ'. ''QL017'')
# INSERT INTO TAIKHOAN VALUES('UserQL018', 'jCEqLXufvv'. ''QL018'')
# INSERT INTO TAIKHOAN VALUES('UserQL019', 'CBMOChJJyo'. ''QL019'')
# INSERT INTO TAIKHOAN VALUES('UserQL020', 'VjmnWJuiWv'. ''QL020'')
# INSERT INTO TAIKHOAN VALUES('UserQL021', 'fYhlfhSLCx'. ''QL021'')
# INSERT INTO TAIKHOAN VALUES('UserQL022', 'SLOmTbOMdy'. ''QL022'')
# INSERT INTO TAIKHOAN VALUES('UserQL023', 'ftfSvLHZvT'. ''QL023'')
# INSERT INTO TAIKHOAN VALUES('UserQL024', 'AguFBnEFGi'. ''QL024'')
# INSERT INTO TAIKHOAN VALUES('UserQL025', 'tfaLGVqOzC'. ''QL025'')
# INSERT INTO TAIKHOAN VALUES('UserQL026', 'vSjdEcXjmG'. ''QL026'')
# INSERT INTO TAIKHOAN VALUES('UserQL027', 'DbJuaEwEWv'. ''QL027'')
# INSERT INTO TAIKHOAN VALUES('UserQL028', 'hdnFMALddm'. ''QL028'')
# INSERT INTO TAIKHOAN VALUES('UserQL029', 'xGaRttoSMn'. ''QL029'')
# INSERT INTO TAIKHOAN VALUES('UserQL030', 'geqJhgDhCr'. ''QL030'')
# INSERT INTO TAIKHOAN VALUES('UserQL031', 'kIWCUxhnbn'. ''QL031'')
# INSERT INTO TAIKHOAN VALUES('UserQL032', 'ULXFyMzERF'. ''QL032'')
# INSERT INTO TAIKHOAN VALUES('UserQL033', 'IEfGPnbTOo'. ''QL033'')
# INSERT INTO TAIKHOAN VALUES('UserQL034', 'FfEEkddlFY'. ''QL034'')
# INSERT INTO TAIKHOAN VALUES('UserQL035', 'zGwgoMjaMG'. ''QL035'')
# INSERT INTO TAIKHOAN VALUES('UserTDA036', 'QuafjLAtey'. ''TDA036'')
# INSERT INTO TAIKHOAN VALUES('UserTDA037', 'lKTkKnwXix'. ''TDA037'')
# INSERT INTO TAIKHOAN VALUES('UserTDA038', 'FCyEZzEZJf'. ''TDA038'')
# INSERT INTO TAIKHOAN VALUES('UserTP039', 'erwhzsDaEe'. ''TP039'')
# INSERT INTO TAIKHOAN VALUES('UserTP040', 'VLKFAIOvlc'. ''TP040'')
# INSERT INTO TAIKHOAN VALUES('UserTP041', 'tsoMJbYmoj'. ''TP041'')
# INSERT INTO TAIKHOAN VALUES('UserTP042', 'kMOvFAKsRi'. ''TP042'')
# INSERT INTO TAIKHOAN VALUES('UserTP043', 'RjAFmAJSZE'. ''TP043'')
# INSERT INTO TAIKHOAN VALUES('UserTP044', 'lPmqJPaRen'. ''TP044'')
# INSERT INTO TAIKHOAN VALUES('UserTP045', 'vditZAiWND'. ''TP045'')
# INSERT INTO TAIKHOAN VALUES('UserTP046', 'sbgmbHbdOE'. ''TP046'')
# INSERT INTO TAIKHOAN VALUES('UserNV47', 'AADzlvedNU'. ''NV47'')
# INSERT INTO TAIKHOAN VALUES('UserNV48', 'fiKAYMOFRD'. ''NV48'')
# INSERT INTO TAIKHOAN VALUES('UserNV49', 'IsiLEGMbCH'. ''NV49'')
# INSERT INTO TAIKHOAN VALUES('UserNV50', 'NGomUWmVNu'. ''NV50'')
# INSERT INTO TAIKHOAN VALUES('UserNV51', 'civooLEooG'. ''NV51'')
# INSERT INTO TAIKHOAN VALUES('UserNV52', 'YRvsDVvIfY'. ''NV52'')
# INSERT INTO TAIKHOAN VALUES('UserNV53', 'hVmEUEIQCo'. ''NV53'')
# INSERT INTO TAIKHOAN VALUES('UserNV54', 'nLGxRTrNpT'. ''NV54'')
# INSERT INTO TAIKHOAN VALUES('UserNV55', 'cGVczlBmWt'. ''NV55'')
# INSERT INTO TAIKHOAN VALUES('UserNV56', 'OGNjwyhJSr'. ''NV56'')
# INSERT INTO TAIKHOAN VALUES('UserNV57', 'FjdIJyofMB'. ''NV57'')
# INSERT INTO TAIKHOAN VALUES('UserNV58', 'tgdrZkQRNj'. ''NV58'')
# INSERT INTO TAIKHOAN VALUES('UserNV59', 'LRSdTsSCgM'. ''NV59'')
# INSERT INTO TAIKHOAN VALUES('UserNV60', 'yfRsLyKlWH'. ''NV60'')
# INSERT INTO TAIKHOAN VALUES('UserNV61', 'UIFcuoCkVb'. ''NV61'')
# INSERT INTO TAIKHOAN VALUES('UserNV62', 'OKWUjNxoWP'. ''NV62'')
# INSERT INTO TAIKHOAN VALUES('UserNV63', 'ZdrqNWlsUl'. ''NV63'')
# INSERT INTO TAIKHOAN VALUES('UserNV64', 'pPPyCBqQap'. ''NV64'')
# INSERT INTO TAIKHOAN VALUES('UserNV65', 'cJIkuFhjTz'. ''NV65'')
# INSERT INTO TAIKHOAN VALUES('UserNV66', 'GKNpKOnVXg'. ''NV66'')
# INSERT INTO TAIKHOAN VALUES('UserNV67', 'dPqqaopDEJ'. ''NV67'')
# INSERT INTO TAIKHOAN VALUES('UserNV68', 'kwUpbbTBwh'. ''NV68'')
# INSERT INTO TAIKHOAN VALUES('UserNV69', 'RsAgsqnBAU'. ''NV69'')
# INSERT INTO TAIKHOAN VALUES('UserNV70', 'cGBVSCkblM'. ''NV70'')
# INSERT INTO TAIKHOAN VALUES('UserNV71', 'VkJeGonGIw'. ''NV71'')
# INSERT INTO TAIKHOAN VALUES('UserNV72', 'GNEJwuHCsY'. ''NV72'')
# INSERT INTO TAIKHOAN VALUES('UserNV73', 'PTQOxaFepo'. ''NV73'')
# INSERT INTO TAIKHOAN VALUES('UserNV74', 'zHrBRHcXpi'. ''NV74'')
# INSERT INTO TAIKHOAN VALUES('UserNV75', 'QMMZMNVJIB'. ''NV75'')
# INSERT INTO TAIKHOAN VALUES('UserNV76', 'qQdBaYhuCW'. ''NV76'')
# INSERT INTO TAIKHOAN VALUES('UserNV77', 'YFvpNvHkhl'. ''NV77'')
# INSERT INTO TAIKHOAN VALUES('UserNV78', 'JhswnSFiVW'. ''NV78'')
# INSERT INTO TAIKHOAN VALUES('UserNV79', 'tNhmcYuRBM'. ''NV79'')
# INSERT INTO TAIKHOAN VALUES('UserNV80', 'TRwVTVbIwY'. ''NV80'')
# INSERT INTO TAIKHOAN VALUES('UserNV81', 'hqCAJaitxh'. ''NV81'')
# INSERT INTO TAIKHOAN VALUES('UserNV82', 'XqPRymAtnp'. ''NV82'')
# INSERT INTO TAIKHOAN VALUES('UserNV83', 'CBLmdRRUPm'. ''NV83'')
# INSERT INTO TAIKHOAN VALUES('UserNV84', 'xKmTuqMisB'. ''NV84'')
# INSERT INTO TAIKHOAN VALUES('UserNV85', 'BgYyZpOesR'. ''NV85'')
# INSERT INTO TAIKHOAN VALUES('UserNV86', 'AvbdAteiET'. ''NV86'')
# INSERT INTO TAIKHOAN VALUES('UserNV87', 'ZqnfLIbHMw'. ''NV87'')
# INSERT INTO TAIKHOAN VALUES('UserNV88', 'gdaOLYeasH'. ''NV88'')
# INSERT INTO TAIKHOAN VALUES('UserNV89', 'BvjjSIkrTY'. ''NV89'')
# INSERT INTO TAIKHOAN VALUES('UserNV90', 'uQfWoWuDvk'. ''NV90'')
# INSERT INTO TAIKHOAN VALUES('UserNV91', 'WHTUjkGUQC'. ''NV91'')
# INSERT INTO TAIKHOAN VALUES('UserNV92', 'flcUEynNwx'. ''NV92'')
# INSERT INTO TAIKHOAN VALUES('UserNV93', 'ECfTLOtNbR'. ''NV93'')
# INSERT INTO TAIKHOAN VALUES('UserNV94', 'GSMZBhamso'. ''NV94'')
# INSERT INTO TAIKHOAN VALUES('UserNV95', 'xUEzSkVBrh'. ''NV95'')
# INSERT INTO TAIKHOAN VALUES('UserNV96', 'sVRIlujaEB'. ''NV96'')
# INSERT INTO TAIKHOAN VALUES('UserNV97', 'AWCZToDvBZ'. ''NV97'')
# INSERT INTO TAIKHOAN VALUES('UserNV98', 'PVFBOPkaeN'. ''NV98'')
# INSERT INTO TAIKHOAN VALUES('UserNV99', 'NgmazUVWVm'. ''NV99'')
# INSERT INTO TAIKHOAN VALUES('UserNV100', 'LpvUWnbEgZ'. ''NV100'')
# INSERT INTO TAIKHOAN VALUES('UserNV101', 'nTwmGpaCAi'. ''NV101'')
# INSERT INTO TAIKHOAN VALUES('UserNV102', 'gPIKvtqiDH'. ''NV102'')
# INSERT INTO TAIKHOAN VALUES('UserNV103', 'rxjHHlrgvB'. ''NV103'')
# INSERT INTO TAIKHOAN VALUES('UserNV104', 'owmXeAvdUp'. ''NV104'')
# INSERT INTO TAIKHOAN VALUES('UserNV105', 'RXduxMqVQv'. ''NV105'')
# INSERT INTO TAIKHOAN VALUES('UserNV106', 'WIMclRiHwz'. ''NV106'')
# INSERT INTO TAIKHOAN VALUES('UserNV107', 'DUQFlwSbUj'. ''NV107'')
# INSERT INTO TAIKHOAN VALUES('UserNV108', 'iwUQFrpIbr'. ''NV108'')
# INSERT INTO TAIKHOAN VALUES('UserNV109', 'WnOpCcZyJf'. ''NV109'')
# INSERT INTO TAIKHOAN VALUES('UserNV110', 'BBOfwuOwke'. ''NV110'')
# INSERT INTO TAIKHOAN VALUES('UserNV111', 'bMNaGutQta'. ''NV111'')
# INSERT INTO TAIKHOAN VALUES('UserNV112', 'uZIKPMnCfC'. ''NV112'')
# INSERT INTO TAIKHOAN VALUES('UserNV113', 'bhIRzcvXUa'. ''NV113'')
# INSERT INTO TAIKHOAN VALUES('UserNV114', 'xtoKSoOXhF'. ''NV114'')
# INSERT INTO TAIKHOAN VALUES('UserNV115', 'LeUGfmfJij'. ''NV115'')
# INSERT INTO TAIKHOAN VALUES('UserNV116', 'zDHzjNgUhY'. ''NV116'')
# INSERT INTO TAIKHOAN VALUES('UserNV117', 'vCUmKpQIEQ'. ''NV117'')
# INSERT INTO TAIKHOAN VALUES('UserNV118', 'OqflSYYWFB'. ''NV118'')
# INSERT INTO TAIKHOAN VALUES('UserNV119', 'VJUFUZCaly'. ''NV119'')
# INSERT INTO TAIKHOAN VALUES('UserNV120', 'wSrtbdmZwz'. ''NV120'')
# INSERT INTO TAIKHOAN VALUES('UserNV121', 'BcpJAIQwNM'. ''NV121'')
# INSERT INTO TAIKHOAN VALUES('UserNV122', 'iXivbUCVSP'. ''NV122'')
# INSERT INTO TAIKHOAN VALUES('UserNV123', 'pejhujlSGq'. ''NV123'')
# INSERT INTO TAIKHOAN VALUES('UserNV124', 'FMaxASdXyH'. ''NV124'')
# INSERT INTO TAIKHOAN VALUES('UserNV125', 'ZnLKDyVEBY'. ''NV125'')
# INSERT INTO TAIKHOAN VALUES('UserNV126', 'EatBHdTvQu'. ''NV126'')
# INSERT INTO TAIKHOAN VALUES('UserNV127', 'LybMWrMitr'. ''NV127'')
# INSERT INTO TAIKHOAN VALUES('UserNV128', 'TXqaBIlSBs'. ''NV128'')
# INSERT INTO TAIKHOAN VALUES('UserNV129', 'vyjVxAziyF'. ''NV129'')
# INSERT INTO TAIKHOAN VALUES('UserNV130', 'pnvivsRUwA'. ''NV130'')
# INSERT INTO TAIKHOAN VALUES('UserNV131', 'VCpzOdUfdS'. ''NV131'')
# INSERT INTO TAIKHOAN VALUES('UserNV132', 'barMnXCExD'. ''NV132'')
# INSERT INTO TAIKHOAN VALUES('UserNV133', 'aKbzcdRBMc'. ''NV133'')
# INSERT INTO TAIKHOAN VALUES('UserNV134', 'IlIhHcRdib'. ''NV134'')
# INSERT INTO TAIKHOAN VALUES('UserNV135', 'kmHCDNpTWd'. ''NV135'')
# INSERT INTO TAIKHOAN VALUES('UserNV136', 'nLFPSIPrqi'. ''NV136'')
# INSERT INTO TAIKHOAN VALUES('UserNV137', 'SJVZVOjccd'. ''NV137'')
# INSERT INTO TAIKHOAN VALUES('UserNV138', 'AwzlwgABIq'. ''NV138'')
# INSERT INTO TAIKHOAN VALUES('UserNV139', 'dHFDHqlHmE'. ''NV139'')
# INSERT INTO TAIKHOAN VALUES('UserNV140', 'QMziouBCuT'. ''NV140'')
# INSERT INTO TAIKHOAN VALUES('UserNV141', 'MDAGRRuAPJ'. ''NV141'')
# INSERT INTO TAIKHOAN VALUES('UserNV142', 'FJRZvqXgvL'. ''NV142'')
# INSERT INTO TAIKHOAN VALUES('UserNV143', 'opslbcRCYE'. ''NV143'')
# INSERT INTO TAIKHOAN VALUES('UserNV144', 'kouhVJdrMK'. ''NV144'')
# INSERT INTO TAIKHOAN VALUES('UserNV145', 'TpfHLcFfGu'. ''NV145'')
# INSERT INTO TAIKHOAN VALUES('UserNV146', 'GipYTuFLhS'. ''NV146'')
# INSERT INTO TAIKHOAN VALUES('UserNV147', 'jMUJgrfEud'. ''NV147'')
# INSERT INTO TAIKHOAN VALUES('UserNV148', 'fcFWjCEChy'. ''NV148'')
# INSERT INTO TAIKHOAN VALUES('UserNV149', 'fIEtAmpOQw'. ''NV149'')
# INSERT INTO TAIKHOAN VALUES('UserNV150', 'UaLPmKYfOX'. ''NV150'')
# INSERT INTO TAIKHOAN VALUES('UserNV151', 'xNnqMFoiaV'. ''NV151'')
# INSERT INTO TAIKHOAN VALUES('UserNV152', 'YacKAhGaAg'. ''NV152'')
# INSERT INTO TAIKHOAN VALUES('UserNV153', 'ExDUYadRlE'. ''NV153'')
# INSERT INTO TAIKHOAN VALUES('UserNV154', 'xsbJEtoSFy'. ''NV154'')
# INSERT INTO TAIKHOAN VALUES('UserNV155', 'deiIwtvQZD'. ''NV155'')
# INSERT INTO TAIKHOAN VALUES('UserNV156', 'KXxzCZqwbx'. ''NV156'')
# INSERT INTO TAIKHOAN VALUES('UserNV157', 'qDnHjiYPAo'. ''NV157'')
# INSERT INTO TAIKHOAN VALUES('UserNV158', 'AsieGVXaEj'. ''NV158'')
# INSERT INTO TAIKHOAN VALUES('UserNV159', 'IKcqEJiyOH'. ''NV159'')
# INSERT INTO TAIKHOAN VALUES('UserNV160', 'GqcyjdIyop'. ''NV160'')
# INSERT INTO TAIKHOAN VALUES('UserNV161', 'UqzpqUyyQN'. ''NV161'')
# INSERT INTO TAIKHOAN VALUES('UserNV162', 'LuYnsBlWVD'. ''NV162'')
# INSERT INTO TAIKHOAN VALUES('UserNV163', 'XBIDELVYYz'. ''NV163'')
# INSERT INTO TAIKHOAN VALUES('UserNV164', 'RegANMlTwS'. ''NV164'')
# INSERT INTO TAIKHOAN VALUES('UserNV165', 'BcMaIhsASg'. ''NV165'')
# INSERT INTO TAIKHOAN VALUES('UserNV166', 'ZWrOVyKpdI'. ''NV166'')
# INSERT INTO TAIKHOAN VALUES('UserNV167', 'YQmampSFTH'. ''NV167'')
# INSERT INTO TAIKHOAN VALUES('UserNV168', 'ECHJstQkQu'. ''NV168'')
# INSERT INTO TAIKHOAN VALUES('UserNV169', 'aWATJfYpho'. ''NV169'')
# INSERT INTO TAIKHOAN VALUES('UserNV170', 'vpeuMFSKSp'. ''NV170'')
# INSERT INTO TAIKHOAN VALUES('UserNV171', 'ckGCAkKFRP'. ''NV171'')
# INSERT INTO TAIKHOAN VALUES('UserNV172', 'LaPpAfccjQ'. ''NV172'')
# INSERT INTO TAIKHOAN VALUES('UserNV173', 'zovbvxDZIp'. ''NV173'')
# INSERT INTO TAIKHOAN VALUES('UserNV174', 'hvOdxtTMCB'. ''NV174'')
# INSERT INTO TAIKHOAN VALUES('UserNV175', 'oVLFhzLoZK'. ''NV175'')
# INSERT INTO TAIKHOAN VALUES('UserNV176', 'tyfwsjZvXr'. ''NV176'')
# INSERT INTO TAIKHOAN VALUES('UserNV177', 'iqqKBAhYlp'. ''NV177'')
# INSERT INTO TAIKHOAN VALUES('UserNV178', 'eieabqXuGi'. ''NV178'')
# INSERT INTO TAIKHOAN VALUES('UserNV179', 'DrfstQimSg'. ''NV179'')
# INSERT INTO TAIKHOAN VALUES('UserNV180', 'LmEiUOYQsu'. ''NV180'')
# INSERT INTO TAIKHOAN VALUES('UserNV181', 'UCkWaHJvNf'. ''NV181'')
# INSERT INTO TAIKHOAN VALUES('UserNV182', 'TpTTQsWZJK'. ''NV182'')
# INSERT INTO TAIKHOAN VALUES('UserNV183', 'jiIPRghWsZ'. ''NV183'')
# INSERT INTO TAIKHOAN VALUES('UserNV184', 'nfNHlUaMuZ'. ''NV184'')
# INSERT INTO TAIKHOAN VALUES('UserNV185', 'CWoelUNPzO'. ''NV185'')
# INSERT INTO TAIKHOAN VALUES('UserNV186', 'mCVnnrFHIR'. ''NV186'')
# INSERT INTO TAIKHOAN VALUES('UserNV187', 'teEHJwEoLd'. ''NV187'')
# INSERT INTO TAIKHOAN VALUES('UserNV188', 'ENLoGEDPCU'. ''NV188'')
# INSERT INTO TAIKHOAN VALUES('UserNV189', 'RhTqcweEwQ'. ''NV189'')
# INSERT INTO TAIKHOAN VALUES('UserNV190', 'faQCWdKUua'. ''NV190'')
# INSERT INTO TAIKHOAN VALUES('UserNV191', 'iUWuhplNyx'. ''NV191'')
# INSERT INTO TAIKHOAN VALUES('UserNV192', 'cRvwDquPlX'. ''NV192'')
# INSERT INTO TAIKHOAN VALUES('UserNV193', 'bMcMUiXtit'. ''NV193'')
# INSERT INTO TAIKHOAN VALUES('UserNV194', 'HveTumefyG'. ''NV194'')
# INSERT INTO TAIKHOAN VALUES('UserNV195', 'geXTJcvLRk'. ''NV195'')
# INSERT INTO TAIKHOAN VALUES('UserNV196', 'rtenYfYGKK'. ''NV196'')
# INSERT INTO TAIKHOAN VALUES('UserNV197', 'oHAekBtknr'. ''NV197'')
# INSERT INTO TAIKHOAN VALUES('UserNV198', 'odVBBVhPFd'. ''NV198'')
# INSERT INTO TAIKHOAN VALUES('UserNV199', 'gbdDCsCWcD'. ''NV199'')
# INSERT INTO TAIKHOAN VALUES('UserNV200', 'CFPxdCyPHV'. ''NV200'')
# INSERT INTO TAIKHOAN VALUES('UserNV201', 'pCLGATMKKg'. ''NV201'')
# INSERT INTO TAIKHOAN VALUES('UserNV202', 'WSijYwOsLg'. ''NV202'')
# INSERT INTO TAIKHOAN VALUES('UserNV203', 'cwzsGhCKpr'. ''NV203'')
# INSERT INTO TAIKHOAN VALUES('UserNV204', 'KxJzgPzVTx'. ''NV204'')
# INSERT INTO TAIKHOAN VALUES('UserNV205', 'EySNCFFodx'. ''NV205'')
# INSERT INTO TAIKHOAN VALUES('UserNV206', 'EydBFLgMlQ'. ''NV206'')
# INSERT INTO TAIKHOAN VALUES('UserNV207', 'WpsvygaQYF'. ''NV207'')
# INSERT INTO TAIKHOAN VALUES('UserNV208', 'QKJqqhbsya'. ''NV208'')
# INSERT INTO TAIKHOAN VALUES('UserNV209', 'HzbBCtMCyX'. ''NV209'')
# INSERT INTO TAIKHOAN VALUES('UserNV210', 'mvOEspdlTY'. ''NV210'')
# INSERT INTO TAIKHOAN VALUES('UserNV211', 'vlUQYTdEeU'. ''NV211'')
# INSERT INTO TAIKHOAN VALUES('UserNV212', 'ItgseMqGQC'. ''NV212'')
# INSERT INTO TAIKHOAN VALUES('UserNV213', 'blnvFQaVet'. ''NV213'')
# INSERT INTO TAIKHOAN VALUES('UserNV214', 'qDWVdqsTrg'. ''NV214'')
# INSERT INTO TAIKHOAN VALUES('UserNV215', 'pUTymdiwZC'. ''NV215'')
# INSERT INTO TAIKHOAN VALUES('UserNV216', 'gEzxvUjqew'. ''NV216'')
# INSERT INTO TAIKHOAN VALUES('UserNV217', 'vosPdqcKYS'. ''NV217'')
# INSERT INTO TAIKHOAN VALUES('UserNV218', 'oylRwxrckO'. ''NV218'')
# INSERT INTO TAIKHOAN VALUES('UserNV219', 'eCDQCBTGRq'. ''NV219'')
# INSERT INTO TAIKHOAN VALUES('UserNV220', 'SuFWTHtLhU'. ''NV220'')
# INSERT INTO TAIKHOAN VALUES('UserNV221', 'BfcwfkBMiI'. ''NV221'')
# INSERT INTO TAIKHOAN VALUES('UserNV222', 'dewNmDIUCn'. ''NV222'')
# INSERT INTO TAIKHOAN VALUES('UserNV223', 'lbxJjwdTyY'. ''NV223'')
# INSERT INTO TAIKHOAN VALUES('UserNV224', 'YgEfGZpLRA'. ''NV224'')
# INSERT INTO TAIKHOAN VALUES('UserNV225', 'rawUGjuajy'. ''NV225'')
# INSERT INTO TAIKHOAN VALUES('UserNV226', 'IFLLMFqxPk'. ''NV226'')
# INSERT INTO TAIKHOAN VALUES('UserNV227', 'VyOWKonGnB'. ''NV227'')
# INSERT INTO TAIKHOAN VALUES('UserNV228', 'mQWTQKYBAl'. ''NV228'')
# INSERT INTO TAIKHOAN VALUES('UserNV229', 'tqFNJlviga'. ''NV229'')
# INSERT INTO TAIKHOAN VALUES('UserNV230', 'TArxEKcSDM'. ''NV230'')
# INSERT INTO TAIKHOAN VALUES('UserNV231', 'zXXjxZTHiY'. ''NV231'')
# INSERT INTO TAIKHOAN VALUES('UserNV232', 'WTzoiJSVBA'. ''NV232'')
# INSERT INTO TAIKHOAN VALUES('UserNV233', 'dlqCzmcOHW'. ''NV233'')
# INSERT INTO TAIKHOAN VALUES('UserNV234', 'OYDdqDKiTp'. ''NV234'')
# INSERT INTO TAIKHOAN VALUES('UserNV235', 'UMgEVkqNWQ'. ''NV235'')
# INSERT INTO TAIKHOAN VALUES('UserNV236', 'MlJfgyRaUa'. ''NV236'')
# INSERT INTO TAIKHOAN VALUES('UserNV237', 'TDVAjuHjNy'. ''NV237'')
# INSERT INTO TAIKHOAN VALUES('UserNV238', 'zrQIFVEcko'. ''NV238'')
# INSERT INTO TAIKHOAN VALUES('UserNV239', 'GvADRZHTzW'. ''NV239'')
# INSERT INTO TAIKHOAN VALUES('UserNV240', 'pNmJpuhnPO'. ''NV240'')
# INSERT INTO TAIKHOAN VALUES('UserNV241', 'PVniAitVDh'. ''NV241'')
# INSERT INTO TAIKHOAN VALUES('UserNV242', 'JmSDstoibK'. ''NV242'')
# INSERT INTO TAIKHOAN VALUES('UserNV243', 'uMZWyaWeVb'. ''NV243'')
# INSERT INTO TAIKHOAN VALUES('UserNV244', 'tcUJSVGNyi'. ''NV244'')
# INSERT INTO TAIKHOAN VALUES('UserNV245', 'sEIMTNKdHE'. ''NV245'')
# INSERT INTO TAIKHOAN VALUES('UserNV246', 'ToFOLjmCvk'. ''NV246'')
# INSERT INTO TAIKHOAN VALUES('UserNV247', 'wOzBigUWue'. ''NV247'')
# INSERT INTO TAIKHOAN VALUES('UserNV248', 'NVojJliPaq'. ''NV248'')
# INSERT INTO TAIKHOAN VALUES('UserNV249', 'bJIaacuRbE'. ''NV249'')
# INSERT INTO TAIKHOAN VALUES('UserNV250', 'MKRlUaCBAX'. ''NV250'')
# INSERT INTO TAIKHOAN VALUES('UserNV251', 'AInTzOUcsD'. ''NV251'')
# INSERT INTO TAIKHOAN VALUES('UserNV252', 'bfjuQDadYL'. ''NV252'')
# INSERT INTO TAIKHOAN VALUES('UserNV253', 'WooSrCcCZJ'. ''NV253'')
# INSERT INTO TAIKHOAN VALUES('UserNV254', 'hqgwXvzxGM'. ''NV254'')
# INSERT INTO TAIKHOAN VALUES('UserNV255', 'cCBeDryukA'. ''NV255'')
# INSERT INTO TAIKHOAN VALUES('UserNV256', 'tTLzZUVyRa'. ''NV256'')
# INSERT INTO TAIKHOAN VALUES('UserNV257', 'QKUsBNcsXF'. ''NV257'')
# INSERT INTO TAIKHOAN VALUES('UserNV258', 'DdvWXIefHL'. ''NV258'')
# INSERT INTO TAIKHOAN VALUES('UserNV259', 'rIvWgqsYsY'. ''NV259'')
# INSERT INTO TAIKHOAN VALUES('UserNV260', 'QElmiAEZTd'. ''NV260'')
# INSERT INTO TAIKHOAN VALUES('UserNV261', 'YqpNPwNpLz'. ''NV261'')
# INSERT INTO TAIKHOAN VALUES('UserNV262', 'JfDMnvtnIk'. ''NV262'')
# INSERT INTO TAIKHOAN VALUES('UserNV263', 'HDUUJFFVrK'. ''NV263'')
# INSERT INTO TAIKHOAN VALUES('UserNV264', 'vRxaejyzqF'. ''NV264'')
# INSERT INTO TAIKHOAN VALUES('UserNV265', 'mzbefQqBKB'. ''NV265'')
# INSERT INTO TAIKHOAN VALUES('UserNV266', 'GgRrVbfsjt'. ''NV266'')
# INSERT INTO TAIKHOAN VALUES('UserNV267', 'CnGvLNUTXG'. ''NV267'')
# INSERT INTO TAIKHOAN VALUES('UserNV268', 'OwKlIvXvcd'. ''NV268'')
# INSERT INTO TAIKHOAN VALUES('UserNV269', 'jtICjeIhGy'. ''NV269'')
# INSERT INTO TAIKHOAN VALUES('UserNV270', 'lKHdQpytAQ'. ''NV270'')
# INSERT INTO TAIKHOAN VALUES('UserNV271', 'sjfadSiBKR'. ''NV271'')
# INSERT INTO TAIKHOAN VALUES('UserNV272', 'TrumKIrbcN'. ''NV272'')
# INSERT INTO TAIKHOAN VALUES('UserNV273', 'wpipWncyUN'. ''NV273'')
# INSERT INTO TAIKHOAN VALUES('UserNV274', 'NKUbjqwIot'. ''NV274'')
# INSERT INTO TAIKHOAN VALUES('UserNV275', 'mruANocVMx'. ''NV275'')
# INSERT INTO TAIKHOAN VALUES('UserNV276', 'EhtOfRZiVj'. ''NV276'')
# INSERT INTO TAIKHOAN VALUES('UserNV277', 'ruLgfhObfF'. ''NV277'')
# INSERT INTO TAIKHOAN VALUES('UserNV278', 'gcmmPROoSl'. ''NV278'')
# INSERT INTO TAIKHOAN VALUES('UserNV279', 'lLPtjoCRnt'. ''NV279'')
# INSERT INTO TAIKHOAN VALUES('UserNV280', 'sTgqlliuCv'. ''NV280'')
# INSERT INTO TAIKHOAN VALUES('UserNV281', 'omZeuRNwgC'. ''NV281'')
# INSERT INTO TAIKHOAN VALUES('UserNV282', 'BadSGTwyXw'. ''NV282'')
# INSERT INTO TAIKHOAN VALUES('UserNV283', 'uxsnppJTEY'. ''NV283'')
# INSERT INTO TAIKHOAN VALUES('UserNV284', 'QknpZpZWJy'. ''NV284'')
# INSERT INTO TAIKHOAN VALUES('UserNV285', 'kaGaBrKeEp'. ''NV285'')
# INSERT INTO TAIKHOAN VALUES('UserNV286', 'EandpFQhVr'. ''NV286'')
# INSERT INTO TAIKHOAN VALUES('UserNV287', 'HLWmnKzBtJ'. ''NV287'')
# INSERT INTO TAIKHOAN VALUES('UserNV288', 'tTsHngmrij'. ''NV288'')
# INSERT INTO TAIKHOAN VALUES('UserNV289', 'eXkqcOEVrN'. ''NV289'')
# INSERT INTO TAIKHOAN VALUES('UserNV290', 'hOwXNXECRC'. ''NV290'')
# INSERT INTO TAIKHOAN VALUES('UserNV291', 'IVmMKarqYd'. ''NV291'')
# INSERT INTO TAIKHOAN VALUES('UserNV292', 'NCBzRROwDy'. ''NV292'')
# INSERT INTO TAIKHOAN VALUES('UserNV293', 'eJZnTUrZOG'. ''NV293'')
# INSERT INTO TAIKHOAN VALUES('UserNV294', 'ziWeovYBIw'. ''NV294'')
# INSERT INTO TAIKHOAN VALUES('UserNV295', 'plLSynBget'. ''NV295'')
# INSERT INTO TAIKHOAN VALUES('UserNV296', 'NFrxIphXuf'. ''NV296'')
# INSERT INTO TAIKHOAN VALUES('UserNV297', 'QbMGOqRzWB'. ''NV297'')
# INSERT INTO TAIKHOAN VALUES('UserNV298', 'tUxxAfuvAF'. ''NV298'')
# INSERT INTO TAIKHOAN VALUES('UserNV299', 'WpNHXAtKkE'. ''NV299'')
# INSERT INTO TAIKHOAN VALUES('UserNV300', 'LxajCnhMFp'. ''NV300'')
# INSERT INTO TAIKHOAN VALUES('UserNV301', 'mHPkJoxgQe'. ''NV301'')
# INSERT INTO TAIKHOAN VALUES('UserNV302', 'vZSUYxkSbH'. ''NV302'')
# INSERT INTO TAIKHOAN VALUES('UserNV303', 'ryQnklpvZL'. ''NV303'')
# INSERT INTO TAIKHOAN VALUES('UserNV304', 'AuBTMFaVwi'. ''NV304'')
# INSERT INTO TAIKHOAN VALUES('UserNV305', 'weuNMSynLN'. ''NV305'')
# INSERT INTO TAIKHOAN VALUES('UserNV306', 'fXtOPcVkor'. ''NV306'')
# INSERT INTO TAIKHOAN VALUES('UserNV307', 'tZJCOzgvTg'. ''NV307'')
# INSERT INTO TAIKHOAN VALUES('UserNV308', 'bNZuLzanet'. ''NV308'')
# INSERT INTO TAIKHOAN VALUES('UserNV309', 'odLRcCNlqj'. ''NV309'')
# INSERT INTO TAIKHOAN VALUES('UserNV310', 'taCjJhZOza'. ''NV310'')
# INSERT INTO TAIKHOAN VALUES('UserNV311', 'ZWhpBaWcyz'. ''NV311'')
# INSERT INTO TAIKHOAN VALUES('UserNV312', 'vbDXoDxvIY'. ''NV312'')
# INSERT INTO TAIKHOAN VALUES('UserNV313', 'wliLnvRHMD'. ''NV313'')
# INSERT INTO TAIKHOAN VALUES('UserNV314', 'AChdirmgXC'. ''NV314'')
# INSERT INTO TAIKHOAN VALUES('UserNV315', 'GFxgYQjSTa'. ''NV315'')
# INSERT INTO TAIKHOAN VALUES('UserNV316', 'jwBkufyrXB'. ''NV316'')
# INSERT INTO TAIKHOAN VALUES('UserNV317', 'yjeFijMxJh'. ''NV317'')
# INSERT INTO TAIKHOAN VALUES('UserNV318', 'PnDHIfjbCf'. ''NV318'')
# INSERT INTO TAIKHOAN VALUES('UserNV319', 'XUOTDxHYmW'. ''NV319'')
# INSERT INTO TAIKHOAN VALUES('UserNV320', 'hdGQQvIMPu'. ''NV320'')
# INSERT INTO TAIKHOAN VALUES('UserNV321', 'RcPOuBSsXr'. ''NV321'')
# INSERT INTO TAIKHOAN VALUES('UserNV322', 'RLHLZfjjPK'. ''NV322'')
# INSERT INTO TAIKHOAN VALUES('UserNV323', 'AMRvgzgvkV'. ''NV323'')
# INSERT INTO TAIKHOAN VALUES('UserNV324', 'eYeGeqqaLV'. ''NV324'')
# INSERT INTO TAIKHOAN VALUES('UserNV325', 'HBHPxMSoQO'. ''NV325'')
# INSERT INTO TAIKHOAN VALUES('UserNV326', 'NXfXQrfOIF'. ''NV326'')
# INSERT INTO TAIKHOAN VALUES('UserNV327', 'KCYxwaPaCz'. ''NV327'')
# INSERT INTO TAIKHOAN VALUES('UserNV328', 'pUBBPEIdhk'. ''NV328'')
# INSERT INTO TAIKHOAN VALUES('UserNV329', 'MqzrqORCJj'. ''NV329'')
# INSERT INTO TAIKHOAN VALUES('UserNV330', 'HDfzWLYhcE'. ''NV330'')
# INSERT INTO TAIKHOAN VALUES('UserNV331', 'YBVCFZVQHT'. ''NV331'')
# INSERT INTO TAIKHOAN VALUES('UserNV332', 'VSoEieKyBw'. ''NV332'')
# INSERT INTO TAIKHOAN VALUES('UserNV333', 'JOfAGlthYo'. ''NV333'')
# INSERT INTO TAIKHOAN VALUES('UserNV334', 'fMbzGXNWPC'. ''NV334'')
# INSERT INTO TAIKHOAN VALUES('UserNV335', 'mICpKvKKsD'. ''NV335'')
# INSERT INTO TAIKHOAN VALUES('UserNV336', 'IaoFDgWSXZ'. ''NV336'')
# INSERT INTO TAIKHOAN VALUES('UserNV337', 'cYReTLkFmH'. ''NV337'')
# INSERT INTO TAIKHOAN VALUES('UserNV338', 'cQGORGzVNg'. ''NV338'')
# INSERT INTO TAIKHOAN VALUES('UserNV339', 'uYReKGHIcC'. ''NV339'')
# INSERT INTO TAIKHOAN VALUES('UserNV340', 'AWLcmeidGP'. ''NV340'')
# INSERT INTO TAIKHOAN VALUES('UserNV341', 'rMGJjEXXiP'. ''NV341'')
# INSERT INTO TAIKHOAN VALUES('UserNV342', 'zvLzEKgpgo'. ''NV342'')
# INSERT INTO TAIKHOAN VALUES('UserNV343', 'ugCyEpJqBm'. ''NV343'')
# INSERT INTO TAIKHOAN VALUES('UserNV344', 'kMhIHxruDR'. ''NV344'')
# INSERT INTO TAIKHOAN VALUES('UserNV345', 'vthSvtJVFp'. ''NV345'')
# INSERT INTO TAIKHOAN VALUES('UserNV346', 'biGpMGmaWi'. ''NV346'')
