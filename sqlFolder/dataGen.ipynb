# %%
import random as rd

insert = "insert into table "

# %%
Ho = [ 'Ho','Bui', 'Đoan', 'Le', 'Nguyen', 'Duong', 'Tran', 'Ly', 'Vu', 'Vo', 'Đang', 'Pham', 'Ung', 'An', 'Au','Truong', 'Lai', 'Gian' ]
tendem = ['Van','Thi','Chi','Gia','Hoang', 'Song', 'Tung' ]
ten = ['Ngoc Nhi','An','Anh','Bac','Bao','Cau','Cuc','Đan','Đang','Đuc','Thong','Tien','Tuan','Tin','Tiep','Viet','Vinh','Vu','Vy','Minh','Giang','khanh','Sang','Duy','Chi','Thuong','Chung','Phu','Quoc','Nam','Ngan','Nguyet','May' 
       ,'Tu','Thien','Tan','Han']

# %%
'''
NhanVien (
	MaNV 		varchar(10) primary key,
	TenNV 	varchar2(60) not null,
	Phai 		varchar2(4),
	NgaySinh 	date,
	DiaChi 	varchar2(100),
	SoDT 		varchar(10) not null unique,
	Luong 	number,
	PhuCap 	number,
	VaiTro 	varchar2(50),
	MaNQL 	varchar(10),
	PHG 		number
	
)
go
'''
'''
Nhân viên - 300
Quản lí - 20
Trưởng phòng - 8
Tài chính - 5
Nhân sự - 5
Trưởng đề án - 3
Ban giám đốc - 5
'''
sex = ['Nam', 'Nu']
import string

username = ''
MaNV = ''
TenNV = ''
Phai = ''
NgaySinh = ''
DiaChi 	= ''
SoDT 	= ''
Luong 	= 0
PhuCap 	= 0
VaiTro 	= ''
MaNQL 	= 'NULL'
PHG 	= 0
for i in range(1, 347):
    Luong = rd.randint(1000, 9999)
    PhuCap = rd.randint(1000, 2000)
    PHG = i % 8 + 1
    if i < 6:
        MaNV = '\'GD00'+ str(i) + '\''
        VaiTro 	= '\'Ban giam doc\''
        Luong = 55555
    elif i < 11:
        MaNV = '\'TC0'+ str(i) + '\''
        VaiTro 	= '\'Tai chinh\''
        Luong = 11000
    elif i < 16:
        MaNV = '\'NS0'+ str(i) + '\''
        VaiTro 	= '\'Nhan su\''
        Luong = 13000
    elif i < 36:
        MaNV = '\'QL0'+ str(i) + '\''
        VaiTro 	= '\'Quan li\''
        Luong = 25000
    elif i < 39:
        MaNV = '\'TDA0'+ str(i) + '\''
        VaiTro 	= '\'Truong de an\''
        Luong = 20000
    elif i < 47:
        MaNV = '\'TP0'+ str(i) + '\''
        VaiTro 	= '\'Truong phong\''
        Luong = 22000
        PHG = i - 38
    else:
        MaNV = '\'NV'+ str(i) + '\''
        VaiTro 	= '\'Nhan vien\''
        MaNQL = '\'QL0' + str((i - 47) % 20 + 16) + '\''
     
    
    account_suffix = MaNV.replace("'", "")
    username = f'\'User{account_suffix}\''

    SoDT = '\'0945000' + str(i) + '\''
    TenNV = '\'' + rd.choice(Ho) + ' ' + rd.choice(tendem) + ' ' + rd.choice(ten) + '\''
    DiaChi = '\'227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh\'' 
    Phai = '\'' + rd.choice(sex) + '\''
    NgaySinh  = 'TO_DATE(' + '\'' + str(rd.randint(2000, 2022)) + '-' + str(rd.randint(1, 12)) + '-' + str(rd.randint(1, 28)) + '\',\'YYYY-MM-DD\')'
    
    final = MaNV + ', ' + TenNV + ', ' + Phai + ', ' + NgaySinh + ', ' + DiaChi +', ' + SoDT + ', ' + str(Luong) + ', ' + str(PhuCap) +', '+ VaiTro + ', ' + MaNQL + ', ' + str(PHG) + ', ' + username
    
    print (' into GOD.NHANVIEN values(' +  final + ')')
    
   # print('insert into TaiKhoan values(' + TenTaiKhoan + HoTen + str(Mk) + sdt + DiaChi + Email + LoaiTaiKhoan +')')
# Out:
#  into GOD.NHANVIEN values('GD001', 'Tran Thi Han', 'Nu', TO_DATE('2003-12-19','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '09450001', 55555, 1161, 'Ban giam doc', NULL, 2, 'UserGD001')
#  into GOD.NHANVIEN values('GD002', 'Lai Chi Tan', 'Nu', TO_DATE('2016-1-16','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '09450002', 55555, 1985, 'Ban giam doc', NULL, 3, 'UserGD002')
#  into GOD.NHANVIEN values('GD003', 'Vo Tung Đang', 'Nu', TO_DATE('2007-3-9','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '09450003', 55555, 1326, 'Ban giam doc', NULL, 4, 'UserGD003')
#  into GOD.NHANVIEN values('GD004', 'Ung Tung Han', 'Nam', TO_DATE('2005-4-4','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '09450004', 55555, 1401, 'Ban giam doc', NULL, 5, 'UserGD004')
#  into GOD.NHANVIEN values('GD005', 'Nguyen Song Nguyet', 'Nam', TO_DATE('2012-7-18','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '09450005', 55555, 1094, 'Ban giam doc', NULL, 6, 'UserGD005')
#  into GOD.NHANVIEN values('TC06', 'Pham Hoang Ngan', 'Nu', TO_DATE('2018-5-10','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '09450006', 11000, 1475, 'Tai chinh', NULL, 7, 'UserTC06')
#  into GOD.NHANVIEN values('TC07', 'Vu Van Vy', 'Nam', TO_DATE('2002-8-14','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '09450007', 11000, 1569, 'Tai chinh', NULL, 8, 'UserTC07')
#  into GOD.NHANVIEN values('TC08', 'Bui Chi Tin', 'Nu', TO_DATE('2017-4-14','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '09450008', 11000, 1011, 'Tai chinh', NULL, 1, 'UserTC08')
#  into GOD.NHANVIEN values('TC09', 'Duong Thi Chi', 'Nam', TO_DATE('2013-10-13','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '09450009', 11000, 1706, 'Tai chinh', NULL, 2, 'UserTC09')
#  into GOD.NHANVIEN values('TC010', 'An Chi An', 'Nu', TO_DATE('2012-5-28','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500010', 11000, 1070, 'Tai chinh', NULL, 3, 'UserTC010')
#  into GOD.NHANVIEN values('NS011', 'Truong Song Tien', 'Nu', TO_DATE('2001-10-12','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500011', 13000, 1104, 'Nhan su', NULL, 4, 'UserNS011')
#  into GOD.NHANVIEN values('NS012', 'Tran Song Chi', 'Nam', TO_DATE('2000-10-10','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500012', 13000, 1629, 'Nhan su', NULL, 5, 'UserNS012')
#  into GOD.NHANVIEN values('NS013', 'Le Chi Tiep', 'Nu', TO_DATE('2019-5-18','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500013', 13000, 1061, 'Nhan su', NULL, 6, 'UserNS013')
#  into GOD.NHANVIEN values('NS014', 'Nguyen Tung Viet', 'Nam', TO_DATE('2019-5-28','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500014', 13000, 1184, 'Nhan su', NULL, 7, 'UserNS014')
#  into GOD.NHANVIEN values('NS015', 'Tran Hoang Thien', 'Nam', TO_DATE('2016-4-27','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500015', 13000, 1188, 'Nhan su', NULL, 8, 'UserNS015')
#  into GOD.NHANVIEN values('QL016', 'Ly Gia Cuc', 'Nu', TO_DATE('2012-4-2','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500016', 25000, 1890, 'Quan li', NULL, 1, 'UserQL016')
#  into GOD.NHANVIEN values('QL017', 'Đoan Tung Sang', 'Nam', TO_DATE('2004-4-24','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500017', 25000, 1714, 'Quan li', NULL, 2, 'UserQL017')
#  into GOD.NHANVIEN values('QL018', 'Ho Song Vinh', 'Nu', TO_DATE('2020-8-18','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500018', 25000, 1942, 'Quan li', NULL, 3, 'UserQL018')
#  into GOD.NHANVIEN values('QL019', 'Đoan Chi Viet', 'Nu', TO_DATE('2019-4-23','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500019', 25000, 1150, 'Quan li', NULL, 4, 'UserQL019')
#  into GOD.NHANVIEN values('QL020', 'Gian Thi Tan', 'Nu', TO_DATE('2017-8-14','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500020', 25000, 1053, 'Quan li', NULL, 5, 'UserQL020')
#  into GOD.NHANVIEN values('QL021', 'Au Chi Vy', 'Nam', TO_DATE('2009-10-4','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500021', 25000, 1054, 'Quan li', NULL, 6, 'UserQL021')
#  into GOD.NHANVIEN values('QL022', 'Pham Gia Bao', 'Nu', TO_DATE('2013-1-5','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500022', 25000, 1309, 'Quan li', NULL, 7, 'UserQL022')
#  into GOD.NHANVIEN values('QL023', 'Đoan Van Tiep', 'Nu', TO_DATE('2001-2-2','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500023', 25000, 1258, 'Quan li', NULL, 8, 'UserQL023')
#  into GOD.NHANVIEN values('QL024', 'Ung Tung Tuan', 'Nu', TO_DATE('2000-1-8','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500024', 25000, 1320, 'Quan li', NULL, 1, 'UserQL024')
#  into GOD.NHANVIEN values('QL025', 'Ho Song Nam', 'Nam', TO_DATE('2011-3-13','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500025', 25000, 1688, 'Quan li', NULL, 2, 'UserQL025')
#  into GOD.NHANVIEN values('QL026', 'Ung Tung Giang', 'Nu', TO_DATE('2021-7-17','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500026', 25000, 1932, 'Quan li', NULL, 3, 'UserQL026')
#  into GOD.NHANVIEN values('QL027', 'Ly Chi Cuc', 'Nam', TO_DATE('2005-7-21','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500027', 25000, 1597, 'Quan li', NULL, 4, 'UserQL027')
#  into GOD.NHANVIEN values('QL028', 'Vo Hoang khanh', 'Nam', TO_DATE('2013-9-28','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500028', 25000, 1231, 'Quan li', NULL, 5, 'UserQL028')
#  into GOD.NHANVIEN values('QL029', 'Tran Gia Thien', 'Nam', TO_DATE('2005-12-6','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500029', 25000, 1613, 'Quan li', NULL, 6, 'UserQL029')
#  into GOD.NHANVIEN values('QL030', 'Đang Thi Thien', 'Nam', TO_DATE('2009-6-17','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500030', 25000, 1733, 'Quan li', NULL, 7, 'UserQL030')
#  into GOD.NHANVIEN values('QL031', 'Tran Chi Cuc', 'Nam', TO_DATE('2001-12-12','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500031', 25000, 1000, 'Quan li', NULL, 8, 'UserQL031')
#  into GOD.NHANVIEN values('QL032', 'Lai Chi Tien', 'Nu', TO_DATE('2015-2-16','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500032', 25000, 1928, 'Quan li', NULL, 1, 'UserQL032')
#  into GOD.NHANVIEN values('QL033', 'Ung Thi Chi', 'Nu', TO_DATE('2022-6-26','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500033', 25000, 1651, 'Quan li', NULL, 2, 'UserQL033')
#  into GOD.NHANVIEN values('QL034', 'Ly Tung Vinh', 'Nu', TO_DATE('2009-6-28','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500034', 25000, 1157, 'Quan li', NULL, 3, 'UserQL034')
#  into GOD.NHANVIEN values('QL035', 'Đoan Thi Đuc', 'Nam', TO_DATE('2016-4-22','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500035', 25000, 1892, 'Quan li', NULL, 4, 'UserQL035')
#  into GOD.NHANVIEN values('TDA036', 'Au Song Vu', 'Nu', TO_DATE('2021-9-2','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500036', 20000, 1844, 'Truong de an', NULL, 5, 'UserTDA036')
#  into GOD.NHANVIEN values('TDA037', 'Đoan Hoang Nam', 'Nu', TO_DATE('2021-5-22','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500037', 20000, 1890, 'Truong de an', NULL, 6, 'UserTDA037')
#  into GOD.NHANVIEN values('TDA038', 'Ung Van Bao', 'Nam', TO_DATE('2007-5-27','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500038', 20000, 1612, 'Truong de an', NULL, 7, 'UserTDA038')
#  into GOD.NHANVIEN values('TP039', 'Vo Hoang Duy', 'Nu', TO_DATE('2020-7-5','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500039', 22000, 1568, 'Truong phong', NULL, 1, 'UserTP039')
#  into GOD.NHANVIEN values('TP040', 'An Van Viet', 'Nam', TO_DATE('2012-11-1','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500040', 22000, 1223, 'Truong phong', NULL, 2, 'UserTP040')
#  into GOD.NHANVIEN values('TP041', 'Au Tung Ngan', 'Nam', TO_DATE('2013-3-26','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500041', 22000, 1485, 'Truong phong', NULL, 3, 'UserTP041')
#  into GOD.NHANVIEN values('TP042', 'Truong Van May', 'Nu', TO_DATE('2019-10-9','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500042', 22000, 1386, 'Truong phong', NULL, 4, 'UserTP042')
#  into GOD.NHANVIEN values('TP043', 'Đang Tung Nam', 'Nu', TO_DATE('2007-10-13','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500043', 22000, 1686, 'Truong phong', NULL, 5, 'UserTP043')
#  into GOD.NHANVIEN values('TP044', 'Au Tung Minh', 'Nam', TO_DATE('2021-3-3','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500044', 22000, 1611, 'Truong phong', NULL, 6, 'UserTP044')
#  into GOD.NHANVIEN values('TP045', 'Tran Van May', 'Nu', TO_DATE('2018-4-10','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500045', 22000, 1510, 'Truong phong', NULL, 7, 'UserTP045')
#  into GOD.NHANVIEN values('TP046', 'Au Hoang Minh', 'Nu', TO_DATE('2021-10-9','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500046', 22000, 1755, 'Truong phong', NULL, 8, 'UserTP046')
#  into GOD.NHANVIEN values('NV47', 'Ly Hoang Giang', 'Nam', TO_DATE('2015-1-11','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500047', 8121, 1330, 'Nhan vien', 'QL016', 8, 'UserNV47')
#  into GOD.NHANVIEN values('NV48', 'Au Chi Cuc', 'Nu', TO_DATE('2007-11-21','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500048', 7592, 1890, 'Nhan vien', 'QL017', 1, 'UserNV48')
#  into GOD.NHANVIEN values('NV49', 'Bui Tung Tuan', 'Nu', TO_DATE('2006-10-11','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500049', 5695, 1321, 'Nhan vien', 'QL018', 2, 'UserNV49')
#  into GOD.NHANVIEN values('NV50', 'Lai Tung An', 'Nam', TO_DATE('2016-11-13','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500050', 8909, 1754, 'Nhan vien', 'QL019', 3, 'UserNV50')
#  into GOD.NHANVIEN values('NV51', 'Đang Chi Thuong', 'Nam', TO_DATE('2020-3-21','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500051', 4546, 1899, 'Nhan vien', 'QL020', 4, 'UserNV51')
#  into GOD.NHANVIEN values('NV52', 'Đang Song Chi', 'Nam', TO_DATE('2015-2-27','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500052', 3254, 1916, 'Nhan vien', 'QL021', 5, 'UserNV52')
#  into GOD.NHANVIEN values('NV53', 'Au Hoang Tuan', 'Nam', TO_DATE('2017-5-2','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500053', 5640, 1057, 'Nhan vien', 'QL022', 6, 'UserNV53')
#  into GOD.NHANVIEN values('NV54', 'Gian Van Bac', 'Nam', TO_DATE('2017-8-24','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500054', 8214, 1592, 'Nhan vien', 'QL023', 7, 'UserNV54')
#  into GOD.NHANVIEN values('NV55', 'Vu Van Chung', 'Nu', TO_DATE('2004-12-21','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500055', 1505, 1283, 'Nhan vien', 'QL024', 8, 'UserNV55')
#  into GOD.NHANVIEN values('NV56', 'Ly Van Minh', 'Nu', TO_DATE('2005-10-28','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500056', 4127, 1901, 'Nhan vien', 'QL025', 1, 'UserNV56')
#  into GOD.NHANVIEN values('NV57', 'Duong Song Giang', 'Nu', TO_DATE('2008-9-5','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500057', 3165, 1754, 'Nhan vien', 'QL026', 2, 'UserNV57')
#  into GOD.NHANVIEN values('NV58', 'Tran Song Cuc', 'Nu', TO_DATE('2009-8-7','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500058', 5477, 1804, 'Nhan vien', 'QL027', 3, 'UserNV58')
#  into GOD.NHANVIEN values('NV59', 'Ung Tung Giang', 'Nam', TO_DATE('2006-6-28','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500059', 2151, 1508, 'Nhan vien', 'QL028', 4, 'UserNV59')
#  into GOD.NHANVIEN values('NV60', 'Au Hoang Sang', 'Nam', TO_DATE('2006-1-23','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500060', 8707, 1384, 'Nhan vien', 'QL029', 5, 'UserNV60')
#  into GOD.NHANVIEN values('NV61', 'Nguyen Thi Chi', 'Nu', TO_DATE('2010-5-16','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500061', 3680, 1816, 'Nhan vien', 'QL030', 6, 'UserNV61')
#  into GOD.NHANVIEN values('NV62', 'Ly Hoang Phu', 'Nam', TO_DATE('2004-12-12','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500062', 3066, 1918, 'Nhan vien', 'QL031', 7, 'UserNV62')
#  into GOD.NHANVIEN values('NV63', 'Ly Gia Cau', 'Nam', TO_DATE('2006-4-3','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500063', 8792, 1990, 'Nhan vien', 'QL032', 8, 'UserNV63')
#  into GOD.NHANVIEN values('NV64', 'Pham Chi An', 'Nam', TO_DATE('2004-11-24','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500064', 2536, 1751, 'Nhan vien', 'QL033', 1, 'UserNV64')
#  into GOD.NHANVIEN values('NV65', 'Pham Van Đuc', 'Nu', TO_DATE('2014-2-15','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500065', 1115, 1401, 'Nhan vien', 'QL034', 2, 'UserNV65')
#  into GOD.NHANVIEN values('NV66', 'Truong Van Tan', 'Nam', TO_DATE('2009-2-3','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500066', 5760, 1534, 'Nhan vien', 'QL035', 3, 'UserNV66')
#  into GOD.NHANVIEN values('NV67', 'Gian Tung Tin', 'Nu', TO_DATE('2014-11-27','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500067', 5133, 1654, 'Nhan vien', 'QL016', 4, 'UserNV67')
#  into GOD.NHANVIEN values('NV68', 'Gian Van Đan', 'Nam', TO_DATE('2018-1-3','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500068', 5924, 1264, 'Nhan vien', 'QL017', 5, 'UserNV68')
#  into GOD.NHANVIEN values('NV69', 'Pham Van Tu', 'Nu', TO_DATE('2011-3-21','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500069', 8706, 1505, 'Nhan vien', 'QL018', 6, 'UserNV69')
#  into GOD.NHANVIEN values('NV70', 'Vo Thi Tien', 'Nam', TO_DATE('2013-10-21','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500070', 2661, 1633, 'Nhan vien', 'QL019', 7, 'UserNV70')
#  into GOD.NHANVIEN values('NV71', 'Duong Van Bac', 'Nam', TO_DATE('2005-12-21','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500071', 7609, 1637, 'Nhan vien', 'QL020', 8, 'UserNV71')
#  into GOD.NHANVIEN values('NV72', 'Đoan Song May', 'Nam', TO_DATE('2020-5-4','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500072', 4311, 1736, 'Nhan vien', 'QL021', 1, 'UserNV72')
#  into GOD.NHANVIEN values('NV73', 'Gian Thi Duy', 'Nam', TO_DATE('2012-6-19','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500073', 6834, 1630, 'Nhan vien', 'QL022', 2, 'UserNV73')
#  into GOD.NHANVIEN values('NV74', 'Lai Song Cau', 'Nam', TO_DATE('2003-9-9','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500074', 9319, 1792, 'Nhan vien', 'QL023', 3, 'UserNV74')
#  into GOD.NHANVIEN values('NV75', 'Tran Gia Vy', 'Nam', TO_DATE('2019-10-19','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500075', 2504, 1185, 'Nhan vien', 'QL024', 4, 'UserNV75')
#  into GOD.NHANVIEN values('NV76', 'Lai Song Tan', 'Nam', TO_DATE('2018-2-22','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500076', 5766, 1679, 'Nhan vien', 'QL025', 5, 'UserNV76')
#  into GOD.NHANVIEN values('NV77', 'Le Thi Bac', 'Nam', TO_DATE('2008-6-16','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500077', 5592, 1081, 'Nhan vien', 'QL026', 6, 'UserNV77')
#  into GOD.NHANVIEN values('NV78', 'Pham Gia Đan', 'Nu', TO_DATE('2015-10-23','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500078', 8450, 1769, 'Nhan vien', 'QL027', 7, 'UserNV78')
#  into GOD.NHANVIEN values('NV79', 'Pham Gia Tuan', 'Nu', TO_DATE('2021-2-3','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500079', 5117, 1101, 'Nhan vien', 'QL028', 8, 'UserNV79')
#  into GOD.NHANVIEN values('NV80', 'An Thi Đuc', 'Nu', TO_DATE('2017-7-19','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500080', 6086, 1368, 'Nhan vien', 'QL029', 1, 'UserNV80')
#  into GOD.NHANVIEN values('NV81', 'Gian Chi Sang', 'Nam', TO_DATE('2013-7-14','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500081', 1356, 1373, 'Nhan vien', 'QL030', 2, 'UserNV81')
#  into GOD.NHANVIEN values('NV82', 'Ly Tung Cuc', 'Nam', TO_DATE('2002-1-13','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500082', 4420, 1219, 'Nhan vien', 'QL031', 3, 'UserNV82')
#  into GOD.NHANVIEN values('NV83', 'Ly Thi Han', 'Nam', TO_DATE('2009-11-10','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500083', 6537, 1241, 'Nhan vien', 'QL032', 4, 'UserNV83')
#  into GOD.NHANVIEN values('NV84', 'Bui Song Đuc', 'Nam', TO_DATE('2022-3-22','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500084', 3683, 1712, 'Nhan vien', 'QL033', 5, 'UserNV84')
#  into GOD.NHANVIEN values('NV85', 'Đang Van Thong', 'Nu', TO_DATE('2022-7-2','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500085', 2571, 1614, 'Nhan vien', 'QL034', 6, 'UserNV85')
#  into GOD.NHANVIEN values('NV86', 'Pham Hoang Thong', 'Nam', TO_DATE('2019-7-13','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500086', 1013, 1130, 'Nhan vien', 'QL035', 7, 'UserNV86')
#  into GOD.NHANVIEN values('NV87', 'Vu Van Minh', 'Nu', TO_DATE('2011-5-21','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500087', 6180, 1135, 'Nhan vien', 'QL016', 8, 'UserNV87')
#  into GOD.NHANVIEN values('NV88', 'Pham Chi Đang', 'Nam', TO_DATE('2011-3-6','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500088', 2667, 1775, 'Nhan vien', 'QL017', 1, 'UserNV88')
#  into GOD.NHANVIEN values('NV89', 'Truong Van Đan', 'Nu', TO_DATE('2020-2-25','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500089', 5226, 1825, 'Nhan vien', 'QL018', 2, 'UserNV89')
#  into GOD.NHANVIEN values('NV90', 'Tran Van Minh', 'Nam', TO_DATE('2022-6-1','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500090', 6530, 1735, 'Nhan vien', 'QL019', 3, 'UserNV90')
#  into GOD.NHANVIEN values('NV91', 'Gian Van May', 'Nam', TO_DATE('2013-10-17','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500091', 2813, 1789, 'Nhan vien', 'QL020', 4, 'UserNV91')
#  into GOD.NHANVIEN values('NV92', 'Duong Van Vu', 'Nu', TO_DATE('2020-11-11','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500092', 8595, 1919, 'Nhan vien', 'QL021', 5, 'UserNV92')
#  into GOD.NHANVIEN values('NV93', 'Vu Tung Bao', 'Nam', TO_DATE('2002-2-1','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500093', 3033, 1223, 'Nhan vien', 'QL022', 6, 'UserNV93')
#  into GOD.NHANVIEN values('NV94', 'Ly Van Nguyet', 'Nam', TO_DATE('2002-6-21','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500094', 3926, 1054, 'Nhan vien', 'QL023', 7, 'UserNV94')
#  into GOD.NHANVIEN values('NV95', 'Ung Tung Quoc', 'Nam', TO_DATE('2006-8-23','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500095', 3791, 1845, 'Nhan vien', 'QL024', 8, 'UserNV95')
#  into GOD.NHANVIEN values('NV96', 'Duong Thi Vinh', 'Nu', TO_DATE('2014-10-6','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500096', 2454, 1891, 'Nhan vien', 'QL025', 1, 'UserNV96')
#  into GOD.NHANVIEN values('NV97', 'Tran Tung Giang', 'Nam', TO_DATE('2015-1-28','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500097', 4540, 1591, 'Nhan vien', 'QL026', 2, 'UserNV97')
#  into GOD.NHANVIEN values('NV98', 'Ho Tung Đuc', 'Nam', TO_DATE('2010-3-2','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500098', 3212, 1328, 'Nhan vien', 'QL027', 3, 'UserNV98')
#  into GOD.NHANVIEN values('NV99', 'Le Song Tu', 'Nu', TO_DATE('2005-6-21','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '094500099', 9909, 1125, 'Nhan vien', 'QL028', 4, 'UserNV99')
#  into GOD.NHANVIEN values('NV100', 'Pham Gia Tuan', 'Nam', TO_DATE('2017-4-3','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000100', 7985, 1882, 'Nhan vien', 'QL029', 5, 'UserNV100')
#  into GOD.NHANVIEN values('NV101', 'Ly Song Vinh', 'Nu', TO_DATE('2002-2-24','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000101', 8765, 1895, 'Nhan vien', 'QL030', 6, 'UserNV101')
#  into GOD.NHANVIEN values('NV102', 'Ly Hoang Ngoc Nhi', 'Nam', TO_DATE('2003-7-18','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000102', 6200, 1281, 'Nhan vien', 'QL031', 7, 'UserNV102')
#  into GOD.NHANVIEN values('NV103', 'Tran Thi An', 'Nu', TO_DATE('2007-6-20','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000103', 5088, 1092, 'Nhan vien', 'QL032', 8, 'UserNV103')
#  into GOD.NHANVIEN values('NV104', 'Pham Tung khanh', 'Nu', TO_DATE('2005-12-25','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000104', 1412, 1328, 'Nhan vien', 'QL033', 1, 'UserNV104')
#  into GOD.NHANVIEN values('NV105', 'Ho Gia May', 'Nu', TO_DATE('2002-3-1','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000105', 6037, 1277, 'Nhan vien', 'QL034', 2, 'UserNV105')
#  into GOD.NHANVIEN values('NV106', 'Ho Gia May', 'Nam', TO_DATE('2001-1-2','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000106', 4311, 1147, 'Nhan vien', 'QL035', 3, 'UserNV106')
#  into GOD.NHANVIEN values('NV107', 'Gian Thi Tu', 'Nu', TO_DATE('2017-2-2','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000107', 7361, 1917, 'Nhan vien', 'QL016', 4, 'UserNV107')
#  into GOD.NHANVIEN values('NV108', 'Truong Tung Cuc', 'Nu', TO_DATE('2019-4-23','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000108', 6327, 1935, 'Nhan vien', 'QL017', 5, 'UserNV108')
#  into GOD.NHANVIEN values('NV109', 'Đoan Tung Thong', 'Nu', TO_DATE('2011-9-27','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000109', 8662, 1749, 'Nhan vien', 'QL018', 6, 'UserNV109')
#  into GOD.NHANVIEN values('NV110', 'Gian Hoang Phu', 'Nam', TO_DATE('2012-11-16','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000110', 2182, 1751, 'Nhan vien', 'QL019', 7, 'UserNV110')
#  into GOD.NHANVIEN values('NV111', 'Lai Tung Tiep', 'Nu', TO_DATE('2002-4-14','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000111', 1503, 1944, 'Nhan vien', 'QL020', 8, 'UserNV111')
#  into GOD.NHANVIEN values('NV112', 'Đang Gia Thuong', 'Nu', TO_DATE('2001-6-15','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000112', 8675, 1501, 'Nhan vien', 'QL021', 1, 'UserNV112')
#  into GOD.NHANVIEN values('NV113', 'Bui Hoang Tu', 'Nu', TO_DATE('2008-3-27','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000113', 2191, 1715, 'Nhan vien', 'QL022', 2, 'UserNV113')
#  into GOD.NHANVIEN values('NV114', 'Ho Hoang Đan', 'Nam', TO_DATE('2007-12-24','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000114', 5890, 1548, 'Nhan vien', 'QL023', 3, 'UserNV114')
#  into GOD.NHANVIEN values('NV115', 'Ung Chi Vinh', 'Nu', TO_DATE('2011-6-27','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000115', 4776, 1068, 'Nhan vien', 'QL024', 4, 'UserNV115')
#  into GOD.NHANVIEN values('NV116', 'Truong Gia Quoc', 'Nu', TO_DATE('2002-8-3','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000116', 7350, 1787, 'Nhan vien', 'QL025', 5, 'UserNV116')
#  into GOD.NHANVIEN values('NV117', 'Le Van Đuc', 'Nu', TO_DATE('2017-12-13','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000117', 4227, 1917, 'Nhan vien', 'QL026', 6, 'UserNV117')
#  into GOD.NHANVIEN values('NV118', 'Lai Thi Vy', 'Nam', TO_DATE('2015-11-9','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000118', 1781, 1167, 'Nhan vien', 'QL027', 7, 'UserNV118')
#  into GOD.NHANVIEN values('NV119', 'Au Tung Tuan', 'Nu', TO_DATE('2015-4-20','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000119', 9886, 1615, 'Nhan vien', 'QL028', 8, 'UserNV119')
#  into GOD.NHANVIEN values('NV120', 'Tran Gia Nguyet', 'Nu', TO_DATE('2016-6-18','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000120', 7969, 1691, 'Nhan vien', 'QL029', 1, 'UserNV120')
#  into GOD.NHANVIEN values('NV121', 'Đoan Chi Tan', 'Nu', TO_DATE('2020-8-26','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000121', 9003, 1966, 'Nhan vien', 'QL030', 2, 'UserNV121')
#  into GOD.NHANVIEN values('NV122', 'Tran Chi Bao', 'Nu', TO_DATE('2007-2-16','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000122', 4577, 1649, 'Nhan vien', 'QL031', 3, 'UserNV122')
#  into GOD.NHANVIEN values('NV123', 'Bui Thi Giang', 'Nam', TO_DATE('2000-2-26','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000123', 2571, 1453, 'Nhan vien', 'QL032', 4, 'UserNV123')
#  into GOD.NHANVIEN values('NV124', 'Ly Thi Thong', 'Nam', TO_DATE('2015-8-16','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000124', 9272, 1676, 'Nhan vien', 'QL033', 5, 'UserNV124')
#  into GOD.NHANVIEN values('NV125', 'Le Gia Tu', 'Nu', TO_DATE('2007-1-10','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000125', 5330, 1685, 'Nhan vien', 'QL034', 6, 'UserNV125')
#  into GOD.NHANVIEN values('NV126', 'Ung Van Đang', 'Nu', TO_DATE('2022-9-23','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000126', 3586, 1515, 'Nhan vien', 'QL035', 7, 'UserNV126')
#  into GOD.NHANVIEN values('NV127', 'Pham Chi khanh', 'Nu', TO_DATE('2005-1-22','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000127', 6583, 1499, 'Nhan vien', 'QL016', 8, 'UserNV127')
#  into GOD.NHANVIEN values('NV128', 'Ho Gia Thien', 'Nu', TO_DATE('2015-1-16','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000128', 7075, 1721, 'Nhan vien', 'QL017', 1, 'UserNV128')
#  into GOD.NHANVIEN values('NV129', 'Ho Tung Thong', 'Nam', TO_DATE('2003-9-22','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000129', 4215, 1964, 'Nhan vien', 'QL018', 2, 'UserNV129')
#  into GOD.NHANVIEN values('NV130', 'An Thi Đuc', 'Nam', TO_DATE('2005-6-8','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000130', 2980, 1223, 'Nhan vien', 'QL019', 3, 'UserNV130')
#  into GOD.NHANVIEN values('NV131', 'Ho Thi Nam', 'Nam', TO_DATE('2018-5-1','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000131', 5951, 1964, 'Nhan vien', 'QL020', 4, 'UserNV131')
#  into GOD.NHANVIEN values('NV132', 'Ung Van Duy', 'Nam', TO_DATE('2011-8-18','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000132', 7930, 1255, 'Nhan vien', 'QL021', 5, 'UserNV132')
#  into GOD.NHANVIEN values('NV133', 'Đoan Chi Nguyet', 'Nam', TO_DATE('2011-4-24','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000133', 2226, 1900, 'Nhan vien', 'QL022', 6, 'UserNV133')
#  into GOD.NHANVIEN values('NV134', 'Ung Song Vy', 'Nam', TO_DATE('2018-5-25','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000134', 8463, 1166, 'Nhan vien', 'QL023', 7, 'UserNV134')
#  into GOD.NHANVIEN values('NV135', 'Tran Tung Tuan', 'Nu', TO_DATE('2016-2-5','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000135', 7453, 1677, 'Nhan vien', 'QL024', 8, 'UserNV135')
#  into GOD.NHANVIEN values('NV136', 'An Van Quoc', 'Nu', TO_DATE('2019-3-15','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000136', 6211, 1579, 'Nhan vien', 'QL025', 1, 'UserNV136')
#  into GOD.NHANVIEN values('NV137', 'Bui Gia May', 'Nu', TO_DATE('2020-7-19','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000137', 6698, 1686, 'Nhan vien', 'QL026', 2, 'UserNV137')
#  into GOD.NHANVIEN values('NV138', 'Bui Van Vy', 'Nu', TO_DATE('2021-4-19','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000138', 2652, 1328, 'Nhan vien', 'QL027', 3, 'UserNV138')
#  into GOD.NHANVIEN values('NV139', 'Ly Van Đan', 'Nu', TO_DATE('2010-10-27','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000139', 8000, 1635, 'Nhan vien', 'QL028', 4, 'UserNV139')
#  into GOD.NHANVIEN values('NV140', 'Au Song Phu', 'Nam', TO_DATE('2005-3-1','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000140', 5703, 1564, 'Nhan vien', 'QL029', 5, 'UserNV140')
#  into GOD.NHANVIEN values('NV141', 'Lai Hoang Thong', 'Nam', TO_DATE('2020-8-25','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000141', 3649, 1706, 'Nhan vien', 'QL030', 6, 'UserNV141')
#  into GOD.NHANVIEN values('NV142', 'Đoan Tung Giang', 'Nam', TO_DATE('2016-6-8','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000142', 2099, 1622, 'Nhan vien', 'QL031', 7, 'UserNV142')
#  into GOD.NHANVIEN values('NV143', 'Le Tung Chi', 'Nam', TO_DATE('2021-6-15','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000143', 2594, 1064, 'Nhan vien', 'QL032', 8, 'UserNV143')
#  into GOD.NHANVIEN values('NV144', 'Pham Chi Giang', 'Nu', TO_DATE('2001-1-16','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000144', 7938, 1115, 'Nhan vien', 'QL033', 1, 'UserNV144')
#  into GOD.NHANVIEN values('NV145', 'Tran Song Vy', 'Nam', TO_DATE('2021-7-14','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000145', 1537, 1127, 'Nhan vien', 'QL034', 2, 'UserNV145')
#  into GOD.NHANVIEN values('NV146', 'Le Tung Minh', 'Nam', TO_DATE('2001-2-6','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000146', 8345, 1565, 'Nhan vien', 'QL035', 3, 'UserNV146')
#  into GOD.NHANVIEN values('NV147', 'Đang Gia Vu', 'Nam', TO_DATE('2001-8-8','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000147', 5502, 1614, 'Nhan vien', 'QL016', 4, 'UserNV147')
#  into GOD.NHANVIEN values('NV148', 'Ung Chi Giang', 'Nu', TO_DATE('2022-1-27','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000148', 4951, 1643, 'Nhan vien', 'QL017', 5, 'UserNV148')
#  into GOD.NHANVIEN values('NV149', 'Ly Tung Ngoc Nhi', 'Nu', TO_DATE('2017-4-2','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000149', 6782, 1791, 'Nhan vien', 'QL018', 6, 'UserNV149')
#  into GOD.NHANVIEN values('NV150', 'Duong Gia Vu', 'Nu', TO_DATE('2006-2-1','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000150', 1012, 1914, 'Nhan vien', 'QL019', 7, 'UserNV150')
#  into GOD.NHANVIEN values('NV151', 'Vu Van khanh', 'Nu', TO_DATE('2012-6-1','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000151', 3938, 1949, 'Nhan vien', 'QL020', 8, 'UserNV151')
#  into GOD.NHANVIEN values('NV152', 'Duong Gia Tu', 'Nam', TO_DATE('2021-6-20','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000152', 3059, 1192, 'Nhan vien', 'QL021', 1, 'UserNV152')
#  into GOD.NHANVIEN values('NV153', 'Tran Song Minh', 'Nam', TO_DATE('2001-3-20','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000153', 6198, 1671, 'Nhan vien', 'QL022', 2, 'UserNV153')
#  into GOD.NHANVIEN values('NV154', 'Ung Gia Bao', 'Nu', TO_DATE('2007-9-2','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000154', 3009, 1093, 'Nhan vien', 'QL023', 3, 'UserNV154')
#  into GOD.NHANVIEN values('NV155', 'Pham Gia Viet', 'Nam', TO_DATE('2021-4-21','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000155', 7689, 1766, 'Nhan vien', 'QL024', 4, 'UserNV155')
#  into GOD.NHANVIEN values('NV156', 'Vo Thi May', 'Nam', TO_DATE('2020-7-10','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000156', 9224, 1540, 'Nhan vien', 'QL025', 5, 'UserNV156')
#  into GOD.NHANVIEN values('NV157', 'Đoan Van Vy', 'Nam', TO_DATE('2013-9-21','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000157', 3669, 1314, 'Nhan vien', 'QL026', 6, 'UserNV157')
#  into GOD.NHANVIEN values('NV158', 'Pham Hoang Cau', 'Nam', TO_DATE('2017-8-2','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000158', 1006, 1071, 'Nhan vien', 'QL027', 7, 'UserNV158')
#  into GOD.NHANVIEN values('NV159', 'Nguyen Hoang Thong', 'Nam', TO_DATE('2022-2-27','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000159', 2015, 1176, 'Nhan vien', 'QL028', 8, 'UserNV159')
#  into GOD.NHANVIEN values('NV160', 'Au Chi Minh', 'Nu', TO_DATE('2018-2-17','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000160', 4946, 1031, 'Nhan vien', 'QL029', 1, 'UserNV160')
#  into GOD.NHANVIEN values('NV161', 'Bui Thi khanh', 'Nu', TO_DATE('2015-12-28','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000161', 5814, 1870, 'Nhan vien', 'QL030', 2, 'UserNV161')
#  into GOD.NHANVIEN values('NV162', 'Ly Chi Sang', 'Nam', TO_DATE('2014-4-20','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000162', 2973, 1819, 'Nhan vien', 'QL031', 3, 'UserNV162')
#  into GOD.NHANVIEN values('NV163', 'Truong Tung Nam', 'Nu', TO_DATE('2010-9-8','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000163', 9361, 1633, 'Nhan vien', 'QL032', 4, 'UserNV163')
#  into GOD.NHANVIEN values('NV164', 'Vo Thi Đang', 'Nam', TO_DATE('2007-3-24','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000164', 7451, 1478, 'Nhan vien', 'QL033', 5, 'UserNV164')
#  into GOD.NHANVIEN values('NV165', 'Đoan Van Bac', 'Nu', TO_DATE('2019-2-10','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000165', 5106, 1736, 'Nhan vien', 'QL034', 6, 'UserNV165')
#  into GOD.NHANVIEN values('NV166', 'Gian Thi Tan', 'Nam', TO_DATE('2016-1-3','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000166', 3051, 1223, 'Nhan vien', 'QL035', 7, 'UserNV166')
#  into GOD.NHANVIEN values('NV167', 'Duong Hoang Phu', 'Nam', TO_DATE('2012-4-7','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000167', 8023, 1909, 'Nhan vien', 'QL016', 8, 'UserNV167')
#  into GOD.NHANVIEN values('NV168', 'Bui Gia Ngoc Nhi', 'Nam', TO_DATE('2006-6-11','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000168', 2891, 1252, 'Nhan vien', 'QL017', 1, 'UserNV168')
#  into GOD.NHANVIEN values('NV169', 'Ung Hoang Vu', 'Nu', TO_DATE('2003-8-9','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000169', 9789, 1699, 'Nhan vien', 'QL018', 2, 'UserNV169')
#  into GOD.NHANVIEN values('NV170', 'Ly Hoang May', 'Nu', TO_DATE('2011-4-8','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000170', 2833, 1603, 'Nhan vien', 'QL019', 3, 'UserNV170')
#  into GOD.NHANVIEN values('NV171', 'Duong Chi Tien', 'Nu', TO_DATE('2002-12-12','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000171', 3279, 1966, 'Nhan vien', 'QL020', 4, 'UserNV171')
#  into GOD.NHANVIEN values('NV172', 'Vo Gia Ngan', 'Nam', TO_DATE('2007-6-23','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000172', 8680, 1302, 'Nhan vien', 'QL021', 5, 'UserNV172')
#  into GOD.NHANVIEN values('NV173', 'Bui Hoang Đang', 'Nu', TO_DATE('2021-2-18','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000173', 2445, 1300, 'Nhan vien', 'QL022', 6, 'UserNV173')
#  into GOD.NHANVIEN values('NV174', 'Lai Gia Đuc', 'Nu', TO_DATE('2014-10-20','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000174', 2591, 1824, 'Nhan vien', 'QL023', 7, 'UserNV174')
#  into GOD.NHANVIEN values('NV175', 'Duong Hoang Tu', 'Nam', TO_DATE('2021-11-11','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000175', 1647, 1063, 'Nhan vien', 'QL024', 8, 'UserNV175')
#  into GOD.NHANVIEN values('NV176', 'Pham Gia khanh', 'Nam', TO_DATE('2006-11-2','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000176', 8658, 1452, 'Nhan vien', 'QL025', 1, 'UserNV176')
#  into GOD.NHANVIEN values('NV177', 'Gian Song Han', 'Nu', TO_DATE('2005-7-19','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000177', 7820, 1043, 'Nhan vien', 'QL026', 2, 'UserNV177')
#  into GOD.NHANVIEN values('NV178', 'Bui Gia Tiep', 'Nam', TO_DATE('2009-8-5','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000178', 2881, 1162, 'Nhan vien', 'QL027', 3, 'UserNV178')
#  into GOD.NHANVIEN values('NV179', 'Pham Van Vy', 'Nu', TO_DATE('2000-8-3','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000179', 8512, 1461, 'Nhan vien', 'QL028', 4, 'UserNV179')
#  into GOD.NHANVIEN values('NV180', 'Le Van Đang', 'Nam', TO_DATE('2000-3-8','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000180', 1742, 1823, 'Nhan vien', 'QL029', 5, 'UserNV180')
#  into GOD.NHANVIEN values('NV181', 'Vu Tung Quoc', 'Nam', TO_DATE('2001-9-5','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000181', 9146, 1325, 'Nhan vien', 'QL030', 6, 'UserNV181')
#  into GOD.NHANVIEN values('NV182', 'Nguyen Song Chung', 'Nam', TO_DATE('2022-2-17','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000182', 8362, 1050, 'Nhan vien', 'QL031', 7, 'UserNV182')
#  into GOD.NHANVIEN values('NV183', 'Bui Thi Cuc', 'Nu', TO_DATE('2018-8-20','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000183', 6162, 1883, 'Nhan vien', 'QL032', 8, 'UserNV183')
#  into GOD.NHANVIEN values('NV184', 'Truong Chi An', 'Nu', TO_DATE('2018-7-4','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000184', 2725, 1469, 'Nhan vien', 'QL033', 1, 'UserNV184')
#  into GOD.NHANVIEN values('NV185', 'Vu Chi Thien', 'Nam', TO_DATE('2002-8-25','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000185', 8797, 1463, 'Nhan vien', 'QL034', 2, 'UserNV185')
#  into GOD.NHANVIEN values('NV186', 'Ung Thi Bac', 'Nam', TO_DATE('2020-7-25','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000186', 8379, 1640, 'Nhan vien', 'QL035', 3, 'UserNV186')
#  into GOD.NHANVIEN values('NV187', 'Ho Tung Minh', 'Nam', TO_DATE('2010-1-26','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000187', 1975, 1254, 'Nhan vien', 'QL016', 4, 'UserNV187')
#  into GOD.NHANVIEN values('NV188', 'Ly Gia Tin', 'Nu', TO_DATE('2014-7-9','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000188', 2262, 1395, 'Nhan vien', 'QL017', 5, 'UserNV188')
#  into GOD.NHANVIEN values('NV189', 'Đoan Tung Ngoc Nhi', 'Nu', TO_DATE('2013-2-7','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000189', 3324, 1889, 'Nhan vien', 'QL018', 6, 'UserNV189')
#  into GOD.NHANVIEN values('NV190', 'Lai Hoang Vu', 'Nam', TO_DATE('2017-5-2','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000190', 5119, 1119, 'Nhan vien', 'QL019', 7, 'UserNV190')
#  into GOD.NHANVIEN values('NV191', 'Tran Tung Vu', 'Nu', TO_DATE('2013-9-4','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000191', 1476, 1568, 'Nhan vien', 'QL020', 8, 'UserNV191')
#  into GOD.NHANVIEN values('NV192', 'Lai Thi Tin', 'Nam', TO_DATE('2008-5-17','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000192', 1006, 1340, 'Nhan vien', 'QL021', 1, 'UserNV192')
#  into GOD.NHANVIEN values('NV193', 'Au Hoang Vu', 'Nam', TO_DATE('2022-6-5','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000193', 9352, 1915, 'Nhan vien', 'QL022', 2, 'UserNV193')
#  into GOD.NHANVIEN values('NV194', 'Lai Thi Vinh', 'Nu', TO_DATE('2010-3-25','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000194', 8508, 1413, 'Nhan vien', 'QL023', 3, 'UserNV194')
#  into GOD.NHANVIEN values('NV195', 'An Gia Tin', 'Nam', TO_DATE('2019-1-21','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000195', 8316, 1759, 'Nhan vien', 'QL024', 4, 'UserNV195')
#  into GOD.NHANVIEN values('NV196', 'An Van Thuong', 'Nam', TO_DATE('2002-6-11','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000196', 6710, 1410, 'Nhan vien', 'QL025', 5, 'UserNV196')
#  into GOD.NHANVIEN values('NV197', 'Nguyen Gia Duy', 'Nam', TO_DATE('2016-4-1','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000197', 3895, 1877, 'Nhan vien', 'QL026', 6, 'UserNV197')
#  into GOD.NHANVIEN values('NV198', 'Đang Thi Han', 'Nu', TO_DATE('2004-4-8','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000198', 3545, 1657, 'Nhan vien', 'QL027', 7, 'UserNV198')
#  into GOD.NHANVIEN values('NV199', 'Tran Tung Tien', 'Nu', TO_DATE('2003-9-7','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000199', 6872, 1641, 'Nhan vien', 'QL028', 8, 'UserNV199')
#  into GOD.NHANVIEN values('NV200', 'Le Chi Vu', 'Nam', TO_DATE('2002-7-11','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000200', 1768, 1225, 'Nhan vien', 'QL029', 1, 'UserNV200')
#  into GOD.NHANVIEN values('NV201', 'Đoan Van Han', 'Nam', TO_DATE('2011-4-5','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000201', 1538, 1300, 'Nhan vien', 'QL030', 2, 'UserNV201')
#  into GOD.NHANVIEN values('NV202', 'Lai Tung Vinh', 'Nam', TO_DATE('2019-10-14','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000202', 4088, 1406, 'Nhan vien', 'QL031', 3, 'UserNV202')
#  into GOD.NHANVIEN values('NV203', 'Vu Hoang Bac', 'Nu', TO_DATE('2013-5-20','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000203', 8917, 1743, 'Nhan vien', 'QL032', 4, 'UserNV203')
#  into GOD.NHANVIEN values('NV204', 'Ly Van Chi', 'Nu', TO_DATE('2022-8-10','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000204', 8572, 1452, 'Nhan vien', 'QL033', 5, 'UserNV204')
#  into GOD.NHANVIEN values('NV205', 'Gian Tung Bac', 'Nam', TO_DATE('2021-6-9','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000205', 6262, 1480, 'Nhan vien', 'QL034', 6, 'UserNV205')
#  into GOD.NHANVIEN values('NV206', 'Nguyen Gia Tien', 'Nam', TO_DATE('2020-6-18','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000206', 5876, 1137, 'Nhan vien', 'QL035', 7, 'UserNV206')
#  into GOD.NHANVIEN values('NV207', 'Ly Van Ngoc Nhi', 'Nu', TO_DATE('2007-7-2','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000207', 1359, 1041, 'Nhan vien', 'QL016', 8, 'UserNV207')
#  into GOD.NHANVIEN values('NV208', 'Đang Hoang khanh', 'Nam', TO_DATE('2001-8-12','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000208', 3591, 1109, 'Nhan vien', 'QL017', 1, 'UserNV208')
#  into GOD.NHANVIEN values('NV209', 'Ho Van Tan', 'Nam', TO_DATE('2014-4-16','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000209', 3058, 1363, 'Nhan vien', 'QL018', 2, 'UserNV209')
#  into GOD.NHANVIEN values('NV210', 'Duong Chi Sang', 'Nam', TO_DATE('2014-8-12','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000210', 8793, 1535, 'Nhan vien', 'QL019', 3, 'UserNV210')
#  into GOD.NHANVIEN values('NV211', 'Ho Chi Ngoc Nhi', 'Nam', TO_DATE('2006-7-26','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000211', 8946, 1024, 'Nhan vien', 'QL020', 4, 'UserNV211')
#  into GOD.NHANVIEN values('NV212', 'An Chi Bac', 'Nu', TO_DATE('2014-10-4','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000212', 6105, 1161, 'Nhan vien', 'QL021', 5, 'UserNV212')
#  into GOD.NHANVIEN values('NV213', 'Nguyen Tung Đan', 'Nu', TO_DATE('2012-12-12','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000213', 7051, 1296, 'Nhan vien', 'QL022', 6, 'UserNV213')
#  into GOD.NHANVIEN values('NV214', 'Nguyen Hoang Tan', 'Nu', TO_DATE('2020-10-23','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000214', 6159, 1807, 'Nhan vien', 'QL023', 7, 'UserNV214')
#  into GOD.NHANVIEN values('NV215', 'Nguyen Hoang Cau', 'Nam', TO_DATE('2008-2-16','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000215', 4179, 1143, 'Nhan vien', 'QL024', 8, 'UserNV215')
#  into GOD.NHANVIEN values('NV216', 'An Hoang Ngoc Nhi', 'Nu', TO_DATE('2021-4-15','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000216', 6304, 1082, 'Nhan vien', 'QL025', 1, 'UserNV216')
#  into GOD.NHANVIEN values('NV217', 'Nguyen Gia Đuc', 'Nam', TO_DATE('2009-12-9','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000217', 8466, 1789, 'Nhan vien', 'QL026', 2, 'UserNV217')
#  into GOD.NHANVIEN values('NV218', 'Au Gia Tuan', 'Nu', TO_DATE('2011-7-18','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000218', 5436, 1775, 'Nhan vien', 'QL027', 3, 'UserNV218')
#  into GOD.NHANVIEN values('NV219', 'Truong Van Han', 'Nu', TO_DATE('2020-12-8','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000219', 8698, 1493, 'Nhan vien', 'QL028', 4, 'UserNV219')
#  into GOD.NHANVIEN values('NV220', 'An Van Han', 'Nu', TO_DATE('2019-2-4','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000220', 4202, 1399, 'Nhan vien', 'QL029', 5, 'UserNV220')
#  into GOD.NHANVIEN values('NV221', 'Ho Song Thien', 'Nam', TO_DATE('2015-4-5','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000221', 1601, 1315, 'Nhan vien', 'QL030', 6, 'UserNV221')
#  into GOD.NHANVIEN values('NV222', 'Ho Chi Thien', 'Nam', TO_DATE('2003-5-1','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000222', 7266, 1527, 'Nhan vien', 'QL031', 7, 'UserNV222')
#  into GOD.NHANVIEN values('NV223', 'Vu Thi khanh', 'Nu', TO_DATE('2009-4-16','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000223', 3176, 1453, 'Nhan vien', 'QL032', 8, 'UserNV223')
#  into GOD.NHANVIEN values('NV224', 'Au Tung Tiep', 'Nu', TO_DATE('2013-12-5','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000224', 2342, 1803, 'Nhan vien', 'QL033', 1, 'UserNV224')
#  into GOD.NHANVIEN values('NV225', 'Truong Gia Cau', 'Nu', TO_DATE('2011-10-16','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000225', 5772, 1671, 'Nhan vien', 'QL034', 2, 'UserNV225')
#  into GOD.NHANVIEN values('NV226', 'Lai Thi May', 'Nu', TO_DATE('2002-2-22','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000226', 3096, 1685, 'Nhan vien', 'QL035', 3, 'UserNV226')
# ...
#  into GOD.NHANVIEN values('NV273', 'Au Song Đang', 'Nam', TO_DATE('2021-7-13','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000273', 4123, 1831, 'Nhan vien', 'QL022', 2, 'UserNV273')
#  into GOD.NHANVIEN values('NV274', 'Le Thi Phu', 'Nu', TO_DATE('2004-1-13','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000274', 3665, 1639, 'Nhan vien', 'QL023', 3, 'UserNV274')
#  into GOD.NHANVIEN values('NV275', 'Vu Van Thuong', 'Nu', TO_DATE('2018-6-10','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000275', 2383, 1578, 'Nhan vien', 'QL024', 4, 'UserNV275')
#  into GOD.NHANVIEN values('NV276', 'Đang Van Bac', 'Nam', TO_DATE('2004-9-16','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000276', 9189, 1807, 'Nhan vien', 'QL025', 5, 'UserNV276')
#  into GOD.NHANVIEN values('NV277', 'Truong Van Tan', 'Nam', TO_DATE('2011-1-11','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000277', 1733, 1716, 'Nhan vien', 'QL026', 6, 'UserNV277')
#  into GOD.NHANVIEN values('NV278', 'Tran Tung Tan', 'Nam', TO_DATE('2019-2-10','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000278', 1867, 1375, 'Nhan vien', 'QL027', 7, 'UserNV278')
#  into GOD.NHANVIEN values('NV279', 'Pham Van Vinh', 'Nam', TO_DATE('2015-8-27','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000279', 5809, 1090, 'Nhan vien', 'QL028', 8, 'UserNV279')
#  into GOD.NHANVIEN values('NV280', 'Bui Thi Vinh', 'Nam', TO_DATE('2006-7-2','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000280', 5948, 1684, 'Nhan vien', 'QL029', 1, 'UserNV280')
#  into GOD.NHANVIEN values('NV281', 'Vu Chi Sang', 'Nu', TO_DATE('2010-7-13','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000281', 2930, 1060, 'Nhan vien', 'QL030', 2, 'UserNV281')
#  into GOD.NHANVIEN values('NV282', 'Vo Chi Minh', 'Nu', TO_DATE('2011-8-1','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000282', 6049, 1410, 'Nhan vien', 'QL031', 3, 'UserNV282')
#  into GOD.NHANVIEN values('NV283', 'Bui Van Han', 'Nam', TO_DATE('2003-9-9','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000283', 7809, 1962, 'Nhan vien', 'QL032', 4, 'UserNV283')
#  into GOD.NHANVIEN values('NV284', 'Truong Gia Duy', 'Nam', TO_DATE('2011-7-19','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000284', 7794, 1113, 'Nhan vien', 'QL033', 5, 'UserNV284')
#  into GOD.NHANVIEN values('NV285', 'Truong Song Duy', 'Nu', TO_DATE('2018-2-3','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000285', 9971, 1258, 'Nhan vien', 'QL034', 6, 'UserNV285')
#  into GOD.NHANVIEN values('NV286', 'Pham Song Vu', 'Nam', TO_DATE('2006-11-13','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000286', 5223, 1250, 'Nhan vien', 'QL035', 7, 'UserNV286')
#  into GOD.NHANVIEN values('NV287', 'Tran Hoang An', 'Nu', TO_DATE('2000-11-13','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000287', 7559, 1529, 'Nhan vien', 'QL016', 8, 'UserNV287')
#  into GOD.NHANVIEN values('NV288', 'Ly Thi May', 'Nam', TO_DATE('2006-2-17','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000288', 7952, 1763, 'Nhan vien', 'QL017', 1, 'UserNV288')
#  into GOD.NHANVIEN values('NV289', 'Vu Song Tien', 'Nu', TO_DATE('2002-7-27','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000289', 3402, 1000, 'Nhan vien', 'QL018', 2, 'UserNV289')
#  into GOD.NHANVIEN values('NV290', 'Le Song Bac', 'Nam', TO_DATE('2000-3-12','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000290', 7172, 1980, 'Nhan vien', 'QL019', 3, 'UserNV290')
#  into GOD.NHANVIEN values('NV291', 'Pham Tung Cuc', 'Nam', TO_DATE('2009-1-10','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000291', 3458, 1098, 'Nhan vien', 'QL020', 4, 'UserNV291')
#  into GOD.NHANVIEN values('NV292', 'Tran Hoang Ngoc Nhi', 'Nam', TO_DATE('2001-7-19','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000292', 2176, 1987, 'Nhan vien', 'QL021', 5, 'UserNV292')
#  into GOD.NHANVIEN values('NV293', 'Vo Chi Tu', 'Nu', TO_DATE('2011-8-9','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000293', 6361, 1111, 'Nhan vien', 'QL022', 6, 'UserNV293')
#  into GOD.NHANVIEN values('NV294', 'Gian Van Bac', 'Nam', TO_DATE('2012-9-10','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000294', 4962, 1151, 'Nhan vien', 'QL023', 7, 'UserNV294')
#  into GOD.NHANVIEN values('NV295', 'Đoan Tung Bac', 'Nu', TO_DATE('2006-5-28','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000295', 6575, 1771, 'Nhan vien', 'QL024', 8, 'UserNV295')
#  into GOD.NHANVIEN values('NV296', 'Đoan Van Đang', 'Nam', TO_DATE('2012-6-12','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000296', 4907, 1031, 'Nhan vien', 'QL025', 1, 'UserNV296')
#  into GOD.NHANVIEN values('NV297', 'Đang Van Thien', 'Nam', TO_DATE('2008-10-14','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000297', 6816, 1415, 'Nhan vien', 'QL026', 2, 'UserNV297')
#  into GOD.NHANVIEN values('NV298', 'Nguyen Song Thien', 'Nam', TO_DATE('2013-5-19','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000298', 2662, 1490, 'Nhan vien', 'QL027', 3, 'UserNV298')
#  into GOD.NHANVIEN values('NV299', 'Đang Tung Vu', 'Nam', TO_DATE('2015-7-25','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000299', 9685, 1329, 'Nhan vien', 'QL028', 4, 'UserNV299')
#  into GOD.NHANVIEN values('NV300', 'Ly Gia Đang', 'Nam', TO_DATE('2016-12-25','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000300', 3347, 1293, 'Nhan vien', 'QL029', 5, 'UserNV300')
#  into GOD.NHANVIEN values('NV301', 'Truong Hoang Tuan', 'Nam', TO_DATE('2020-3-24','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000301', 6953, 1958, 'Nhan vien', 'QL030', 6, 'UserNV301')
#  into GOD.NHANVIEN values('NV302', 'Lai Song Bac', 'Nam', TO_DATE('2003-4-21','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000302', 7113, 1095, 'Nhan vien', 'QL031', 7, 'UserNV302')
#  into GOD.NHANVIEN values('NV303', 'Duong Song Bao', 'Nam', TO_DATE('2010-2-12','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000303', 4012, 1353, 'Nhan vien', 'QL032', 8, 'UserNV303')
#  into GOD.NHANVIEN values('NV304', 'Ung Song Vu', 'Nu', TO_DATE('2022-11-24','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000304', 2002, 1627, 'Nhan vien', 'QL033', 1, 'UserNV304')
#  into GOD.NHANVIEN values('NV305', 'Le Hoang Đuc', 'Nam', TO_DATE('2004-7-24','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000305', 9532, 1059, 'Nhan vien', 'QL034', 2, 'UserNV305')
#  into GOD.NHANVIEN values('NV306', 'Đang Chi khanh', 'Nu', TO_DATE('2002-1-19','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000306', 9136, 1273, 'Nhan vien', 'QL035', 3, 'UserNV306')
#  into GOD.NHANVIEN values('NV307', 'Pham Van Duy', 'Nam', TO_DATE('2021-2-17','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000307', 8480, 1741, 'Nhan vien', 'QL016', 4, 'UserNV307')
#  into GOD.NHANVIEN values('NV308', 'Tran Song Tan', 'Nu', TO_DATE('2013-6-22','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000308', 8932, 1637, 'Nhan vien', 'QL017', 5, 'UserNV308')
#  into GOD.NHANVIEN values('NV309', 'Pham Tung Tien', 'Nu', TO_DATE('2003-11-26','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000309', 5603, 1031, 'Nhan vien', 'QL018', 6, 'UserNV309')
#  into GOD.NHANVIEN values('NV310', 'Ho Thi Sang', 'Nam', TO_DATE('2013-3-22','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000310', 4679, 1701, 'Nhan vien', 'QL019', 7, 'UserNV310')
#  into GOD.NHANVIEN values('NV311', 'Vo Hoang An', 'Nu', TO_DATE('2016-12-21','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000311', 5350, 1815, 'Nhan vien', 'QL020', 8, 'UserNV311')
#  into GOD.NHANVIEN values('NV312', 'Au Gia Thong', 'Nam', TO_DATE('2003-9-22','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000312', 1099, 1458, 'Nhan vien', 'QL021', 1, 'UserNV312')
#  into GOD.NHANVIEN values('NV313', 'Truong Song Thong', 'Nu', TO_DATE('2013-11-24','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000313', 7267, 1305, 'Nhan vien', 'QL022', 2, 'UserNV313')
#  into GOD.NHANVIEN values('NV314', 'Lai Tung Duy', 'Nu', TO_DATE('2008-7-19','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000314', 1628, 1682, 'Nhan vien', 'QL023', 3, 'UserNV314')
#  into GOD.NHANVIEN values('NV315', 'An Thi Han', 'Nam', TO_DATE('2014-12-12','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000315', 8101, 1520, 'Nhan vien', 'QL024', 4, 'UserNV315')
#  into GOD.NHANVIEN values('NV316', 'Duong Hoang Nguyet', 'Nam', TO_DATE('2009-5-12','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000316', 8747, 1147, 'Nhan vien', 'QL025', 5, 'UserNV316')
#  into GOD.NHANVIEN values('NV317', 'Vu Tung Phu', 'Nu', TO_DATE('2007-9-24','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000317', 2672, 1326, 'Nhan vien', 'QL026', 6, 'UserNV317')
#  into GOD.NHANVIEN values('NV318', 'Ly Van Vu', 'Nam', TO_DATE('2011-6-18','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000318', 1174, 1982, 'Nhan vien', 'QL027', 7, 'UserNV318')
#  into GOD.NHANVIEN values('NV319', 'Au Tung Bac', 'Nu', TO_DATE('2010-3-12','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000319', 9676, 1350, 'Nhan vien', 'QL028', 8, 'UserNV319')
#  into GOD.NHANVIEN values('NV320', 'Nguyen Van Bao', 'Nam', TO_DATE('2011-2-26','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000320', 9078, 1478, 'Nhan vien', 'QL029', 1, 'UserNV320')
#  into GOD.NHANVIEN values('NV321', 'Nguyen Song Chung', 'Nam', TO_DATE('2014-5-2','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000321', 5457, 1592, 'Nhan vien', 'QL030', 2, 'UserNV321')
#  into GOD.NHANVIEN values('NV322', 'Le Hoang Anh', 'Nu', TO_DATE('2006-4-19','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000322', 3946, 1487, 'Nhan vien', 'QL031', 3, 'UserNV322')
#  into GOD.NHANVIEN values('NV323', 'Nguyen Chi khanh', 'Nam', TO_DATE('2018-7-20','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000323', 7976, 1091, 'Nhan vien', 'QL032', 4, 'UserNV323')
#  into GOD.NHANVIEN values('NV324', 'Duong Hoang Tiep', 'Nu', TO_DATE('2002-2-10','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000324', 4730, 1700, 'Nhan vien', 'QL033', 5, 'UserNV324')
#  into GOD.NHANVIEN values('NV325', 'Ly Tung Vy', 'Nu', TO_DATE('2007-1-8','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000325', 7064, 1608, 'Nhan vien', 'QL034', 6, 'UserNV325')
#  into GOD.NHANVIEN values('NV326', 'Nguyen Chi Cuc', 'Nam', TO_DATE('2018-10-20','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000326', 3155, 1305, 'Nhan vien', 'QL035', 7, 'UserNV326')
#  into GOD.NHANVIEN values('NV327', 'Vo Chi Ngan', 'Nu', TO_DATE('2021-12-18','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000327', 6251, 1139, 'Nhan vien', 'QL016', 8, 'UserNV327')
#  into GOD.NHANVIEN values('NV328', 'Ho Hoang Nguyet', 'Nam', TO_DATE('2001-9-6','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000328', 9122, 1508, 'Nhan vien', 'QL017', 1, 'UserNV328')
#  into GOD.NHANVIEN values('NV329', 'Duong Thi Nam', 'Nam', TO_DATE('2006-10-15','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000329', 3292, 1126, 'Nhan vien', 'QL018', 2, 'UserNV329')
#  into GOD.NHANVIEN values('NV330', 'Vo Tung Bao', 'Nu', TO_DATE('2010-6-26','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000330', 3761, 1747, 'Nhan vien', 'QL019', 3, 'UserNV330')
#  into GOD.NHANVIEN values('NV331', 'Lai Hoang Nguyet', 'Nu', TO_DATE('2018-1-5','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000331', 9371, 1574, 'Nhan vien', 'QL020', 4, 'UserNV331')
#  into GOD.NHANVIEN values('NV332', 'Lai Van Viet', 'Nu', TO_DATE('2013-11-11','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000332', 1595, 1184, 'Nhan vien', 'QL021', 5, 'UserNV332')
#  into GOD.NHANVIEN values('NV333', 'Ung Chi Han', 'Nam', TO_DATE('2007-6-10','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000333', 8576, 1943, 'Nhan vien', 'QL022', 6, 'UserNV333')
#  into GOD.NHANVIEN values('NV334', 'Vu Thi Anh', 'Nam', TO_DATE('2009-5-7','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000334', 8903, 1771, 'Nhan vien', 'QL023', 7, 'UserNV334')
#  into GOD.NHANVIEN values('NV335', 'Bui Chi Sang', 'Nam', TO_DATE('2007-9-9','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000335', 2296, 1368, 'Nhan vien', 'QL024', 8, 'UserNV335')
#  into GOD.NHANVIEN values('NV336', 'Đang Song Viet', 'Nu', TO_DATE('2008-8-13','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000336', 5169, 1395, 'Nhan vien', 'QL025', 1, 'UserNV336')
#  into GOD.NHANVIEN values('NV337', 'Au Song Ngan', 'Nu', TO_DATE('2017-8-28','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000337', 8919, 1363, 'Nhan vien', 'QL026', 2, 'UserNV337')
#  into GOD.NHANVIEN values('NV338', 'Nguyen Hoang Thien', 'Nam', TO_DATE('2007-12-19','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000338', 8211, 1275, 'Nhan vien', 'QL027', 3, 'UserNV338')
#  into GOD.NHANVIEN values('NV339', 'Tran Chi Tin', 'Nu', TO_DATE('2019-12-10','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000339', 4767, 1078, 'Nhan vien', 'QL028', 4, 'UserNV339')
#  into GOD.NHANVIEN values('NV340', 'Truong Chi Nguyet', 'Nu', TO_DATE('2011-7-28','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000340', 3843, 1034, 'Nhan vien', 'QL029', 5, 'UserNV340')
#  into GOD.NHANVIEN values('NV341', 'Vu Gia Tiep', 'Nu', TO_DATE('2017-12-22','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000341', 3878, 1995, 'Nhan vien', 'QL030', 6, 'UserNV341')
#  into GOD.NHANVIEN values('NV342', 'An Van Thong', 'Nam', TO_DATE('2017-10-14','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000342', 8388, 1782, 'Nhan vien', 'QL031', 7, 'UserNV342')
#  into GOD.NHANVIEN values('NV343', 'Gian Tung May', 'Nu', TO_DATE('2001-1-14','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000343', 6214, 1983, 'Nhan vien', 'QL032', 8, 'UserNV343')
#  into GOD.NHANVIEN values('NV344', 'Tran Van Anh', 'Nam', TO_DATE('2018-4-6','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000344', 2828, 1957, 'Nhan vien', 'QL033', 1, 'UserNV344')
#  into GOD.NHANVIEN values('NV345', 'Đang Tung Đan', 'Nam', TO_DATE('2000-6-5','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000345', 4503, 1984, 'Nhan vien', 'QL034', 2, 'UserNV345')
#  into GOD.NHANVIEN values('NV346', 'Lai Chi Thuong', 'Nu', TO_DATE('2010-7-21','YYYY-MM-DD'), '227 Nguyễn Văn Cừ, Phường 4, Quận 5, TP. Hồ Chí Minh', '0945000346', 4621, 1428, 'Nhan vien', 'QL035', 3, 'UserNV346')

# %%
KV = ['Quan 1', 'Quan 2', 'Quan 3','Quan 4','Quan 5','Quan 6','Quan 7','Quan 8','Quan 9','Quan 10','Quan 11','Quan 12','Quan 13', 'Quan Bình Thạnh', 'Quan Tân Bình', 'Hóoc Môn']

# %% [markdown]
# ## Phong Ban

# %%
'''
PhongBan (
	MaPB 	number primary key,
	TenPB 	varchar2(60) not null,
	TrPHG 	varchar(10)
	
)	
'''


for i in range(1, 9):
    final = str(i) + ', ' + '\'Phong ' + str(i) + '\', NULL' 
    print('into GOD.PHONGBAN values(' +  final + ')')
# Out:
# into GOD.PHONGBAN values(1, 'Phong 1', NULL)
# into GOD.PHONGBAN values(2, 'Phong 2', NULL)
# into GOD.PHONGBAN values(3, 'Phong 3', NULL)
# into GOD.PHONGBAN values(4, 'Phong 4', NULL)
# into GOD.PHONGBAN values(5, 'Phong 5', NULL)
# into GOD.PHONGBAN values(6, 'Phong 6', NULL)
# into GOD.PHONGBAN values(7, 'Phong 7', NULL)
# into GOD.PHONGBAN values(8, 'Phong 8', NULL)

# %%
for i in range(1, 9):
    print( ' UPDATE GOD.PHONGBAN set TrPHG = ' + '\'TP0'+ str(i+ 38) + '\'' + ' WHERE ' +  'MaPB = ' + str(i)+ ';')
# Out:
#  UPDATE GOD.PHONGBAN set TrPHG = 'TP039' WHERE MaPB = 1;
#  UPDATE GOD.PHONGBAN set TrPHG = 'TP040' WHERE MaPB = 2;
#  UPDATE GOD.PHONGBAN set TrPHG = 'TP041' WHERE MaPB = 3;
#  UPDATE GOD.PHONGBAN set TrPHG = 'TP042' WHERE MaPB = 4;
#  UPDATE GOD.PHONGBAN set TrPHG = 'TP043' WHERE MaPB = 5;
#  UPDATE GOD.PHONGBAN set TrPHG = 'TP044' WHERE MaPB = 6;
#  UPDATE GOD.PHONGBAN set TrPHG = 'TP045' WHERE MaPB = 7;
#  UPDATE GOD.PHONGBAN set TrPHG = 'TP046' WHERE MaPB = 8;

# %% [markdown]
# # DE AN

# %%
'''
DeAn (
	MaDA 		varchar(10) primary key,
	TenDA 	varchar2(60) not null,
	NgayBD 	date,
	Phong 	number,
    TruongDeAn varchar(10)
	
)
'''
l = []
for i in range(1, 9):
    for j in range(1, rd.randint(3, 5)):
        MaDA = '\'DA' + str(i) + '0' + str(j) + '\'';
        l.append(MaDA);

        TenDA = '\'De An so ' + str(j) + ' Phong ' + str(i) + '\'';
        NgayBD  = 'TO_DATE(' + '\'' + str(rd.randint(2020, 2022)) + '-' + str(rd.randint(1, 12)) + '-' + str(rd.randint(1, 28)) + '\',\'YYYY-MM-DD\')'
        Phong = str(i)
        TruongDA = 'TDA0' + str(rd.randint(36, 38))
        final = MaDA + ', ' + TenDA + ', ' + NgayBD + ', ' + Phong + ', ' + '\'' +  TruongDA + '\''
        print('into GOD.DEAN values(' +  final + ')')
# Out:
# into GOD.DEAN values('DA101', 'De An so 1 Phong 1', TO_DATE('2020-12-24','YYYY-MM-DD'), 1, 'TDA038')
# into GOD.DEAN values('DA102', 'De An so 2 Phong 1', TO_DATE('2022-11-25','YYYY-MM-DD'), 1, 'TDA038')
# into GOD.DEAN values('DA103', 'De An so 3 Phong 1', TO_DATE('2020-6-14','YYYY-MM-DD'), 1, 'TDA036')
# into GOD.DEAN values('DA104', 'De An so 4 Phong 1', TO_DATE('2022-5-24','YYYY-MM-DD'), 1, 'TDA038')
# into GOD.DEAN values('DA201', 'De An so 1 Phong 2', TO_DATE('2022-2-15','YYYY-MM-DD'), 2, 'TDA037')
# into GOD.DEAN values('DA202', 'De An so 2 Phong 2', TO_DATE('2020-7-12','YYYY-MM-DD'), 2, 'TDA036')
# into GOD.DEAN values('DA301', 'De An so 1 Phong 3', TO_DATE('2021-12-16','YYYY-MM-DD'), 3, 'TDA038')
# into GOD.DEAN values('DA302', 'De An so 2 Phong 3', TO_DATE('2022-4-27','YYYY-MM-DD'), 3, 'TDA036')
# into GOD.DEAN values('DA401', 'De An so 1 Phong 4', TO_DATE('2022-5-28','YYYY-MM-DD'), 4, 'TDA037')
# into GOD.DEAN values('DA402', 'De An so 2 Phong 4', TO_DATE('2020-2-15','YYYY-MM-DD'), 4, 'TDA038')
# into GOD.DEAN values('DA403', 'De An so 3 Phong 4', TO_DATE('2020-10-26','YYYY-MM-DD'), 4, 'TDA038')
# into GOD.DEAN values('DA404', 'De An so 4 Phong 4', TO_DATE('2020-9-23','YYYY-MM-DD'), 4, 'TDA038')
# into GOD.DEAN values('DA501', 'De An so 1 Phong 5', TO_DATE('2022-12-14','YYYY-MM-DD'), 5, 'TDA037')
# into GOD.DEAN values('DA502', 'De An so 2 Phong 5', TO_DATE('2021-7-11','YYYY-MM-DD'), 5, 'TDA037')
# into GOD.DEAN values('DA601', 'De An so 1 Phong 6', TO_DATE('2021-6-23','YYYY-MM-DD'), 6, 'TDA037')
# into GOD.DEAN values('DA602', 'De An so 2 Phong 6', TO_DATE('2021-12-7','YYYY-MM-DD'), 6, 'TDA038')
# into GOD.DEAN values('DA603', 'De An so 3 Phong 6', TO_DATE('2021-3-10','YYYY-MM-DD'), 6, 'TDA037')
# into GOD.DEAN values('DA604', 'De An so 4 Phong 6', TO_DATE('2022-6-22','YYYY-MM-DD'), 6, 'TDA036')
# into GOD.DEAN values('DA701', 'De An so 1 Phong 7', TO_DATE('2022-5-22','YYYY-MM-DD'), 7, 'TDA038')
# into GOD.DEAN values('DA702', 'De An so 2 Phong 7', TO_DATE('2022-3-12','YYYY-MM-DD'), 7, 'TDA036')
# into GOD.DEAN values('DA801', 'De An so 1 Phong 8', TO_DATE('2020-4-25','YYYY-MM-DD'), 8, 'TDA038')
# into GOD.DEAN values('DA802', 'De An so 2 Phong 8', TO_DATE('2020-8-23','YYYY-MM-DD'), 8, 'TDA036')
# into GOD.DEAN values('DA803', 'De An so 3 Phong 8', TO_DATE('2021-10-17','YYYY-MM-DD'), 8, 'TDA038')

# %% [markdown]
# ## Phan Cong

# %%
'''
	PhanCong (
	MaNV 		varchar(10) primary key,
	MaDA 		varchar(10) primary key,
	ThoiGian 	date
	
)

'''
import numpy as np
for i in range(47, 347, 3):
    MaNV = '\'NV'+ str(i) + '\''
    for j in range(1, rd.randint(2, 3)):
        MaDA = '\'DA' + str(i%8 + 1) + '0' + str(j) + '\'';
        TG  = 'TO_DATE(' + '\'' + str(rd.randint(2020, 2022)) + '-' + str(rd.randint(1, 12)) + '-' + str(rd.randint(1, 28)) + '\',\'YYYY-MM-DD\')'
        final = MaNV + ', ' + MaDA + ', ' + TG  
        print('into PHANCONG values(' +  final + ')')
# Out:
# into PHANCONG values('NV47', 'DA801', TO_DATE('2022-12-6','YYYY-MM-DD'))
# into PHANCONG values('NV50', 'DA301', TO_DATE('2020-7-8','YYYY-MM-DD'))
# into PHANCONG values('NV50', 'DA302', TO_DATE('2021-5-10','YYYY-MM-DD'))
# into PHANCONG values('NV53', 'DA601', TO_DATE('2022-7-2','YYYY-MM-DD'))
# into PHANCONG values('NV56', 'DA101', TO_DATE('2021-1-23','YYYY-MM-DD'))
# into PHANCONG values('NV59', 'DA401', TO_DATE('2022-9-8','YYYY-MM-DD'))
# into PHANCONG values('NV59', 'DA402', TO_DATE('2020-8-4','YYYY-MM-DD'))
# into PHANCONG values('NV62', 'DA701', TO_DATE('2020-2-21','YYYY-MM-DD'))
# into PHANCONG values('NV62', 'DA702', TO_DATE('2021-4-26','YYYY-MM-DD'))
# into PHANCONG values('NV65', 'DA201', TO_DATE('2021-4-5','YYYY-MM-DD'))
# into PHANCONG values('NV65', 'DA202', TO_DATE('2021-6-3','YYYY-MM-DD'))
# into PHANCONG values('NV68', 'DA501', TO_DATE('2021-12-22','YYYY-MM-DD'))
# into PHANCONG values('NV68', 'DA502', TO_DATE('2022-12-26','YYYY-MM-DD'))
# into PHANCONG values('NV71', 'DA801', TO_DATE('2022-2-14','YYYY-MM-DD'))
# into PHANCONG values('NV74', 'DA301', TO_DATE('2021-6-21','YYYY-MM-DD'))
# into PHANCONG values('NV74', 'DA302', TO_DATE('2021-3-6','YYYY-MM-DD'))
# into PHANCONG values('NV77', 'DA601', TO_DATE('2020-6-25','YYYY-MM-DD'))
# into PHANCONG values('NV77', 'DA602', TO_DATE('2021-12-19','YYYY-MM-DD'))
# into PHANCONG values('NV80', 'DA101', TO_DATE('2021-8-9','YYYY-MM-DD'))
# into PHANCONG values('NV83', 'DA401', TO_DATE('2021-9-22','YYYY-MM-DD'))
# into PHANCONG values('NV83', 'DA402', TO_DATE('2022-9-22','YYYY-MM-DD'))
# into PHANCONG values('NV86', 'DA701', TO_DATE('2022-10-16','YYYY-MM-DD'))
# into PHANCONG values('NV86', 'DA702', TO_DATE('2020-11-17','YYYY-MM-DD'))
# into PHANCONG values('NV89', 'DA201', TO_DATE('2022-7-9','YYYY-MM-DD'))
# into PHANCONG values('NV92', 'DA501', TO_DATE('2021-9-11','YYYY-MM-DD'))
# into PHANCONG values('NV95', 'DA801', TO_DATE('2020-3-16','YYYY-MM-DD'))
# into PHANCONG values('NV95', 'DA802', TO_DATE('2021-7-12','YYYY-MM-DD'))
# into PHANCONG values('NV98', 'DA301', TO_DATE('2022-3-7','YYYY-MM-DD'))
# into PHANCONG values('NV98', 'DA302', TO_DATE('2021-7-8','YYYY-MM-DD'))
# into PHANCONG values('NV101', 'DA601', TO_DATE('2021-9-1','YYYY-MM-DD'))
# into PHANCONG values('NV101', 'DA602', TO_DATE('2020-10-10','YYYY-MM-DD'))
# into PHANCONG values('NV104', 'DA101', TO_DATE('2020-1-26','YYYY-MM-DD'))
# into PHANCONG values('NV104', 'DA102', TO_DATE('2020-6-13','YYYY-MM-DD'))
# into PHANCONG values('NV107', 'DA401', TO_DATE('2020-2-14','YYYY-MM-DD'))
# into PHANCONG values('NV107', 'DA402', TO_DATE('2020-7-8','YYYY-MM-DD'))
# into PHANCONG values('NV110', 'DA701', TO_DATE('2022-10-17','YYYY-MM-DD'))
# into PHANCONG values('NV113', 'DA201', TO_DATE('2022-3-9','YYYY-MM-DD'))
# into PHANCONG values('NV113', 'DA202', TO_DATE('2022-1-20','YYYY-MM-DD'))
# into PHANCONG values('NV116', 'DA501', TO_DATE('2022-2-17','YYYY-MM-DD'))
# into PHANCONG values('NV119', 'DA801', TO_DATE('2022-4-14','YYYY-MM-DD'))
# into PHANCONG values('NV122', 'DA301', TO_DATE('2020-12-20','YYYY-MM-DD'))
# into PHANCONG values('NV125', 'DA601', TO_DATE('2020-4-3','YYYY-MM-DD'))
# into PHANCONG values('NV128', 'DA101', TO_DATE('2021-3-27','YYYY-MM-DD'))
# into PHANCONG values('NV128', 'DA102', TO_DATE('2022-2-14','YYYY-MM-DD'))
# into PHANCONG values('NV131', 'DA401', TO_DATE('2021-5-11','YYYY-MM-DD'))
# into PHANCONG values('NV131', 'DA402', TO_DATE('2020-6-18','YYYY-MM-DD'))
# into PHANCONG values('NV134', 'DA701', TO_DATE('2021-8-27','YYYY-MM-DD'))
# into PHANCONG values('NV134', 'DA702', TO_DATE('2022-11-26','YYYY-MM-DD'))
# into PHANCONG values('NV137', 'DA201', TO_DATE('2020-2-14','YYYY-MM-DD'))
# into PHANCONG values('NV137', 'DA202', TO_DATE('2021-12-1','YYYY-MM-DD'))
# into PHANCONG values('NV140', 'DA501', TO_DATE('2021-5-15','YYYY-MM-DD'))
# into PHANCONG values('NV143', 'DA801', TO_DATE('2021-8-28','YYYY-MM-DD'))
# into PHANCONG values('NV143', 'DA802', TO_DATE('2020-11-6','YYYY-MM-DD'))
# into PHANCONG values('NV146', 'DA301', TO_DATE('2020-7-26','YYYY-MM-DD'))
# into PHANCONG values('NV149', 'DA601', TO_DATE('2021-9-2','YYYY-MM-DD'))
# into PHANCONG values('NV152', 'DA101', TO_DATE('2022-1-15','YYYY-MM-DD'))
# into PHANCONG values('NV152', 'DA102', TO_DATE('2020-11-18','YYYY-MM-DD'))
# into PHANCONG values('NV155', 'DA401', TO_DATE('2021-6-3','YYYY-MM-DD'))
# into PHANCONG values('NV158', 'DA701', TO_DATE('2020-1-4','YYYY-MM-DD'))
# into PHANCONG values('NV158', 'DA702', TO_DATE('2021-3-21','YYYY-MM-DD'))
# into PHANCONG values('NV161', 'DA201', TO_DATE('2020-2-24','YYYY-MM-DD'))
# into PHANCONG values('NV161', 'DA202', TO_DATE('2020-5-9','YYYY-MM-DD'))
# into PHANCONG values('NV164', 'DA501', TO_DATE('2021-1-12','YYYY-MM-DD'))
# into PHANCONG values('NV167', 'DA801', TO_DATE('2022-1-10','YYYY-MM-DD'))
# into PHANCONG values('NV170', 'DA301', TO_DATE('2020-2-27','YYYY-MM-DD'))
# into PHANCONG values('NV173', 'DA601', TO_DATE('2020-6-14','YYYY-MM-DD'))
# into PHANCONG values('NV173', 'DA602', TO_DATE('2020-5-2','YYYY-MM-DD'))
# into PHANCONG values('NV176', 'DA101', TO_DATE('2022-6-10','YYYY-MM-DD'))
# into PHANCONG values('NV179', 'DA401', TO_DATE('2021-11-25','YYYY-MM-DD'))
# into PHANCONG values('NV179', 'DA402', TO_DATE('2022-2-22','YYYY-MM-DD'))
# into PHANCONG values('NV182', 'DA701', TO_DATE('2020-6-24','YYYY-MM-DD'))
# into PHANCONG values('NV182', 'DA702', TO_DATE('2021-11-25','YYYY-MM-DD'))
# into PHANCONG values('NV185', 'DA201', TO_DATE('2022-11-3','YYYY-MM-DD'))
# into PHANCONG values('NV188', 'DA501', TO_DATE('2020-5-18','YYYY-MM-DD'))
# into PHANCONG values('NV188', 'DA502', TO_DATE('2022-10-4','YYYY-MM-DD'))
# into PHANCONG values('NV191', 'DA801', TO_DATE('2020-11-9','YYYY-MM-DD'))
# into PHANCONG values('NV194', 'DA301', TO_DATE('2022-6-25','YYYY-MM-DD'))
# into PHANCONG values('NV194', 'DA302', TO_DATE('2020-5-5','YYYY-MM-DD'))
# into PHANCONG values('NV197', 'DA601', TO_DATE('2021-2-2','YYYY-MM-DD'))
# into PHANCONG values('NV200', 'DA101', TO_DATE('2021-4-24','YYYY-MM-DD'))
# into PHANCONG values('NV203', 'DA401', TO_DATE('2021-6-20','YYYY-MM-DD'))
# into PHANCONG values('NV206', 'DA701', TO_DATE('2022-6-2','YYYY-MM-DD'))
# into PHANCONG values('NV209', 'DA201', TO_DATE('2020-6-18','YYYY-MM-DD'))
# into PHANCONG values('NV212', 'DA501', TO_DATE('2022-1-12','YYYY-MM-DD'))
# into PHANCONG values('NV212', 'DA502', TO_DATE('2021-2-4','YYYY-MM-DD'))
# into PHANCONG values('NV215', 'DA801', TO_DATE('2021-6-15','YYYY-MM-DD'))
# into PHANCONG values('NV218', 'DA301', TO_DATE('2020-10-11','YYYY-MM-DD'))
# into PHANCONG values('NV221', 'DA601', TO_DATE('2020-11-14','YYYY-MM-DD'))
# into PHANCONG values('NV221', 'DA602', TO_DATE('2020-1-4','YYYY-MM-DD'))
# into PHANCONG values('NV224', 'DA101', TO_DATE('2020-2-6','YYYY-MM-DD'))
# into PHANCONG values('NV224', 'DA102', TO_DATE('2022-6-26','YYYY-MM-DD'))
# into PHANCONG values('NV227', 'DA401', TO_DATE('2021-12-7','YYYY-MM-DD'))
# into PHANCONG values('NV230', 'DA701', TO_DATE('2020-8-27','YYYY-MM-DD'))
# into PHANCONG values('NV230', 'DA702', TO_DATE('2022-11-4','YYYY-MM-DD'))
# into PHANCONG values('NV233', 'DA201', TO_DATE('2022-5-13','YYYY-MM-DD'))
# into PHANCONG values('NV236', 'DA501', TO_DATE('2022-11-25','YYYY-MM-DD'))
# into PHANCONG values('NV239', 'DA801', TO_DATE('2020-2-5','YYYY-MM-DD'))
# into PHANCONG values('NV239', 'DA802', TO_DATE('2021-1-13','YYYY-MM-DD'))
# into PHANCONG values('NV242', 'DA301', TO_DATE('2020-9-7','YYYY-MM-DD'))
# into PHANCONG values('NV242', 'DA302', TO_DATE('2020-1-19','YYYY-MM-DD'))
# into PHANCONG values('NV245', 'DA601', TO_DATE('2022-4-8','YYYY-MM-DD'))
# into PHANCONG values('NV245', 'DA602', TO_DATE('2022-10-9','YYYY-MM-DD'))
# into PHANCONG values('NV248', 'DA101', TO_DATE('2020-3-9','YYYY-MM-DD'))
# into PHANCONG values('NV251', 'DA401', TO_DATE('2021-5-1','YYYY-MM-DD'))
# into PHANCONG values('NV251', 'DA402', TO_DATE('2021-6-27','YYYY-MM-DD'))
# into PHANCONG values('NV254', 'DA701', TO_DATE('2022-7-12','YYYY-MM-DD'))
# into PHANCONG values('NV254', 'DA702', TO_DATE('2022-7-7','YYYY-MM-DD'))
# into PHANCONG values('NV257', 'DA201', TO_DATE('2022-4-18','YYYY-MM-DD'))
# into PHANCONG values('NV260', 'DA501', TO_DATE('2021-5-13','YYYY-MM-DD'))
# into PHANCONG values('NV260', 'DA502', TO_DATE('2022-9-14','YYYY-MM-DD'))
# into PHANCONG values('NV263', 'DA801', TO_DATE('2020-4-17','YYYY-MM-DD'))
# into PHANCONG values('NV266', 'DA301', TO_DATE('2022-5-22','YYYY-MM-DD'))
# into PHANCONG values('NV269', 'DA601', TO_DATE('2020-1-17','YYYY-MM-DD'))
# into PHANCONG values('NV272', 'DA101', TO_DATE('2020-5-3','YYYY-MM-DD'))
# into PHANCONG values('NV272', 'DA102', TO_DATE('2021-5-12','YYYY-MM-DD'))
# into PHANCONG values('NV275', 'DA401', TO_DATE('2021-1-21','YYYY-MM-DD'))
# into PHANCONG values('NV278', 'DA701', TO_DATE('2020-1-16','YYYY-MM-DD'))
# into PHANCONG values('NV281', 'DA201', TO_DATE('2020-4-24','YYYY-MM-DD'))
# into PHANCONG values('NV284', 'DA501', TO_DATE('2021-4-15','YYYY-MM-DD'))
# into PHANCONG values('NV284', 'DA502', TO_DATE('2021-3-14','YYYY-MM-DD'))
# into PHANCONG values('NV287', 'DA801', TO_DATE('2020-7-2','YYYY-MM-DD'))
# into PHANCONG values('NV287', 'DA802', TO_DATE('2021-8-21','YYYY-MM-DD'))
# into PHANCONG values('NV290', 'DA301', TO_DATE('2021-8-15','YYYY-MM-DD'))
# into PHANCONG values('NV293', 'DA601', TO_DATE('2022-8-19','YYYY-MM-DD'))
# into PHANCONG values('NV293', 'DA602', TO_DATE('2022-4-11','YYYY-MM-DD'))
# into PHANCONG values('NV296', 'DA101', TO_DATE('2020-12-25','YYYY-MM-DD'))
# into PHANCONG values('NV299', 'DA401', TO_DATE('2020-6-24','YYYY-MM-DD'))
# into PHANCONG values('NV299', 'DA402', TO_DATE('2020-10-4','YYYY-MM-DD'))
# into PHANCONG values('NV302', 'DA701', TO_DATE('2020-2-16','YYYY-MM-DD'))
# into PHANCONG values('NV305', 'DA201', TO_DATE('2021-4-6','YYYY-MM-DD'))
# into PHANCONG values('NV308', 'DA501', TO_DATE('2022-4-23','YYYY-MM-DD'))
# into PHANCONG values('NV308', 'DA502', TO_DATE('2021-3-27','YYYY-MM-DD'))
# into PHANCONG values('NV311', 'DA801', TO_DATE('2020-2-5','YYYY-MM-DD'))
# into PHANCONG values('NV314', 'DA301', TO_DATE('2020-8-13','YYYY-MM-DD'))
# into PHANCONG values('NV317', 'DA601', TO_DATE('2022-9-28','YYYY-MM-DD'))
# into PHANCONG values('NV320', 'DA101', TO_DATE('2022-6-11','YYYY-MM-DD'))
# into PHANCONG values('NV320', 'DA102', TO_DATE('2021-9-20','YYYY-MM-DD'))
# into PHANCONG values('NV323', 'DA401', TO_DATE('2022-10-3','YYYY-MM-DD'))
# into PHANCONG values('NV326', 'DA701', TO_DATE('2022-6-25','YYYY-MM-DD'))
# into PHANCONG values('NV329', 'DA201', TO_DATE('2020-8-26','YYYY-MM-DD'))
# into PHANCONG values('NV332', 'DA501', TO_DATE('2021-7-13','YYYY-MM-DD'))
# into PHANCONG values('NV332', 'DA502', TO_DATE('2022-10-15','YYYY-MM-DD'))
# into PHANCONG values('NV335', 'DA801', TO_DATE('2021-8-28','YYYY-MM-DD'))
# into PHANCONG values('NV335', 'DA802', TO_DATE('2021-11-8','YYYY-MM-DD'))
# into PHANCONG values('NV338', 'DA301', TO_DATE('2022-3-10','YYYY-MM-DD'))
# into PHANCONG values('NV341', 'DA601', TO_DATE('2021-10-2','YYYY-MM-DD'))
# into PHANCONG values('NV341', 'DA602', TO_DATE('2020-12-13','YYYY-MM-DD'))
# into PHANCONG values('NV344', 'DA101', TO_DATE('2021-3-25','YYYY-MM-DD'))

# %% [markdown]
# # Tai khoan

# %%
'''
tai khoan:
    username varchar(50),
    password varchar(150)
'''
import random
import string

username = ''
password = ''
for i in range(1, 347):
    if i < 6:
        username = '\'UserGD00'+ str(i) + '\''

    elif i < 11:
        username = '\'UserTC0'+ str(i) + '\''

    elif i < 16:
        username = '\'UserNS0'+ str(i) + '\''

    elif i < 36:
        username = '\'UserQL0'+ str(i) + '\''

    elif i < 39:
        username = '\'UserTDA0'+ str(i) + '\''
    elif i < 47:
        username = '\'UserTP0'+ str(i) + '\''

    else:
        username = '\'UserNV'+ str(i) + '\''
        
    
    # pass random mac dinh 10 char
    password = '123'
    print (f'INTO GOD.TAIKHOAN VALUES({username}, \'{password}\')')
# Out:
# INTO GOD.TAIKHOAN VALUES('UserGD001', '123')
# INTO GOD.TAIKHOAN VALUES('UserGD002', '123')
# INTO GOD.TAIKHOAN VALUES('UserGD003', '123')
# INTO GOD.TAIKHOAN VALUES('UserGD004', '123')
# INTO GOD.TAIKHOAN VALUES('UserGD005', '123')
# INTO GOD.TAIKHOAN VALUES('UserTC06', '123')
# INTO GOD.TAIKHOAN VALUES('UserTC07', '123')
# INTO GOD.TAIKHOAN VALUES('UserTC08', '123')
# INTO GOD.TAIKHOAN VALUES('UserTC09', '123')
# INTO GOD.TAIKHOAN VALUES('UserTC010', '123')
# INTO GOD.TAIKHOAN VALUES('UserNS011', '123')
# INTO GOD.TAIKHOAN VALUES('UserNS012', '123')
# INTO GOD.TAIKHOAN VALUES('UserNS013', '123')
# INTO GOD.TAIKHOAN VALUES('UserNS014', '123')
# INTO GOD.TAIKHOAN VALUES('UserNS015', '123')
# INTO GOD.TAIKHOAN VALUES('UserQL016', '123')
# INTO GOD.TAIKHOAN VALUES('UserQL017', '123')
# INTO GOD.TAIKHOAN VALUES('UserQL018', '123')
# INTO GOD.TAIKHOAN VALUES('UserQL019', '123')
# INTO GOD.TAIKHOAN VALUES('UserQL020', '123')
# INTO GOD.TAIKHOAN VALUES('UserQL021', '123')
# INTO GOD.TAIKHOAN VALUES('UserQL022', '123')
# INTO GOD.TAIKHOAN VALUES('UserQL023', '123')
# INTO GOD.TAIKHOAN VALUES('UserQL024', '123')
# INTO GOD.TAIKHOAN VALUES('UserQL025', '123')
# INTO GOD.TAIKHOAN VALUES('UserQL026', '123')
# INTO GOD.TAIKHOAN VALUES('UserQL027', '123')
# INTO GOD.TAIKHOAN VALUES('UserQL028', '123')
# INTO GOD.TAIKHOAN VALUES('UserQL029', '123')
# INTO GOD.TAIKHOAN VALUES('UserQL030', '123')
# INTO GOD.TAIKHOAN VALUES('UserQL031', '123')
# INTO GOD.TAIKHOAN VALUES('UserQL032', '123')
# INTO GOD.TAIKHOAN VALUES('UserQL033', '123')
# INTO GOD.TAIKHOAN VALUES('UserQL034', '123')
# INTO GOD.TAIKHOAN VALUES('UserQL035', '123')
# INTO GOD.TAIKHOAN VALUES('UserTDA036', '123')
# INTO GOD.TAIKHOAN VALUES('UserTDA037', '123')
# INTO GOD.TAIKHOAN VALUES('UserTDA038', '123')
# INTO GOD.TAIKHOAN VALUES('UserTP039', '123')
# INTO GOD.TAIKHOAN VALUES('UserTP040', '123')
# INTO GOD.TAIKHOAN VALUES('UserTP041', '123')
# INTO GOD.TAIKHOAN VALUES('UserTP042', '123')
# INTO GOD.TAIKHOAN VALUES('UserTP043', '123')
# INTO GOD.TAIKHOAN VALUES('UserTP044', '123')
# INTO GOD.TAIKHOAN VALUES('UserTP045', '123')
# INTO GOD.TAIKHOAN VALUES('UserTP046', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV47', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV48', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV49', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV50', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV51', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV52', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV53', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV54', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV55', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV56', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV57', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV58', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV59', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV60', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV61', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV62', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV63', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV64', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV65', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV66', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV67', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV68', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV69', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV70', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV71', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV72', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV73', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV74', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV75', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV76', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV77', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV78', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV79', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV80', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV81', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV82', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV83', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV84', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV85', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV86', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV87', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV88', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV89', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV90', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV91', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV92', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV93', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV94', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV95', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV96', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV97', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV98', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV99', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV100', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV101', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV102', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV103', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV104', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV105', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV106', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV107', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV108', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV109', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV110', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV111', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV112', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV113', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV114', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV115', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV116', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV117', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV118', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV119', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV120', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV121', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV122', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV123', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV124', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV125', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV126', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV127', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV128', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV129', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV130', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV131', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV132', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV133', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV134', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV135', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV136', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV137', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV138', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV139', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV140', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV141', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV142', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV143', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV144', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV145', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV146', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV147', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV148', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV149', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV150', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV151', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV152', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV153', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV154', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV155', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV156', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV157', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV158', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV159', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV160', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV161', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV162', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV163', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV164', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV165', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV166', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV167', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV168', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV169', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV170', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV171', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV172', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV173', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV174', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV175', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV176', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV177', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV178', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV179', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV180', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV181', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV182', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV183', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV184', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV185', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV186', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV187', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV188', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV189', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV190', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV191', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV192', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV193', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV194', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV195', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV196', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV197', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV198', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV199', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV200', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV201', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV202', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV203', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV204', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV205', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV206', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV207', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV208', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV209', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV210', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV211', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV212', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV213', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV214', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV215', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV216', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV217', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV218', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV219', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV220', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV221', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV222', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV223', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV224', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV225', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV226', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV227', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV228', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV229', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV230', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV231', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV232', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV233', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV234', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV235', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV236', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV237', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV238', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV239', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV240', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV241', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV242', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV243', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV244', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV245', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV246', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV247', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV248', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV249', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV250', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV251', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV252', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV253', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV254', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV255', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV256', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV257', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV258', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV259', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV260', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV261', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV262', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV263', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV264', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV265', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV266', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV267', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV268', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV269', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV270', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV271', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV272', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV273', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV274', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV275', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV276', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV277', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV278', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV279', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV280', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV281', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV282', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV283', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV284', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV285', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV286', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV287', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV288', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV289', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV290', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV291', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV292', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV293', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV294', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV295', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV296', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV297', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV298', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV299', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV300', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV301', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV302', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV303', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV304', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV305', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV306', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV307', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV308', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV309', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV310', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV311', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV312', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV313', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV314', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV315', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV316', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV317', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV318', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV319', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV320', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV321', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV322', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV323', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV324', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV325', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV326', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV327', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV328', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV329', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV330', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV331', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV332', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV333', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV334', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV335', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV336', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV337', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV338', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV339', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV340', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV341', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV342', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV343', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV344', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV345', '123')
# INTO GOD.TAIKHOAN VALUES('UserNV346', '123')
